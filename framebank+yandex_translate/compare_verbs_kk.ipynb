# %%
import pandas as pd
import ast

# %%
pd.set_option("max_info_columns", 5)
pd.set_option("display.max_colwidth", None)

# %%
res_2_models_ba = pd.read_csv('data_SRL/res_2_models_kk1.csv')

# %%
res_2_models_ba.head()
# Out:
#    Unnamed: 0  \
# 0           0
# 1           1
# 2           2
# 3           3
# 4           4
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        srl_kk  \
# 0                                                                                                                                                                                                                   {'verbs': [{'verb': 'дегенге', 'description': {'V': 'дегенге', 'Arg(субъект восприятия)': 'Арабиясы', 'Arg(стимул)': 'қарасақ,', 'Arg(конечная точка)': 'тартылады'}, 'tags': ['O', 'Arg(субъект восприятия)', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'Arg(стимул)', 'O', 'O', 'O', 'O', 'O', 'O', 'Arg(конечная точка)', 'V', 'O', 'O']}], 'words': ['Сауд', 'Арабиясы', 'журналист,', '“Вашингтон', 'пост”', 'шолушысы', 'Жамал', 'Хашоггидің', 'корольдіктің', 'Стамбұлдағы', 'консулдығында', 'өлтірілгенін', 'мойындағанымен,', 'жүріп', 'жатқан', 'тергеу', 'процесіне', 'қарасақ,', 'оның', 'жоғалуына', 'жауапты', 'адамдардың', 'барлығы', 'сотқа', 'тартылады', 'дегенге', 'сену', 'қиын.'], 'metric': 0.8}
# 1  {'verbs': [{'verb': 'Осы', 'description': {'V': 'Осы', 'Arg(агенс)': 'ұйым', 'Arg(способ)': 'арқылы'}, 'tags': ['O', 'Arg(агенс)', 'O', 'O', 'O', 'O', 'O', 'O', 'Arg(способ)', 'O', 'O', 'O', 'O', 'V', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']}, {'verb': 'бері', 'description': {'V': 'бері', 'Arg(пациенс)': 'көптен'}, 'tags': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'Arg(пациенс)', 'V', 'O', 'O', 'O']}], 'words': ['Біздің', 'ұйым', 'жыл', 'сайын', 'шығатын', '“Жаһандық', 'жазасыздық', 'индексі”', 'арқылы', 'осы', 'бастамаға', 'қолдау', 'білдіреді.', 'Осы', 'индекс', 'көрсеткеніндей,', 'Мексика,', 'Бразилия,', 'Үндістан,', 'Пәкістан', 'және', 'Филиппин', 'сияқты', 'демократиялық', 'елдер', 'журналистерді', 'өлтіргендерді', 'көптен', 'бері', 'жазалай', 'алмай', 'келеді.'], 'metric': 0.83}
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                {'verbs': [{'verb': 'енгізді.', 'description': {'V': 'енгізді.', 'Arg(агенс)': 'үкімет'}, 'tags': ['O', 'Arg(агенс)', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'V']}], 'words': ['Федералдық', 'үкімет', 'ой', 'еркіндігіне', 'қарсы', 'қылмыстар', 'бойынша', 'арнайы', 'прокурор', 'лауазымын', 'енгізді.'], 'metric': 1.0}
# 3                                                                                                              {'verbs': [{'verb': 'байланысты.', 'description': {'V': 'байланысты.', 'Arg(пациенс)': 'пайызы'}, 'tags': ['O', 'O', 'O', 'Arg(пациенс)', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'V', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']}, {'verb': 'беріледі.', 'description': {'V': 'беріледі.', 'Arg(пациенс)': 'дәрі'}, 'tags': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'Arg(пациенс)', 'V']}], 'words': ['АИВ-ға', 'шалдыққандардың', '90', 'пайызы', 'тексеруден', 'өткен', 'соң', 'екінші', '90-ды', 'бағындыру', 'қаржының', 'бөлінуі', 'мен', 'тиісті', 'қызметкерлердің', 'болуына', 'байланысты.', 'Денсаулық', 'саласына', 'лайықты', 'қаражат', 'бөлінсе,', 'вирус', 'жұқтырғандардың', 'бәріне', 'дәрі', 'беріледі.'], 'metric': 0.83}
# 4                                                                                                                                                                                                                                                                                                                                                                                                                   {'verbs': [{'verb': 'толық', 'description': {'V': 'толық', 'Arg(причина)': 'аурудан', 'Arg(пациенс)': 'ынталандырып,', 'Arg(эталон)': 'де'}, 'tags': ['O', 'O', 'O', 'O', 'O', 'Arg(причина)', 'V', 'O', 'O', 'Arg(эталон)', 'O', 'O', 'O', 'Arg(пациенс)', 'O', 'O', 'V', 'O', 'O', 'O', 'O']}], 'words': ['Бұл', 'үшін', 'әлеуметтік', 'қызметкерлер', 'науқастарды', 'аурудан', 'толық', 'айығып', 'кетсе', 'де', 'дәріні', 'ішіп', 'жүруге', 'ынталандырып,', 'оларды', 'дәрімен', 'толық', 'қамтамасыз', 'етіп', 'отыруы', 'керек.'], 'metric': 1.0}
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         result_srl_kk  \
# 0  {'verbs': [{'verb': 'мойындағанымен', 'description': {'ARG0': 'Сауд Арабиясы', 'V': 'мойындағанымен', 'ARG1': 'жатқан өлтірілгенін жоғалуына “Вашингтон пост” журналист шолушысы консулдығында Жамал Хашоггидің қарасақ корольдіктің'}, 'tags': ['ARG0', 'ARG0', 'ARG1', 'ARG1', 'ARG1', 'ARG1', 'ARG1', 'ARG1', 'ARG1', 'O', 'ARG1', 'ARG1', 'V', 'O', 'ARG1', 'O', 'O', 'ARG1', 'O', 'ARG1', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']}, {'verb': 'қарасақ', 'description': {'ARG0': '“Вашингтон пост” журналист шолушысы консулдығында Жамал Хашоггидің', 'V': 'қарасақ', 'ARG1': 'қарасақ жатқан жүріп тергеу сотқа'}, 'tags': ['O', 'O', 'ARG0', 'ARG0', 'ARG0', 'ARG0', 'ARG0', 'ARG0', 'O', 'O', 'ARG0', 'O', 'O', 'ARG1', 'ARG1', 'ARG1', 'O', 'V', 'O', 'O', 'O', 'O', 'O', 'ARG1', 'O', 'O', 'O', 'O']}, {'verb': '', 'description': {'ARGM-ADV': 'мойындағанымен қарасақ Сауд Арабиясы жатқан өлтірілгенін жоғалуына “Вашингтон пост” журналист шолушысы консулдығында Жамал Хашоггидің корольдіктің жүріп тергеу сотқа', 'V': '', 'ARG2': 'қиын', 'ARG1': 'сотқа мойындағанымен дегенге барлығы адамдардың жауапты оның өлтірілгенін жоғалуына тартылады'}, 'tags': ['ARGM-ADV', 'ARGM-ADV', 'ARGM-ADV', 'ARGM-ADV', 'ARGM-ADV', 'ARGM-ADV', 'ARGM-ADV', 'ARGM-ADV', 'ARGM-ADV', 'O', 'ARGM-ADV', 'ARGM-ADV', 'ARGM-ADV', 'ARGM-ADV', 'ARGM-ADV', 'ARGM-ADV', 'O', 'ARGM-ADV', 'ARG1', 'ARGM-ADV', 'ARG1', 'ARG1', 'ARG1', 'ARGM-ADV', 'ARG1', 'ARG1', 'O', 'ARG2']}, {'verb': 'мойындағанымен', 'description': {'V': 'мойындағанымен', 'ARG1': 'дегенге барлығы адамдардың жауапты оның өлтірілгенін жоғалуына тартылады сотқа'}, 'tags': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'ARG1', 'V', 'O', 'O', 'O', 'O', 'O', 'ARG1', 'ARG1', 'ARG1', 'ARG1', 'ARG1', 'ARG1', 'ARG1', 'ARG1', 'O', 'O']}, {'verb': 'тартылады', 'description': {'ARG1': 'барлығы адамдардың жауапты оның өлтірілгенін жоғалуына', 'ARGM-MOD': '', 'V': 'тартылады', 'ARG2': 'сотқа'}, 'tags': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'ARG1', 'O', 'O', 'O', 'O', 'O', 'O', 'ARG1', 'ARG1', 'ARG1', 'ARG1', 'ARG1', 'ARG2', 'V', 'O', 'O', 'O']}], 'words': ['Сауд', 'Арабиясы', 'журналист,', '“Вашингтон', 'пост”', 'шолушысы', 'Жамал', 'Хашоггидің', 'корольдіктің', 'Стамбұлдағы', 'консулдығында', 'өлтірілгенін', 'мойындағанымен,', 'жүріп', 'жатқан', 'тергеу', 'процесіне', 'қарасақ,', 'оның', 'жоғалуына', 'жауапты', 'адамдардың', 'барлығы', 'сотқа', 'тартылады', 'дегенге', 'сену', 'қиын.']}
# 1                                                                                                                                                                                                   {'verbs': [{'verb': 'қолдау білдіреді', 'description': {'ARG0': 'Біздің ұйым', 'V': 'қолдау білдіреді', 'ARG1': 'осы Осы ұйым бастамаға', 'ARGM-MNR': 'арқылы Үндістан елдер жыл сайын “Жаһандық жазасыздық өлтіргендерді'}, 'tags': ['ARG0', 'ARG0', 'ARGM-MNR', 'ARGM-MNR', 'O', 'ARGM-MNR', 'ARGM-MNR', 'O', 'ARGM-MNR', 'ARG1', 'ARG1', 'V', 'V', 'ARG1', 'O', 'O', 'O', 'O', 'ARGM-MNR', 'O', 'O', 'O', 'O', 'O', 'ARGM-MNR', 'O', 'ARGM-MNR', 'O', 'O', 'O', 'O', 'O']}, {'verb': '', 'description': {'ARG0': 'осы Осы индексі”', 'V': ''}, 'tags': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'ARG0', 'O', 'ARG0', 'O', 'O', 'O', 'ARG0', 'ARG0', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']}, {'verb': 'келеді', 'description': {'ARGM-ADV': 'көрсеткеніндей осы Осы индексі”', 'ARG1': 'демократиялық елдер сияқты Пәкістан Үндістан және Филиппин', 'ARGM-TMP': 'жыл көптен', 'V': 'келеді', 'ARG2': 'алмай өлтіргендерді жазалай'}, 'tags': ['O', 'O', 'ARGM-TMP', 'O', 'O', 'O', 'O', 'ARGM-ADV', 'O', 'ARGM-ADV', 'O', 'O', 'O', 'ARGM-ADV', 'ARGM-ADV', 'ARGM-ADV', 'O', 'O', 'ARG1', 'ARG1', 'ARG1', 'ARG1', 'ARG1', 'ARG1', 'ARG1', 'O', 'ARG2', 'ARGM-TMP', 'O', 'ARG2', 'ARG2', 'V']}, {'verb': 'өлтіргендерді жазалай', 'description': {'ARG0': 'демократиялық елдер сияқты Пәкістан Үндістан және Филиппин', 'V': 'өлтіргендерді жазалай', 'ARG1': 'өлтіргендерді'}, 'tags': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'ARG0', 'ARG0', 'ARG0', 'ARG0', 'ARG0', 'ARG0', 'ARG0', 'O', 'V', 'O', 'O', 'V', 'O', 'O']}, {'verb': 'өлтіргендерді', 'description': {'ARG0': 'өлтіргендерді', 'R-ARG0': 'өлтіргендерді', 'V': 'өлтіргендерді', 'ARG1': ''}, 'tags': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'ARG0', 'O', 'O', 'O', 'O', 'O']}], 'words': ['Біздің', 'ұйым', 'жыл', 'сайын', 'шығатын', '“Жаһандық', 'жазасыздық', 'индексі”', 'арқылы', 'осы', 'бастамаға', 'қолдау', 'білдіреді.', 'Осы', 'индекс', 'көрсеткеніндей,', 'Мексика,', 'Бразилия,', 'Үндістан,', 'Пәкістан', 'және', 'Филиппин', 'сияқты', 'демократиялық', 'елдер', 'журналистерді', 'өлтіргендерді', 'көптен', 'бері', 'жазалай', 'алмай', 'келеді.']}
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      {'verbs': [{'verb': 'енгізді', 'description': {'ARG0': 'Федералдық үкімет', 'V': 'енгізді', 'ARG1': 'лауазымын арнайы прокурор бойынша қылмыстар қарсы еркіндігіне'}, 'tags': ['ARG0', 'ARG0', 'ARG1', 'ARG1', 'ARG1', 'ARG1', 'ARG1', 'ARG1', 'ARG1', 'ARG1', 'V']}], 'words': ['Федералдық', 'үкімет', 'ой', 'еркіндігіне', 'қарсы', 'қылмыстар', 'бойынша', 'арнайы', 'прокурор', 'лауазымын', 'енгізді.']}
# 3                                                                                                                                                                                                                                   {'verbs': [{'verb': '', 'description': {'ARG1': 'пайызы АИВға шалдыққандардың қызметкерлердің жұқтырғандардың', 'V': ''}, 'tags': ['ARG1', 'ARG1', 'O', 'ARG1', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'ARG1', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'ARG1', 'O', 'O', 'O']}, {'verb': 'байланысты', 'description': {'ARGM-TMP': 'соң пайызы АИВға шалдыққандардың қызметкерлердің жұқтырғандардың', 'ARG0': 'шалдыққандардың тексеруден бағындыру жұқтырғандардың екінші', 'V': 'байланысты', 'ARG1': 'болуына байланысты allocated бөлінуі бөлінсе қаржының қаражат мен тиісті беріледі лайықты'}, 'tags': ['ARGM-TMP', 'ARGM-TMP', 'O', 'ARGM-TMP', 'ARG0', 'O', 'ARGM-TMP', 'ARG0', 'O', 'ARG0', 'ARG1', 'ARG1', 'ARG1', 'ARG1', 'ARGM-TMP', 'ARG1', 'V', 'O', 'O', 'ARG1', 'ARG1', 'ARG1', 'O', 'ARGM-TMP', 'O', 'O', 'ARG1']}, {'verb': 'allocation бөлінсе беріледі', 'description': {'ARG1': 'appropriate тиісті лайықты қаржының қаражат', 'V': 'allocation бөлінсе беріледі', 'ARG2': 'Денсаулық'}, 'tags': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'ARG1', 'O', 'O', 'ARG1', 'O', 'O', 'O', 'ARG2', 'O', 'ARG1', 'ARG1', 'V', 'O', 'O', 'O', 'O', 'V']}, {'verb': 'шалдыққандардың вирус жұқтырғандардың', 'description': {'ARG1': 'бәріне', 'V': 'шалдыққандардың вирус жұқтырғандардың', 'ARG2': 'вирус'}, 'tags': ['O', 'V', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'V', 'V', 'ARG1', 'O', 'O']}, {'verb': 'беріледі', 'description': {'ARGM-ADV': 'appropriate тиісті лайықты қаржының қаражат allocation бөлінсе беріледі Денсаулық', 'ARG2': 'бәріне шалдыққандардың вирус жұқтырғандардың', 'ARGM-MOD': '', 'V': 'беріледі', 'ARG1': ''}, 'tags': ['O', 'ARG2', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'ARGM-ADV', 'O', 'O', 'ARGM-ADV', 'O', 'O', 'O', 'ARGM-ADV', 'O', 'ARGM-ADV', 'ARGM-ADV', 'ARGM-ADV', 'ARG2', 'ARG2', 'ARG2', 'O', 'ARGM-ADV']}], 'words': ['АИВ-ға', 'шалдыққандардың', '90', 'пайызы', 'тексеруден', 'өткен', 'соң', 'екінші', '90-ды', 'бағындыру', 'қаржының', 'бөлінуі', 'мен', 'тиісті', 'қызметкерлердің', 'болуына', 'байланысты.', 'Денсаулық', 'саласына', 'лайықты', 'қаражат', 'бөлінсе,', 'вирус', 'жұқтырғандардың', 'бәріне', 'дәрі', 'беріледі.']}
# 4                                                                                                                                                                                    {'verbs': [{'verb': '', 'description': {'V': '', 'ARG1': '', 'ARG0': 'әлеуметтік қызметкерлер'}, 'tags': ['O', 'O', 'ARG0', 'ARG0', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']}, {'verb': 'ынталандырып', 'description': {'R-ARG0': '', 'ARG0': 'әлеуметтік қызметкерлер', 'ARGM-MOD': 'керек', 'V': 'ынталандырып', 'ARG1': 'қызметкерлер науқастарды', 'ARG2': 'ынталандырып жүруге ішіп кетсе де оларды толық айығып қамтамасыз аурудан дәрімен medications дәріні'}, 'tags': ['O', 'O', 'ARG0', 'ARG0', 'ARG1', 'ARG2', 'ARG2', 'ARG2', 'ARG2', 'ARG2', 'ARG2', 'ARG2', 'ARG2', 'V', 'ARG2', 'ARG2', 'ARG2', 'ARG2', 'O', 'O', 'ARGM-MOD']}, {'verb': 'жүруге ынталандырып', 'description': {'ARG0': 'қызметкерлер науқастарды', 'V': 'жүруге ынталандырып', 'ARG1': 'ішіп', 'ARGM-ADV': 'кетсе де оларды толық айығып ішіп жүруге қамтамасыз аурудан'}, 'tags': ['O', 'O', 'O', 'ARG0', 'ARG0', 'ARGM-ADV', 'ARGM-ADV', 'ARGM-ADV', 'ARGM-ADV', 'ARGM-ADV', 'O', 'ARG1', 'V', 'V', 'ARGM-ADV', 'O', 'ARGM-ADV', 'ARGM-ADV', 'O', 'O', 'O']}, {'verb': 'ішіп', 'description': {'ARG0': 'қызметкерлер науқастарды', 'V': 'ішіп', 'ARG1': '', 'ARGM-ADV': 'кетсе де оларды толық айығып ішіп жүруге қамтамасыз аурудан'}, 'tags': ['O', 'O', 'O', 'ARG0', 'ARG0', 'ARGM-ADV', 'ARGM-ADV', 'ARGM-ADV', 'ARGM-ADV', 'ARGM-ADV', 'O', 'V', 'ARGM-ADV', 'O', 'ARGM-ADV', 'O', 'ARGM-ADV', 'ARGM-ADV', 'O', 'O', 'O']}, {'verb': 'айығып ішіп жүруге қамтамасыз', 'description': {'ARG1': 'оларды', 'ARGM-EXT': 'толық', 'V': 'айығып ішіп жүруге қамтамасыз', 'ARG2': 'аурудан'}, 'tags': ['O', 'O', 'O', 'O', 'O', 'ARG2', 'ARGM-EXT', 'V', 'O', 'O', 'O', 'V', 'V', 'O', 'ARG1', 'O', 'ARGM-EXT', 'V', 'O', 'O', 'O']}, {'verb': 'қамтамасыз', 'description': {'ARG0': 'әлеуметтік қызметкерлер', 'ARGM-MOD': 'керек', 'V': 'қамтамасыз', 'ARG2': 'оларды', 'ARG1': 'дәрімен medications дәріні', 'ARGM-MNR': ''}, 'tags': ['O', 'O', 'ARG0', 'ARG0', 'O', 'O', 'O', 'O', 'O', 'O', 'ARG1', 'O', 'O', 'O', 'ARG2', 'ARG1', 'O', 'V', 'O', 'O', 'ARGM-MOD']}], 'words': ['Бұл', 'үшін', 'әлеуметтік', 'қызметкерлер', 'науқастарды', 'аурудан', 'толық', 'айығып', 'кетсе', 'де', 'дәріні', 'ішіп', 'жүруге', 'ынталандырып,', 'оларды', 'дәрімен', 'толық', 'қамтамасыз', 'етіп', 'отыруы', 'керек.']}
#
#    preds_kk  \
# 0         0
# 1         0
# 2         1
# 3         1
# 4         0
#
#                                                                                                                                                                                                                                                                      sentence  \
# 0                 Сауд Арабиясы журналист, “Вашингтон пост” шолушысы Жамал Хашоггидің корольдіктің Стамбұлдағы консулдығында өлтірілгенін мойындағанымен, жүріп жатқан тергеу процесіне қарасақ, оның жоғалуына жауапты адамдардың барлығы сотқа тартылады дегенге сену қиын.
# 1  Біздің ұйым жыл сайын шығатын “Жаһандық жазасыздық индексі” арқылы осы бастамаға қолдау білдіреді. Осы индекс көрсеткеніндей, Мексика, Бразилия, Үндістан, Пәкістан және Филиппин сияқты демократиялық елдер журналистерді өлтіргендерді көптен бері жазалай алмай келеді.
# 2                                                                                                                                                                                 Федералдық үкімет ой еркіндігіне қарсы қылмыстар бойынша арнайы прокурор лауазымын енгізді.
# 3                                        АИВ-ға шалдыққандардың 90 пайызы тексеруден өткен соң екінші 90-ды бағындыру қаржының бөлінуі мен тиісті қызметкерлердің болуына байланысты. Денсаулық саласына лайықты қаражат бөлінсе, вирус жұқтырғандардың бәріне дәрі беріледі.
# 4                                                                                                              Бұл үшін әлеуметтік қызметкерлер науқастарды аурудан толық айығып кетсе де дәріні ішіп жүруге ынталандырып, оларды дәрімен толық қамтамасыз етіп отыруы керек.
#
#    sent_len
# 0        28
# 1        32
# 2        11
# 3        27
# 4        21

# %%
print(ast.literal_eval(res_2_models_ba.loc[0, 'srl_kk'])['verbs'][0]['verb'])
print(ast.literal_eval(res_2_models_ba.loc[0, 'result_srl_kk'])['verbs'][0]['verb'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/envs/srl/lib/python3.9/site-packages/pandas/core/indexes/base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File ~/anaconda3/envs/srl/lib/python3.9/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/anaconda3/envs/srl/lib/python3.9/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'srl_ba'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In [5], line 1
# ----> 1 print(ast.literal_eval(res_2_models_ba.loc[0, 'srl_ba'])['verbs'][0]['verb'])
#       2 print(ast.literal_eval(res_2_models_ba.loc[0, 'result_srl_kk'])['verbs'][0]['verb'])
#
# File ~/anaconda3/envs/srl/lib/python3.9/site-packages/pandas/core/indexing.py:1066, in _LocationIndexer.__getitem__(self, key)
#    1064     key = tuple(com.apply_if_callable(x, self.obj) for x in key)
#    1065     if self._is_scalar_access(key):
# -> 1066         return self.obj._get_value(*key, takeable=self._takeable)
#    1067     return self._getitem_tuple(key)
#    1068 else:
#    1069     # we by definition only have the 0th axis
#
# File ~/anaconda3/envs/srl/lib/python3.9/site-packages/pandas/core/frame.py:3915, in DataFrame._get_value(self, index, col, takeable)
#    3912     series = self._ixs(col, axis=1)
#    3913     return series._values[index]
# -> 3915 series = self._get_item_cache(col)
#    3916 engine = self.index._engine
#    3918 if not isinstance(self.index, MultiIndex):
#    3919     # CategoricalIndex: Trying to use the engine fastpath may give incorrect
#    3920     #  results if our categories are integers that dont match our codes
#    3921     # IntervalIndex: IntervalTree has no get_loc
#
# File ~/anaconda3/envs/srl/lib/python3.9/site-packages/pandas/core/frame.py:4279, in DataFrame._get_item_cache(self, item)
#    4274 res = cache.get(item)
#    4275 if res is None:
#    4276     # All places that call _get_item_cache have unique columns,
#    4277     #  pending resolution of GH#33047
# -> 4279     loc = self.columns.get_loc(item)
#    4280     res = self._ixs(loc, axis=1)
#    4282     cache[item] = res
#
# File ~/anaconda3/envs/srl/lib/python3.9/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key, method, tolerance)
#    3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
# -> 3805     raise KeyError(key) from err
#    3806 except TypeError:
#    3807     # If we have a listlike key, _check_indexing_error will raise
#    3808     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3809     #  the TypeError.
#    3810     self._check_indexing_error(key)
#
# KeyError: 'srl_ba'

# %%
for i in range(len(res_2_models_ba)):
    try:
        verb1 = ast.literal_eval(res_2_models_ba.loc[i, 'srl_ba'])['verbs'][0]['verb']
        verb2 = set()
        for j in range(len(ast.literal_eval(res_2_models_ba.loc[i, 'result_srl_kk'])['verbs'])):
            verb2.add(ast.literal_eval(res_2_models_ba.loc[i, 'result_srl_kk'])['verbs'][j]['verb'])
        if (verb1 in verb2) & (verb1 != ""):
            res_2_models_ba.loc[i, 'preds_kk_new'] = 1
        else:
            res_2_models_ba.loc[i, 'preds_kk_new'] = 0
    except:
        pass
    print(i, 'v1: ', verb1, 'v2: ', verb2, res_2_models_ba.loc[i, 'preds_kk_new'])

# %%
(res_2_models_ba['preds_kk_new'] == 1).sum()

# %%
(res_2_models_ba['preds_kk'] == 1).sum()

# %%
arguments1 = ast.literal_eval(res_2_models_ba.loc[0, 'srl_ba'])['verbs'][0]['description']
args1 = set()
for key, value in arguments1.items():
    if key != 'V':
        args1.add(value)
print(args1)

# %%
arguments2 = ast.literal_eval(res_2_models_ba.loc[0, 'result_srl_kk'])['verbs'][0]['description']
args2 = set()
for key, value in arguments2.items():
    if key != 'V':
        args2.add(value)
print(args2)

# %%
if len(args1.intersection(args2)) != 0:
    print('ok')

# %%
for i in range(len(res_2_models_ba)):
    try:
        verb1 = ast.literal_eval(res_2_models_ba.loc[i, 'srl_ba'])['verbs'][0]['verb']
        verb2 = set()
        for j in range(len(ast.literal_eval(res_2_models_ba.loc[i, 'result_srl_kk'])['verbs'])):
            verb2.add(ast.literal_eval(res_2_models_ba.loc[i, 'result_srl_kk'])['verbs'][j]['verb'])
        if (verb1 in verb2) & (verb1 != ""):
            res_2_models_ba.loc[i, 'preds_kk_new'] = 1
        else:
            res_2_models_ba.loc[i, 'preds_kk_new'] = 0
        
        arguments1 = ast.literal_eval(res_2_models_ba.loc[i, 'srl_ba'])['verbs'][0]['description']
        args1 = set()
        for key, value in arguments1.items():
            if key != 'V':
                args1.add(value)
        
        args2 = set()
        
        for j in range(len(ast.literal_eval(res_2_models_ba.loc[i, 'result_srl_kk'])['verbs'])):
            arguments2 = ast.literal_eval(res_2_models_ba.loc[i, 'result_srl_kk'])['verbs'][j]['description']
            for key, value in arguments2.items():
                if key != 'V':
                    args2.add(value)
        if len(args1.intersection(args2)) != 0:
            res_2_models_ba.loc[i, 'preds_kk_args'] = 1
        else:
            res_2_models_ba.loc[i, 'preds_kk_args'] = 0
    except:
        pass
    print(i, 'v1: ', verb1, 'v2: ', verb2, res_2_models_ba.loc[i, 'preds_kk_new'], 'args1: ', args1,
          'args2: ', args2, res_2_models_ba.loc[i, 'preds_kk_args'])

# %%
res_2_models_ba

# %%
(res_2_models_ba['preds_kk_args'] == 1).sum()
