# %%
import pandas as pd
import ast

# %%
pd.set_option("max_info_columns", 5)
pd.set_option("display.max_colwidth", None)

# %%
res_2_models_ba = pd.read_csv('data_SRL/res_2_models_ba.csv')

# %%
res_2_models_ba.shape
# Out:
# (576, 6)

# %%
res_2_models_ba.head()
# Out:
#    Unnamed: 0  \
# 0           0
# 1           1
# 2           2
# 3           3
# 4           4
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           srl_ba  \
# 0                                                                                                                                                                                                  {'verbs': [{'verb': 'күрә', 'description': {'V': 'күрә', 'Arg(субъект ментального состояния)': 'кемдәр', 'Arg(эталон)': 'кемдәр', 'Arg(стимул)': 'донъяны'}, 'tags': ['O', 'V', 'O', 'Arg(субъект ментального состояния)', 'O', 'O', 'O', 'O', 'O', 'Arg(стимул)', 'O', 'O', 'V', 'O', 'O', 'O', 'O', 'O', 'O']}], 'words': ['Шуға', 'күрә', 'мин', 'кемдәр', 'иҫ', 'киткес', 'ғәҙәти', 'күренеш,', 'улар', 'донъяны', 'бик', 'яҡшы', 'күрә', 'һәм', 'етешһеҙлектәрҙе', 'һанға', 'һуҡмай', 'тип', 'уйланым.'], 'metric': 1.0}
# 1  {'verbs': [{'verb': 'торғанда', 'description': {'V': 'торғанда', 'Arg(эталон)': 'торошта.', 'Arg(цель)': 'өлөшө', 'Arg(тема)': 'проценты', 'Arg(пациенс)': 'өлөшө', 'Arg(предмет мысли)': 'мәғлүмәттәренә'}, 'tags': ['O', 'O', 'O', 'O', 'O', 'O', 'Arg(тема)', 'O', 'O', 'O', 'O', 'V', 'O', 'O', 'Arg(цель)', 'O', 'O', 'O', 'Arg(цель)', 'O', 'O', 'Arg(предмет мысли)', 'O', 'O', 'O', 'Arg(эталон)']}], 'words': ['Әммә', 'килеме', 'түбән', 'булған', 'кешеләрҙең', '90', 'проценты', 'сирек', 'быуат', 'дауамында', 'торғонлоҡта', 'торғанда', '(һәм', 'байтаҡ', 'өлөшө', 'кәмей),', 'илдең', 'күпселек', 'өлөшө,', 'һаулыҡ', 'һаҡлау', 'мәғлүмәттәренә', 'мөрәжәғәт', 'итһәң,', 'насар', 'торошта.'], 'metric': 1.0}
# 2                                                                                                                                                                                                                                                                                                                           {'verbs': [{'verb': 'билдәһеҙ', 'description': {'V': 'билдәһеҙ', 'Arg(тема)': '-'}, 'tags': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'V', 'O', 'O', 'O', 'V', 'O']}], 'words': ['Ниндәй', 'сәйәсмәндәр', 'үткәрергә', 'Трамп,', 'ниндәй', 'улар', 'уңышлы', 'булыр', 'йәки', 'ниндәй', 'эҙемтәләре', 'булыр', '-', 'былар', 'барыһы', 'ла', 'билдәһеҙ', 'ҡала.'], 'metric': 1.0}
# 3                                                                                                                                                                                                                                                                                                                                                                                                      {'verbs': [{'verb': 'ҡайта', 'description': {'V': 'ҡайта', 'Arg(конечная точка)': 'балансҡа'}, 'tags': ['O', 'O', 'O', 'O', 'O', 'O', 'Arg(конечная точка)', 'O', 'V', 'Arg(конечная точка)']}], 'words': ['Ә', 'Был', 'Ваҡытҡа', 'Американың', 'сауҙа', 'иҫәбе', 'балансҡа', 'әйләнеп', 'ҡайта', 'ала.'], 'metric': 1.0}
# 4                                                                                                                                                                                                                                                                                 {'verbs': [{'verb': 'килтерәсәк,', 'description': {'V': 'килтерәсәк,', 'Arg(результат)': 'ҡотолғоһоҙ'}, 'tags': ['O', 'O', 'O', 'O', 'O', 'V', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'Arg(результат)', 'O', 'V']}], 'words': ['Был', 'милли', 'һаҡсыллыҡты', 'артабан', 'ҡыҫҡартыуға', 'килтерәсәк,', 'был', 'иһә', 'норманан', 'күпкә', 'юғары', 'булған', 'сауҙа', 'дефицитының', 'ҡотолғоһоҙ', 'артыуына', 'килтерәсәк.'], 'metric': 1.0}
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              result_srl_kk  \
# 0                                                                                                                                                                                       {'verbs': [{'verb': '', 'description': {'ARGM-DIS': 'Шуға', 'ARG0': 'мин уйланым', 'V': '', 'ARG1': 'кемдәр улар яҡшы етешһеҙлектәрҙе күрә күренеш донъяны бик һәм'}, 'tags': ['ARGM-DIS', 'ARG1', 'ARG0', 'ARG1', 'O', 'O', 'O', 'ARG1', 'ARG1', 'ARG1', 'ARG1', 'ARG1', 'ARG1', 'ARG1', 'ARG1', 'O', 'O', 'O', 'ARG0']}, {'verb': '', 'description': {'R-ARG1': 'кемдәр', 'V': '', 'ARG2': 'улар яҡшы етешһеҙлектәрҙе кемдәр күрә күренеш донъяны бик һәм'}, 'tags': ['O', 'ARG2', 'O', 'R-ARG1', 'O', 'O', 'O', 'ARG2', 'ARG2', 'ARG2', 'ARG2', 'ARG2', 'ARG2', 'ARG2', 'ARG2', 'O', 'O', 'O', 'O']}, {'verb': 'күрә күренеш', 'description': {'ARG0': 'улар яҡшы етешһеҙлектәрҙе кемдәр', 'R-ARG0': 'кемдәр', 'V': 'күрә күренеш', 'ARG1': 'донъяны', 'ARGM-MNR': 'бик яҡшы'}, 'tags': ['O', 'V', 'O', 'ARG0', 'O', 'O', 'O', 'V', 'ARG0', 'ARG1', 'ARGM-MNR', 'ARG0', 'V', 'O', 'ARG0', 'O', 'O', 'O', 'O']}, {'verb': '', 'description': {'ARG0': 'улар яҡшы етешһеҙлектәрҙе кемдәр', 'R-ARG0': 'кемдәр', 'V': '', 'ARG1': 'донъяны'}, 'tags': ['O', 'O', 'O', 'ARG0', 'O', 'O', 'O', 'O', 'ARG0', 'ARG1', 'O', 'ARG0', 'O', 'O', 'ARG0', 'O', 'O', 'O', 'O']}], 'words': ['Шуға', 'күрә', 'мин', 'кемдәр', 'иҫ', 'киткес', 'ғәҙәти', 'күренеш,', 'улар', 'донъяны', 'бик', 'яҡшы', 'күрә', 'һәм', 'етешһеҙлектәрҙе', 'һанға', 'һуҡмай', 'тип', 'уйланым.']}
# 1  {'verbs': [{'verb': '', 'description': {'ARG1': 'проценты кешеләрҙең', 'V': '', 'ARGM-TMP': 'кешеләрҙең илдең'}, 'tags': ['O', 'O', 'O', 'O', 'ARG1', 'O', 'ARG1', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'ARGM-TMP', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']}, {'verb': '', 'description': {'ARG1': 'күпселек түбән проценты', 'V': ''}, 'tags': ['O', 'O', 'ARG1', 'O', 'O', 'O', 'ARG1', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'ARG1', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']}, {'verb': '', 'description': {'ARG1': 'күпселек түбән проценты', 'V': ''}, 'tags': ['O', 'O', 'ARG1', 'O', 'O', 'O', 'ARG1', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'ARG1', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']}, {'verb': '', 'description': {'ARG0': 'итһәң', 'V': '', 'ARG1': ''}, 'tags': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'ARG0', 'O', 'O']}, {'verb': '', 'description': {'ARGM-DIS': 'Әммә', 'ARGM-ADV': 'итһәң', 'ARG1': 'күпселек', 'V': '', 'ARG2': 'булған'}, 'tags': ['ARGM-DIS', 'O', 'O', 'ARG2', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'ARG1', 'O', 'O', 'O', 'O', 'O', 'ARGM-ADV', 'O', 'O']}], 'words': ['Әммә', 'килеме', 'түбән', 'булған', 'кешеләрҙең', '90', 'проценты', 'сирек', 'быуат', 'дауамында', 'торғонлоҡта', 'торғанда', '(һәм', 'байтаҡ', 'өлөшө', 'кәмей),', 'илдең', 'күпселек', 'өлөшө,', 'һаулыҡ', 'һаҡлау', 'мәғлүмәттәренә', 'мөрәжәғәт', 'итһәң,', 'насар', 'торошта.']}
# 2                                                                                                                                                                                                                                                                                                                                                                                                  {'verbs': [{'verb': '', 'description': {'ARG1': 'Ниндәй ниндәй эҙемтәләре', 'ARG0': 'Трамп', 'ARGM-MOD': 'булыр', 'V': ''}, 'tags': ['ARG1', 'O', 'O', 'ARG0', 'ARG1', 'O', 'O', 'ARGM-MOD', 'O', 'ARG1', 'ARG1', 'ARGM-MOD', 'ARG1', 'O', 'O', 'O', 'O', 'O']}, {'verb': 'булыр', 'description': {'ARG1': 'улар', 'ARGM-MOD': 'булыр', 'V': 'булыр', 'ARG2': 'уңышлы'}, 'tags': ['O', 'O', 'O', 'O', 'O', 'ARG1', 'ARG2', 'ARGM-MOD', 'O', 'O', 'O', 'ARGM-MOD', 'ARG1', 'O', 'O', 'ARG1', 'O', 'O']}, {'verb': 'булыр', 'description': {'ARG2': 'Ниндәй ниндәй', 'ARG1': 'эҙемтәләре', 'ARGM-MOD': 'булыр', 'V': 'булыр'}, 'tags': ['ARG2', 'O', 'O', 'O', 'ARG2', 'O', 'O', 'ARGM-MOD', 'O', 'ARG2', 'ARG1', 'ARGM-MOD', 'ARG2', 'O', 'O', 'O', 'O', 'O']}, {'verb': '', 'description': {'ARG3': '', 'ARG1': 'былар барыһы', 'V': ''}, 'tags': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'ARG3', 'ARG1', 'ARG1', 'ARG1', 'O', 'O']}], 'words': ['Ниндәй', 'сәйәсмәндәр', 'үткәрергә', 'Трамп,', 'ниндәй', 'улар', 'уңышлы', 'булыр', 'йәки', 'ниндәй', 'эҙемтәләре', 'булыр', '-', 'былар', 'барыһы', 'ла', 'билдәһеҙ', 'ҡала.']}
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             {'verbs': [{'verb': 'ала', 'description': {'ARGM-TMP': 'Был', 'ARG1': 'балансҡа', 'V': 'ала', 'ARG2': 'ала'}, 'tags': ['O', 'ARGM-TMP', 'O', 'O', 'O', 'O', 'ARG1', 'O', 'O', 'ARG1']}, {'verb': '', 'description': {'ARG1': 'балансҡа', 'V': '', 'ARG4': ''}, 'tags': ['O', 'O', 'O', 'O', 'O', 'O', 'ARG1', 'O', 'O', 'ARG1']}], 'words': ['Ә', 'Был', 'Ваҡытҡа', 'Американың', 'сауҙа', 'иҫәбе', 'балансҡа', 'әйләнеп', 'ҡайта', 'ала.']}
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             {'verbs': [{'verb': '', 'description': {'ARG0': 'Был был', 'ARGM-MOD': '', 'V': '', 'ARG2': 'артабан күпкә артыуына килтерәсәк дефицитының юғары норманан'}, 'tags': ['ARG0', 'O', 'O', 'ARG2', 'O', 'ARG2', 'ARG0', 'O', 'ARG2', 'ARG2', 'ARG2', 'O', 'O', 'ARG2', 'O', 'ARG2', 'ARG2']}, {'verb': 'артабан артыуына', 'description': {'ARG0': 'артабан күпкә артыуына', 'R-ARG0': 'килтерәсәк', 'ARGM-MOD': '', 'ARGM-ADV': 'артабан килтерәсәк', 'V': 'артабан артыуына', 'ARG1': 'дефицитының', 'ARG2': 'күпкә юғары артабан артыуына норманан'}, 'tags': ['O', 'O', 'O', 'ARG0', 'O', 'R-ARG0', 'O', 'O', 'ARG2', 'ARG0', 'ARG2', 'O', 'O', 'ARG1', 'O', 'ARG0', 'R-ARG0']}], 'words': ['Был', 'милли', 'һаҡсыллыҡты', 'артабан', 'ҡыҫҡартыуға', 'килтерәсәк,', 'был', 'иһә', 'норманан', 'күпкә', 'юғары', 'булған', 'сауҙа', 'дефицитының', 'ҡотолғоһоҙ', 'артыуына', 'килтерәсәк.']}
#
#    preds_kk  \
# 0       0.0
# 1       0.0
# 2       1.0
# 3       1.0
# 4       0.0
#
#                                                                                                                                                                                                   sentence  \
# 0                                                                                  Шуға күрә мин кемдәр иҫ киткес ғәҙәти күренеш, улар донъяны бик яҡшы күрә һәм етешһеҙлектәрҙе һанға һуҡмай тип уйланым.
# 1  Әммә килеме түбән булған кешеләрҙең 90 проценты сирек быуат дауамында торғонлоҡта торғанда (һәм байтаҡ өлөшө кәмей), илдең күпселек өлөшө, һаулыҡ һаҡлау мәғлүмәттәренә мөрәжәғәт итһәң, насар торошта.
# 2                                                                               Ниндәй сәйәсмәндәр үткәрергә Трамп, ниндәй улар уңышлы булыр йәки ниндәй эҙемтәләре булыр - былар барыһы ла билдәһеҙ ҡала.
# 3                                                                                                                                         Ә Был Ваҡытҡа Американың сауҙа иҫәбе балансҡа әйләнеп ҡайта ала.
# 4                                                              Был милли һаҡсыллыҡты артабан ҡыҫҡартыуға килтерәсәк, был иһә норманан күпкә юғары булған сауҙа дефицитының ҡотолғоһоҙ артыуына килтерәсәк.
#
#    sent_len
# 0        19
# 1        26
# 2        18
# 3        10
# 4        17

# %%
print(ast.literal_eval(res_2_models_ba.loc[0, 'srl_ba'])['verbs'][0]['verb'])
print(ast.literal_eval(res_2_models_ba.loc[0, 'result_srl_kk'])['verbs'][0]['verb'])
# Out:
# күрә

# %%
for i in range(len(res_2_models_ba)):
    try:
        verb1 = set()
        for j in range(len(ast.literal_eval(res_2_models_ba.loc[i, 'srl_ba'])['verbs'])):
            verb1.add(ast.literal_eval(res_2_models_ba.loc[i, 'srl_ba'])['verbs'][j]['verb'])
        verb2 = set()
        for j in range(len(ast.literal_eval(res_2_models_ba.loc[i, 'result_srl_kk'])['verbs'])):
            verb2.add(ast.literal_eval(res_2_models_ba.loc[i, 'result_srl_kk'])['verbs'][j]['verb'])
        if (len(verb1.intersection(verb2)) != 0) & (verb1 != ""):
            res_2_models_ba.loc[i, 'preds_kk_new'] = 1
        else:
            res_2_models_ba.loc[i, 'preds_kk_new'] = 0
    except:
        pass
    print(i, 'v1: ', verb1, 'v2: ', verb2, res_2_models_ba.loc[i, 'preds_kk_new'])
# Out:
# 0 v1:  {'күрә'} v2:  {'', 'күрә күренеш'} 0.0
# 1 v1:  {'торғанда'} v2:  {''} 0.0
# 2 v1:  {'билдәһеҙ'} v2:  {'', 'булыр'} 0.0
# 3 v1:  {'ҡайта'} v2:  {'', 'ала'} 0.0
# 4 v1:  {'килтерәсәк,'} v2:  {'', 'артабан артыуына'} 0.0
# 5 v1:  {'барлыҡҡа'} v2:  {'', 'булып'} 0.0
# 6 v1:  {'йәки'} v2:  {'', 'алынған', 'төҙөлгән алынған'} 0.0
# 7 v1:  {'туплана.'} v2:  {'ҡарала туплана', 'күренеш'} 0.0
# 8 v1:  {'кәмеүе'} v2:  {'', 'күрһәтелеүенсә'} 0.0
# 9 v1:  {'кәметте,'} v2:  {'', 'була', 'йөкләмәләрҙе', 'Артабанғы һуңғы'} 0.0
# 10 v1:  {'был'} v2:  {'килемлелеген', '', 'булмай', 'булып'} 0.0
# 11 v1:  {'Болсонару'} v2:  {'', 'араһында таяна'} 0.0
# 12 v1:  {''} v2:  {'', 'башланы'} 1.0
# 13 v1:  {'төҙөү'} v2:  {'төҙөү', 'юҡ'} 1.0
# 14 v1:  {'самаһы'} v2:  {'', 'инвестициялап', 'була', 'һатып алып'} 0.0
# 15 v1:  {'хаҡтар'} v2:  {''} 0.0
# 16 v1:  {'күберәк'} v2:  {'', 'алыу', 'импорттан алыу'} 0.0
# 17 v1:  {'', 'йөкләмәләрен'} v2:  {'', 'булыуы'} 1.0
# 18 v1:  {'юғарыраҡ'} v2:  {'', 'алырға', 'инвестицияларға', 'белдереүенсә', 'мәжбүр', 'етәкселегендәге мәжбүр'} 0.0
# 19 v1:  {'хәле'} v2:  {''} 0.0
# 20 v1:  {'финанслау'} v2:  {'булдырыуҙы', 'менән булдырыуҙы', 'булдырыуҙы индерелде'} 0.0
# 21 v1:  {'араһында', '35'} v2:  {'ашырыу арттырырға', 'Берләшкән ашырыу', 'ашырыу киңәйтә', 'ашырыу арттырырға киңәйтә', 'йөкләмә'} 0.0
# 22 v1:  {'көтөргә'} v2:  {'', 'көтөргә', 'талап ителә'} 1.0
# 23 v1:  {'буйһонорға'} v2:  {'тырыша', 'сәйәсәткә'} 0.0
# 24 v1:  {'аса.'} v2:  {'аса'} 0.0
# 25 v1:  {'позицияны'} v2:  {'Был', 'нығытырға'} 0.0
# 26 v1:  {'алмаштырырға'} v2:  {'', 'алмаштырырға', 'әҙерләүселәрҙең алмаштырырға'} 1.0
# 27 v1:  {'операциялар'} v2:  {'', 'башҡарырға'} 0.0
# 28 v1:  {'мәғлүмәт'} v2:  {'', 'белдереүенсә', 'мәжбүр', 'контролдә'} 0.0
# 29 v1:  {'сығарып,'} v2:  {'', 'кәрәклеген', 'сығарып үҙгәртеү', 'аңлау', 'үҙгәртеү'} 0.0
# 30 v1:  {'пошлиналары'} v2:  {''} 0.0
# 31 v1:  {'пошлинаны'} v2:  {'контролдә', 'ҡарай', 'сығарыу итеп ҡарай'} 0.0
# 32 v1:  {'килтерәсәк.'} v2:  {'Хәбәр', 'килтерәсәк'} 0.0
# 33 v1:  {'яҡлай'} v2:  {'', 'яҡлай'} 1.0
# 34 v1:  {'күберәк'} v2:  {'килтерә', 'КҮРҺӘТЕҮЕНСӘ'} 0.0
# 35 v1:  {'сығымдарға'} v2:  {'һөҙөмтәлелеген максималләштереүҙә ҡаҡшатыр килтерер', 'килтерер', 'булып', 'ҡаҡшатыр килтерер'} 0.0
# 36 v1:  {'кәметергә'} v2:  {'', 'кире', 'тырышырға', 'иҡтисады билдәһеҙлектең'} 0.0
# 37 v1:  {'теләмәй.'} v2:  {'', 'һайлаһа етәкләмәйенсә', 'булырға', 'теләмәй'} 0.0
# 38 v1:  {'хоҡуҡтарын'} v2:  {'', 'сығырҙан БЕРЛЕГЕНЕҢ', 'теләй', 'һаҡлап'} 0.0
# 39 v1:  {'тамамланмауы'} v2:  {''} 0.0
# 40 v1:  {'әҙерләнгән'} v2:  {'Евросоюзға инеүгә', 'әҙерләнгән әҙерләнә', 'инеүгә әҙерләнгән әҙерләнә'} 0.0
# 41 v1:  {'айырылып'} v2:  {''} 0.0
# 42 v1:  {'яғынан'} v2:  {'', 'осраша'} 0.0
# 43 v1:  {'тураһында'} v2:  {'', 'итеүгә итергә', 'килә'} 0.0
# 44 v1:  {'хаҡы'} v2:  {'күрһәткестәренә', 'нигеҙләнгән итә', 'алып', 'арттырыуға'} 0.0
# 45 v1:  {''} v2:  {'', 'түләргә'} 1.0
# 46 v1:  {'баһалай'} v2:  {'', 'продукцияһын етештереү', 'мохтаж', 'ала баһалай', 'алмай', 'алмаҫ алмай', 'яңы'} 0.0
# 47 v1:  {'бизнесҡа'} v2:  {'', 'һатыуы'} 0.0
# 48 v1:  {'венчурлы', 'инновацион'} v2:  {'', 'ҡурҡып бирәсәк', 'структуралана'} 0.0
# 49 v1:  {'һайлаған'} v2:  {'', 'күрә', 'һайлаған'} 1.0
# 50 v1:  {'вәкилдәрен'} v2:  {'', 'йәлеп', 'кәрәк', 'үткәрергә'} 0.0
# 51 v1:  {'шарапты'} v2:  {''} 0.0
# 52 v1:  {'тотонорға'} v2:  {'', 'яңыртылған етештереүгә булдырыласаҡ', 'аңлап'} 0.0
# 53 v1:  {''} v2:  {'', 'бүлеп сығарған', 'йөрөйәсәк', 'ярашлы'} 1.0
# 54 v1:  {'күләмендә'} v2:  {'', 'buyers тартып', 'тартып', 'һүрәтләгән үҫтерәсәк туҡтатырға', 'тартып алған', 'һүрәтләгән', 'бирәсәк', 'һүрәтләгән ниәтләй'} 0.0
# 55 v1:  {'шөғөлләнгән'} v2:  {'шөғөлләнгән йыһазландырылған'} 0.0
# 56 v1:  {'ярҙам'} v2:  {'ярҙам итә'} 0.0
# 57 v1:  {'Урбанизация'} v2:  {'', 'төҙөлөшө', 'булып', 'артты', 'сығарған килгән', 'артты сығарған килгән', 'сығарған ярашлы'} 0.0
# 58 v1:  {'бирһә'} v2:  {'йөрөргә эшләргә', 'мөмкинлек бирһә бирмәй', 'йөрөргә', 'бирһә бирмәй'} 0.0
# 59 v1:  {'иҫәпләй.'} v2:  {'', 'килдем', 'быны'} 0.0
# 60 v1:  {'ҡаршы'} v2:  {'', 'теләмәй'} 0.0
# 61 v1:  {'эшләй'} v2:  {'эшләй', 'алмай', 'йәшәгән йәшәй'} 1.0
# 62 v1:  {'буйы'} v2:  {'', 'көсәйтә'} 0.0
# 63 v1:  {'ысулдарын'} v2:  {'сығарыу', 'эҙләй', 'башланы'} 0.0
# 64 v1:  {'һайлауына'} v2:  {'', 'ғәйепләй', 'манипулировкалауҙа конвертацияланған', 'конвертацияланған ирекле контролдә тотолған'} 0.0
# 65 v1:  {'тураһында'} v2:  {'һөйләшеүҙәр яҙмышы һөйләмәгән', 'алып', 'алып барыу'} 0.0
# 66 v1:  {'әйләнеп'} v2:  {'', 'кире', 'һуңыраҡ'} 0.0
# 67 v1:  {'килтерәсәк', 'эске'} v2:  {'', 'нигеҙләнеп арҡаһында', 'тигән'} 0.0
# 68 v1:  {'аңлатыуы'} v2:  {'', 'аңлатыуы'} 1.0
# 69 v1:  {'етәкселек'} v2:  {'була', 'биргән'} 0.0
# 70 v1:  {'инә.'} v2:  {''} 0.0
# 71 v1:  {'ителгән'} v2:  {'', 'ителгән'} 1.0
# 72 v1:  {'акцияларҙы'} v2:  {'', 'менән тигеҙләргә', 'юғары'} 0.0
# 73 v1:  {'өсөн'} v2:  {'менән', 'артыуы артыуын арттырасаҡ', 'компенсациялау'} 0.0
# 74 v1:  {'етештереүселәрен'} v2:  {'ашыу', 'мәжбүр итә', 'борсомайынса', ''} 0.0
# 75 v1:  {'аша'} v2:  {'трендыул', 'артҡандыр', 'таратылған'} 0.0
# 76 v1:  {'', 'раҫлай.'} v2:  {'раҫлай', 'түләгән'} 0.0
# 77 v1:  {'үҙгәртергә,'} v2:  {'', 'финанслау'} 0.0
# 78 v1:  {'юғары'} v2:  {'', 'бирә юғары', 'бирә'} 0.0
# 79 v1:  {'дискредитациялау', 'үҙҙәренең'} v2:  {'', 'дискредитациялау', 'advised бурысы', 'кәңәш', 'иткән'} 1.0
# 80 v1:  {'пакеттарын'} v2:  {'', 'тарттырылмағандыр башлаған', 'тарттырылмағандыр', 'башлаған'} 0.0
# 81 v1:  {'һәм'} v2:  {'', 'бирергә яҡшыртырға', 'бирергә', 'яҡшыртырға', 'әҙерләү бирергә булдырырға'} 0.0
# 82 v1:  {'симпозиумға'} v2:  {'нығытыу', 'барлыҡҡа'} 0.0
# 83 v1:  {'үҙгәртә'} v2:  {'', 'талап', 'башланы'} 0.0
# 84 v1:  {'күрһәтә.'} v2:  {'күрһәтә', 'илһамландыра күрһәтә'} 0.0
# 85 v1:  {'бара.'} v2:  {'', 'булдырыу'} 0.0
# 86 v1:  {'байлыҡтан'} v2:  {'', 'алмаҫ'} 0.0
# 87 v1:  {'процесҡа'} v2:  {'', 'йәлеп'} 0.0
# 88 v1:  {'алырға'} v2:  {'зыянға файҙа'} 0.0
# 89 v1:  {'менән'} v2:  {'барған бара', 'барған алға'} 0.0
# 90 v1:  {'хаҡта'} v2:  {'', 'һөйләй'} 0.0
# 91 v1:  {'', 'эҙләргә'} v2:  {'', 'ҡатмарлаштыра'} 1.0
# 92 v1:  {'роль'} v2:  {'уйнағаны'} 0.0
# 93 v1:  {'өҫтөнлөк'} v2:  {''} 0.0
# 94 v1:  {'ниндәй'} v2:  {'', 'алға киткән итә көткәнен', 'күрһәтегеҙ', 'ышаныслылығын', 'булмаған'} 0.0
# 95 v1:  {'доллары)'} v2:  {'', 'талабы тейеш', 'штраф һалынасаҡ', 'исеме Яңы'} 0.0
# 96 v1:  {'ҡыҫҡартыла.'} v2:  {'', 'алып', 'һалым әҙер'} 0.0
# 97 v1:  {'менән', 'килешеүен', 'тураһындағы'} v2:  {'', 'ала башлай алаБигерәк тартҡас', 'итеп', 'яуап', 'башлай'} 0.0
# 98 v1:  {'сикләргә'} v2:  {'ҡатыландырырға', 'ниәтләй'} 0.0
# 99 v1:  {'был'} v2:  {'булыуынса', 'булыуынса юҡ', 'итергә'} 0.0
# 100 v1:  {'йоғонто'} v2:  {'', 'эшләй ойошҡан'} 0.0
# 101 v1:  {'йылдың'} v2:  {'', 'тамамлана', 'рөхсәт'} 0.0
# 102 v1:  {'уйнай.'} v2:  {''} 0.0
# 103 v1:  {'алырға'} v2:  {'', 'менән хәлдәрҙә төрлө', 'менән бәйле төрлө'} 0.0
# 104 v1:  {'зыян'} v2:  {'', 'зыян'} 1.0
# 105 v1:  {'һөйләргә'} v2:  {'', 'һөйләргә', 'аңлау'} 1.0
# 106 v1:  {'кешене', 'үткәрәһегеҙ'} v2:  {'', 'танышаһығыҙ билдәләй', 'күҙлегенән', 'уҡыйһығыҙ һөйләшәһегеҙ', 'булырға', 'күрә', 'айыра', 'һөйләшәһегеҙ'} 0.0
# 107 v1:  {''} v2:  {'', 'булмай'} 1.0
# 108 v1:  {'өйрәтәләр,'} v2:  {'бар', 'өйрәтәләр'} 0.0
# 109 v1:  {'конкурентлыҡ'} v2:  {'нигеҙетехнологияларҙы', 'эшҡыуарлыҡты эшләгән', 'таратыуға', 'эшҡыуарлыҡты эшләгән конкурентлыҡ', 'таратыуға сәнәғәт дәртләндерә'} 0.0
# 110 v1:  {'белә.'} v2:  {'', 'белә', 'үҙен килгән', 'яҡлай'} 0.0
# 111 v1:  {'тарафынан'} v2:  {'тырыша', 'үлтереүселәр өҙөлгән еткерергә тырыша', 'тарафынан өҙөлгән', 'булды'} 0.0
# 112 v1:  {'килемен'} v2:  {'биреү', 'стреыла ала', 'Башланғыс', 'яҡшыртырға', 'яҡшыртырға арттырырға'} 0.0
# 113 v1:  {'293-ө'} v2:  {'йыйған алды'} 0.0
# 114 v1:  {'буйынса'} v2:  {'ашырылырға'} 0.0
# 115 v1:  {'стратегия'} v2:  {'', 'табырға'} 0.0
# 116 v1:  {'структура'} v2:  {'тырыша', 'анализ яһағандан', 'яһағандан билдәләргә', 'яһағандан'} 0.0
# 117 v1:  {'сараларҙы'} v2:  {'шулай иғтибар итә оҙатып бара', 'бара'} 0.0
# 118 v1:  {'маҡсатын'} v2:  {'билдәләмәй'} 0.0
# 119 v1:  {'текле'} v2:  {'', 'кәрәкле', 'талап итә', 'алдағы', 'һәм'} 0.0
# 120 v1:  {'йәлеп'} v2:  {'', 'булып'} 0.0
# 121 v1:  {'бирә:'} v2:  {'', 'алыу', 'илгә килем', 'бирә', 'булһа'} 0.0
# 122 v1:  {''} v2:  {'тырыша', '', 'мөмкинлек', 'булып', 'иткән'} 1.0
# 123 v1:  {'ята.'} v2:  {''} 0.0
# 124 v1:  {'эшләмәй.'} v2:  {'', 'яһаған', 'булмаған', 'иткәндә яһаған'} 0.0
# 125 v1:  {'кәметәсәк.'} v2:  {''} 0.0
# 126 v1:  {'килергә,'} v2:  {'танылыуынса', '', 'килергә'} 0.0
# 127 v1:  {'билдәләү,'} v2:  {'', 'кәрәкмәгән'} 0.0
# 128 v1:  {'раҫлай.'} v2:  {'раҫлай'} 0.0
# 129 v1:  {'иҫәпләйҙәр.'} v2:  {''} 0.0
# 130 v1:  {'етешһеҙлектәре'} v2:  {'бар', 'ярыша', 'етешһеҙлектәре'} 1.0
# 131 v1:  {'күренә.'} v2:  {'', 'урынлашҡан', 'булып күренә'} 0.0
# 132 v1:  {'сигенһә,'} v2:  {''} 0.0
# 133 v1:  {'рецессиянан', 'бер'} v2:  {'veto көрсөгөнән вето', '', 'көрсөгөнән күрә һалынған килтерә', 'һалынған килтерә'} 0.0
# 134 v1:  {'сикһеҙ'} v2:  {'', 'ышандыра', 'нығытыу тергеҙеү', 'эшләргә', 'башланыуы', 'strengthening нығытыу йомшартып', 'softening нығытыу'} 0.0
# 135 v1:  {'тора'} v2:  {'һәләтлелеген', ''} 0.0
# 136 v1:  {'ҡырҡа'} v2:  {'кимәлен', '', 'өлгәшеүҙең иткән килеүен', 'мөмкин'} 0.0
# 137 v1:  {'тәғәйенләнеү'} v2:  {'емерелгән', 'барып'} 0.0
# 138 v1:  {'көтә,'} v2:  {'', 'көтә', 'килгән торлаҡ', 'һайлаған килгән'} 0.0
# 139 v1:  {'башлана.'} v2:  {'', 'башлана', 'бирелә'} 0.0
# 140 v1:  {'күрһәтә'} v2:  {''} 0.0
# 141 v1:  {'ҡайта'} v2:  {'', 'яуап', 'тураһында'} 0.0
# 142 v1:  {'тирә-йүндәгеләр'} v2:  {'күренә', 'ҡыҫып', 'ҡыҫып төшөрә'} 0.0
# 143 v1:  {'контролгә'} v2:  {'', 'алынған'} 0.0
# 144 v1:  {'маташыу'} v2:  {'', 'шул иҫәптән'} 0.0
# 145 v1:  {'сәйәсәтендә'} v2:  {'сигнал бирә'} 0.0
# 146 v1:  {'асҡан'} v2:  {'', 'асҡан'} 1.0
# 147 v1:  {'демократияһын'} v2:  {'', 'уйлау', 'формалаштырған'} 0.0
# 148 v1:  {'тип'} v2:  {'', 'ҡараған', 'тип'} 1.0
# 149 v1:  {'тип', 'идара'} v2:  {'', 'тип', 'алып'} 1.0
# 150 v1:  {'сауҙа'} v2:  {''} 0.0
# 151 v1:  {'төрҙәрен'} v2:  {'', 'үҙгәртеүҙең'} 0.0
# 152 v1:  {'белмәй'} v2:  {'булған', 'белмәй'} 1.0
# 153 v1:  {'яулай'} v2:  set() nan
# 154 v1:  {'күпмелер'} v2:  {'булды булып'} 0.0
# 155 v1:  {'бик'} v2:  {''} 0.0
# 156 v1:  {'сығымдары'} v2:  {'', 'булып'} 0.0
# 157 v1:  {'булып'} v2:  {'ҡарамаҫтан', 'булып'} 1.0
# 158 v1:  {'иртәрәк'} v2:  {'', 'индикаторКөньяҡ'} 0.0
# 159 v1:  {'темптары'} v2:  {''} 0.0
# 160 v1:  {'бар:'} v2:  {'бар', 'итә', 'Үҫешеүсе', 'әҙерләнеүен итә'} 0.0
# 161 v1:  {'асырға'} v2:  {'асырға', '', 'буласаҡ', 'иҡтисадты ышандырһа'} 1.0
# 162 v1:  {'йыйыр.'} v2:  {'', 'өстән', 'көтөлгәнсә'} 0.0
# 163 v1:  {'ҡулланырға'} v2:  {'', 'бүлеү', 'тыуҙыра'} 0.0
# 164 v1:  {'ҙә'} v2:  {'', 'була'} 0.0
# 165 v1:  {'кәметергә'} v2:  {'', 'ярҙам итә'} 0.0
# 166 v1:  {'һәм'} v2:  {'', 'иҫәптән инә'} 0.0
# 167 v1:  {'күберәк'} v2:  {'стимуллаштыра', '', 'күберәк алыу өсөн', 'башлай'} 0.0
# 168 v1:  {'эшләй.'} v2:  {'эшләй'} 0.0
# 169 v1:  {'талап'} v2:  {'булмағанса', 'талап', 'үҫтереү', 'инвестициялар'} 1.0
# 170 v1:  {'таянып'} v2:  {'баҫылып', 'иҫбатлап', 'баҫылып таянып', 'таянып иҫбатлап'} 0.0
# 171 v1:  {'менән'} v2:  {'тарата итә', 'тарата'} 0.0
# 172 v1:  {'алды.'} v2:  {'алды'} 0.0
# 173 v1:  {'ҡабул'} v2:  {'итә', 'көрсөгөнән Булған араһында'} 0.0
# 174 v1:  {'кәметтем.', 'иҫәпләйем.'} v2:  {'', 'иҫәпләйем'} 0.0
# 175 v1:  {'улар'} v2:  {'көсләп', 'теләмәһә теләмәй', 'мәжбүр', ''} 0.0
# 176 v1:  {''} v2:  {'', 'кире', 'яҙмайым', 'теләмәгән кире'} 1.0
# 177 v1:  {'уларҙың'} v2:  {'вәғәҙә бирәм', 'бирәм'} 0.0
# 178 v1:  {'тыйыу'} v2:  {'', 'шөғөлләнгән көсөнә', 'буласағын шөғөлләнгән', 'буласағын'} 0.0
# 179 v1:  {'донъя'} v2:  {'', 'билдәләүенсә', 'төрлө билдәләүенсә', 'килмәй'} 0.0
# 180 v1:  {'ҡаршы'} v2:  {'', 'килтерә'} 0.0
# 181 v1:  {''} v2:  {'', 'һаҡланыуы', 'булмаған', 'ышанмай'} 1.0
# 182 v1:  {'әйтә'} v2:  {'', 'әйтә'} 1.0
# 183 v1:  {'асыҡлауға'} v2:  {'раҫлаған аңлай', 'булыуын', 'аңлай', 'килтергән'} 0.0
# 184 v1:  {'һала.'} v2:  {''} 0.0
# 185 v1:  {'контрактты'} v2:  {'', 'ҡаплау үтәүҙән'} 0.0
# 186 v1:  {'тенденцияларҙы'} v2:  {'', 'бер', 'туҡтатырға', 'ашырһа'} 0.0
# 187 v1:  {''} v2:  {'', 'күскенселәрҙең'} 1.0
# 188 v1:  {'үҙгәртер'} v2:  {'', 'ине'} 0.0
# 189 v1:  {'менән'} v2:  {'таҙалығын һаҡлау', 'биреү'} 0.0
# 190 v1:  {'юл'} v2:  {'берләштереп әйләнеп', 'ҡайтып'} 0.0
# 191 v1:  {'ярҙамында'} v2:  {'', 'яҡшырта', 'таба бирә', 'бирә', 'стратегия эшкәртеүҙең'} 0.0
# 192 v1:  {'миллион', 'ситләтелгән'} v2:  {'', 'иткән', 'гарантиялай', 'ситләтелгән гарантиялай иткән киңәйтеүҙә'} 0.0
# 193 v1:  {'сағылдырыу'} v2:  {''} 0.0
# 194 v1:  {'бүленешен'} v2:  {'бүленешен', 'билдәләй'} 1.0
# 195 v1:  {'тирәләй'} v2:  {'реформалаштырырға бөтөрөргә сикләгән', 'табыуҙар', 'реформалаштырырға', 'реформалаштырырға ҡыҫҡартырға бөтөрөргә сикләгән', 'мөмкин', 'реформалаштырырға ҡыҫҡартырға бөтөрөргә'} 0.0
# 196 v1:  {'реформалау'} v2:  {'булған', 'реформалау', 'булмаҫ'} 1.0
# 197 v1:  {'индустрияһын'} v2:  {'ҡатнашам'} 0.0
# 198 v1:  {'көслө'} v2:  {'', 'мөмкинлек бирә'} 0.0
# 199 v1:  {'проекттарын'} v2:  {'', 'Ҡулланыусылар ҡушылғанға', 'монетизацияларға'} 0.0
# 200 v1:  {'тип'} v2:  {'', 'тип тасуирлай'} 0.0
# 201 v1:  {'лә'} v2:  {''} 0.0
# 202 v1:  {'ҡалды.'} v2:  {'килде', 'булып'} 0.0
# 203 v1:  {'бүлеү'} v2:  {'', 'вәғәҙә'} 0.0
# 204 v1:  {'артты.'} v2:  {'менән сағыштырғанда', '', 'йәшәүсе', 'артты'} 0.0
# 205 v1:  {'һаҡлап', 'тип'} v2:  {'', 'һанала'} 0.0
# 206 v1:  {'өсөн'} v2:  {'әҙерләнгән', 'әҙерләнгән тәржемәләренә'} 0.0
# 207 v1:  {'кәметә.'} v2:  {'ташыуға йүнәлтелгән', 'артыуына', 'йүнәлтелгән килтерһә'} 0.0
# 208 v1:  {'эшләй.'} v2:  {'эшләй', 'гражданы иҫәптән', 'алып'} 0.0
# 209 v1:  {'составын'} v2:  {'', 'киңәйтергә'} 0.0
# 210 v1:  {'килеп'} v2:  {'', 'Барған'} 0.0
# 211 v1:  {'идара'} v2:  {'', 'идара'} 1.0
# 212 v1:  {'кәметеү'} v2:  {'', 'булыу', 'тотороҡландырыуҙы стабилләштереү', 'ауырлаштыра', 'тотороҡландырыуҙы'} 0.0
# 213 v1:  {'ярҙам'} v2:  {'', 'буласаҡ'} 0.0
# 214 v1:  {'план'} v2:  {'раҫлай', 'яҙылған'} 0.0
# 215 v1:  {'берләштерә.'} v2:  {'', 'ҡамасаулаусы'} 0.0
# 216 v1:  {'билдәләргә'} v2:  {'', 'ярҙам итер', 'булыу'} 0.0
# 217 v1:  {'аға'} v2:  {''} 0.0
# 218 v1:  {'килтерә.'} v2:  {'тарала килтерә', 'башланған', 'тарала', 'артабан'} 0.0
# 219 v1:  {'хаҡҡа'} v2:  {'', 'һатыла'} 0.0
# 220 v1:  {'кимәлгә'} v2:  {'', 'кире'} 0.0
# 221 v1:  {'үтте?'} v2:  {''} 0.0
# 222 v1:  {''} v2:  {'булып үткән', 'яҡшырта'} 0.0
# 223 v1:  {'мөрәжәғәт'} v2:  {'', 'көрсөктән'} 0.0
# 224 v1:  {'хөкүмәткә'} v2:  {'ҡыҫҡартып', '', 'ҡарашты итәләр', 'ҡарашты ҡыҫҡартып'} 0.0
# 225 v1:  {'отчет'} v2:  {''} 0.0
# 226 v1:  {'биргән'} v2:  {'', 'элитаға', 'биргән'} 1.0
# 227 v1:  {'уны'} v2:  {'баһалай'} 0.0
# 228 v1:  {'белә,'} v2:  {'', 'белә', 'көрсөгөн өйрәнгән'} 0.0
# 229 v1:  {'итеү'} v2:  {''} 0.0
# 230 v1:  {'дәүере'} v2:  {'оноторға', '', 'йәшәгәнен', 'башланғанын'} 0.0
# 231 v1:  {'көсәймәй.'} v2:  {''} 0.0
# 232 v1:  {'килтерәсәк'} v2:  {'', 'килтерәсәк', 'артмаясаҡ юҡ'} 1.0
# 233 v1:  {'элитаның'} v2:  {'таныла', 'тыуҙыра'} 0.0
# 234 v1:  {'формалаштыра.'} v2:  {'', 'була', 'формалаштыра'} 0.0
# 235 v1:  {'сауҙанан'} v2:  {'', 'алған', 'әйтеүенсә'} 0.0
# 236 v1:  {'күрә.'} v2:  {'күрә'} 0.0
# 237 v1:  {'йәшәй,'} v2:  {'', 'юҡ', 'уйлап', 'йәшәй'} 0.0
# 238 v1:  {'', 'кәметә,'} v2:  {'', 'increase increases', 'буласаҡ', 'reduces increases артыуына', 'биреүсенең'} 1.0
# 239 v1:  {'әйтергә'} v2:  {'әйтергә', '–'} 1.0
# 240 v1:  {'француздарҙан'} v2:  {''} 0.0
# 241 v1:  {'урынды'} v2:  {'көрсөгөнә көйләү урынды биләй'} 0.0
# 242 v1:  {'уйнай'} v2:  {'ҡарағанда'} 0.0
# 243 v1:  {'алдан'} v2:  {'', 'кәрәкмәүен'} 0.0
# 244 v1:  {'барғанда,'} v2:  {'', 'тураһында барғанда'} 0.0
# 245 v1:  {'ныҡлы'} v2:  {'хуплаған', 'булдырыу'} 0.0
# 246 v1:  {'партнерлығын'} v2:  {'', 'яҡлап һаҡлап', 'яҡлап һаҡлап ҡала'} 0.0
# 247 v1:  {'арбаһын'} v2:  {'', 'ала'} 0.0
# 248 v1:  {'хәл'} v2:  {'булыр'} 0.0
# 249 v1:  {'эшләү?'} v2:  {''} 0.0
# 250 v1:  {'яңылыҡтарға'} v2:  {'ышанырға'} 0.0
# 251 v1:  {'эш'} v2:  {'', 'бәйле', 'кәрәк', 'башҡарырға'} 0.0
# 252 v1:  {'һығылмалы'} v2:  {'менән', '', 'көрсөгө Күрһәтеүенсә'} 0.0
# 253 v1:  {'ай'} v2:  set() 0.0
# 254 v1:  {'биләп,'} v2:  {'', 'алыу', 'буласаҡ', 'Әйтеүенсә'} 0.0
# 255 v1:  {'булып'} v2:  {'булһа булып', 'еңгәндән'} 0.0
# 256 v1:  {'тип', 'тиклемге'} v2:  {'яҡлаған раҫланы', 'яҡлаған', 'лидеры яҡлаған', 'итә яҡлаған'} 0.0
# 257 v1:  {'эштәргә'} v2:  {''} 0.0
# 258 v1:  {'үлтергән'} v2:  {'бар', 'үлтергән'} 1.0
# 259 v1:  {'киләсәк.'} v2:  {''} 0.0
# 260 v1:  {'уйлайым,'} v2:  {'', 'булды', 'һалды'} 0.0
# 261 v1:  {'билдәләрен'} v2:  {'', 'күрһәтә'} 0.0
# 262 v1:  {'янай'} v2:  {'', 'башлай'} 0.0
# 263 v1:  {'ҡарашҡа'} v2:  {'килтереү', ''} 0.0
# 264 v1:  {'дөрөҫлөктө'} v2:  {'', 'таянғанлыҡтан', 'ярашлы яһау', 'айырып'} 0.0
# 265 v1:  {'йыл'} v2:  {'', 'йүнәлтелгән уйланылған итә', 'таралған'} 0.0
# 266 v1:  {'эшкәртергә'} v2:  {'өйрәттеләр', ''} 0.0
# 267 v1:  {'яуаплылыҡҡа'} v2:  {'', 'тыуҙырған'} 0.0
# 268 v1:  {'килтерер,'} v2:  {'', 'килтерер', 'үтәлә көтөлмәгән килтерер'} 0.0
# 269 v1:  {'булышлыҡ'} v2:  {'булышлыҡ итә'} 0.0
# 270 v1:  {'урындарын'} v2:  {'алға', '', 'бүленә', 'ярыша'} 0.0
# 271 v1:  {'компанияларға'} v2:  {'', 'китә', 'итеп йүнәлтелгән сәйәсәте менән хәсрәтләнә', 'йүнәлтелгән страховкалау менән хәсрәтләнә арта'} 0.0
# 272 v1:  {'адаптив'} v2:  {'стреылған көрсөгөнән башланған адаптив тартырға', 'стреыла', 'тартырға'} 0.0
# 273 v1:  {''} v2:  {'төшөүе', 'булған', 'белә', ''} 1.0
# 274 v1:  {'килһә,'} v2:  {'барлыҡҡа булыр', 'борсолоу', 'барлыҡҡа'} 0.0
# 275 v1:  {'ваҡытта'} v2:  {'', 'артыуы тырыша', 'артыуы', 'тырыша'} 0.0
# 276 v1:  {'ҡала,'} v2:  {'', 'булып', 'финанслауға', 'арта юғарыраҡ бүленергә', 'нигеҙендәге', 'тенденцияларға'} 0.0
# 277 v1:  {'компаниялар'} v2:  {'', 'артабан үҫтереү баҫтырыу', 'һатып', 'үҫтереү баҫтырыу', 'яңы конкурентлыҡ'} 0.0
# 278 v1:  {'мөмкинлектәр'} v2:  {'нигеҙләнгән', 'ҡалдырмай'} 0.0
# 279 v1:  {'тип'} v2:  {'атаным'} 0.0
# 280 v1:  {'артыуына'} v2:  {'итегеҙ', 'арттырыу'} 0.0
# 281 v1:  {'проценттан'} v2:  {'финансланған', 'артмай'} 0.0
# 282 v1:  {'процентҡа'} v2:  {''} 0.0
# 283 v1:  {'өлөштө'} v2:  {'арттырыу арттыра', 'арттырыу'} 0.0
# 284 v1:  {'тип'} v2:  {'ҡарап ҡыҫыла'} 0.0
# 285 v1:  {'буласағын'} v2:  {'', 'таный', 'буласағын'} 1.0
# 286 v1:  {'кеше'} v2:  {''} 0.0
# 287 v1:  {'итергә'} v2:  {'теләһә кәрәк', 'конкурентлыҡ', 'кәрәк', 'кимәлдә һайлай'} 0.0
# 288 v1:  {'Японияла'} v2:  {'йәшәргә', 'мөмкинлек биргән', 'төҙөргә биргән'} 0.0
# 289 v1:  {'мөмкинлектәрен'} v2:  {'', 'дискредитациялай', 'дискредитациялай шартлата'} 0.0
# 290 v1:  {'миҫалы'} v2:  {'атаған'} 0.0
# 291 v1:  {'мәнфәғәтендә'} v2:  {'', 'булмай', 'раҫлай', 'эшләүен'} 0.0
# 292 v1:  {'индерергә'} v2:  {''} 0.0
# 293 v1:  {'көйләү'} v2:  {'менән', 'килгән', 'итеүҙә', ''} 0.0
# 294 v1:  {'булған'} v2:  {'булып ҡалмай', '', 'булып', 'үҙгәреүсән'} 0.0
# 295 v1:  {'нығыраҡ'} v2:  {'раҫлай'} 0.0
# 296 v1:  {'юғалта.'} v2:  {'', 'юғалта'} 0.0
# 297 v1:  {'ҡала.'} v2:  {'', 'булып'} 0.0
# 298 v1:  {'сығара.', 'индерә.'} v2:  {'', 'булдырыу', 'сығара'} 0.0
# 299 v1:  {'әммә'} v2:  {'', 'ҡалырға', 'теләй'} 0.0
# 300 v1:  {'һала.'} v2:  {'', 'нигеҙендә үҙгәртеп ҡиммәттәрендә', 'үҙгәртеп ҡороуға консерватория'} 0.0
# 301 v1:  {'юҡҡа'} v2:  {'', 'көсһөҙләнә тапшырыла'} 0.0
# 302 v1:  {'конфликтҡа'} v2:  {'йылыныунасар', 'башланған', 'башланған килтерә'} 0.0
# 303 v1:  {'национализациялай.'} v2:  {'национализациялай'} 0.0
# 304 v1:  {'', 'асыҡланған'} v2:  {'иғтибарға иҡтисады', 'ала', 'юғарыраҡ'} 0.0
# 305 v1:  {'өҫтәлһә.'} v2:  {''} 0.0
# 306 v1:  {'күрһәттем.'} v2:  {'яһап күрһәттем', 'күрһәттем'} 0.0
# 307 v1:  {'', 'тамамламаным.'} v2:  {'башланым', 'эҙләп тейеш', 'тейеш', 'был эште'} 0.0
# 308 v1:  {'билдәләргә'} v2:  {'', 'билдәләргә'} 1.0
# 309 v1:  {'әле'} v2:  {'күрмәйбеҙ', 'булдырырға', 'ҡамасаулау', 'талап ителә'} 0.0
# 310 v1:  {'подразделениеһы'} v2:  {'', 'контролдә', 'булып'} 0.0
# 311 v1:  {'буфер'} v2:  {'булыуын', 'күрәбеҙ', 'ойошторорға'} 0.0
# 312 v1:  {'менән'} v2:  {'', 'аңлай', 'кимәле эштә башлай', 'башлай'} 0.0
# 313 v1:  {'ҡала.'} v2:  {'етәкләгән', 'булып'} 0.0
# 314 v1:  {'донъяға'} v2:  {'суверенитетты', 'юғалтмаған юғалтмайынса', 'онотмай юғалтмайынса'} 0.0
# 315 v1:  {'күрҙек.'} v2:  {'күрҙек'} 0.0
# 316 v1:  {'кәметә.'} v2:  {'эшләй', ''} 0.0
# 317 v1:  {'һалымдар', 'экспектацияның'} v2:  {'булыуҙан', 'килтерҙе', 'килтерҙе булыуҙан туҡтай'} 0.0
# 318 v1:  {'дә'} v2:  {'', 'артыуға компенсация', 'артыуға', 'кире артыуға', 'һөҙөмтәлелеген рекламалана'} 0.0
# 319 v1:  {'табышты'} v2:  {'', 'килтерһә тырышҡан', 'айырырға', 'килтерһә'} 0.0
# 320 v1:  {'өсөн'} v2:  {'', 'йүнәлтелергә'} 0.0
# 321 v1:  {'килгән'} v2:  {'килгән', 'булып'} 1.0
# 322 v1:  {'сикләргә'} v2:  {'әҙерләргә', '', 'кәрәк тейеш', 'тейеш'} 0.0
# 323 v1:  {'пистолеттан'} v2:  {'эҙләгәндә ҡайтарыуға һалған', 'ҡайтарыуға', 'эҙләгәндә һалған'} 0.0
# 324 v1:  {'булып'} v2:  {'туҡтатты', 'булып', 'ҡабатланыуын'} 1.0
# 325 v1:  {'булараҡ'} v2:  {''} 0.0
# 326 v1:  {'үлтерелеүгә'} v2:  {'килтергән тигәнде', 'тигәнде аңлата'} 0.0
# 327 v1:  {'талап'} v2:  {'', 'туплап', 'талап иткән', 'туплап арала'} 0.0
# 328 v1:  {'торғанда,'} v2:  {'барыбыҙ'} 0.0
# 329 v1:  {'осраҡтары'} v2:  {''} 0.0
# 330 v1:  {'янай.'} v2:  {''} 0.0
# 331 v1:  {'ла,'} v2:  {'', 'сараһына', 'тураһындағы индерелгән үҙгәрештәргә бирә', 'бирә'} 0.0
# 332 v1:  {'фонды'} v2:  {'Respond', 'хәүефһеҙлеген шөғөлләнгән яллаған', 'шөғөлләнгән', 'хәүефһеҙлеген шөғөлләнгән'} 0.0
# 333 v1:  {'ҡулын', 'ҡасҡан'} v2:  {'', 'мөрәжәғәт', 'ойошторолған', 'алып итте'} 0.0
# 334 v1:  {'тураһында'} v2:  {'', 'яһағанлыҡтан һөйләргә'} 0.0
# 335 v1:  {'күләме'} v2:  {''} 0.0
# 336 v1:  {'MTVA'} v2:  {'килгәндән сығара', 'килгәндән'} 0.0
# 337 v1:  {'килтермәй.'} v2:  {'килтермәй', 'яраҡлаштыра'} 0.0
# 338 v1:  {'ҡаты'} v2:  {'', 'нығыта', 'булмаған нығыта', 'булмаған була'} 0.0
# 339 v1:  {'көсөргәнешлекте'} v2:  {'көсөргәнешлекте', 'сикләй'} 1.0
# 340 v1:  {'балансты'} v2:  {'менән сағыштырғанда', '', 'сағыштырғанда башланы һаҡлап', 'башланы', 'булмаһа'} 0.0
# 341 v1:  {'кәмеүен'} v2:  {'', 'ҡарамаҫтан итә'} 0.0
# 342 v1:  {'икеләтә'} v2:  {'', 'билдәләй', 'артыуын'} 0.0
# 343 v1:  {'юҡ'} v2:  {'', 'күрһәтә', 'Көнсығыш оҙайлы', 'өҫтөнлөгөнә алып', 'осрай өҫтөнлөгөнә'} 0.0
# 344 v1:  {'көтөргә'} v2:  {''} 0.0
# 345 v1:  {'менән'} v2:  {'', 'эш'} 0.0
# 346 v1:  {'тәьмин'} v2:  {'', 'барАлексей'} 0.0
# 347 v1:  {'кампанияһын'} v2:  {'һайлау', 'анализлай', 'мөмкинлек бирә'} 0.0
# 348 v1:  {'карьераһын', 'сығарҙы,', 'доллар'} v2:  {'сығарҙы', 'күрһәтте', 'һатып алыуын ҡараған', 'күрһәтте ҡараған', 'ҡараған', 'һатып алыуға'} 0.0
# 349 v1:  {'тураһында'} v2:  {'', 'ҡаршы алдынан', 'ителгән яһарға', 'ителгән талап иткән'} 0.0
# 350 v1:  {'үҙ'} v2:  {'күрә', 'эшләүен ярашлы', 'ҡарамаҫтан', 'ҡолатырға'} 0.0
# 351 v1:  {'талап'} v2:  {'', 'талап'} 1.0
# 352 v1:  {'эшләмәһәләр,'} v2:  {'', 'эшмәкәрлеген оҙатыусы'} 0.0
# 353 v1:  {'йыл'} v2:  {'башланған башланыу', 'башланған тамамлана'} 0.0
# 354 v1:  {'яҡшыртыусы'} v2:  {'мөмкинлек бирҙе', '', 'яҡшыртыусы'} 1.0
# 355 v1:  {'өҫтөнлөк'} v2:  {'', 'булмауы', 'башынан булмауы'} 0.0
# 356 v1:  {'дауам'} v2:  {'башлаған', 'иҡтисадына ҡаршы башлаған итә'} 0.0
# 357 v1:  {'ингән'} v2:  {'иҡтисадҡа ерҙә һалынасаҡ', 'ситләтеп'} 0.0
# 358 v1:  {'килем'} v2:  {'түләү сығарыуға', 'сығарыуға килтерә'} 0.0
# 359 v1:  {'та'} v2:  {'', 'алынған', 'таратыласаҡ', 'булмаған'} 0.0
# 360 v1:  {'борсолһа,'} v2:  set() nan
# 361 v1:  {'файҙаланырға'} v2:  {'', 'тыуҙырған'} 0.0
# 362 v1:  {'алыу'} v2:  {'һорау', 'барлыҡҡа'} 0.0
# 363 v1:  {'атаған'} v2:  {'', 'эске үтергә', 'башлана', 'юл киләсәк', 'атаған'} 1.0
# 364 v1:  {'һанала,'} v2:  {'һанала'} 0.0
# 365 v1:  {'һымаҡ'} v2:  {'', 'күренә'} 0.0
# 366 v1:  {'тыңлай.'} v2:  {'тыңлаусылары көрсөгө ҡарарында', 'тыңлаусылары һоҡланып тыңлай'} 0.0
# 367 v1:  {'иҫәпләй.'} v2:  {'', 'тип'} 0.0
# 368 v1:  {'туплауҙың'} v2:  {'күрһәтте'} 0.0
# 369 v1:  {'ҡулында'} v2:  {'туплай', 'башҡарма туплай'} 0.0
# 370 v1:  {'сәйәсәттең'} v2:  {'ҡала'} 0.0
# 371 v1:  {'магазиндарына'} v2:  {'һатып', 'килә'} 0.0
# 372 v1:  {'һаҡланыуын'} v2:  {'баһаланы'} 0.0
# 373 v1:  {''} v2:  {'', 'бергә тикшерә'} 1.0
# 374 v1:  {'һүҙҙәр'} v2:  {'эшләне', 'уртаҡлашты'} 0.0
# 375 v1:  {'үҙгәрешһеҙ'} v2:  {''} 0.0
# 376 v1:  {'кеүек'} v2:  {'эшләй'} 0.0
# 377 v1:  {'МЕНӘН'} v2:  {''} 0.0
# 378 v1:  {'рәсәй'} v2:  {'составына ингән'} 0.0
# 379 v1:  {'ултыра.'} v2:  {''} 0.0
# 380 v1:  {'скважиналары'} v2:  {'йыһазландырылған', '', 'итеп йыһазландырылған юғалтылған'} 0.0
# 381 v1:  {'курстарҙы', 'үткәргән'} v2:  {'', 'күрһәтте', 'үткәргән биргән үткәрелгән', 'биргән', 'үткәргән өйрәнеүҙе'} 0.0
# 382 v1:  {'ҡыҫҡартып,'} v2:  {'', 'ҡыҫҡартып'} 0.0
# 383 v1:  {'ҡыҫҡартыу,'} v2:  {''} 0.0
# 384 v1:  {'зыян'} v2:  {''} 0.0
# 385 v1:  {'үҙләштереү'} v2:  {'үҙләштереү', 'кәрәкмәй'} 1.0
# 386 v1:  {'зыян'} v2:  {'', 'һөйләй'} 0.0
# 387 v1:  {'көрәшмәй.'} v2:  {'көрәшмәй'} 0.0
# 388 v1:  {'уҡ'} v2:  {'', 'башҡарыр', 'шул эште'} 0.0
# 389 v1:  {'ташлаған'} v2:  {'', 'ташлаған'} 1.0
# 390 v1:  {'сәскә'} v2:  {'', 'булмай', 'теләй', 'булмай була'} 0.0
# 391 v1:  {'көрәшеп,'} v2:  {'', 'көрәшеп тапшыра'} 0.0
# 392 v1:  {'ҡәтғи'} v2:  {'Күнекмә иҫкәрттеләр', '', 'КӨСТӘРЕНЕҢ'} 0.0
# 393 v1:  {'һәм'} v2:  {'еңеләйтә арттыра', 'үҙгәртеү', 'арттыра'} 0.0
# 394 v1:  {'командир'} v2:  {'', 'уҡырға барғанда', 'барғанда'} 0.0
# 395 v1:  {'проблемаларҙы'} v2:  {'', 'төҙөлгән', 'буласаҡ'} 0.0
# 396 v1:  {''} v2:  {'булып киткәс итә', 'булып'} 0.0
# 397 v1:  {'ҡарай.'} v2:  {'', 'хосусилаштырыу'} 0.0
# 398 v1:  {'хәүефте'} v2:  {'', 'мөмкинлегенә'} 0.0
# 399 v1:  {'итеү'} v2:  {'', 'талаптар тырыша', 'еңеләйтеүсе артты', 'артты', 'еңеләйтеүсе'} 0.0
# 400 v1:  {'күтәрә.'} v2:  {''} 0.0
# 401 v1:  {'парад', 'йәки'} v2:  {'', 'ҡатнашырға көсләп ҡулланылыуы', 'раҫлаған', 'булыр'} 0.0
# 402 v1:  {'ителешендә'} v2:  {''} 0.0
# 403 v1:  {'компанияларының'} v2:  {'', 'арттыра', 'тарта', 'танырға', 'мәжбүр'} 0.0
# 404 v1:  {'яуаплылыҡ'} v2:  {''} 0.0
# 405 v1:  {'һәм'} v2:  {''} 0.0
# 406 v1:  {'йәлеп'} v2:  {'', 'йүнәлтеп', 'бәйләп эшләй', 'йәлеп маҡсаттарына иткән'} 0.0
# 407 v1:  {'туплана.'} v2:  {'йәлеп итеү', 'туплана'} 0.0
# 408 v1:  {'иҫәпләй.'} v2:  {''} 0.0
# 409 v1:  {'ярҙам'} v2:  {'ҡарағанда', 'күрһәтеп'} 0.0
# 410 v1:  {'ҡабул'} v2:  {'иткән итә', 'итә'} 0.0
# 411 v1:  {'урынды'} v2:  {'тупланған', ''} 0.0
# 412 v1:  {'йылдарҙа'} v2:  {'алдағы', 'өҫтәләсәк бирә', 'бирә'} 0.0
# 413 v1:  {'алмаштырыусы'} v2:  {'бар', 'алмаштырыусы'} 1.0
# 414 v1:  {'киңәйергә'} v2:  {'', 'һалмайынса', 'башлағас', 'мөмкинлеге булды'} 0.0
# 415 v1:  {'һаҡлау'} v2:  {'', 'аңлауҙы билдәләргә', 'һаҡлау'} 1.0
# 416 v1:  {'ҡоралы', 'был'} v2:  {''} 0.0
# 417 v1:  {'үҙ', 'аса.'} v2:  {'', 'ҡалдырып', 'барған', 'яҡшырта', 'аса ҡалдырып', 'эш', 'improving яҡшырта'} 0.0
# 418 v1:  {'иртәнге'} v2:  {''} 0.0
# 419 v1:  {'өлгәшә,'} v2:  {'', 'өлгәшә', 'таратыуға'} 0.0
# 420 v1:  {'туиттарҙан'} v2:  {'', 'оҡшамаған', 'уйнамай', 'булмауы була'} 0.0
# 421 v1:  {'лә'} v2:  {'ителмәй'} 0.0
# 422 v1:  {'эшселәр'} v2:  {''} 0.0
# 423 v1:  {'нисек'} v2:  {'', 'белмәй', 'юғалтҡан', 'зыян'} 0.0
# 424 v1:  {'табыш'} v2:  {'', 'килтерә'} 0.0
# 425 v1:  {'алырға'} v2:  {'алырға'} 1.0
# 426 v1:  {'мөмкинлеге'} v2:  {'', 'бар', 'туҡтатыу'} 0.0
# 427 v1:  {'ителгән'} v2:  {'', 'ителгән', 'булмаһа буласаҡ'} 1.0
# 428 v1:  {'ғына'} v2:  {'', 'билдәле', 'һатып түләй', 'өйрәнеүсе', 'ҡулланыусы ҡалдырмай һатып алырлыҡ', 'һатып алған', 'яҡшы'} 0.0
# 429 v1:  {'кәметә.'} v2:  {'', 'кәметә'} 0.0
# 430 v1:  {'хәл'} v2:  {'ҡулланыусылар ҡалдырған', 'бара', 'ҡулланыусылар ҡалдырған ҡуллана', 'ҡулланыусылар'} 0.0
# 431 v1:  {'килтерә.'} v2:  {''} 0.0
# 432 v1:  {'билдәләгәндә'} v2:  {'кәрәкле талап итте', 'билдәләгәндә', 'кәрәкле', 'табыу'} 1.0
# 433 v1:  {'һәм'} v2:  {''} 0.0
# 434 v1:  {''} v2:  set() nan
# 435 v1:  {'раҫлаусы'} v2:  {''} 0.0
# 436 v1:  {'башланды.'} v2:  {'йүнәлтелгән башланды', 'башланды'} 0.0
# 437 v1:  {'янай.'} v2:  {'', 'шартлата янай'} 0.0
# 438 v1:  {'ҡабул'} v2:  {''} 0.0
# 439 v1:  {'ҡурҡыныс'} v2:  set() nan
# 440 v1:  {'тәьмин'} v2:  {'алған', '', 'иткән'} 0.0
# 441 v1:  {'шартлата.'} v2:  {'берләштергән шартлата', 'берләштергән'} 0.0
# 442 v1:  {'альянстарын'} v2:  {'тышҡы танымай емерә', 'танымай'} 0.0
# 443 v1:  {'илгә'} v2:  {'', 'әйтергә', 'ғәйепләргә', 'эшләргә'} 0.0
# 444 v1:  {'йәшереү'} v2:  {'', 'тигәнде аңлата'} 0.0
# 445 v1:  {'мөнәсәбәттәренә'} v2:  {'дискредитациялау', 'дискредитациялау тәғәйенләнгән', 'тәғәйенләнгән'} 0.0
# 446 v1:  {'күрәһең,'} v2:  {'тыуҙырған', ''} 0.0
# 447 v1:  {'ҡаты'} v2:  {'сығарылды', 'алыу'} 0.0
# 448 v1:  {'итеүҙе'} v2:  {'', 'талап итә', 'корпорацияһыбәлки', 'алдынғы'} 0.0
# 449 v1:  {'айырыла.'} v2:  {'', 'ҡоролмаларынан торған'} 0.0
# 450 v1:  {'видеоны'} v2:  {'бар', 'аңлатыусы', 'һайлаусыларға итәм', 'ҡарарға'} 0.0
# 451 v1:  {'төрлө'} v2:  {'', 'тура', 'киләсәк', 'билдәле таныһа', 'йыйыу сығарыу'} 0.0
# 452 v1:  {'үтәлешен'} v2:  {'бар', ''} 0.0
# 453 v1:  {'талап'} v2:  {'талап итә', 'дөйөм алғанда'} 0.0
# 454 v1:  {'мөрәжәғәт'} v2:  {'тормошҡа'} 0.0
# 455 v1:  {'баҙарын'} v2:  {'бар', 'киңәйтә'} 0.0
# 456 v1:  {'ҡарауҙы'} v2:  {'итеп', 'талап итеп'} 0.0
# 457 v1:  {'финанслай', 'процентын'} v2:  {'түләгәндәр алһа', 'түләгәндәр', 'ҡарағанда мөмкинлегенә ҡарап', 'финанслай', 'алаәгәр'} 1.0
# 458 v1:  {'йылдарҙан'} v2:  {''} 0.0
# 459 v1:  {'ярҙам'} v2:  {'итәләр'} 0.0
# 460 v1:  {'барыһы'} v2:  {'талап итә'} 0.0
# 461 v1:  {'һәм'} v2:  {'', 'арттырыу'} 0.0
# 462 v1:  {'лидерлыҡ'} v2:  {'Трампҡа', 'күрһәтергә'} 0.0
# 463 v1:  {'традицияларҙы'} v2:  {'арттырып', 'булып'} 0.0
# 464 v1:  {'йәйелдерергә'} v2:  {'биреүҙе', 'талап итә', 'рөхсәт'} 0.0
# 465 v1:  {'дискредитациялай.'} v2:  {'дискредитациялай', 'бер килтермәй'} 0.0
# 466 v1:  {'ҡайтты.'} v2:  {'ҡайтты'} 0.0
# 467 v1:  {'юл'} v2:  {'күрһәтергә'} 0.0
# 468 v1:  {'йәки'} v2:  {'арттырырға'} 0.0
# 469 v1:  {'өсөн'} v2:  {'арттырыуҙың булып', 'арттырыуҙың', 'булып'} 0.0
# 470 v1:  {'долларға'} v2:  {'артыуы', 'алмағанда'} 0.0
# 471 v1:  {'яҡларға'} v2:  {'', 'мөмкин', 'ышандырырға'} 0.0
# 472 v1:  {'проекттарын'} v2:  {'килтергән күсереп яҙған'} 0.0
# 473 v1:  {'шөғөлләнә,'} v2:  {'бар', 'шөғөлләнә бар'} 0.0
# 474 v1:  {'ҡаты'} v2:  {''} 0.0
# 475 v1:  {'ҡаршы'} v2:  {'', 'артыуына', 'һөйләй'} 0.0
# 476 v1:  {'һатып'} v2:  {'', 'һатып', 'һатып булдырыу'} 1.0
# 477 v1:  {'үҙгәрҙе,'} v2:  {'', 'танымаҫлыҡ'} 0.0
# 478 v1:  {'доллары'} v2:  {''} 0.0
# 479 v1:  {'сығымдарҙы'} v2:  {'артыҡ дәртләндереүсе', 'дәртләндереүсе', 'килтерҙе'} 0.0
# 480 v1:  {'Ғәмәлдәре'} v2:  {'', 'ҡыуаныслы', 'уйлаған аңлатты'} 0.0
# 481 v1:  {'улар'} v2:  {'', 'алған', 'йөкләмәләрен', 'башлаясаҡ'} 0.0
# 482 v1:  {'дошмандан'} v2:  {'ышандыра', '', 'һаҡланыу', 'алһа'} 0.0
# 483 v1:  {'иғлан'} v2:  {'үтмәне', 'иғлан иткәнсә'} 0.0
# 484 v1:  {'1'} v2:  {'', 'Параллель', 'эшләүен', 'файҙаланып', 'Йылытыу һыуытыу'} 0.0
# 485 v1:  {'айырыла.'} v2:  {''} 0.0
# 486 v1:  {'килтерҙе.'} v2:  {'килтерҙе'} 0.0
# 487 v1:  {'тура'} v2:  {'килгән'} 0.0
# 488 v1:  {'институционализация'} v2:  {'талап итә'} 0.0
# 489 v1:  {'валюта'} v2:  {'еңеләйтеү', 'алмашты'} 0.0
# 490 v1:  {'сағылдырмай.'} v2:  {''} 0.0
# 491 v1:  {'сауҙаһын'} v2:  {'зыян килтерә боҙоп', 'ҡулланыусыларына', 'зыян'} 0.0
# 492 v1:  {'иҫбатлау', 'аутсорсинг'} v2:  {'', 'тыуған итәсәк тултырырға', 'мөмкинлек бирәсәк', 'ҡарамаҫтан', 'эшләүен', 'түләүселәр йылытыу', 'итеүенсә'} 0.0
# 493 v1:  {'килтерә.'} v2:  {'килтерә'} 0.0
# 494 v1:  {'йүнәлештә'} v2:  {'тора', 'һайлау алды алып'} 0.0
# 495 v1:  {'ҡулланыу'} v2:  {'', 'булдырыла итеп', 'булдырыла'} 0.0
# 496 v1:  {'дауам'} v2:  {'', 'арттырыу', 'Ҡыҫҡартылған арттырыу'} 0.0
# 497 v1:  {'бәхәстәр'} v2:  {'булдыра', '', 'ҡамасаулай булдыра', 'булдыра етәкләгән билдәләй'} 0.0
# 498 v1:  {'оноторға'} v2:  {''} 0.0
# 499 v1:  {'сығыш'} v2:  {'', 'продукцияның'} 0.0
# 500 v1:  {'бүлмәһә,'} v2:  {'', 'булмаҫ', 'реформалаштырыуға', 'башлағас'} 0.0
# 501 v1:  {'иһә'} v2:  {'эшләй', '', 'алмай уңында'} 0.0
# 502 v1:  {'кимәлдә'} v2:  {'булмаған', 'ағып киткәнлектән'} 0.0
# 503 v1:  {'тип'} v2:  {'', 'тәғәйенләп тарта', 'прокурор тәғәйенләп тикшереүҙән', 'тәғәйенләп', 'прокурор'} 0.0
# 504 v1:  {'күрергә'} v2:  {'менән иҫәптән', 'күрергә', 'әйткәндә һайланған'} 1.0
# 505 v1:  {'тигеҙһеҙлеккә'} v2:  {'', 'тейеш килтерҙе', 'танырға', 'килтерҙе'} 0.0
# 506 v1:  {'тәҡдим'} v2:  {''} 0.0
# 507 v1:  {'һөҙөмтәләр'} v2:  {'булған', 'көтә', 'үткәрелгән'} 0.0
# 508 v1:  {''} v2:  {'', 'һөйләй'} 1.0
# 509 v1:  {'көтөлә.'} v2:  {'көтөлә'} 0.0
# 510 v1:  {'ул'} v2:  {'', 'алмаҫ', 'күрмәне', 'эшләй', 'теләгән'} 0.0
# 511 v1:  {'ярҙам'} v2:  {''} 0.0
# 512 v1:  {'дөрөҫ'} v2:  {'', 'тейеш', 'итергә биреү', 'аңлай', 'талап иткән', 'булмауын', 'үлтереүҙең'} 0.0
# 513 v1:  {'булышлыҡ'} v2:  {'бирелгәнлеге', 'сағыла өҫтәйәсәк'} 0.0
# 514 v1:  {'-'} v2:  {'', 'increase артыуы', 'буласаҡ', 'expanded артыуы'} 0.0
# 515 v1:  {'сәйәси'} v2:  {'', 'аңлата', 'ашырыу'} 0.0
# 516 v1:  {'тикшереүгә'} v2:  {'раҫлау', 'мохтаж талап', 'мохтаж'} 0.0
# 517 v1:  {'һайлаусыларҙың'} v2:  {'', 'яҡлаған', 'яҙылмаһа яҡлаған'} 0.0
# 518 v1:  {'көрәшергә'} v2:  {'', 'кәрәк', 'көрәшергә'} 1.0
# 519 v1:  {'таныу,'} v2:  {'танырға', 'булмаһын'} 0.0
# 520 v1:  {'идараһы'} v2:  {'', 'ала', 'киңәйтеп нығыта', 'киңәйтеп'} 0.0
# 521 v1:  {'яҡланған,'} v2:  {'', 'булыр'} 0.0
# 522 v1:  {'дә'} v2:  {'', 'белмәй', 'тыуҙырҙы'} 0.0
# 523 v1:  {'килтерә.'} v2:  {'', 'ҡалһа һаҡланһа түбәнәйһә', 'һаҡланһа килтерә', 'һаҡланһа түбәнәйһә килтерә'} 0.0
# 524 v1:  {'ҡаласаҡ.'} v2:  {''} 0.0
# 525 v1:  {'буйынса'} v2:  {'', 'ҡыйбатлана'} 0.0
# 526 v1:  {'дәрәжәһенә'} v2:  {''} 0.0
# 527 v1:  {'мәғлүмәттәр'} v2:  {'бирер'} 0.0
# 528 v1:  {'', 'өлөшөн'} v2:  {'', 'Башланған үҙгәртеп тамамлауға әҙерләгән ҡулланыуға индерелгән күҙәтелгән', 'тамамлауға әҙерләгән индерелгән күҙәтелгән', 'әйләнде әҙерләгән өлгәшелде', 'Башланған', 'өлөшөн әйләнде әҙерләгән өлгәшелде', 'булмаған'} 1.0
# 529 v1:  {'туҡтатып,'} v2:  {'', 'нығытып', 'иҫкергән алған менән', 'ебәреп иҫкергән', 'promoting', 'promote туҡтатып', 'нығытып туҡтатып'} 0.0
# 530 v1:  {'доллар'} v2:  {'экономиялай'} 0.0
# 531 v1:  {'йыймауын'} v2:  {'', 'иҫәпкә'} 0.0
# 532 v1:  {'күрһәтте.'} v2:  {'', 'күрһәтте'} 0.0
# 533 v1:  {'ҡытай'} v2:  {'эшләй', ''} 0.0
# 534 v1:  {'насарайыуын'} v2:  {'', 'аңлатыу', 'яҙырға', 'ине'} 0.0
# 535 v1:  {'реструктуризациялауға'} v2:  {'', 'була', 'әҙерләгәндә бирә'} 0.0
# 536 v1:  {'ҡаса'} v2:  {'', 'алды'} 0.0
# 537 v1:  {'биргән'} v2:  {'', 'менән биргән', 'биргән'} 1.0
# 538 v1:  {'сәскә'} v2:  {'', 'теләгән'} 0.0
# 539 v1:  {'эләгә.'} v2:  {''} 0.0
# 540 v1:  {'булып'} v2:  {'', 'бәйле', 'көрсөгө күрһәткән', 'булып'} 1.0
# 541 v1:  {'сәйәсәтен'} v2:  {'яңыртырға', ''} 0.0
# 542 v1:  {'штраф'} v2:  {'ҡаршы файҙаланыуы', 'була', 'штраф'} 1.0
# 543 v1:  {'ЭШЛӘРГӘ'} v2:  {'Был', '', 'саҡырыу пауза'} 0.0
# 544 v1:  {'нығытырға'} v2:  {'', 'өйрәнергә', 'нығытырға'} 1.0
# 545 v1:  {'хужалығына'} v2:  {'', 'буласаҡ'} 0.0
# 546 v1:  {'үҙгәртелмәһә'} v2:  {'артыуы', ''} 0.0
# 547 v1:  {'булып'} v2:  {'булып'} 1.0
# 548 v1:  {'ҡайтырға'} v2:  {'', 'ҡайтырға', 'теләй'} 1.0
# 549 v1:  {'', 'иғлан'} v2:  {'', 'итә'} 1.0
# 550 v1:  {'ҡулға'} v2:  {''} 0.0
# 551 v1:  {'булып'} v2:  {'булып'} 1.0
# 552 v1:  {'ныҡ'} v2:  {'', 'сәйәсмәндәр', 'эшләмәһәләр биреләсәк'} 0.0
# 553 v1:  {'', 'үҙгәреүенә'} v2:  {'', 'булып'} 1.0
# 554 v1:  {'ҡулланыла'} v2:  {'', 'бар', 'ҡулланыла', 'булмаған'} 1.0
# 555 v1:  {'үткәреп,'} v2:  {'үткәреп', 'кампанияны үткәреп'} 0.0
# 556 v1:  {'үтергә'} v2:  {'үткәрелгәйне ине', 'үтергә'} 1.0
# 557 v1:  {'вазифаға'} v2:  {'итеп һайлана'} 0.0
# 558 v1:  {'мөрәжәғәт'} v2:  {'', 'һорап итергә', 'мәжбүр'} 0.0
# 559 v1:  {'туплай'} v2:  {'', 'туплай', 'Артабанғы', 'башлай'} 1.0
# 560 v1:  {'үткәрергә'} v2:  {'араһында параллель үткәрергә'} 0.0
# 561 v1:  {'миссияһын'} v2:  {''} 0.0
# 562 v1:  {'вазифаға'} v2:  {'', 'етәкселегендәге яллай', 'яллай'} 0.0
# 563 v1:  {'өҫтәмә'} v2:  {'', 'финанслау алыусы', 'транспарентлыҡ үтәргә алыусы'} 0.0
# 564 v1:  {'еңел'} v2:  {'бирә', 'арттырыу'} 0.0
# 565 v1:  {'эш'} v2:  {'күләмен тип', 'билдәләнгән', 'арттырыр'} 0.0
# 566 v1:  {'тотоуҙы'} v2:  {'', 'арттырыуға'} 0.0
# 567 v1:  {''} v2:  {'бар', 'теләгенә таянып', 'башлаясаҡ', ''} 1.0
# 568 v1:  {''} v2:  {'атаған'} 0.0
# 569 v1:  {'асырға'} v2:  {'асырға'} 1.0
# 570 v1:  {'нығыта.'} v2:  {'', 'тәғәйенләнгәндән нығыта'} 0.0
# 571 v1:  {'булыуын'} v2:  set() nan
# 572 v1:  {'араһында'} v2:  {''} 0.0
# 573 v1:  {''} v2:  {'булып', 'баҫылған күрһәтелгән'} 0.0
# 574 v1:  {'урынды'} v2:  {'', 'кәметте белдерҙе'} 0.0
# 575 v1:  {'тора,'} v2:  {''} 0.0

# %%
print((res_2_models_ba['preds_kk_new'] == 1).sum() / res_2_models_ba.shape[0])
# Out:
# 0.13020833333333334

# %%
print((res_2_models_ba['preds_kk'] == 1).sum() / res_2_models_ba.shape[0])
# Out:
# 0.4340277777777778

# %%
arguments1 = ast.literal_eval(res_2_models_ba.loc[0, 'srl_ba'])['verbs'][0]['description']
args1 = set()
for key, value in arguments1.items():
    if key != 'V':
        args1.add(value)
print(args1)
# Out:
# {'донъяны', 'кемдәр'}

# %%
arguments2 = ast.literal_eval(res_2_models_ba.loc[0, 'result_srl_kk'])['verbs'][0]['description']
args2 = set()
for key, value in arguments2.items():
    if key != 'V':
        args2.add(value)
print(args2)
# Out:
# {'Шуға', 'кемдәр улар яҡшы етешһеҙлектәрҙе күрә күренеш донъяны бик һәм', 'мин уйланым'}

# %%
if len(args1.intersection(args2)) != 0:
    print('ok')

# %%
for i in range(len(res_2_models_ba)):
    try:
        verb1 = set()
        for j in range(len(ast.literal_eval(res_2_models_ba.loc[i, 'srl_ba'])['verbs'])):
            verb1.add(ast.literal_eval(res_2_models_ba.loc[i, 'srl_ba'])['verbs'][j]['verb'])
        verb2 = set()
        for j in range(len(ast.literal_eval(res_2_models_ba.loc[i, 'result_srl_kk'])['verbs'])):
            verb2.add(ast.literal_eval(res_2_models_ba.loc[i, 'result_srl_kk'])['verbs'][j]['verb'])
        if (verb1 in verb2) & (verb1 != ""):
            res_2_models_ba.loc[i, 'preds_kk_new'] = 1
        else:
            res_2_models_ba.loc[i, 'preds_kk_new'] = 0
        
        arguments1 = ast.literal_eval(res_2_models_ba.loc[i, 'srl_ba'])['verbs'][0]['description']
        args1 = set()
        for key, value in arguments1.items():
            if key != 'V':
                args1.add(value)
        
        args2 = set()
        
        for j in range(len(ast.literal_eval(res_2_models_ba.loc[i, 'result_srl_kk'])['verbs'])):
            arguments2 = ast.literal_eval(res_2_models_ba.loc[i, 'result_srl_kk'])['verbs'][j]['description']
            for key, value in arguments2.items():
                if key != 'V':
                    args2.add(value)
        if len(args1.intersection(args2)) != 0:
            res_2_models_ba.loc[i, 'preds_kk_args'] = 1
        else:
            res_2_models_ba.loc[i, 'preds_kk_args'] = 0
    except:
        pass
    print(i, 'v1: ', verb1, 'v2: ', verb2, res_2_models_ba.loc[i, 'preds_kk_new'], 'args1: ', args1,
          'args2: ', args2, res_2_models_ba.loc[i, 'preds_kk_args'])
# Out:
# 0 v1:  {'күрә'} v2:  {'', 'күрә күренеш'} 0.0 args1:  {'донъяны', 'кемдәр'} args2:  {'мин уйланым', 'улар яҡшы етешһеҙлектәрҙе кемдәр күрә күренеш донъяны бик һәм', 'кемдәр улар яҡшы етешһеҙлектәрҙе күрә күренеш донъяны бик һәм', 'кемдәр', 'улар яҡшы етешһеҙлектәрҙе кемдәр', 'бик яҡшы', 'Шуға', 'донъяны'} 1.0
# 1 v1:  {'торғанда'} v2:  {''} 0.0 args1:  {'проценты', 'торошта.', 'өлөшө', 'мәғлүмәттәренә'} args2:  {'', 'күпселек', 'кешеләрҙең илдең', 'булған', 'күпселек түбән проценты', 'итһәң', 'Әммә', 'проценты кешеләрҙең'} 0.0
# 2 v1:  {'билдәһеҙ'} v2:  {'', 'булыр'} 0.0 args1:  {'-'} args2:  {'эҙемтәләре', '', 'улар', 'Трамп', 'былар барыһы', 'уңышлы', 'Ниндәй ниндәй', 'Ниндәй ниндәй эҙемтәләре', 'булыр'} 0.0
# 3 v1:  {'ҡайта'} v2:  {'', 'ала'} 0.0 args1:  {'балансҡа'} args2:  {'Был', 'балансҡа', 'ала', ''} 1.0
# 4 v1:  {'килтерәсәк,'} v2:  {'', 'артабан артыуына'} 0.0 args1:  {'ҡотолғоһоҙ'} args2:  {'', 'дефицитының', 'артабан күпкә артыуына', 'Был был', 'килтерәсәк', 'күпкә юғары артабан артыуына норманан', 'артабан күпкә артыуына килтерәсәк дефицитының юғары норманан', 'артабан килтерәсәк'} 0.0
# 5 v1:  {'барлыҡҡа'} v2:  {'', 'булып'} 0.0 args1:  {'проблемаһы', 'яҡлы'} args2:  {'илдәргә бүлә һәм ҡытай Мексика килә барлыҡҡа булып иғтибар проблемаһы дефициты', '', 'Ул', 'айырым', 'илдәргә бүлә һәм ҡытай Мексика', 'булып иғтибар проблемаһы дефициты', 'килә', 'иғтибар проблемаһы дефициты'} 0.0
# 6 v1:  {'йәки'} v2:  {'', 'алынған', 'төҙөлгән алынған'} 0.0 args1:  {'фаразды'} args2:  {'', 'иҡтисади советниктары энергетик сәйәсәт питер Наварро Һәм һәм йәки Уилбур', 'был сәйәсәт', 'меморандумда позицияларын тураһындағы улар', 'түгел алмай', 'тураһындағы позицияларын ҡырҡа дефицитының Америка сауҙа', 'позицияларын дефицитының', 'меморандумда позицияларын тураһындағы улар төҙөлгән алынған', 'был түгел алмай позицияларын дефицитының реформаларҙан энергетик һөҙөмтәһендә Һәм һәм йәки алынған тураһындағы ҡырҡа Америка сауҙа', 'был', 'позицияларын дефицитының реформаларҙан энергетик һөҙөмтәһендә Һәм һәм йәки алынған тураһындағы ҡырҡа Америка сауҙа'} 0.0
# 7 v1:  {'туплана.'} v2:  {'ҡарала туплана', 'күренеш'} 0.0 args1:  {'сәйәсәттәр'} args2:  {'Инфляция', 'хроник', 'policy тип', 'менән һәм policy тип'} 0.0
# 8 v1:  {'кәмеүе'} v2:  {'', 'күрһәтелеүенсә'} 0.0 args1:  {'илдә'} args2:  {'', 'һайын теркәлмәгән йыл', 'күрһәтелеүенсә', 'бер һайын илдә', 'араһында күрһәтелеүенсә алдынғы һәм'} 0.0
# 9 v1:  {'кәметте,'} v2:  {'', 'була', 'йөкләмәләрҙе', 'Артабанғы һуңғы'} 0.0 args1:  {'инфляция', 'йөкләмәләрҙе'} args2:  {'', 'дефляция инфляция', 'тип дефляция инфляция була йөкләмәләрҙе үлсәмдәр', 'күп үҙәк банктар', 'Артабанғы һуңғы', 'юғары', 'дефляция үлсәмдәр инфляция йөкләмәләрҙе'} 0.0
# 10 v1:  {'был'} v2:  {'килемлелеген', '', 'булмай', 'булып'} 0.0 args1:  {'йыл', 'ла,', 'ҙур'} args2:  {'', 'килемлелеген кимәленән йылы йылдан йәһәттән', 'япония', 'дефляцияның инфляция артмаһа түгеллеген булмай килемлелеген тиҫтә ун күңелһеҙ билдәләү йылы йылдан йәһәттән', 'дефляцияның инфляция', 'булып был', 'тиҫтә ун күңелһеҙ билдәләү йылы йылдан йәһәттән', 'артмаһа түгеллеген булмай', 'күңелһеҙ нервничаться был', 'ун йылы йылдан йәһәттән киң килемлелеген кимәленән', 'килемлелеген', 'торһа булып ун йылы йылдан йәһәттән киң килемлелеген кимәленән', 'банктарҙың', 'банктарҙың артмаһа түгеллеген булмай күңелһеҙ нервничаться был дефляцияның инфляция килемлелеген тиҫтә ун билдәләү йылы йылдан йәһәттән япония булып', 'киң'} 0.0
# 11 v1:  {'Болсонару'} v2:  {'', 'араһында таяна'} 0.0 args1:  {'Жаир'} args2:  {'Хәҙерге йәш', 'Жаир Болсонару', 'марин Ле һайлаусыларға парады фронт Франциялағы Һәм Жаир Болсонару араһында таяна Хәҙерге йәш', 'араһында Хәҙерге популярсылар'} 0.0
# 12 v1:  {''} v2:  {'', 'башланы'} 0.0 args1:  {'арҡаһында', 'пенсионерҙар'} args2:  {'', 'пенсионерҙар', 'Ул', 'арҡаһында Ул хәҙер пенсионерҙар башланы балалары', 'арҡаһында Ул хәҙер', 'балалары', 'хәҙер'} 1.0
# 13 v1:  {'төҙөү'} v2:  {'төҙөү', 'юҡ'} 0.0 args1:  {'ҡойма'} args2:  {'менән араһында төҙөү тәҡдименән ОШО мексика', 'юҡ символ араһында ОШО менән тәҡдименән аныҡ сәбәпле төҙөү мексика', 'сәбәпле'} 0.0
# 14 v1:  {'самаһы'} v2:  {'', 'инвестициялап', 'була', 'һатып алып'} 0.0 args1:  {'аҡш', 'милеккә', 'уларҙа'} args2:  {'', 'утыҙ йыл', 'кешеләре була әҙер инвестициялап милеккә аҡса һатып алып аҡш акцияларын облигацияларын тота уларҙа', 'инвестициялап һатып алып аҡш акцияларын облигацияларын тота кешеләре уларҙа', 'әҙер инвестициялап милеккә аҡса һатып алып аҡш акцияларын облигацияларын тота кешеләре уларҙа', 'милеккә аҡса', 'уларҙа', 'кешеләре', 'аҡш акцияларын облигацияларын тота кешеләре инвестициялап', 'дефицитын'} 1.0
# 15 v1:  {'хаҡтар'} v2:  {''} 0.0 args1:  {'экспорты'} args2:  {'', 'экспорты импортҡа', 'ҺУҢ АҠШ экспорты импортҡа'} 0.0
# 16 v1:  {'күберәк'} v2:  {'', 'алыу', 'импорттан алыу'} 0.0 args1:  {'уҡ', 'хаҡы', 'уның'} args2:  {'', 'уның хаҡы араһында импорттан продукттың ҡулланыусылар', 'элеккесә кәмей ла ошондай физик Милли продукттың', 'уларға', 'күберәк', 'алыу ошондай импорттан', 'ла ошондай', 'ошондай уларға тура киләсәк импорттан алыу күберәк', 'импорттан', 'ошондай', 'ла ошондай физик Милли продукттың'} 0.0
# 17 v1:  {'', 'йөкләмәләрен'} v2:  {'', 'булыуы'} 0.0 args1:  {'сигенән', 'үҙ'} args2:  {'Был', '', 'һауа температураһының', 'ике', 'махсус диалог 2020 һәм дәүләттәрҙе үҙ йөкләмәләрҙең температураһының йөкләмәләрен', '2020', 'махсус диалог', 'бәйле ниәтләй ағымдағы йөкләмәләрҙең температураһының йөкләмәләрен булыуы түбәнерәк сигенән Париж һауа ике махсус диалог 2020 һәм дәүләттәрҙе үҙ', 'дәүләттәрҙе', 'түбәнерәк сигенән Париж һауа температураһының ике', 'үҙ йөкләмәләрҙең температураһының йөкләмәләрен', 'ағымдағы йөкләмәләрҙең температураһының йөкләмәләрен'} 0.0
# 18 v1:  {'юғарыраҡ'} v2:  {'', 'алырға', 'инвестицияларға', 'белдереүенсә', 'мәжбүр', 'етәкселегендәге мәжбүр'} 0.0 args1:  {'валютаны', 'иҡтисадсылары', 'илдәрҙә'} args2:  {'отчеттар доллар валютаны валюталарға', 'ставкалы юғарыраҡ процент ставкалары', 'финанс Банкының иҡтисадсылары илдәрҙә баҙарҙары валюталарға', 'уны', 'валюталарға инвестицияларға отчеттар доллар валютаны', 'НьюЙорк Лондон', 'Халыҡара илдәрҙә', 'белдереүенсә юғарыраҡ процент ставкалары ставкалы доллар валюталарға инвестицияларға Халыҡара илдәрҙә мәжбүр финанс Банкының иҡтисадсылары баҙарҙары етәкселегендәге НьюЙорк Лондон алырға отчеттар валютаны уны', 'Хен Шин башҡа иҡтисадсылары финанс Банкының Халыҡара отчеттар', 'финанс Банкының иҡтисадсылары илдәрҙә баҙарҙары валюталарға етәкселегендәге мәжбүр НьюЙорк Лондон', 'юғарыраҡ процент ставкалары ставкалы доллар валюталарға инвестицияларға Халыҡара илдәрҙә', 'алырға отчеттар доллар валютаны валюталарға ставкалы юғарыраҡ процент ставкалары инвестицияларға уны'} 0.0
# 19 v1:  {'хәле'} v2:  {''} 0.0 args1:  {'финанс'} args2:  {'Традицион', 'капитал финанс ағымына', 'төшөнсәгә ярашлы һәм яһай капитал', 'тигеҙһеҙлек алмашыу'} 0.0
# 20 v1:  {'финанслау'} v2:  {'булдырыуҙы', 'менән булдырыуҙы', 'булдырыуҙы индерелде'} 0.0 args1:  {'күҙ', '(ОПИК)', 'үҫеш'} args2:  {'', 'менән шөғөлләнәсәк учреждение булдырыуҙы яңы уңында шәхси инвестициялар корпорацияһы маҡсатында финанслау', 'учреждение ПекинҠушма Штаттарҙа', 'закон', 'учреждение шәхси инвестициялар корпорацияһы', 'булдырыуҙы менән шөғөлләнәсәк учреждение яңы уңында шәхси инвестициялар корпорацияһы маҡсатында финанслау', 'менән', 'маҡсатында менән инвестициялар финанслау шөғөлләнәсәк булдырыуҙы'} 0.0
# 21 v1:  {'араһында', '35'} v2:  {'ашырыу арттырырға', 'Берләшкән ашырыу', 'ашырыу киңәйтә', 'ашырыу арттырырға киңәйтә', 'йөкләмә'} 0.0 args1:  {'секторҙа', 'финанслау', 'үҫеш'} args2:  {'ИНФРАСТРУКТУРАҒА финанслау Ойошмаһының банктары инвесторҙарға өлкәһендә араһында спектрын башҡа һәм мөһим уларҙың шәхси секторҙа БДБла БРК', 'Берләшкән ашырыу спектрын Ойошмаһының Тотороҡло өс', 'спектрын ярҙам ашырыу арттырырға инструменттары инвесторҙарға шәхси инвестицияларға башҡа араһында мөһим', 'спектрын өлкәһендә ИНФРАСТРУКТУРАҒА БРК', 'спектрын Ойошмаһының Тотороҡло Берләшкән ашырыу өс', 'спектрын алдағы өс йылда', 'маҡсаттарын инвестицияларға инвесторҙарға', 'ашырыу киңәйтә маҡсаттарын инвестицияларға инвесторҙарға', 'шәхси секторҙа финанслау инвестицияларға', 'процентҡа'} 0.0
# 22 v1:  {'көтөргә'} v2:  {'', 'көтөргә', 'талап ителә'} 0.0 args1:  {'емештәрен'} args2:  {'', 'илдәрҙә инфраструктураға инвестицияларҙың', 'көтөргә хәүефтәр инфраструктураға', 'башланғыс осорҙа', 'оҙағыраҡ әҙер', 'көтөргә арттырыу тыныс капиталын инфраструктураға инвестицияларҙың инвесторҙарҙың әҙер ошондай хәүефтәр емештәрен башланғыс осорҙа һәм оҙағыраҡ', 'инфраструктураға инвестициялар инвестицияларҙың инвесторҙарҙың', 'әҙер көтөргә ошондай хәүефтәр емештәрен башланғыс осорҙа һәм оҙағыраҡ инфраструктураға', 'тыныс капиталын инфраструктураға инвестицияларҙың инвесторҙарҙың әҙер көтөргә ошондай хәүефтәр емештәрен башланғыс осорҙа һәм оҙағыраҡ', 'ошондай хәүефтәр емештәрен', 'инвестицияларҙың инвесторҙарҙың'} 0.0
# 23 v1:  {'буйһонорға'} v2:  {'тырыша', 'сәйәсәткә'} 0.0 args1:  {'банкы'} args2:  {'сәйәсәткә', 'тырыша сәйәсәткә', 'банкы Банкы Англия үҙәк Европа'} 0.0
# 24 v1:  {'аса.'} v2:  {'аса'} 0.0 args1:  {'юл'} args2:  {'', 'ағымдағы юл инфляцияның', 'ағымдағы уның'} 0.0
# 25 v1:  {'позицияны'} v2:  {'Был', 'нығытырға'} 0.0 args1:  {'был'} args2:  {'Евросоюз ағзалары', 'тейеш', 'Был шуға', 'бик', 'был'} 1.0
# 26 v1:  {'алмаштырырға'} v2:  {'', 'алмаштырырға', 'әҙерләүселәрҙең алмаштырырға'} 0.0 args1:  {'долларҙы'} args2:  {'арзан мөһимерәк', 'Программаларҙы', 'долларҙы', 'алмаштырырға әҙерләүселәрҙең механизмына арзан һәм мөһимерәк түләү арҡаһында долларҙы биткойнды', 'механизмына арзан һәм мөһимерәк алмаштырырға түләү'} 1.0
# 27 v1:  {'операциялар'} v2:  {'', 'башҡарырға'} 0.0 args1:  {'Хөкүмәттең'} args2:  {'', 'Хөкүмәттең башҡарырға виртуаль аноним операциялар менән валюталар', 'Хөкүмәттең', 'виртуаль аноним операциялар менән валюталар'} 1.0
# 28 v1:  {'мәғлүмәт'} v2:  {'', 'белдереүенсә', 'мәжбүр', 'контролдә'} 0.0 args1:  {'Хөкүмәт', 'биржалары', 'тураһында'} args2:  {'', 'белдереүенсә тураһында эшмәкәрлеген хужалары биржалары', 'биткойн биржалары', 'белдереүенсә биткойн биржалары контролдә ҡәтғи мәғлүмәт эшмәкәрлеген һәм буласаҡ мәжбүр тураһында хужалары', 'Хөкүмәт', 'ҡәтғи мәғлүмәт эшмәкәрлеген'} 1.0
# 29 v1:  {'сығарып,'} v2:  {'', 'кәрәклеген', 'сығарып үҙгәртеү', 'аңлау', 'үҙгәртеү'} 0.0 args1:  {'валютаһын', 'файҙаһына'} args2:  {'', 'уларға', 'һанлы банктарға аңлау ниндәй валютаһын уларға кәрәклеген үҙгәртеү файҙаһына сығарып', 'банктарға сығарып үҙгәртеү', 'ниндәй валютаһын уларға кәрәклеген үҙгәртеү һанлы файҙаһына банктарға сығарып', 'һанлы', 'һанлы банктарға', 'үҙгәртеү һанлы файҙаһына уларға кәрәклеген банктарға сығарып', 'Бынан', 'ниндәй валютаһын'} 0.0
# 30 v1:  {'пошлиналары'} v2:  {''} 0.0 args1:  {'таможня'} args2:  {'', 'НьюЙОРКяҡын', 'пошлиналары', 'НьюЙОРКяҡын көйләнә', 'НьюЙОРКяҡын ҡушма Штаттарҙа'} 0.0
# 31 v1:  {'пошлинаны'} v2:  {'контролдә', 'ҡарай', 'сығарыу итеп ҡарай'} 0.0 args1:  {'америка', 'тотҡан', 'ваҡытта'} args2:  {'', 'ваҡытта башҡарма контролдә закондар корпоратив', 'был партияһы реформаһының', 'мөһим элементы реформаһының корпоратив һалым штрафтар', 'компанияларына америка', 'закондар корпоратив', 'ваҡытта башҡарма', 'штрафтар экспортерҙарына субсидиялар компанияларына америка'} 0.0
# 32 v1:  {'килтерәсәк.'} v2:  {'Хәбәр', 'килтерәсәк'} 0.0 args1:  {'яҡшыртыуға', 'БЫЛ'} args2:  {'килтерәсәк', 'арттырып яҡшыртыуға мәшғүллекте инвестицияларҙы һәм', 'арттырып яҡшыртыуға АҠШтың мәшғүллекте балансын', 'ителеүенсә БЫЛ килтерәсәк арттырып яҡшыртыуға АҠШтың мәшғүллекте балансын инвестицияларҙы һәм', 'БЫЛ'} 1.0
# 33 v1:  {'яҡлай'} v2:  {'', 'яҡлай'} 0.0 args1:  {'насарыраҡ,', 'конкуренцияһынан', 'фирмаларын'} args2:  {'', 'КБД', 'конкуренцияһынан', 'америка фирмаларын'} 1.0
# 34 v1:  {'күберәк'} v2:  {'килтерә', 'КҮРҺӘТЕҮЕНСӘ'} 0.0 args1:  {'аҡш-та', 'һалым'} args2:  {'бер яңы', 'бер', 'КҮРҺӘТЕҮЕНСӘ беренсе йылында яңы ала килтерә инфляцияға йәки', 'ала', 'инфляцияға йәки', 'беренсе йылында'} 0.0
# 35 v1:  {'сығымдарға'} v2:  {'һөҙөмтәлелеген максималләштереүҙә ҡаҡшатыр килтерер', 'килтерер', 'булып', 'ҡаҡшатыр килтерер'} 0.0 args1:  {'мәҙәни', 'потенциалын'} args2:  {'', 'социаль һәм капитал максималләштереүҙә донъя БЫЛ', 'донъя һөҙөмтәлелеген компанияларҙың һәм', 'ҡаҡшатыр килтерер донъя потенциалын компанияларҙың һөҙөмтәлелеген максималләштереүҙә хеҙмәт һәм социаль капитал БЫЛ', 'донъя хеҙмәт һөҙөмтәлелеген компанияларҙың һәм', 'донъя потенциалын компанияларҙың һөҙөмтәлелеген максималләштереүҙә ҡаҡшатыр килтерер хеҙмәт һәм социаль капитал БЫЛ', 'һөҙөмтәлелеген ҡаҡшатыр килтерер мотивацияһы компанияларҙың Оффшорҙың', 'компанияларҙың'} 0.0
# 36 v1:  {'кәметергә'} v2:  {'', 'кире', 'тырышырға', 'иҡтисады билдәһеҙлектең'} 0.0 args1:  {'йоғонтоһон'} args2:  {'', 'британия бизнес', 'тырышырға билдәһеҙлектең менән нисек', 'билдәһеҙлектең', 'Әгәр британия бизнес иҡтисады билдәһеҙлектең нисек тырышырға кире', 'хөкүмәт билдәһеҙлектең менән бизнес', 'тейеш', 'менән нисек', 'нисек', 'нисек тырышырға кире'} 0.0
# 37 v1:  {'теләмәй.'} v2:  {'', 'һайлаһа етәкләмәйенсә', 'булырға', 'теләмәй'} 0.0 args1:  {'урынында', 'аҙсылыҡты', 'бер'} args2:  {'', 'Әгәр мэй һайлаһа етәкләмәйенсә бындай', 'ала етәкләмәйенсә бер', 'урынында уның', 'ул', 'бер', 'етәкләмәйенсә бер', 'бындай', 'мэй бер кем теләмәй', 'мэй', 'етәкләмәйенсә мэй бер кем теләмәй булырға урынында уның', 'булырға урынында уның'} 1.0
# 38 v1:  {'хоҡуҡтарын'} v2:  {'', 'сығырҙан БЕРЛЕГЕНЕҢ', 'теләй', 'һаҡлап'} 0.0 args1:  {'БЕРЛЕГЕНЕҢ', 'күсеү', 'британия', 'Берләшкән', 'бюджетына'} args2:  {'', 'үҙ бюджетына ЕВРОПА', 'ағзалыҡҡа', 'үҙ коммерция хәҙер хоҡуҡтарын ҡарарҙары ЕВРОПА', 'йөрөүен', 'ЕВРОПА акттары ҡарарҙары һәм ирекле', 'алда хәҙер сығырҙан БЕРЛЕГЕНЕҢ ЕВРОПА', 'ЕВРОПА', 'британия хөкүмәте', 'британия хөкүмәте Короллек', 'хәҙер теләй Берләшкән британия хөкүмәте Короллек һаҡлап үҙ коммерция хоҡуҡтарын ҡарарҙары ЕВРОПА БЕРЛЕГЕНДӘ һәм шулай бюджетына акттары ирекле йөрөүен'} 0.0
# 39 v1:  {'тамамланмауы'} v2:  {''} 0.0 args1:  {'уның', 'оҙайтыу'} args2:  {'', 'әгәр бер оҙайтыу ителһә', 'бер оҙайтыу', 'әгәр', 'ихтимал'} 0.0
# 40 v1:  {'әҙерләнгән'} v2:  {'Евросоюзға инеүгә', 'әҙерләнгән әҙерләнә', 'инеүгә әҙерләнгән әҙерләнә'} 0.0 args1:  {'структура'} args2:  {'', 'Евросоюзға', 'ЕЭК Евросоюзға', 'булараҡ төрлө ваҡытлыса структура БАШТА илдәр инеүгә әҙерләнгән әҙерләнә Евросоюзға', 'БАШТА илдәр', 'инеүгә Евросоюзға'} 0.0
# 41 v1:  {'айырылып'} v2:  {''} 0.0 args1:  {'европа', 'моделенән'} args2:  {'', 'Ике ике Европа европа', 'бик айырылып моделенән кимәлле тиҙлекле европа'} 0.0
# 42 v1:  {'яғынан'} v2:  {'', 'осраша'} 0.0 args1:  {'менән'} args2:  {'', 'ике БЕРЛӘШМӘҺЕ норматив бюрократик', 'халыҡара менән ваҡытта яғынан', 'Улар', 'бюрократик компаниялар менән яғынан һәм', 'Британиялағы компаниялар'} 0.0
# 43 v1:  {'тураһында'} v2:  {'', 'итеүгә итергә', 'килә'} 0.0 args1:  {'итеүгә'} args2:  {'Тәрән структура проблемаларын', 'өмөт Мэй Тәрән структура проблемаларын', 'хөкүмәттең', 'стратегияһын сәнәғәт итергә', 'тураһында менән етәкселегендәге Мэй ниәтләүе хөкүмәттең килә алды итеүгә итергә стратегияһын сәнәғәт', 'алды'} 0.0
# 44 v1:  {'хаҡы'} v2:  {'күрһәткестәренә', 'нигеҙләнгән итә', 'алып', 'арттырыуға'} 0.0 args1:  {'кеүек'} args2:  {'', 'файҙаһын ҡыҫҡартыуға нигеҙләнгән кәмселекле тәшкил алып арттырыуға инвестицияларҙы лондонға йәки Төньяҡ Бөйөк', 'файҙаһын ҡыҫҡартыуға нигеҙләнгән кәмселекле тәшкил', 'Анализлауҙы проекттарының потенциаль хаҡтар сығымдарын йәки файҙаһын инфраструктура күрһәткестәренә милеккә ставкаһы нигеҙләнгән баҙар инвестицияларҙы', 'инвестицияларҙы', 'алып арттырыуға инвестицияларҙы лондонға йәки Төньяҡ Бөйөк', 'күрһәткестәренә милеккә инфраструктура ставкаһы проекттарының сығымдарын йәки нигеҙләнгән баҙар инвестицияларҙы', 'Анализлауҙы проекттарының потенциаль хаҡтар сығымдарын йәки файҙаһын инфраструктура'} 0.0
# 45 v1:  {''} v2:  {'', 'түләргә'} 0.0 args1:  {'килеме.', 'уларҙы'} args2:  {'', 'уларҙы', 'һуңынан', 'Ул', 'һуңынан түләргә', 'банкы'} 1.0
# 46 v1:  {'баһалай'} v2:  {'', 'продукцияһын етештереү', 'мохтаж', 'ала баһалай', 'алмай', 'алмаҫ алмай', 'яңы'} 0.0 args1:  {'кредит', 'етештереү', 'ул', 'банктар', 'хәүефен'} args2:  {'', 'алмаҫ алмай ала баһалай', 'капиталға ала алмаҫ алмай продукцияһын етештереү яңы химия продукттарҙың заводында', 'сөнки', 'продукттарҙың хәүефен инновацион продукцияһын', 'яңы химия продукцияһын продукттарҙың', 'алмай', 'алмаҫ алмай', 'алмаҫ алмай сөнки химия продукцияһын сәнәғәте сектор йәки яңы башҡа', 'химия продукцияһын сәнәғәте сектор йәки яңы башҡа', 'банктар алмаҫ алмай продукттарҙың хәүефен инновацион продукцияһын сөнки химия сәнәғәте сектор йәки яңы башҡа', 'капиталға', 'банктар', 'Әммә мохтаж капиталға ала алмаҫ алмай продукцияһын етештереү яңы химия продукттарҙың заводында', 'Әммә', 'заводында яңы'} 1.0
# 47 v1:  {'бизнесҡа'} v2:  {'', 'һатыуы'} 0.0 args1:  {'урта'} args2:  {'Был', '', 'һәм компаниялар бизнесҡа', 'һәм компаниялар бизнесҡа һатыуы', 'булмаған түгел', 'ҡатмарлы', 'Был ҡатмарлы һәм компаниялар бизнесҡа һатыуы', 'вариант'} 0.0
# 48 v1:  {'венчурлы', 'инновацион'} v2:  {'', 'ҡурҡып бирәсәк', 'структуралана'} 0.0 args1:  {'итә', 'был', 'бүлеү'} args2:  {'', 'Бындай финанслауҙан', 'ала мөмкинлек', 'ҡурҡып бирәсәк был фондтар фондтарҙы проекттарҙы хәүефле нығыраҡ яҡынайтырға инвесторҙар инвесторҙарҙы risks венчурлы финанслауҙан', 'ҡурҡып risks хәүефле венчурлы проекттар проекттарҙы финанслауҙан', 'нығыраҡ', 'инвесторҙар инвесторҙарҙы йәки хәүефле венчурлы инновацион проекттар проекттарҙы', 'араһында йәки проекттар проекттарҙы', 'risky проекттарҙы', 'был фондтар фондтарҙы проекттарҙы хәүефле нығыраҡ яҡынайтырға инвесторҙар инвесторҙарҙы ҡурҡып risks венчурлы финанслауҙан', 'структуралана risky проекттарҙы араһында йәки ҡурҡып бирәсәк был фондтар фондтарҙы хәүефле нығыраҡ яҡынайтырға инвесторҙар инвесторҙарҙы risks венчурлы финанслауҙан', 'инвесторҙар инвесторҙарҙы', 'Бындай фондтар фондтарҙы проекттарҙы', 'ҡурҡып нығыраҡ'} 0.0
# 49 v1:  {'һайлаған'} v2:  {'', 'күрә', 'һайлаған'} 0.0 args1:  {'юл', 'белгестәре,', 'улар'} args2:  {'улар', 'ҡарамаҫтан Дә Пауэлл да Йеллен', 'ҡарамаҫтан шуға күрә улар һайлаған яҡшы', 'яҡшы', 'тәжрибәле белгестәре системаһының яҡшы федераль резерв'} 1.0
# 50 v1:  {'вәкилдәрен'} v2:  {'', 'йәлеп', 'кәрәк', 'үткәрергә'} 0.0 args1:  {'индереү'} args2:  {'', 'аҡсакредит сәйәсәтен', 'Үҙәк яңы ҡатынҡыҙҙарҙы алымдар белгестәрҙе банктарға ҡараштар', 'үткәрергә аҡсакредит сәйәсәтен алымдар Үҙәк яңы ҡатынҡыҙҙарҙы белгестәрҙе банктарға ҡараштар йәлеп', 'яңы ҡараштар алымдар', 'Үҙәк банктарға', 'йәлеп яңы ҡараштар алымдар'} 0.0
# 51 v1:  {'шарапты'} v2:  {''} 0.0 args1:  {'беҙ', 'иҫке'} args2:  {'таныш', 'шарапты', 'беҙ эсәбеҙ', 'ҡарағанда', 'күҙлегенән ҡарағанда сәйәсәт һәм'} 0.0
# 52 v1:  {'тотонорға'} v2:  {'', 'яңыртылған етештереүгә булдырыласаҡ', 'аңлап'} 0.0 args1:  {'Ҡытай', 'доллар'} args2:  {'энергияның кәрәклеген Таҙа дә яңыртылған етештереүгә', '', 'Ҡытай', 'яңыртылған етештереүгә булдырыласаҡ энергия энергияның ниәтләй миллион', 'миллиард', 'яңыртылған етештереүгә булдырыласаҡ энергия энергияның', 'кәрәклеген Таҙа дә яңыртылған етештереүгә', 'миллиард етештереүгә яңыртылған булдырыласаҡ энергия энергияның ниәтләй миллион', 'етештереүгә', 'ниәтләй', 'миллион', 'энергияның', 'аңлап энергияның кәрәклеген Таҙа дә яңыртылған етештереүгә'} 1.0
# 53 v1:  {''} v2:  {'', 'бүлеп сығарған', 'йөрөйәсәк', 'ярашлы'} 0.0 args1:  {'хөкүмәте', 'һанын', 'юлдарында'} args2:  {'', 'тырышып планға ярашлы Моторлаштырылған электромобилдәр ағыулы матдәләр етештереүҙе бүлеп сығарған 2020 автомобилдәр', 'планға Моторлаштырылған электромобилдәр ағыулы матдәләр етештереүҙе бүлеп сығарған 2020 автомобилдәр', "планға China's ҡытай хөкүмәте", '2020', '2020 Моторлаштырылған автомобилдәр электромобилдәр', 'юлдарында', 'миллион электромобилдәр электромобиль автомобилдәр', 'планға Моторлаштырылған ярашлы электромобилдәр электромобиль автомобилдәр төп', 'ағыулы матдәләр электромобилдәр етештереүҙе', 'планға ярашлы'} 1.0
# 54 v1:  {'күләмендә'} v2:  {'', 'buyers тартып', 'тартып', 'һүрәтләгән үҫтерәсәк туҡтатырға', 'тартып алған', 'һүрәтләгән', 'бирәсәк', 'һүрәтләгән ниәтләй'} 0.0 args1:  {'эсендә', 'автомобилдәр', 'етештереүҙе', 'доллар', 'һалым'} args2:  {'Электромобилдәрҙе урындарын автомобилдәр', '', 'buy етештереүҙе алыусыларға', 'тартып', 'был федераль льготалары субсидияны', 'Трамп', 'Электромобилдәрҙе урындарын автомобилдәр buyers тартып', 'ниәтләй тартып алған был федераль льготалары субсидияны һәм һүрәтләгән үҫтерәсәк туҡтатырға Электромобилдәрҙе урындарын автомобилдәр buyers бирәсәк етештереүҙе алыусыларға доллар', 'был федераль льготалары субсидияны ниәтләй һәм һүрәтләгән үҫтерәсәк туҡтатырға Электромобилдәрҙе урындарын автомобилдәр buyers тартып бирәсәк етештереүҙе алыусыларға доллар', 'ниәтләй', 'һүрәтләгән Электромобилдәрҙе урындарын автомобилдәр тартып', 'льготалары субсидияны урындарын тартып алыусыларға доллар'} 0.0
# 55 v1:  {'шөғөлләнгән'} v2:  {'шөғөлләнгән йыһазландырылған'} 0.0 args1:  {'сауҙа'} args2:  {'', 'ВЕБСАЙТТАР магазиндары', 'ВЕБСАЙТТАР магазиндары датчиктар', 'шөғөлләнгән ОМО ВЕБСАЙТТАР магазиндары йыһазландырылған электрон', 'электрон'} 0.0
# 56 v1:  {'ярҙам'} v2:  {'ярҙам итә'} 0.0 args1:  {'программаһы'} args2:  {'программаһы күмәк эшҡыуарлыҡ инновациялар акселераторға һәм Дәүләт Советының', '8 күмәк меңдән инновациялар инкубаторға акселераторға һәм'} 0.0
# 57 v1:  {'Урбанизация'} v2:  {'', 'төҙөлөшө', 'булып', 'артты', 'сығарған килгән', 'артты сығарған килгән', 'сығарған ярашлы'} 0.0 args1:  {'Ҡытайҙа', 'йәһәттән'} args2:  {'сығарған талаптарын ХВФ һәм Һәм банкы глобаль', 'индекстарына талаптарын', 'сығарған Һәм был булып 50 биш тапҡырға артығыраҡ артты яҡынса норманан йәһәттән талаптарын глобаль', 'йылдан норманан йәһәттән', '50 биш тапҡырға артығыраҡ артты яҡынса норманан йәһәттән талаптарын глобаль', 'Һәм', 'йылдан', 'хаҡтар Ҡытай', 'булып проблема', 'был', 'талаптарын кәрәкле төҙөлөшө хаҡтар артты сығарған килгән йылдан норманан йәһәттән', 'был булып проблема', 'индекстарына талаптарын сығарған килгән ХВФ һәм Һәм банкы глобаль', 'индекстарына талаптарын сығарған килгән ХВФ һәм Һәм', 'проблема Ҡытай', 'талаптарын кәрәкле', 'Урбанизация спекуляцияларға һәм Һәм асыҡлыҡ кәрәкле хәүефле баҙар', 'талаптарын хаҡтар кәрәкле', 'талаптарын хаҡтар кәрәкле артты сығарған килгән йылдан норманан йәһәттән', 'сығарған ярашлы талаптарын кәрәкле төҙөлөшө хаҡтар артты килгән йылдан норманан йәһәттән һәм Һәм Урбанизация спекуляцияларға асыҡлыҡ хәүефле баҙар'} 0.0
# 58 v1:  {'бирһә'} v2:  {'йөрөргә эшләргә', 'мөмкинлек бирһә бирмәй', 'йөрөргә', 'бирһә бирмәй'} 0.0 args1:  {'ул'} args2:  {'', 'бирмәй', 'Был ул', 'бирһә Был система системалары мөмкинлек бирмәй ҡытайҙарға йөрөргә һәм эшләргә', 'уларға', 'ҡытайҙарға йөрөргә һәм эшләргә', 'Был система системалары', 'кеүек хоҡуҡтар', 'ҡытайҙарға'} 0.0
# 59 v1:  {'иҫәпләй.'} v2:  {'', 'килдем', 'быны'} 0.0 args1:  {'быны', 'улар'} args2:  {'улар', 'иң шәхси', 'килдем', 'менән интервьюларҙан шәхси Ҡытай', 'быны иң шәхси', 'иң килдем улар быны шәхси', 'быны'} 1.0
# 60 v1:  {'ҡаршы'} v2:  {'', 'теләмәй'} 0.0 args1:  {'улар'} args2:  {'', 'Әммә', 'улар', 'теләмәй'} 1.0
# 61 v1:  {'эшләй'} v2:  {'эшләй', 'алмай', 'йәшәгән йәшәй'} 0.0 args1:  {'йыл', 'яртыһында', 'Көнбайыштағы', 'система,'} args2:  {'', 'ике икенсе Half яртыһы яртыһында', 'һаулыҡ һаҡлауға социаль тәьминәткә һәм', 'ике', 'яртыһы ике Халыҡтың', 'алмай', 'икенсе тағы'} 0.0
# 62 v1:  {'буйы'} v2:  {'', 'көсәйтә'} 0.0 args1:  {'шулай'} args2:  {'шулай', 'Ҡытай', 'операцияларын яңы', 'яңы операцияларын көсәйтә', 'туранантура яңы ил инвестициялары Ҡытай ҡытай корпорацияларының'} 1.0
# 63 v1:  {'ысулдарын'} v2:  {'сығарыу', 'эҙләй', 'башланы'} 0.0 args1:  {'граждандары', 'сығарыу'} args2:  {'', 'Һуңғы ике', 'үҙҙәренең байлығын', 'эҙләй сығарыу үҙҙәренең байлығын', 'сығарыу үҙҙәренең байлығын', 'Һуңғы түгел байыған байлығын Ҡытай граждандары'} 0.0
# 64 v1:  {'һайлауына'} v2:  {'', 'ғәйепләй', 'манипулировкалауҙа конвертацияланған', 'конвертацияланған ирекле контролдә тотолған'} 0.0 args1:  {'Ул,'} args2:  {'ҡарамаҫтан кемде', 'Ҡытай', 'ирекле', 'rate валюта курста', 'кемде', 'алдағы', 'манипулировкалауҙа конвертацияланған валюта ҡарамаҫтан кемде', 'валюта', 'хәҙер'} 0.0
# 65 v1:  {'тураһында'} v2:  {'һөйләшеүҙәр яҙмышы һөйләмәгән', 'алып', 'алып барыу'} 0.0 args1:  {'фәләстиндәрҙең', 'бер', 'өлөшө'} args2:  {'', 'алып', 'кәрәкмәй', 'күпселек донъяның', 'алып уға улар', 'бер кем', 'мәлдә күпселек донъяның һөйләшеүҙәр яҙмышы һөйләмәгән тураһында', 'сигенергә', 'тураһында', 'яһамай һөйләмәгән кәрәкмәй', 'Намыҫлы'} 0.0
# 66 v1:  {'әйләнеп'} v2:  {'', 'кире', 'һуңыраҡ'} 0.0 args1:  {'көн', 'әйләндерһә,'} args2:  {'', 'фәләстин фәләстиндәрҙең гражданлыҡ хоҡуҡтарын мәсьәләләренә һуңыраҡ', 'ул', 'Әгәр фәләстин етәкселеге дәүләт һуңыраҡ һәм фәләстиндәрҙең гражданлыҡ хоҡуҡтарын мәсьәләләренә', 'алыр', 'һуңыраҡ', 'фәләстин етәкселеге дәүләт', 'хоҡуҡтарын дәүләт структураһы формаһы һәм'} 0.0
# 67 v1:  {'килтерәсәк', 'эске'} v2:  {'', 'нигеҙләнеп арҡаһында', 'тигән'} 0.0 args1:  {'коллапсҡа', 'хәүеф'} args2:  {'', 'элитаһы', 'килтерәсәк потенциаль дошмандарын', 'потенциаль сәйәси геосәйәси дошмандарын идеалдар проблемаларға', 'тик', 'арҡаһында Ошо шуның', 'Бәлки арҡаһында Ошо шуның', 'потенциаль дошмандарын', 'геосәйәси коллапсҡа хаосҡа һәм', 'борсола илдең', 'илдең', 'нигеҙләнеп арҡаһында Ошо шуның', 'борсола килтерәсәк потенциаль дошмандарын тик геосәйәси коллапсҡа хаосҡа һәм'} 0.0
# 68 v1:  {'аңлатыуы'} v2:  {'', 'аңлатыуы'} 0.0 args1:  {'мөһим'} args2:  {'', 'журналистарҙың Хашогги Сәғүд аңлатыуы Ни мөһим илдәр', 'Ни мөһим илдәр Хашогги Сәғүд', 'мөһим илдәр Хашогги Сәғүд', 'журналистарҙың Хашогги Сәғүд', 'Ни'} 0.0
# 69 v1:  {'етәкселек'} v2:  {'була', 'биргән'} 0.0 args1:  {'үҙе', 'кеше', 'үлтереүгә'} args2:  {'', 'үлтереүгә кеше биргән', 'биргән кеше', 'үлтереүгә кеше', 'үлтереүгә', 'Күпселек', 'үлтереүгә закондың'} 1.0
# 70 v1:  {'инә.'} v2:  {''} 0.0 args1:  {'компонент'} args2:  {'', 'дүрт'} 0.0
# 71 v1:  {'ителгән'} v2:  {'', 'ителгән'} 0.0 args1:  {'ителгән'} args2:  {'', 'КОРПОРАТИВ ПРОДУКТТАН керемдәре ЭСКЕ', 'ителгән процентҡа ПРОДУКТТАН', 'яҡынса йәки миллиард йылына', 'яҡынса тиң ПРОДУКТТАН', 'ПРОДУКТТАН', 'процентҡа ПРОДУКТТАН'} 0.0
# 72 v1:  {'акцияларҙы'} v2:  {'', 'менән тигеҙләргә', 'юғары'} 0.0 args1:  {'һәм'} args2:  {'', 'менән юғары коэффициенттары акцияларҙы', 'юғары менән тигеҙләргә коэффициенттары акцияларҙы һәм', 'менән тигеҙләргә юғары коэффициенттары акцияларҙы', 'мөмкин'} 0.0
# 73 v1:  {'өсөн'} v2:  {'менән', 'артыуы артыуын арттырасаҡ', 'компенсациялау'} 0.0 args1:  {'СИТ', 'хаҡты'} args2:  {'', 'импортҡа хаҡтарҙың', 'хаҡты артыуы артыуын арттырасаҡ импортҡа хаҡтарҙың менән', 'хаҡты хаҡтарҙың импортҡа ҡулланыусылары экспортының ил һалым сумма кәметәсәк өсөн теүәл етерлек компенсациялау', 'теүәл етерлек компенсациялау хаҡты артыуы артыуын арттырасаҡ импортҡа хаҡтарҙың менән', 'менән хаҡты', 'артыуы артыуын арттырасаҡ хаҡты Долларҙың ҡулланыусылары хаҡтарҙың'} 0.0
# 74 v1:  {'етештереүселәрен'} v2:  {'ашыу', 'мәжбүр итә', 'борсомайынса', ''} 0.0 args1:  {'аҡш'} args2:  {'', 'борсомайынса ҡулланыусыларын етештереүселәрен йәки', 'долларҙан миллиард йылына', 'ҡулланыусыларын етештереүселәрен йәки', 'Конгресты', 'мөмкинлеге мәжбүр этәрергә ашыу долларҙан миллиард йылына', 'ошо компонент', 'этәрергә ошо компонент ярҙамында борсомайынса ҡулланыусыларын етештереүселәрен йәки'} 0.0
# 75 v1:  {'аша'} v2:  {'трендыул', 'артҡандыр', 'таратылған'} 0.0 args1:  {'тренды-ул'} args2:  {'', 'таратылған артҡандыр социаль', 'Бәлки', 'социаль', 'таратылған', 'таратылған һанлы трендыул социаль медиа отчеттың быйыл'} 0.0
# 76 v1:  {'', 'раҫлай.'} v2:  {'раҫлай', 'түләгән'} 0.0 args1:  {'һығымтаны'} args2:  {'трендтары', '', 'был', 'проценты меңенең 74 биреүселәрҙең'} 0.0
# 77 v1:  {'үҙгәртергә,'} v2:  {'', 'финанслау'} 0.0 args1:  {'ҡануниәтен'} args2:  {'күберәк кәрәк', '', 'Мәҫәлән', 'журналистика', 'хөкүмәткә һәм йәмәғәт финанслау фондтарына программаларына', 'күберәк', 'финанслау', 'башлаһын кәрәк журналистика', 'финанслау һәм йәмәғәт күберәк хөкүмәткә фондтарына программаларына'} 0.0
# 78 v1:  {'юғары'} v2:  {'', 'бирә юғары', 'бирә'} 0.0 args1:  {'журналистика', 'һайын,'} args2:  {'', 'журналистика', 'был тенденциялар', 'Иң ике', 'журналистика бирә', 'ҡулланыусылар', 'был тенденциялар барған бирә юғары һәм һайын журналистика ҡулланыусылар'} 1.0
# 79 v1:  {'дискредитациялау', 'үҙҙәренең'} v2:  {'', 'дискредитациялау', 'advised бурысы', 'кәңәш', 'иткән'} 0.0 args1:  {'ғәйепләүселәрҙе'} args2:  {'', 'дискредитациялау', 'Уның партнерҙарына агенттарға', 'агенттарға менеджерҙарға ителмәй һәм йәки партнерҙарына репортерҙарға ғәйепләүселәрҙе', 'партнерҙарына репортерҙарға ғәйепләүселәрҙе агенттарға менеджерҙарға', 'иткән дискредитациялау', 'репортерҙарға үҙҙәренең клиенттарына', 'ителмәй'} 0.0
# 80 v1:  {'пакеттарын'} v2:  {'', 'тарттырылмағандыр башлаған', 'тарттырылмағандыр', 'башлаған'} 0.0 args1:  {'йылда', 'түләү'} args2:  {'', 'тынлыҡты', 'етәкселәре инвесторҙар акционерҙар', 'түләү', 'был тынлыҡты тарттырылмағандыр башлаған етәкселәре инвесторҙар акционерҙар корпоратив финанс көрсөгө власть арҡаһында башҡарма итмәгән түләү', 'арҡаһында боҙоу донъя Финанс финанс', 'корпоратив финанс көрсөгө власть', 'моғайын', 'тарттырылмағандыр итмәгән', 'яуаплылыҡҡа ҡабул үҙ', 'етәкселәре инвесторҙар акционерҙар башлаған корпоратив финанс көрсөгө власть', 'корпоратив акционерҙар арҡаһында башҡарма власть'} 1.0
# 81 v1:  {'һәм'} v2:  {'', 'бирергә яҡшыртырға', 'бирергә', 'яҡшыртырға', 'әҙерләү бирергә булдырырға'} 0.0 args1:  {'һәм', 'булдырырға', 'улар'} args2:  {'', 'улар', 'яҡшыртырға', 'етәкселәр поликлиникалар йәмәғәтселектең', 'эш', 'тейеш', 'бының', 'төҙөү поликлиникалар әҙерләү', 'гендер', 'әҙерләү'} 1.0
# 82 v1:  {'симпозиумға'} v2:  {'нығытыу', 'барлыҡҡа'} 0.0 args1:  {'мөмкинлеге', 'буйынса', 'вәкил'} args2:  {'Ливерпулдә', 'Был ошо', 'яҡын меңгә донъянан барлыҡҡа бөтә системаһын', 'системаһын яҡын барлыҡҡа киләсәк бөтә', 'барлыҡҡа мөмкинлеге нығытыу Был ошо', 'йыйыласаҡ', 'симпозиумға системаһын өйрәнеү һаулыҡ һаҡлау', 'Был меся'} 0.0
# 83 v1:  {'үҙгәртә'} v2:  {'', 'талап', 'башланы'} 0.0 args1:  {'стратегияларын', 'ойошмалары'} args2:  {'', 'власть', 'декларация', 'иткәнсә халыҡара ойошмалары лидерҙарға һәм донорҙар башланы үҙ стратегияларын власть', 'халыҡара ойошмалары лидерҙарға һәм донорҙар', 'лидерҙарға үҙ стратегияларын власть һәм', 'үҙ стратегияларын лидерҙарға власть һәм', 'лидерҙарға һәм'} 0.0
# 84 v1:  {'күрһәтә.'} v2:  {'күрһәтә', 'илһамландыра күрһәтә'} 0.0 args1:  {'декларацияһы,', 'беҙгә'} args2:  {'', 'һис шикһеҙ', 'Алматы декларацияһы', 'беҙгә'} 1.0
# 85 v1:  {'бара.'} v2:  {'', 'булдырыу'} 0.0 args1:  {'Һүҙ'} args2:  {'', 'менән бербереһе', 'күберәк', 'бербереһе ирекле зонаһын', 'булдырыу бербереһе ирекле зонаһын', 'тейеш', 'Африка Африкала', 'шуға Әле Һүҙ'} 0.0
# 86 v1:  {'байлыҡтан'} v2:  {'', 'алмаҫ'} 0.0 args1:  {'ошо', 'үҫеш'} args2:  {'', 'юл яңы ҡулланыусылар', 'был байлыҡтан', 'алмаҫ файҙалана был байлыҡтан этабында', 'этабында был', 'алмаҫ', 'коммерцияның ҡулланыусылар мәҙәниәтенә иҡтисадтар', 'файҙалана', 'юл', 'яңы', 'яңы коммерцияның ҡулланыусылар мәҙәниәтенә иҡтисадтар'} 0.0
# 87 v1:  {'процесҡа'} v2:  {'', 'йәлеп'} 0.0 args1:  {'алдан'} args2:  {'улар', 'тейеш', 'ителергә ярлыларҙың йәлеп көсһөҙләнеүсе Бынан дә алдан йәмғиәттәрҙең ризалығын', 'ярлыларҙың йәлеп көсһөҙләнеүсе Бынан дә алдан йәмғиәттәрҙең ризалығын', 'ярлыларҙың процесҡа', 'Бынан', 'алдан башланғандан ярлыларҙың Бынан тыш'} 0.0
# 88 v1:  {'алырға'} v2:  {'зыянға файҙа'} 0.0 args1:  {'файҙа'} args2:  {'инвестицияларҙан инфраструктураға түгел', 'тейеш', 'күргән илдәр'} 0.0
# 89 v1:  {'менән'} v2:  {'барған бара', 'барған алға'} 0.0 args1:  {'Британияла'} args2:  {'', 'Революция', 'менән бер', 'ҡайһы', 'ҡайһы Революция барған алға'} 0.0
# 90 v1:  {'хаҡта'} v2:  {'', 'һөйләй'} 0.0 args1:  {'ҡарата', 'нигеҙләнгән,'} args2:  {'', 'йыш ҡына', 'аңлашылмаусанлыҡҡа нигеҙләнгән иҡтисадсылар йыш ҡына һөйләй', 'АҠШ сәйәсәте', 'аңлашылмаусанлыҡҡа', 'иҡтисадсылар'} 0.0
# 91 v1:  {'', 'эҙләргә'} v2:  {'', 'ҡатмарлаштыра'} 0.0 args1:  {'ысулдарын'} args2:  {'', 'саҡырыуҙарҙа ысулдарын тыуҙырған технологик прогресс', 'Ләкин', 'сәйәсәте прогресс', 'ысулдарын', 'технологик прогресс', 'берберебеҙҙе', 'тағы', 'саҡырыуҙарҙа ысулдарын', 'тейешбеҙ', 'тыуҙырған', 'берберебеҙҙе саҡырыуҙарҙа ысулдарын тыуҙырған технологик прогресс', 'берберебеҙҙе тағы', 'беҙ тейешбеҙ'} 1.0
# 92 v1:  {'роль'} v2:  {'уйнағаны'} 0.0 args1:  {'донъяһында,'} args2:  {'', 'һәм башҡа төрҙәре социаль селтәрҙәр донъяһында', 'мөһим роль уйнағаны', 'донъяһында ваҡытында йылда Украинала селтәрҙәр протесы 2009 иранда ғәрәп 2011'} 0.0
# 93 v1:  {'өҫтөнлөк'} v2:  {''} 0.0 args1:  {'ойошмалар'} args2:  {'', 'ойошмалар селтәрҙәр арҡаһында һәм социаль', 'арҡаһында һәм ойошмалар хәрби селтәрҙәр социаль традицион', 'традицион социаль һәм хәрби селтәрҙәр ойошмалар'} 0.0
# 94 v1:  {'ниндәй'} v2:  {'', 'алға киткән итә көткәнен', 'күрһәтегеҙ', 'ышаныслылығын', 'булмаған'} 0.0 args1:  {'процесының', 'мөмкинлеге', 'илдәрҙе'} args2:  {'', 'ниндәй проблемалар алға киткән итә көткәнен илдәр илдәрҙе булмаған', 'алмаһа мөмкинлеге булмаған ышаныслылығын процесының', 'технологик илдәр илдәрҙе', 'киткән илдәр илдәрҙе булмаған', 'процесының ышаныслылығын', 'ниндәй проблемалар', 'киткән илдәр илдәрҙе', 'булмаған', 'Әгәр алмаһа технологик илдәр илдәрҙе мөмкинлеге булмаған ышаныслылығын процесының'} 0.0
# 95 v1:  {'доллары)'} v2:  {'', 'талабы тейеш', 'штраф һалынасаҡ', 'исеме Яңы'} 0.0 args1:  {'селтәрҙәр', 'юғиһә'} args2:  {'', 'социаль Netzwerkdurchsetzungsgesetz селтәрҙәр', 'миллион евроға АҠШ', 'тейеш аҫтында Яңы талабы буйынса закондың', 'уларға', 'тексты һәм дезинформацияны', 'социаль Netzwerkdurchsetzungsgesetz селтәрҙәр исеме Яңы', 'юғиһә', 'талабы тейеш', 'буйынса'} 1.0
# 96 v1:  {'ҡыҫҡартыла.'} v2:  {'', 'алып', 'һалым әҙер'} 0.0 args1:  {'әҙер'} args2:  {'', 'әҙер инфраструктура', 'етмәй', 'әҙер проекттарын тәнәфестәре', 'әҙер проекттарын тәнәфестәре алып аҙағына инфраструктура һалым', 'алып аҙағына', 'әҙер инфраструктура проекттарын', 'һалым әҙер'} 0.0
# 97 v1:  {'менән', 'килешеүен', 'тураһындағы'} v2:  {'', 'ала башлай алаБигерәк тартҡас', 'итеп', 'яуап', 'башлай'} 0.0 args1:  {'ала.', 'яҡлы'} args2:  {'менән Ҡытай', 'Төньяҡ Ҡытай Америка trade эскалацияһына', 'ала алаБигерәк', 'алаБигерәк Ҡытай башлай тартҡас эскалацияһына аҙыҡтүлеккә ядро менән Төньяҡ', 'Ҡытай', 'He Ул ул', 'эскалацияһына аҙыҡтүлеккә ядро менән Төньяҡ Ҡытай', 'Ул ул', 'башҡа Free яңынан хеҙмәттәшлек эскалацияһына менән көньяҡ ҡоросҡа Ҡытай', 'could ала алаБигерәк', 'тарифтар эскалацияһына һәм менән башҡа', 'яуап тарифтар эскалацияһына һәм менән башҡа'} 0.0
# 98 v1:  {'сикләргә'} v2:  {'ҡатыландырырға', 'ниәтләй'} 0.0 args1:  {'миграцияһын'} args2:  {'ниәтләй ҡатыландырырға миграцияһын хакимиәт юғары квалификациялы кешеләрҙе хеҙмәткәрҙәрҙең тыш һәм иммигранттарҙың документтарһыҙ', 'ниәтләй ҡатыландырырға кешеләрҙе хеҙмәткәрҙәрҙең иленән Алты мосолман иммигранттарҙың', 'хеҙмәткәрҙәрҙең', 'кешеләрҙе хеҙмәткәрҙәрҙең иленән Алты мосолман иммигранттарҙың', 'миграцияһын хакимиәт юғары квалификациялы кешеләрҙе хеҙмәткәрҙәрҙең'} 0.0
# 99 v1:  {'был'} v2:  {'булыуынса', 'булыуынса юҡ', 'итергә'} 0.0 args1:  {'булыуынса,'} args2:  {'барышында был маташыуҙар Проблеманы итергә', 'Проблеманы был', 'булыуынса был юҡ берҙәнбер Проблеманы итергә проблеманың', 'берҙәнбер юҡ Проблеманы итергә проблеманың был'} 0.0
# 100 v1:  {'йоғонто'} v2:  {'', 'эшләй ойошҡан'} 0.0 args1:  {'селтәр'} args2:  {'', 'һеҙ', 'был акторҙар', 'йоғонто', 'бөтә йоғонто'} 0.0
# 101 v1:  {'йылдың'} v2:  {'', 'тамамлана', 'рөхсәт'} 0.0 args1:  {'арзаная,'} args2:  {'', 'тамамлана', 'Долларға Dollar ителә арзаная башҡа ҙур валюталарға', 'системаһы dollar Долларға', 'системаһы Бреттонвуд ҙур', 'тағы', 'мартында'} 0.0
# 102 v1:  {'уйнай.'} v2:  {''} 0.0 args1:  {'ҡытай'} args2:  {'', 'ҙур роль Триффин дилеммаһын', 'ҡытай', 'Триффин дилеммаһын'} 1.0
# 103 v1:  {'алырға'} v2:  {'', 'менән хәлдәрҙә төрлө', 'менән бәйле төрлө'} 0.0 args1:  {'файҙа'} args2:  {'', 'economic аңлау', 'проблемалар проблемаларҙы менән бәйле төрлө ғаилә һәм', 'проблемалар илдәрҙә проблемаларҙы', 'проблемалар илдәрҙә проблемаларҙы менән хәлдәрҙә төрлө бәйле ғаилә һәм', 'Economic илдәрҙә менән бәйле шәхси проблемалар проблемаларҙы мөмкин', 'менән', 'мөмкин', 'ғаилә һәм', 'проблемалар проблемаларҙы'} 0.0
# 104 v1:  {'зыян'} v2:  {'', 'зыян'} 0.0 args1:  {'кешеләр', 'бынан', 'көсһөҙөрәк'} args2:  {'', 'менән бынан', 'төшөнсәләр ҡарарҙар', 'кешеләр', 'был'} 1.0
# 105 v1:  {'һөйләргә'} v2:  {'', 'һөйләргә', 'аңлау'} 0.0 args1:  {'тарихы'} args2:  {'', 'һөйләргә тураһында уларҙың', 'Кешеләрҙе', 'тураһында уларҙың', 'кәрәк', 'аңлау Кешеләрҙе'} 0.0
# 106 v1:  {'кешене', 'үткәрәһегеҙ'} v2:  {'', 'танышаһығыҙ билдәләй', 'күҙлегенән', 'уҡыйһығыҙ һөйләшәһегеҙ', 'булырға', 'күрә', 'айыра', 'һөйләшәһегеҙ'} 0.0 args1:  {'тойғоһо.', 'сәғәт', 'персонаждар'} args2:  {'яҡшы роман', '', 'Һеҙ', 'менән башҡа социаль мәҙәниәт секи һәм мөмкинлектәр ниндәй күҙлегенән айыра персонаждар кешене', 'персонаждар кешене', 'танышаһығыҙ билдәләй һөйләшәһегеҙ сәғәт', 'ниндәй был булырға', 'ниндәй', 'сәғәт', 'менән', 'башҡа социаль мәҙәниәт секи һәм мөмкинлектәр', 'был', 'донъяны'} 1.0
# 107 v1:  {''} v2:  {'', 'булмай'} 0.0 args1:  {'ул', 'башҡа', 'хәстәрлеге'} args2:  {'', 'булмай', 'мөһим тураһында тәбиғи эгоистик былкешеләрҙең башҡа булмай', 'айырыуса мөһим', 'был былкешеләрҙең', 'тәбиғи эгоистик', 'былкешеләрҙең', 'башҡа былкешеләрҙең', 'былкешеләрҙең башҡа'} 0.0
# 108 v1:  {'өйрәтәләр,'} v2:  {'бар', 'өйрәтәләр'} 0.0 args1:  {'күп'} args2:  {'Эконометрик математик моделдәр һәм', 'беҙҙе', 'уларҙың үҙ', 'күп бар', 'уларҙың'} 0.0
# 109 v1:  {'конкурентлыҡ'} v2:  {'нигеҙетехнологияларҙы', 'эшҡыуарлыҡты эшләгән', 'таратыуға', 'эшҡыуарлыҡты эшләгән конкурентлыҡ', 'таратыуға сәнәғәт дәртләндерә'} 0.0 args1:  {'кешеләр'} args2:  {'фирмалар', 'нигеҙетехнологияларҙы системаһы таратыуға булышлыҡ һәм сәнәғәт дәртләндерә ярҙамында менән яңы кешеләр ала эшҡыуарлыҡты эшләгән конкурентлыҡ фирмалар бөтә', 'ярҙамында менән нигеҙетехнологияларҙы яңы кешеләр ала эшҡыуарлыҡты эшләгән конкурентлыҡ фирмалар бөтә', 'таратыуға булышлыҡ нигеҙетехнологияларҙы һәм', 'ала', 'Икенсе', 'ярҙамында бөтә', 'яңы кешеләр', 'нигеҙетехнологияларҙы системаһы', 'ярҙамында менән нигеҙетехнологияларҙы', 'менән фирмалар эшҡыуарлыҡты эшләгән ярҙамында бөтә'} 0.0
# 110 v1:  {'белә.'} v2:  {'', 'белә', 'үҙен килгән', 'яҡлай'} 0.0 args1:  {'бер', 'журналист,', 'үҙен'} args2:  {'', 'яҡлай мәнфәғәттәренә әйберҙәрҙе criminals енәйәтселәр коррупция етәкселәре һәм', 'әгәр улар үҙен килгән ойошҡан яҡлай criminals енәйәтселәр коррупция етәкселәре әйберҙәрҙе', 'бер журналист', 'улар', 'мәнфәғәттәренә әйберҙәрҙе criminals енәйәтселәр коррупция етәкселәре һәм', 'алмай', 'суд енәйәтселәргә мәнфәғәттәренә органдары һәм әйберҙәрҙе', 'ойошҡан яҡлай criminals енәйәтселәр коррупция етәкселәре әйберҙәрҙе', 'бер кем алмай', 'үҙен', 'бер журналист кем яҡлай мәнфәғәттәренә әйберҙәрҙе criminals енәйәтселәр коррупция етәкселәре һәм', 'кем', 'яҡшы', 'бер кем алмай үҙен әгәр улар килгән ойошҡан яҡлай criminals енәйәтселәр коррупция етәкселәре әйберҙәрҙе'} 1.0
# 111 v1:  {'тарафынан'} v2:  {'тырыша', 'үлтереүселәр өҙөлгән еткерергә тырыша', 'тарафынан өҙөлгән', 'булды'} 0.0 args1:  {'төркөмдәр'} args2:  {'тарафынан журналистар халыҡара ойошмалары төркөмдәр evidence', 'үлтереүселәр evidence', 'был ойошмалары төркөмдәр тарафынан', 'еткерергә тырыша тарафынан өҙөлгән үлтереүселәр evidence', 'үлтереүселәр evidence өҙөлгән еткерергә тырыша', 'Икеһе лә', 'өҙөлгән үлтереүселәр', 'хәҙер'} 0.0
# 112 v1:  {'килемен'} v2:  {'биреү', 'стреыла ала', 'Башланғыс', 'яҡшыртырға', 'яҡшыртырға арттырырға'} 0.0 args1:  {'һәм', 'йәш'} args2:  {'', 'ала', 'биреү яҡшыртырға һәм арттырырға', 'түбән ҡарамаҫтан Башланғыс ярҙамында доллар', 'ярҙамында', 'ярҙамында шәфҡәт яҡшыртырға тәжрибә һәм', 'йәш хеҙмәткәрҙәр'} 0.0
# 113 v1:  {'293-ө'} v2:  {'йыйған алды'} 0.0 args1:  {'йыйған', '600'} args2:  {'600 һайлауҙарҙан һуң 293ө урындың', 'Партия урындың һайлауҙарҙан', 'һайлауҙарҙан ноябрендә'} 0.0
# 114 v1:  {'буйынса'} v2:  {'ашырылырға'} 0.0 args1:  {'еврозона'} args2:  {'', 'башҡа араһындағы еврозонаның', 'тейеш', 'бындай схема', 'бындай башҡа еврозонаның'} 0.0
# 115 v1:  {'стратегия'} v2:  {'', 'табырға'} 0.0 args1:  {'торған'} args2:  {'', 'Европаның партиялары', 'тейеш', 'партиялары', 'баланс араһында халыҡара партиялары ниәттәр һәм милли мәнфәғәттәр'} 0.0
# 116 v1:  {'структура'} v2:  {'тырыша', 'анализ яһағандан', 'яһағандан билдәләргә', 'яһағандан'} 0.0 args1:  {'эҙмә-эҙлекле', 'йылда', 'анализ'} args2:  {'етешһеҙлектәренә һәм билдәләргә', 'структура яһағандан был', 'Европа', 'яһағандан билдәләргә структура был', 'яһағандан анализ етешһеҙлектәренә һәм билдәләргә', 'был'} 0.0
# 117 v1:  {'сараларҙы'} v2:  {'шулай иғтибар итә оҙатып бара', 'бара'} 0.0 args1:  {'версияһы'} args2:  {'', 'шулай', 'иғтибар', 'шулай хөкүмәттең һәм протекционистик', 'АҠШ президенты Дональд Трамп', 'уның версияһы'} 0.0
# 118 v1:  {'маҡсатын'} v2:  {'билдәләмәй'} 0.0 args1:  {'төп'} args2:  {'билдәләмәй', 'стратегияның яңы планы', 'яңы Британияның планы'} 0.0
# 119 v1:  {'текле'} v2:  {'', 'кәрәкле', 'талап итә', 'алдағы', 'һәм'} 0.0 args1:  {'иҫәптән'} args2:  {'', 'кәрәкле текле һәм заманса шул индустриаль стратегия', 'алдағы', 'активтарҙы ресурстарҙы һәм кәрәкле алдағы индустриаль', 'активтарҙы ресурстарҙы һәм', 'кәрәкле текле кеше һәм активтарҙы ресурстарҙы алдағы индустриаль', 'шул кәрәкле текле һәм заманса индустриаль стратегия талап итә кеше активтарҙы ресурстарҙы алдағы', 'кеше', 'алдағы индустриаль'} 0.0
# 120 v1:  {'йәлеп'} v2:  {'', 'булып'} 0.0 args1:  {'граждандарын', 'торған', 'илдәрҙең'} args2:  {'', 'граждандарын', 'булып', 'булып граждандарын', 'миграция'} 1.0
# 121 v1:  {'бирә:'} v2:  {'', 'алыу', 'илгә килем', 'бирә', 'булһа'} 0.0 args1:  {'ул', 'үҫешкән'} args2:  {'', 'Яңы илдәрҙә илдәргә', 'ҡына', 'ҡына күберәк тапҡырға юғарыраҡ мөмкинлектәрҙән ҡарағанда илдәргә илдәрҙә', 'ул', 'ҡына күпкә күберәк', 'ҡына илгә килем Яңы илдәрҙә илдәргә булһа', 'илдәрҙә илдәргә', 'илгә килем Яңы илдәрҙә илдәргә', 'алыу мөмкинлектәрҙән паритеты', 'мөмкинлектәрҙән паритеты', 'күберәк паритеты тапҡырға илдәргә илдәрҙә'} 1.0
# 122 v1:  {''} v2:  {'тырыша', '', 'мөмкинлек', 'булып', 'иткән'} 0.0 args1:  {'күрә', 'хөкүмәттәр', 'өсөн', 'һәм'} args2:  {'', 'сәйәсәтте биргән мөмкинлек мигранттарҙы ҡаҙаныштарын сығымдарҙан һәм', 'сәйәсәтте', 'илдәр', 'мигранттарҙы ҡаҙаныштарын сығымдарҙан һәм', 'биргән', 'илдәр хөкүмәттәр', 'мигранттарҙы', 'булып бәхәсле тема', 'илдәр иткән', 'ҡаҙаныштарын сығымдарҙан', 'мигранттарҙы миграция'} 0.0
# 123 v1:  {'ята.'} v2:  {''} 0.0 args1:  {'фекер'} args2:  {'араһында ошо ике', 'ике'} 0.0
# 124 v1:  {'эшләмәй.'} v2:  {'', 'яһаған', 'булмаған', 'иткәндә яһаған'} 0.0 args1:  {'бер', 'илдә', 'улар'} args2:  {'', 'яһаған илдәр кешеләргә', 'кәрәкле иткәндә яһаған мигранттарҙы миграция ағымдары кешеләргә булмаған күнекмәләре яңы', 'илдәр кешеләргә', 'улар', 'бер нәмә кәрәкле иткәндә яһаған мигранттарҙы миграция ағымдары кешеләргә булмаған күнекмәләре яңы', 'кәрәкле', 'Һәр осраҡта иткәндә яһаған илдәр кешеләргә', 'кешеләргә', 'кәрәкле күнекмәләре', 'яңы', 'кешеләргә булмаған кәрәкле күнекмәләре яңы', 'булмаған', 'мигранттарҙы миграция ағымдары', 'Һәр'} 1.0
# 125 v1:  {'кәметәсәк.'} v2:  {''} 0.0 args1:  {'баҫымды'} args2:  {'', 'киләсәктә', 'тиҙ европала', 'киләсәктә европала', 'тиҙ'} 0.0
# 126 v1:  {'килергә,'} v2:  {'танылыуынса', '', 'килергә'} 0.0 args1:  {'секторҙан'} args2:  {'', 'секторҙан шәхси', 'мөһим һәм инвестициялар секторҙан баҙарҙарға', 'һуңғы', 'инвестициялар', 'зарур', 'инвестициялар зарур килергә секторҙан шәхси һәм мөһим баҙарҙарға шулай'} 0.0
# 127 v1:  {'билдәләү,'} v2:  {'', 'кәрәкмәгән'} 0.0 args1:  {'проекттарҙы'} args2:  {'', 'шәхси инвесторҙар', 'Маҡсатинституциональ һәм башҡа', 'проекттарҙы кәрәкмәгән шәхси инвесторҙар Маҡсатинституциональ һәм башҡа', 'проекттарҙы', 'кәрәкмәгән', 'был', 'проекттарҙы кәрәкмәгән шәхси инвесторҙар Маҡсатинституциональ һәм башҡа өҫтөндә эшләү был'} 1.0
# 128 v1:  {'раҫлай.'} v2:  {'раҫлай'} 0.0 args1:  {'маҡсатҡа'} args2:  {'ярашлы раҫлай нейтраль позицияһының һәм', 'Был һөҙөмтәләр'} 0.0
# 129 v1:  {'иҫәпләйҙәр.'} v2:  {''} 0.0 args1:  {'Штаттарҙан', 'артта'} args2:  {'', 'артта Ҡушма Штаттарҙан һәм Азиянан', 'йыш ҡына', 'артта Ҡушма Штаттарҙан һәм Азиянан өлкәһендә һанлы технологиялар', 'өлкәһендә һанлы технологиялар'} 0.0
# 130 v1:  {'етешһеҙлектәре'} v2:  {'бар', 'ярыша', 'етешһеҙлектәре'} 0.0 args1:  {'үҙәне'} args2:  {'гиганттары гиганттарын европа технологик секторының', 'үҙәне технологик гиганттары гиганттарын', 'менән гиганттары гиганттарын Силикон', 'үҙәне технологик гиганттары гиганттарын менән алған алмай етешһеҙлектәре Силикон', 'ул', 'алмай', 'алмай алған ярыша үҙәне технологик гиганттары гиганттарын менән етешһеҙлектәре Силикон', 'менән алған', 'Әлбиттә Әле', 'үҙәне', 'һаман Әле'} 1.0
# 131 v1:  {'күренә.'} v2:  {'', 'урынлашҡан', 'булып күренә'} 0.0 args1:  {'тотороҡло', 'импульсы'} args2:  {'', 'ЕВРОПА Европаның', 'бишәүһе башланғыс талантын импульсы ЕВРОПА Европаның', 'Быға', 'талантын', 'ун иң бишәүһе информатика БЕРЛӘШМӘҺЕНДӘ факультетының'} 0.0
# 132 v1:  {'сигенһә,'} v2:  {''} 0.0 args1:  {'һайлаусылары'} args2:  {'', 'иммиграция сәбәбе популярлыҡтың', 'немец француз һәм голланд популярлыҡтың', 'Әгәр немец француз һайлаусылары һәм голланд популярлыҡтың', 'немец француз һайлаусылары'} 0.0
# 133 v1:  {'рецессиянан', 'бер'} v2:  {'veto көрсөгөнән вето', '', 'көрсөгөнән күрә һалынған килтерә', 'һалынған килтерә'} 0.0 args1:  {'АҠШ-ты', 'уҡ', 'көрсөгөнән'} args2:  {'', 'шулай', 'бер оҙайлы яғынан финанс көрсөгөнән түбәнәйеүҙән зыян', 'бер формаһына финанс валютаның һәм түбәнәйеүҙән стимулдары йомшартыуға', 'рецессиянан', 'немец vetoed ветоһы рецессиянан формаһына финанс оҙайлы валютаның йомшартыуға', 'шулай рецессиянан', 'немец хөкүмәте', 'ЕВРОПА', 'шулай немец хөкүмәте veto көрсөгөнән вето бер формаһына финанс валютаның һәм түбәнәйеүҙән стимулдары йомшартыуға рецессиянан vetoed ветоһы оҙайлы һалынған килтерә юғалыуына', 'көрсөгөнән финанс', 'юғалыуына бер валютаның'} 0.0
# 134 v1:  {'сикһеҙ'} v2:  {'', 'ышандыра', 'нығытыу тергеҙеү', 'эшләргә', 'башланыуы', 'strengthening нығытыу йомшартып', 'softening нығытыу'} 0.0 args1:  {'дәүләте', 'немец', 'процесы'} args2:  {'', 'нығытыу тергеҙеү Европаны юлы менән softening франциянемец', 'юлы менән softening нығытыу франциянемец', 'Европаны', 'һалмай', 'нығытыу ҡатылығын', 'әҙер эшләргә нығытыу тергеҙеү Европаны юлы менән softening франциянемец һайлаусыларын упҡынға башланыуы француз реформалары процесы ышандыра канцлеры күсәрен УЛАРҘЫҢ һалмай strengthening йомшартып ҡатылығын', 'башланыуы франциянемец француз реформалары процесы', 'франциянемец канцлеры күсәрен һайлаусыларын', 'УЛАРҘЫҢ һалмай башланыуы strengthening нығытыу йомшартып ҡатылығын', 'ике һуңғы канцлеры кандидат күсәрен һайлаусыларын УЛАРҘЫҢ франциянемец', 'франциянемец юлы менән', 'УЛАРҘЫҢ', 'strengthening нығытыу йомшартып ҡатылығын'} 0.0
# 135 v1:  {'тора'} v2:  {'һәләтлелеген', ''} 0.0 args1:  {'иҡтисады', 'яҡшы'} args2:  {'', 'референдумдан былтырғы брексит', 'шулай моғайын', 'Британия', 'яҡшы фунттың һәм', 'яҡшы кәмеүенә'} 0.0
# 136 v1:  {'ҡырҡа'} v2:  {'кимәлен', '', 'өлгәшеүҙең иткән килеүен', 'мөмкин'} 0.0 args1:  {'инфляция'} args2:  {'өлгәшеүҙең барлыҡҡа бөтә үҙәк донъяла банк бойондороҡһоҙ мөмкин ҡырҡа инфляция', '', 'мөһим сәбәбе тип өлгәшеүҙең иткән килеүен тотороҡлолоғона кәметергә', 'инфляция бойондороҡһоҙ', 'мөмкин', 'бөтә үҙәк донъяла банк бойондороҡһоҙ', 'тотороҡлолоғона кәметергә', 'ҡырҡа'} 0.0
# 137 v1:  {'тәғәйенләнеү'} v2:  {'емерелгән', 'барып'} 0.0 args1:  {'тормош', 'Ҡасаҡ'} args2:  {'', 'country илдән', 'емерелгән илдән булмағанлыҡтан', 'country илдән емерелгән йәки', 'тәғәйенләнеү country илдән', 'булмағанлыҡтан етмәй', 'емерелгән йәки'} 0.0
# ...
# 518 v1:  {'көрәшергә'} v2:  {'', 'кәрәк', 'көрәшергә'} 0.0 args1:  {'киләсәге'} args2:  {'', 'осрашҡандан менән Трамп һәм башҡа G7нең лидерҙары', 'беҙгә', 'киләсәге көрәшергә беҙгә', 'Германия лидерҙары канцлеры Меркель', 'Европа', 'башҡа башҡаларға', 'Европа башҡа башҡаларға һәм беҙгә кәрәк киләсәге көрәшергә'} 0.0
# 519 v1:  {'таныу,'} v2:  {'танырға', 'булмаһын'} 0.0 args1:  {'тамамланыуын'} args2:  {'', 'шулай', 'һуғыш', 'нисек ауыр', 'нисек булмаһын шулай ауыр Американың сәнәғәтхәрби таныу', 'тейеш', 'Американың сәнәғәтхәрби булмаһын таныу'} 0.0
# 520 v1:  {'идараһы'} v2:  {'', 'ала', 'киңәйтеп нығыта', 'киңәйтеп'} 0.0 args1:  {'Трамп'} args2:  {'', 'икенсе концепцияһын', 'киләсәгенең Һайлауҙарҙа күҙәтеүселәргә активистарға һәм', "ала киңәйтеп нығыта икенсе Russia's оппозицияһын һәм концепцияһын", 'демократик', "икенсе Russia's оппозицияһын", 'күҙәтеүселәргә активистарға', 'киләсәгенең киңәйтеп нығыта активистарға Һайлауҙарҙа күҙәтеүселәргә һәм демократик'} 0.0
# 521 v1:  {'яҡланған,'} v2:  {'', 'булыр'} 0.0 args1:  {'хоҡуҡтары'} args2:  {'', 'демократик диссидентлыҡ', 'перспективала', 'ОҘАЙЛЫ', 'мөнәсәбәттәр менән демократик Рәсәй', 'Рәсәй мөнәсәбәттәр хоҡуҡтары', 'яҡшыраҡ перспективала Рәсәй мөнәсәбәттәр хоҡуҡтары яҡланған демократик диссидентлыҡ'} 0.0
# 522 v1:  {'дә'} v2:  {'', 'белмәй', 'тыуҙырҙы'} 0.0 args1:  {'насарайыуын', 'һорау'} args2:  {'', 'бер кем белмәй', 'долларға', 'ни', 'саҡта', 'Ун йыл'} 0.0
# 523 v1:  {'килтерә.'} v2:  {'', 'ҡалһа һаҡланһа түбәнәйһә', 'һаҡланһа килтерә', 'һаҡланһа түбәнәйһә килтерә'} 0.0 args1:  {'маҡсат', 'дефляция'} args2:  {'', 'inflation инфляция дефляция дефляцияһына', 'әгәр итһә маҡсат 0 һаҡланһа килтерә inflation инфляция дефляция дефляцияһына', 'маҡсат inflation инфляция дефляция дефляцияһына', '0', 'deflation инфляция дефляция дефляцияһына', 'маҡсат', 'оҙайлы һаҡланһа түбәнәйһә 0', 'оҙайлы ваҡыт'} 1.0
# 524 v1:  {'ҡаласаҡ.'} v2:  {''} 0.0 args1:  {'сәйәсәте,'} args2:  {'', 'традицион булмаған финанстарҙа финанскредит йәнә сәйәсәте', 'финанстарҙа финанскредит импульс', 'ҡаласаҡ', 'финанстарҙа'} 0.0
# 525 v1:  {'буйынса'} v2:  {'', 'ҡыйбатлана'} 0.0 args1:  {'баҙарҙарҙың'} args2:  {'', 'ил кредит үҫешеүсе һәм киңәйә ҡаплауы ҡыйбатлана', 'баҙарҙарҙың'} 1.0
# 526 v1:  {'дәрәжәһенә'} v2:  {''} 0.0 args1:  {'кимәлдәге', 'беренсе'} args2:  {'ГонконгҠытайҙың Шанхай Шэньчжэнь ҡалаларында һәм кимәлдәге хаҡтар Пекин Гуанчжоу', 'ГонконгҠытайҙың', 'беренсе'} 1.0
# 527 v1:  {'мәғлүмәттәр'} v2:  {'бирер'} 0.0 args1:  {'ҡиммәтле', 'Урбанизация,'} args2:  {'бирер ҡиммәтле табышлы тарихын ҡарағанда үҙенең тәжрибәһенә Ҡытайҙың мәғлүмәттәр ҡалаларҙа', 'ҡиммәтле табышлы тарихын ҡарағанда үҙенең тәжрибәһенә Ҡытайҙың мәғлүмәттәр ҡалаларҙа', 'Урбанизация Был ҡалаларҙа'} 0.0
# 528 v1:  {'', 'өлөшөн'} v2:  {'', 'Башланған үҙгәртеп тамамлауға әҙерләгән ҡулланыуға индерелгән күҙәтелгән', 'тамамлауға әҙерләгән индерелгән күҙәтелгән', 'әйләнде әҙерләгән өлгәшелде', 'Башланған', 'өлөшөн әйләнде әҙерләгән өлгәшелде', 'булмаған'} 0.0 args1:  {'органдары'} args2:  {'', 'Урындағы органдары предприятиеларының', 'власть керамика enterprises industry', 'власть процесын үҙгәртеп ҡороу ҡулланыуға шәхси предприятиеларының', 'был уңыш', 'власть юғары стандарттар', 'власть Башланған үҙгәртеп ҡороу тамамлауға ҡулланыуға өлгәшелде процесын шәхси предприятиеларының Шулай', 'Шулай бысраҡ нигеҙҙә власть юғары стандарттар Башланған үҙгәртеп тамамлауға әҙерләгән ҡулланыуға индерелгән күҙәтелгән һәм ҡала', 'ҡатмарлы зыянлы булмаған һәм әҙерләгән бысраҡ юғары энергия шәхси һөҙөмтәле enterprises industry', 'Шулай', 'власть ҡала', 'Шулай процесын'} 0.0
# 529 v1:  {'туҡтатып,'} v2:  {'', 'нығытып', 'иҫкергән алған менән', 'ебәреп иҫкергән', 'promoting', 'promote туҡтатып', 'нығытып туҡтатып'} 0.0 args1:  {'тармаҡтарҙы', 'ҡалаларығыҙ'} args2:  {'', 'нығытып менән promote туҡтатып инновацияларҙы һәм үҫешкә иҫкергән шулай эшсе өҙөклөктәрҙе хәл бысраҡлыҡ алған социаль', 'Мәҫәлән', 'һеҙҙең ҡалаларығыҙ promoting улар нығытып һәм ебәреп иҫкергән технологик инновацияларҙы тармаҡтарҙы проблемаларҙы өҙөклөктәрҙе менән promote туҡтатып үҫешкә шулай эшсе хәл бысраҡлыҡ алған социаль', 'һеҙҙең ҡалаларығыҙ', 'улар', 'социаль', 'Фошань', 'эшсе өҙөклөктәрҙе хәл бысраҡлыҡ алған менән иҫкергән социаль', 'инновацияларҙы', 'технологик нығытып инновацияларҙы тармаҡтарҙы проблемаларҙы өҙөклөктәрҙе', 'үҫешкә инновацияларҙы иҫкергән'} 0.0
# 530 v1:  {'доллар'} v2:  {'экономиялай'} 0.0 args1:  {'һәр', '850'} args2:  {'арҡаһында алыу һатып ҡытай американың', 'доллар', 'фекеренсә арҡаһында алыу консультанты', 'һәр американың ғаиләһе'} 0.0
# 531 v1:  {'йыймауын'} v2:  {'', 'иҫәпкә'} 0.0 args1:  {'доллар'} args2:  {'иҫәпкә проценты Америкала ғаиләләрҙең йыймауын 500 доллар датаға кәрәкле', 'йыймауын', 'кәрәкле', 'датаға кәрәкле', 'проценты Америкала ғаиләләрҙең йыймауын 500 доллар датаға кәрәкле', '500 доллар', 'проценты Америкала ғаиләләрҙең', 'был'} 0.0
# 532 v1:  {'күрһәтте.'} v2:  {'', 'күрһәтте'} 0.0 args1:  {'Ҡытай', 'сауҙа'} args2:  {'Ҡытай', 'иң тиҙ миҫалын менән ярлылыҡ тарихында донъяның', 'ярлылыҡ', 'Әлбиттә', 'менән иң Ҡытай һәм башҡа донъяның'} 1.0
# 533 v1:  {'ҡытай'} v2:  {'эшләй', ''} 0.0 args1:  {'ҡуймаһа', 'юл'} args2:  {'Япония ҡытай', 'сикләүҙәре конфликтҡа ирекле юл Япония Бер', 'алыр', 'ҡуймаһа Бер символик сикләүҙәре конфликтҡа ирекле юл Япония', 'быны', 'символик сикләүҙәре'} 0.0
# 534 v1:  {'насарайыуын'} v2:  {'', 'аңлатыу', 'яҙырға', 'ине'} 0.0 args1:  {'китап'} args2:  {'', 'мөнәсәбәте Американың Ҡытайға', 'ни', 'кәрәк', 'яҙырға', 'ни мөнәсәбәте Американың Ҡытайға', 'аңлатыу ни мөнәсәбәте Американың Ҡытайға'} 0.0
# 535 v1:  {'реструктуризациялауға'} v2:  {'', 'була', 'әҙерләгәндә бирә'} 0.0 args1:  {'төнгә', 'бер'} args2:  {'әҙерләгәндә бирә реструктуризациялауға', 'бында ә быға', 'әҙерләгәндә кредиторҙар реструктуризациялауға бер күберәк бирә', 'реструктуризациялауға бер', 'кредиторҙар', 'бер күберәк кредиторҙар', 'реструктуризациялауға', 'Бер ауырыу шок нәмә шундай бында быға', 'шундай Бер'} 0.0
# 536 v1:  {'ҡаса'} v2:  {'', 'алды'} 0.0 args1:  {'ышаныс', 'инвесторҙар'} args2:  {'башланыу менән', 'алды', 'инвесторҙар', 'был ышаныс'} 1.0
# 537 v1:  {'биргән'} v2:  {'', 'менән биргән', 'биргән'} 0.0 args1:  {'төнгә', 'аҡса', 'уларҙың'} args2:  {'', 'АҠШ фондтарын', 'биргән фондтарын ҡағыҙҙарына', 'бер', 'менән итеүҙән фондтарын ҡыуыҡтар һәм', 'АҠШ етәкселеге', 'фондтарын ҡағыҙҙарына биргән', 'төнгә', 'фондтарын ҡағыҙҙарына', 'биргән', 'бер менән биргән итеүҙән фондтарын ҡыуыҡтар һәм', 'тейеш тейештәр', 'уларҙың', 'уларҙың бер менән биргән итеүҙән фондтарын ҡыуыҡтар һәм тейеш тейештәр ҡағыҙҙарына'} 1.0
# 538 v1:  {'сәскә'} v2:  {'', 'теләгән'} 0.0 args1:  {'төнгә'} args2:  {'', 'теләгән ҡыҫҡа', 'теләгән Страховкаланмаған банк', 'ҡыҫҡа', 'бер Страховкаланмаған банк иҫәпләшергә', 'банк ойошмаларға', 'ипотека пулы банк', 'банк ойошмаларға теләгән ҡыҫҡа'} 0.0
# 539 v1:  {'эләгә.'} v2:  {''} 0.0 args1:  {'облигациялар', 'пулдарына'} args2:  {'', 'һатмаһа', 'ипотека', 'казначейство', 'кешеләр'} 0.0
# 540 v1:  {'булып'} v2:  {'', 'бәйле', 'көрсөгө күрһәткән', 'булып'} 0.0 args1:  {'көрсөгө'} args2:  {'глобаль финанс', '', 'булып көрсөгө күрһәткән ни тиклем финанс', 'күрһәткән торлаҡ аҡшта', 'ни тиклем', 'глобаль финанс бәйле күрһәткән торлаҡ аҡшта', 'ни тиклем финанс', 'финанс'} 0.0
# 541 v1:  {'сәйәсәтен'} v2:  {'яңыртырға', ''} 0.0 args1:  {'өсөн', 'Кремль'} args2:  {'', 'үҙ уларҙың санкцияларын Рәсәйгә', 'европа лидерҙары', 'яңыртырға', 'Шулай тейеш тимәк уларҙың ихтимал яңыртырға', 'тейеш', 'ихтимал', 'һәр һайын алты', 'уларҙың', 'Шулай тейеш'} 0.0
# 542 v1:  {'штраф'} v2:  {'ҡаршы файҙаланыуы', 'була', 'штраф'} 0.0 args1:  {'банкына'} args2:  {'', 'француз банкына', 'күп була һөйләшеүҙәр тураһында файҙаланыуы америка', 'санкцияларҙы штраф суданға вәкәләттәрен Иранға һәм', 'миллиард', 'штраф ҡаршы файҙаланыуы санкцияларҙы суданға вәкәләттәрен Иранға һәм', 'штраф француз банкына миллиард ҡаршы файҙаланыуы санкцияларҙы суданға вәкәләттәрен Иранға һәм'} 0.0
# 543 v1:  {'ЭШЛӘРГӘ'} v2:  {'Был', '', 'саҡырыу пауза'} 0.0 args1:  {'бер'} args2:  {'алдынан доллар сауҙа', 'доллар сауҙа', 'теләһә тейеш', 'бер ҡатмарлы', 'Был шуға', 'айырым бер АҠШтың фирмалар кешеләр һәм илдәр'} 0.0
# 544 v1:  {'нығытырға'} v2:  {'', 'өйрәнергә', 'нығытырға'} 0.0 args1:  {'лидерлығын', 'долларға'} args2:  {'', 'шик', 'улар', 'тейеш', 'улар АҠШ америка', 'һәр ниндәйҙер', 'америка лидерлығын һәм тейеш ышанысын долларға'} 0.0
# 545 v1:  {'хужалығына'} v2:  {'', 'буласаҡ'} 0.0 args1:  {'был'} args2:  {'', 'процентҡа йәки', 'уны', 'буйынса тура Яңы', 'был капиталды', 'капиталды тура кәметәсәк хужалығына йәки һәм ауыл инвестицияларға уны корпоратив', 'капиталды тура кәметәсәк хужалығына йәки һәм ауыл инвестицияларға', 'тура корпоратив'} 0.0
# 546 v1:  {'үҙгәртелмәһә'} v2:  {'артыуы', ''} 0.0 args1:  {'ҡағиҙәләре', 'йыл', 'күләме'} args2:  {'үҙгәртелмәһә бюджет ТУЛАЙЫМ', 'бюджет ТУЛАЙЫМ', 'үҙгәртелмәһә', 'дауамында ун йыл', 'дефицит', '34тән', 'үҙгәртелмәһә ихтимал', '34тән бюджет ун ПРОДУКТТЫҢ'} 0.0
# 547 v1:  {'булып'} v2:  {'булып'} 0.0 args1:  {'рузимурадовтың'} args2:  {'', 'берләшмәһе менән күҙәтһә Донъя Бекжановтың рузимурадовтың'} 0.0
# 548 v1:  {'ҡайтырға'} v2:  {'', 'ҡайтырға', 'теләй'} 0.0 args1:  {'ул', 'журналистикаға'} args2:  {'йәш', 'журналистикаға', 'бер', 'уға ул', 'Хәҙер', 'журналистикаға ҡайтырға бер'} 1.0
# 549 v1:  {'', 'иғлан'} v2:  {'', 'итә'} 0.0 args1:  {'ул', 'аслыҡ'} args2:  {'', 'ул', 'йыш ҡына', 'менән', 'менән ауыр формаһы туберкулездың'} 1.0
# 550 v1:  {'ҡулға'} v2:  {''} 0.0 args1:  {'журналист', 'ай'} args2:  {'', 'ике рузимурадтарҙы журналист', 'бер ай Мәҫәлән ҡулға'} 0.0
# 551 v1:  {'булып'} v2:  {'булып'} 0.0 args1:  {'үҙенсәлеге', 'юлы', 'оҙайлы'} args2:  {'перспективалы идара', 'йәғни булып оҙайлы перспективалы юлы'} 0.0
# 552 v1:  {'ныҡ'} v2:  {'', 'сәйәсмәндәр', 'эшләмәһәләр биреләсәк'} 0.0 args1:  {'быны', 'улар'} args2:  {'', 'улар', 'һайлаусыларға', 'тейеш', 'сәйәсмәндәр һөҙөмтәләргә', 'ваҡытлы', 'әгәр эшләмәһәләр улар', 'һайлаусыларға һөҙөмтәләргә', 'һөҙөмтәләргә'} 1.0
# 553 v1:  {'', 'үҙгәреүенә'} v2:  {'', 'булып'} 0.0 args1:  {'ҡабул'} args2:  {'', 'пландарҙың ҡарарҙар', 'Был был', 'in Бынан', 'араһындағы ҡарарҙар был төркөмдәр', 'был бындай дошманлыҡ мөнәсәбәттәр', 'дошманлыҡ араһында араһындағы баҙарҙың һәм төркөмдәр', 'In', 'иреклелек һәм нигеҙләнгән пландарҙың ҡарарҙар', 'пландарҙың һәм бындай ҡарарҙар In араһындағы', 'был', 'баҙарҙың', 'Бынан алдан'} 0.0
# 554 v1:  {'ҡулланыла'} v2:  {'', 'бар', 'ҡулланыла', 'булмаған'} 0.0 args1:  {'ул'} args2:  {'', 'ул', 'айырыуса булмаған', 'Беренсенән айырыуса ул булмаған электораттың бар ҡулланыла', 'электораттың', 'электораттың референдум', 'булмаған ҡулланыла'} 1.0
# 555 v1:  {'үткәреп,'} v2:  {'үткәреп', 'кампанияны үткәреп'} 0.0 args1:  {'Улар', 'кампанияны'} args2:  {'', 'әүҙем үткәреп кампанияны Беренсе референдум һуғышынан ваҡытында реконструкция донъя', 'һуғышынан ваҡытында реконструкция Беренсе донъя', 'Беренсе кампанияны референдум', 'Улар', 'әүҙем үткәреп'} 1.0
# 556 v1:  {'үтергә'} v2:  {'үткәрелгәйне ине', 'үтергә'} 0.0 args1:  {'йыл'} args2:  {'тейеш үткәрелгәйне үтергә ғына', 'ике', 'ике Бынан алдағы киләһе', 'ғына', 'алдағы киләһе эсендә'} 0.0
# 557 v1:  {'вазифаға'} v2:  {'итеп һайлана'} 0.0 args1:  {'ҡабаттан', 'фельдмаршал'} args2:  {'', '1932', 'Веймарҙа', 'иҫке фельдмаршал Пол вон ҡабаттан гинденбург'} 0.0
# 558 v1:  {'мөрәжәғәт'} v2:  {'', 'һорап итергә', 'мәжбүр'} 0.0 args1:  {'хөкүмәт'} args2:  {'', 'хөкүмәт', 'мөрәжәғәт', 'итергә мәжбүр һорап мөрәжәғәт'} 1.0
# 559 v1:  {'туплай'} v2:  {'', 'туплай', 'Артабанғы', 'башлай'} 0.0 args1:  {'европалылар', 'байлығын'} args2:  {'', 'европалылар', 'Артабанғы', 'сәйәси мәҙәни һәм менән бигерәк', 'туплай донъя', 'донъя'} 1.0
# 560 v1:  {'үткәрергә'} v2:  {'араһында параллель үткәрергә'} 0.0 args1:  {'параллель'} args2:  {'араһында', 'мөмкин', 'параллель'} 1.0
# 561 v1:  {'миссияһын'} v2:  {''} 0.0 args1:  {'алдағы'} args2:  {'донъя банкы', 'үҙенең миссияһын алдағы', 'тейеш'} 0.0
# 562 v1:  {'вазифаға'} v2:  {'', 'етәкселегендәге яллай', 'яллай'} 0.0 args1:  {'һаҡлау'} args2:  {'', 'етәкселегендәге Гарлем', 'ойошмаһы етәкселегендәге яллай Гарлем', 'ойошмаһы', 'Ким'} 0.0
# 563 v1:  {'өҫтәмә'} v2:  {'', 'финанслау алыусы', 'транспарентлыҡ үтәргә алыусы'} 0.0 args1:  {'ярҙам', 'һәм', 'тейешле'} args2:  {'', 'өҫтәмә транспарентлыҡ үтәргә алыусы процесында стандарттарына талаптарын һәм финанслау', 'үтәргә процесында стандарттарына талаптарын транспарентлыҡ һәм финанслау', 'Донъя фонды', 'өҫтәмә', 'тейешле техник стандарттарына талаптарын процесында күрһәтеү', 'процесында финанслау алыусы', 'отчеттарын'} 0.0
# 564 v1:  {'еңел'} v2:  {'бирә', 'арттырыу'} 0.0 args1:  {'кире'} args2:  {'', 'насар күренештәрҙе банктарҙың кредиттары һәм бюджет', 'ғына түгел', 'ғына түгел ә', 'еңел мөмкинлек арттырыу насар күренештәрҙе банктарҙың кредиттары һәм бюджет'} 0.0
# 565 v1:  {'эш'} v2:  {'күләмен тип', 'билдәләнгән', 'арттырыр'} 0.0 args1:  {'киләһе', 'билдәләнгән', 'дауамында'} args2:  {'', 'һалым маҡсатҡа хаҡын', 'ителгән', 'киләһе', 'ителгән киләһе Республика маҡсатҡа пакеты билдәләнгән һалым хаҡын һәм инвестицияларҙы арттырыр етештереүсәнлекте эш', 'инвестицияларҙы етештереүсәнлекте һәм эш', 'ышанабыҙ', 'киләһе Республика маҡсатҡа пакеты', 'билдәләнгән һалым маҡсатҡа хаҡын'} 1.0
# 566 v1:  {'тотоуҙы'} v2:  {'', 'арттырыуға'} 0.0 args1:  {'бомбаға'} args2:  {'бомбаға арттырыуға higher күп үҫеш кеше йәшәгән араһында юғары һәм эшһеҙлек', 'Был юғары', 'араһында бәйле алмауға арттырыуға бомбаға higher күп үҫеш кеше йәшәгән юғары һәм эшһеҙлек'} 0.0
# 567 v1:  {''} v2:  {'бар', 'теләгенә таянып', 'башлаясаҡ', ''} 0.0 args1:  {'ярҙам', 'бер', 'сауҙа', 'файҙа', 'кемгә', 'хакимиәте,'} args2:  {'килтермәйәсәк', 'америка', 'килтермәйәсәк теләгенә таянып америка Трамп хакимиәте башлаясаҡ бәхәсен бер кемгә', 'бер кемгә килтермәйәсәк', 'теләгенә таянып америка', 'бәхәсен', 'бәхәсен килтермәйәсәк бер кемгә', 'Трамп хакимиәте'} 0.0
# 568 v1:  {''} v2:  {'атаған'} 0.0 args1:  {'глобалләшеү', 'һатыу', 'тауарҙар'} args2:  {'глобалләшеү globalization', 'атаған тип маҡсатын', 'атаған һатыу һәм бирмәй', 'Матас', 'атаған тип маҡсатын һатыу һәм бирмәй'} 0.0
# 569 v1:  {'асырға'} v2:  {'асырға'} 0.0 args1:  {'баҙарҙарын'} args2:  {'', 'улар', 'тейеш', 'улар ауыл баҙарҙарын', 'ғына генә Улай шулай традицион яңы ауыл тармаҡтар хеҙмәттәр баҙарҙарын һәм хужалығы дә инвестициялар стандарттар'} 0.0
# 570 v1:  {'нығыта.'} v2:  {'', 'тәғәйенләнгәндән нығыта'} 0.0 args1:  {'Си', 'Власты'} args2:  {'', 'тәғәйенләнгәндән нығыта', 'тәғәйенләнгәндән итеп генераль секретарь ноябрендә', 'Си'} 1.0
# 571 v1:  {'булыуын'} v2:  set() nan args1:  {'Си', 'Власты'} args2:  {'', 'тәғәйенләнгәндән нығыта', 'тәғәйенләнгәндән итеп генераль секретарь ноябрендә', 'Си'} nan
# 572 v1:  {'араһында'} v2:  {''} 0.0 args1:  {'роле'} args2:  {'', 'бүлеү', 'көсөргәнешлек һаҡлана Беренсенән менән араһында роле дәүләт һәм ресурстар бүлеү'} 0.0
# 573 v1:  {''} v2:  {'булып', 'баҫылған күрһәтелгән'} 0.0 args1:  {'әлеге', 'сәйәси', 'ҡытай', 'юғары'} args2:  {'', 'отчетта', 'вазифалы структур реформалар баҫылған күрһәтелгән policymakers ғаризаһына отчетта', 'policymakers ғаризаһына отчетта', 'баҫылған Күптән күрһәтелгән отчетта сәйәси ҡытай', 'Күптән', 'юғары', 'вазифалы структур реформалар'} 1.0
# 574 v1:  {'урынды'} v2:  {'', 'кәметте белдерҙе'} 0.0 args1:  {'доклад', 'түбән'} args2:  {'ролен араһында өҫтөнлөктәре', 'был бурыстар', 'өҫтөнлөктәре ролен һәм', 'кәметте белдерҙе был бурыстар ваҡытта ролен араһында өҫтөнлөктәре', 'өҫтөнлөктәре доклад', 'был бурыстар ваҡытта ролен араһында өҫтөнлөктәре', 'Бынан', 'ваҡытта'} 0.0
# 575 v1:  {'тора,'} v2:  {''} 0.0 args1:  {'иҡтисады', 'этабында'} args2:  {'оҙайлы ғына', 'ҡарамаҫтан тип башланғыс этабында ҡытай оҙайлы ғына тик сроклы структура', 'түбәнәйеүсәнлеккә ҡарамаҫтан башланғыс этабында оптимистик отчетында сәйәси ҡытай', 'башланғыс этабында ҡытай', 'башланғыс этабында тик оҙайлы сроклы структура', 'нигеҙ', 'нигеҙ тип ҡарамаҫтан башланғыс этабында ҡытай оҙайлы ғына тик сроклы структура'} 0.0

# %%
res_2_models_ba
# Out:
#      Unnamed: 0  \
# 0             0
# 1             1
# 2             2
# 3             3
# 4             4
# ..          ...
# 571         571
# 572         572
# 573         573
# 574         574
# 575         575
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             srl_ba  \
# 0                                                                                                                                                                                                    {'verbs': [{'verb': 'күрә', 'description': {'V': 'күрә', 'Arg(субъект ментального состояния)': 'кемдәр', 'Arg(эталон)': 'кемдәр', 'Arg(стимул)': 'донъяны'}, 'tags': ['O', 'V', 'O', 'Arg(субъект ментального состояния)', 'O', 'O', 'O', 'O', 'O', 'Arg(стимул)', 'O', 'O', 'V', 'O', 'O', 'O', 'O', 'O', 'O']}], 'words': ['Шуға', 'күрә', 'мин', 'кемдәр', 'иҫ', 'киткес', 'ғәҙәти', 'күренеш,', 'улар', 'донъяны', 'бик', 'яҡшы', 'күрә', 'һәм', 'етешһеҙлектәрҙе', 'һанға', 'һуҡмай', 'тип', 'уйланым.'], 'metric': 1.0}
# 1    {'verbs': [{'verb': 'торғанда', 'description': {'V': 'торғанда', 'Arg(эталон)': 'торошта.', 'Arg(цель)': 'өлөшө', 'Arg(тема)': 'проценты', 'Arg(пациенс)': 'өлөшө', 'Arg(предмет мысли)': 'мәғлүмәттәренә'}, 'tags': ['O', 'O', 'O', 'O', 'O', 'O', 'Arg(тема)', 'O', 'O', 'O', 'O', 'V', 'O', 'O', 'Arg(цель)', 'O', 'O', 'O', 'Arg(цель)', 'O', 'O', 'Arg(предмет мысли)', 'O', 'O', 'O', 'Arg(эталон)']}], 'words': ['Әммә', 'килеме', 'түбән', 'булған', 'кешеләрҙең', '90', 'проценты', 'сирек', 'быуат', 'дауамында', 'торғонлоҡта', 'торғанда', '(һәм', 'байтаҡ', 'өлөшө', 'кәмей),', 'илдең', 'күпселек', 'өлөшө,', 'һаулыҡ', 'һаҡлау', 'мәғлүмәттәренә', 'мөрәжәғәт', 'итһәң,', 'насар', 'торошта.'], 'metric': 1.0}
# 2                                                                                                                                                                                                                                                                                                                             {'verbs': [{'verb': 'билдәһеҙ', 'description': {'V': 'билдәһеҙ', 'Arg(тема)': '-'}, 'tags': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'V', 'O', 'O', 'O', 'V', 'O']}], 'words': ['Ниндәй', 'сәйәсмәндәр', 'үткәрергә', 'Трамп,', 'ниндәй', 'улар', 'уңышлы', 'булыр', 'йәки', 'ниндәй', 'эҙемтәләре', 'булыр', '-', 'былар', 'барыһы', 'ла', 'билдәһеҙ', 'ҡала.'], 'metric': 1.0}
# 3                                                                                                                                                                                                                                                                                                                                                                                                        {'verbs': [{'verb': 'ҡайта', 'description': {'V': 'ҡайта', 'Arg(конечная точка)': 'балансҡа'}, 'tags': ['O', 'O', 'O', 'O', 'O', 'O', 'Arg(конечная точка)', 'O', 'V', 'Arg(конечная точка)']}], 'words': ['Ә', 'Был', 'Ваҡытҡа', 'Американың', 'сауҙа', 'иҫәбе', 'балансҡа', 'әйләнеп', 'ҡайта', 'ала.'], 'metric': 1.0}
# 4                                                                                                                                                                                                                                                                                   {'verbs': [{'verb': 'килтерәсәк,', 'description': {'V': 'килтерәсәк,', 'Arg(результат)': 'ҡотолғоһоҙ'}, 'tags': ['O', 'O', 'O', 'O', 'O', 'V', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'Arg(результат)', 'O', 'V']}], 'words': ['Был', 'милли', 'һаҡсыллыҡты', 'артабан', 'ҡыҫҡартыуға', 'килтерәсәк,', 'был', 'иһә', 'норманан', 'күпкә', 'юғары', 'булған', 'сауҙа', 'дефицитының', 'ҡотолғоһоҙ', 'артыуына', 'килтерәсәк.'], 'metric': 1.0}
# ..                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             ...
# 571                                                                                                                                                       {'verbs': [{'verb': 'булыуын', 'description': {'V': 'булыуын', 'Arg(содержание высказывания)': 'иҡтисадының'}, 'tags': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'Arg(содержание высказывания)', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'V', 'O', 'O', 'O', 'O', 'O', 'O', 'O']}], 'words': ['Был', 'шулай', 'уҡ', '2007', 'йылдың', 'мартында', 'ҡытай', 'иҡтисадының', 'тотороҡһоҙ,', 'тигеҙләнмәгән,', 'тигеҙһеҙ', 'һәм', '[ахыр', 'сиктә]', 'тотороҡһоҙ', 'булыуын', 'билдәләгән', 'элекке', 'премьер-министр', 'Вэнь', 'Цзябаоның', 'тәнҡитләүенә', 'бәйле.'], 'metric': 1.0}
# 572                                                                                                                                                                                                                                                                                                                                                         {'verbs': [{'verb': 'араһында', 'description': {'V': 'араһында', 'Arg(тема)': 'роле'}, 'tags': ['O', 'O', 'Arg(тема)', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'Arg(тема)', 'V', 'O', 'O']}], 'words': ['Беренсенән,', 'дәүләт', 'роле', 'һәм', 'ресурстар', 'бүлеү', 'менән', 'идара', 'итеүҙә', 'баҙар', 'роле', 'араһында', 'көсөргәнешлек', 'һаҡлана.'], 'metric': 1.0}
# 573                                                                                                            {'verbs': [{'verb': '', 'description': {'Arg(место)': 'сәйәси', 'Arg(тема)': 'ҡытай', 'Arg(эталон)': 'әлеге', 'Arg(статус)': 'юғары'}, 'tags': ['O', 'O', 'O', 'Arg(статус)', 'O', 'Arg(тема)', 'O', 'O', 'O', 'Arg(место)', 'O', 'O', 'O', 'O', 'Arg(эталон)', 'O', 'O', 'O', 'O', 'Arg(статус)', 'O', 'O', 'O']}], 'words': ['Күптән', 'түгел', 'баҫылған', 'юғары', 'вазифалы', 'ҡытай', 'чиновниктарының', 'ғаризаһына', 'ярашлы,', 'сәйәси', 'отчетта', 'күрһәтелгән', 'структур', 'реформалар', 'әлеге', 'ваҡытта', 'иҡтисади', 'сәйәсмәндәр', 'өсөн', 'юғары', 'өҫтөнлөк', 'булып', 'тора.'], 'metric': 0.8}
# 574                                                                                                                                            {'verbs': [{'verb': 'урынды', 'description': {'V': 'урынды', 'Arg(агенс)': 'доклад', 'Arg(говорящий)': 'доклад', 'Arg(результат)': 'түбән'}, 'tags': ['O', 'O', 'Arg(агенс)', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'Arg(результат)', 'V', 'O', 'O', 'O']}], 'words': ['Бынан', 'тыш,', 'доклад', 'ҡулланыусылар', 'сығымдарының', 'һәм', 'хеҙмәттәренең', 'ролен', 'кәметте,', 'әлеге', 'ваҡытта', 'был', 'бурыстар', 'иҡтисадты', 'модернизациялау', 'өҫтөнлөктәре', 'араһында', 'түбән', 'урынды', 'биләй,', 'тип', 'белдерҙе.'], 'metric': 0.8}
# 575                                                                                                                                                                                                {'verbs': [{'verb': 'тора,', 'description': {'V': 'тора,', 'Arg(эталон)': 'этабында', 'Arg(тема)': 'иҡтисады'}, 'tags': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'Arg(тема)', 'O', 'O', 'O', 'O', 'O', 'O', 'Arg(эталон)', 'O', 'V', 'O', 'O', 'O', 'O']}], 'words': ['Си', 'сәйәси', 'отчетында', 'оптимистик', 'түбәнәйеүсәнлеккә', 'ҡарамаҫтан,', 'ҡытай', 'иҡтисады', 'оҙайлы', 'сроклы', 'структура', 'трансформацияһының', 'тик', 'башланғыс', 'этабында', 'ғына', 'тора,', 'тип', 'уйларға', 'нигеҙ', 'бар.'], 'metric': 1.0}
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                result_srl_kk  \
# 0                                                                                                                                                                                         {'verbs': [{'verb': '', 'description': {'ARGM-DIS': 'Шуға', 'ARG0': 'мин уйланым', 'V': '', 'ARG1': 'кемдәр улар яҡшы етешһеҙлектәрҙе күрә күренеш донъяны бик һәм'}, 'tags': ['ARGM-DIS', 'ARG1', 'ARG0', 'ARG1', 'O', 'O', 'O', 'ARG1', 'ARG1', 'ARG1', 'ARG1', 'ARG1', 'ARG1', 'ARG1', 'ARG1', 'O', 'O', 'O', 'ARG0']}, {'verb': '', 'description': {'R-ARG1': 'кемдәр', 'V': '', 'ARG2': 'улар яҡшы етешһеҙлектәрҙе кемдәр күрә күренеш донъяны бик һәм'}, 'tags': ['O', 'ARG2', 'O', 'R-ARG1', 'O', 'O', 'O', 'ARG2', 'ARG2', 'ARG2', 'ARG2', 'ARG2', 'ARG2', 'ARG2', 'ARG2', 'O', 'O', 'O', 'O']}, {'verb': 'күрә күренеш', 'description': {'ARG0': 'улар яҡшы етешһеҙлектәрҙе кемдәр', 'R-ARG0': 'кемдәр', 'V': 'күрә күренеш', 'ARG1': 'донъяны', 'ARGM-MNR': 'бик яҡшы'}, 'tags': ['O', 'V', 'O', 'ARG0', 'O', 'O', 'O', 'V', 'ARG0', 'ARG1', 'ARGM-MNR', 'ARG0', 'V', 'O', 'ARG0', 'O', 'O', 'O', 'O']}, {'verb': '', 'description': {'ARG0': 'улар яҡшы етешһеҙлектәрҙе кемдәр', 'R-ARG0': 'кемдәр', 'V': '', 'ARG1': 'донъяны'}, 'tags': ['O', 'O', 'O', 'ARG0', 'O', 'O', 'O', 'O', 'ARG0', 'ARG1', 'O', 'ARG0', 'O', 'O', 'ARG0', 'O', 'O', 'O', 'O']}], 'words': ['Шуға', 'күрә', 'мин', 'кемдәр', 'иҫ', 'киткес', 'ғәҙәти', 'күренеш,', 'улар', 'донъяны', 'бик', 'яҡшы', 'күрә', 'һәм', 'етешһеҙлектәрҙе', 'һанға', 'һуҡмай', 'тип', 'уйланым.']}
# 1    {'verbs': [{'verb': '', 'description': {'ARG1': 'проценты кешеләрҙең', 'V': '', 'ARGM-TMP': 'кешеләрҙең илдең'}, 'tags': ['O', 'O', 'O', 'O', 'ARG1', 'O', 'ARG1', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'ARGM-TMP', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']}, {'verb': '', 'description': {'ARG1': 'күпселек түбән проценты', 'V': ''}, 'tags': ['O', 'O', 'ARG1', 'O', 'O', 'O', 'ARG1', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'ARG1', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']}, {'verb': '', 'description': {'ARG1': 'күпселек түбән проценты', 'V': ''}, 'tags': ['O', 'O', 'ARG1', 'O', 'O', 'O', 'ARG1', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'ARG1', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']}, {'verb': '', 'description': {'ARG0': 'итһәң', 'V': '', 'ARG1': ''}, 'tags': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'ARG0', 'O', 'O']}, {'verb': '', 'description': {'ARGM-DIS': 'Әммә', 'ARGM-ADV': 'итһәң', 'ARG1': 'күпселек', 'V': '', 'ARG2': 'булған'}, 'tags': ['ARGM-DIS', 'O', 'O', 'ARG2', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'ARG1', 'O', 'O', 'O', 'O', 'O', 'ARGM-ADV', 'O', 'O']}], 'words': ['Әммә', 'килеме', 'түбән', 'булған', 'кешеләрҙең', '90', 'проценты', 'сирек', 'быуат', 'дауамында', 'торғонлоҡта', 'торғанда', '(һәм', 'байтаҡ', 'өлөшө', 'кәмей),', 'илдең', 'күпселек', 'өлөшө,', 'һаулыҡ', 'һаҡлау', 'мәғлүмәттәренә', 'мөрәжәғәт', 'итһәң,', 'насар', 'торошта.']}
# 2                                                                                                                                                                                                                                                                                                                                                                                                    {'verbs': [{'verb': '', 'description': {'ARG1': 'Ниндәй ниндәй эҙемтәләре', 'ARG0': 'Трамп', 'ARGM-MOD': 'булыр', 'V': ''}, 'tags': ['ARG1', 'O', 'O', 'ARG0', 'ARG1', 'O', 'O', 'ARGM-MOD', 'O', 'ARG1', 'ARG1', 'ARGM-MOD', 'ARG1', 'O', 'O', 'O', 'O', 'O']}, {'verb': 'булыр', 'description': {'ARG1': 'улар', 'ARGM-MOD': 'булыр', 'V': 'булыр', 'ARG2': 'уңышлы'}, 'tags': ['O', 'O', 'O', 'O', 'O', 'ARG1', 'ARG2', 'ARGM-MOD', 'O', 'O', 'O', 'ARGM-MOD', 'ARG1', 'O', 'O', 'ARG1', 'O', 'O']}, {'verb': 'булыр', 'description': {'ARG2': 'Ниндәй ниндәй', 'ARG1': 'эҙемтәләре', 'ARGM-MOD': 'булыр', 'V': 'булыр'}, 'tags': ['ARG2', 'O', 'O', 'O', 'ARG2', 'O', 'O', 'ARGM-MOD', 'O', 'ARG2', 'ARG1', 'ARGM-MOD', 'ARG2', 'O', 'O', 'O', 'O', 'O']}, {'verb': '', 'description': {'ARG3': '', 'ARG1': 'былар барыһы', 'V': ''}, 'tags': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'ARG3', 'ARG1', 'ARG1', 'ARG1', 'O', 'O']}], 'words': ['Ниндәй', 'сәйәсмәндәр', 'үткәрергә', 'Трамп,', 'ниндәй', 'улар', 'уңышлы', 'булыр', 'йәки', 'ниндәй', 'эҙемтәләре', 'булыр', '-', 'былар', 'барыһы', 'ла', 'билдәһеҙ', 'ҡала.']}
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               {'verbs': [{'verb': 'ала', 'description': {'ARGM-TMP': 'Был', 'ARG1': 'балансҡа', 'V': 'ала', 'ARG2': 'ала'}, 'tags': ['O', 'ARGM-TMP', 'O', 'O', 'O', 'O', 'ARG1', 'O', 'O', 'ARG1']}, {'verb': '', 'description': {'ARG1': 'балансҡа', 'V': '', 'ARG4': ''}, 'tags': ['O', 'O', 'O', 'O', 'O', 'O', 'ARG1', 'O', 'O', 'ARG1']}], 'words': ['Ә', 'Был', 'Ваҡытҡа', 'Американың', 'сауҙа', 'иҫәбе', 'балансҡа', 'әйләнеп', 'ҡайта', 'ала.']}
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               {'verbs': [{'verb': '', 'description': {'ARG0': 'Был был', 'ARGM-MOD': '', 'V': '', 'ARG2': 'артабан күпкә артыуына килтерәсәк дефицитының юғары норманан'}, 'tags': ['ARG0', 'O', 'O', 'ARG2', 'O', 'ARG2', 'ARG0', 'O', 'ARG2', 'ARG2', 'ARG2', 'O', 'O', 'ARG2', 'O', 'ARG2', 'ARG2']}, {'verb': 'артабан артыуына', 'description': {'ARG0': 'артабан күпкә артыуына', 'R-ARG0': 'килтерәсәк', 'ARGM-MOD': '', 'ARGM-ADV': 'артабан килтерәсәк', 'V': 'артабан артыуына', 'ARG1': 'дефицитының', 'ARG2': 'күпкә юғары артабан артыуына норманан'}, 'tags': ['O', 'O', 'O', 'ARG0', 'O', 'R-ARG0', 'O', 'O', 'ARG2', 'ARG0', 'ARG2', 'O', 'O', 'ARG1', 'O', 'ARG0', 'R-ARG0']}], 'words': ['Был', 'милли', 'һаҡсыллыҡты', 'артабан', 'ҡыҫҡартыуға', 'килтерәсәк,', 'был', 'иһә', 'норманан', 'күпкә', 'юғары', 'булған', 'сауҙа', 'дефицитының', 'ҡотолғоһоҙ', 'артыуына', 'килтерәсәк.']}
# ..                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       ...
# 571                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     None
# 572                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               {'verbs': [{'verb': '', 'description': {'ARGM-ADV': '', 'V': '', 'ARG1': 'көсөргәнешлек һаҡлана Беренсенән менән араһында роле дәүләт һәм ресурстар бүлеү'}, 'tags': ['ARG1', 'ARG1', 'ARG1', 'ARG1', 'ARG1', 'ARG1', 'ARG1', 'O', 'O', 'O', 'ARG1', 'ARG1', 'ARG1', 'ARG1']}, {'verb': '', 'description': {'V': '', 'ARG1': 'бүлеү'}, 'tags': ['O', 'O', 'O', 'O', 'O', 'ARG1', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']}], 'words': ['Беренсенән,', 'дәүләт', 'роле', 'һәм', 'ресурстар', 'бүлеү', 'менән', 'идара', 'итеүҙә', 'баҙар', 'роле', 'араһында', 'көсөргәнешлек', 'һаҡлана.']}
# 573                                                                                                                                                                                                    {'verbs': [{'verb': 'баҫылған күрһәтелгән', 'description': {'ARGM-TMP': 'Күптән', 'V': 'баҫылған күрһәтелгән', 'ARG1': 'отчетта'}, 'tags': ['ARGM-TMP', 'O', 'V', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'ARG1', 'V', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']}, {'verb': 'баҫылған күрһәтелгән', 'description': {'ARG1': 'вазифалы структур реформалар', 'V': 'баҫылған күрһәтелгән', 'ARGM-LOC': 'policymakers ғаризаһына отчетта'}, 'tags': ['O', 'O', 'V', 'O', 'ARG1', 'O', 'O', 'ARGM-LOC', 'O', 'O', 'ARGM-LOC', 'V', 'ARG1', 'ARG1', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']}, {'verb': 'булып', 'description': {'ARGM-ADV': 'баҫылған Күптән күрһәтелгән отчетта сәйәси ҡытай', 'ARG1': 'вазифалы структур реформалар баҫылған күрһәтелгән policymakers ғаризаһына отчетта', 'V': 'булып', 'ARGM-TMP': 'Күптән', 'ARG2': 'юғары', 'ARGM-GOL': ''}, 'tags': ['ARGM-ADV', 'O', 'ARGM-ADV', 'ARG2', 'ARG1', 'ARGM-ADV', 'O', 'ARG1', 'O', 'ARGM-ADV', 'ARGM-ADV', 'ARGM-ADV', 'ARG1', 'ARG1', 'O', 'O', 'O', 'O', 'O', 'ARG2', 'O', 'V', 'O']}], 'words': ['Күптән', 'түгел', 'баҫылған', 'юғары', 'вазифалы', 'ҡытай', 'чиновниктарының', 'ғаризаһына', 'ярашлы,', 'сәйәси', 'отчетта', 'күрһәтелгән', 'структур', 'реформалар', 'әлеге', 'ваҡытта', 'иҡтисади', 'сәйәсмәндәр', 'өсөн', 'юғары', 'өҫтөнлөк', 'булып', 'тора.']}
# 574                                                                                                                                                                                                                                                                      {'verbs': [{'verb': '', 'description': {'ARGM-DIS': 'Бынан', 'ARG0': 'өҫтөнлөктәре доклад', 'V': '', 'ARG1': 'өҫтөнлөктәре ролен һәм', 'ARGM-ADV': 'кәметте белдерҙе был бурыстар ваҡытта ролен араһында өҫтөнлөктәре'}, 'tags': ['ARGM-DIS', 'O', 'ARG0', 'O', 'O', 'ARG1', 'O', 'ARG1', 'ARGM-ADV', 'O', 'ARGM-ADV', 'ARGM-ADV', 'ARGM-ADV', 'O', 'O', 'ARG0', 'ARGM-ADV', 'O', 'O', 'O', 'O', 'ARGM-ADV']}, {'verb': 'кәметте белдерҙе', 'description': {'ARG0': 'өҫтөнлөктәре доклад', 'V': 'кәметте белдерҙе', 'ARG1': 'был бурыстар ваҡытта ролен араһында өҫтөнлөктәре'}, 'tags': ['O', 'O', 'ARG0', 'O', 'O', 'O', 'O', 'ARG1', 'V', 'O', 'ARG1', 'ARG1', 'ARG1', 'O', 'O', 'ARG0', 'ARG1', 'O', 'O', 'O', 'O', 'V']}, {'verb': '', 'description': {'ARG0': 'был бурыстар', 'ARGM-TMP': 'ваҡытта', 'V': '', 'ARG1': 'ролен араһында өҫтөнлөктәре'}, 'tags': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'ARG1', 'O', 'O', 'ARGM-TMP', 'ARG0', 'ARG0', 'O', 'O', 'ARG1', 'ARG1', 'O', 'O', 'O', 'O', 'O']}], 'words': ['Бынан', 'тыш,', 'доклад', 'ҡулланыусылар', 'сығымдарының', 'һәм', 'хеҙмәттәренең', 'ролен', 'кәметте,', 'әлеге', 'ваҡытта', 'был', 'бурыстар', 'иҡтисадты', 'модернизациялау', 'өҫтөнлөктәре', 'араһында', 'түбән', 'урынды', 'биләй,', 'тип', 'белдерҙе.']}
# 575                                                                                                                                                                                                                {'verbs': [{'verb': '', 'description': {'ARGM-ADV': 'түбәнәйеүсәнлеккә ҡарамаҫтан башланғыс этабында оптимистик отчетында сәйәси ҡытай', 'V': '', 'ARG1': 'нигеҙ тип ҡарамаҫтан башланғыс этабында ҡытай оҙайлы ғына тик сроклы структура'}, 'tags': ['O', 'ARGM-ADV', 'ARGM-ADV', 'ARGM-ADV', 'ARGM-ADV', 'ARGM-ADV', 'ARGM-ADV', 'O', 'ARG1', 'ARG1', 'ARG1', 'O', 'ARGM-ADV', 'ARGM-ADV', 'ARGM-ADV', 'ARG1', 'O', 'ARG1', 'O', 'ARG1', 'O']}, {'verb': '', 'description': {'ARGM-CAU': 'нигеҙ', 'V': '', 'ARG1': 'ҡарамаҫтан тип башланғыс этабында ҡытай оҙайлы ғына тик сроклы структура'}, 'tags': ['O', 'O', 'O', 'O', 'O', 'ARG1', 'ARG1', 'O', 'ARG1', 'ARG1', 'ARG1', 'O', 'ARG1', 'ARG1', 'ARG1', 'ARG1', 'O', 'ARG1', 'O', 'ARGM-CAU', 'O']}, {'verb': '', 'description': {'ARG1': 'башланғыс этабында ҡытай', 'V': '', 'ARGM-ADV': 'оҙайлы ғына', 'ARG2': 'башланғыс этабында тик оҙайлы сроклы структура'}, 'tags': ['O', 'O', 'O', 'O', 'O', 'O', 'ARG1', 'O', 'ARGM-ADV', 'ARG2', 'ARG2', 'O', 'ARG2', 'ARG1', 'ARG1', 'ARGM-ADV', 'O', 'O', 'O', 'O', 'O']}], 'words': ['Си', 'сәйәси', 'отчетында', 'оптимистик', 'түбәнәйеүсәнлеккә', 'ҡарамаҫтан,', 'ҡытай', 'иҡтисады', 'оҙайлы', 'сроклы', 'структура', 'трансформацияһының', 'тик', 'башланғыс', 'этабында', 'ғына', 'тора,', 'тип', 'уйларға', 'нигеҙ', 'бар.']}
#
#      preds_kk  \
# 0         0.0
# 1         0.0
# 2         1.0
# 3         1.0
# 4         0.0
# ..        ...
# 571       NaN
# 572       NaN
# 573       NaN
# 574       NaN
# 575       NaN
#
#                                                                                                                                                                                                     sentence  \
# 0                                                                                    Шуға күрә мин кемдәр иҫ киткес ғәҙәти күренеш, улар донъяны бик яҡшы күрә һәм етешһеҙлектәрҙе һанға һуҡмай тип уйланым.
# 1    Әммә килеме түбән булған кешеләрҙең 90 проценты сирек быуат дауамында торғонлоҡта торғанда (һәм байтаҡ өлөшө кәмей), илдең күпселек өлөшө, һаулыҡ һаҡлау мәғлүмәттәренә мөрәжәғәт итһәң, насар торошта.
# 2                                                                                 Ниндәй сәйәсмәндәр үткәрергә Трамп, ниндәй улар уңышлы булыр йәки ниндәй эҙемтәләре булыр - былар барыһы ла билдәһеҙ ҡала.
# 3                                                                                                                                           Ә Был Ваҡытҡа Американың сауҙа иҫәбе балансҡа әйләнеп ҡайта ала.
# 4                                                                Был милли һаҡсыллыҡты артабан ҡыҫҡартыуға килтерәсәк, был иһә норманан күпкә юғары булған сауҙа дефицитының ҡотолғоһоҙ артыуына килтерәсәк.
# ..                                                                                                                                                                                                       ...
# 571         Был шулай уҡ 2007 йылдың мартында ҡытай иҡтисадының тотороҡһоҙ, тигеҙләнмәгән, тигеҙһеҙ һәм [ахыр сиктә] тотороҡһоҙ булыуын билдәләгән элекке премьер-министр Вэнь Цзябаоның тәнҡитләүенә бәйле.
# 572                                                                                                Беренсенән, дәүләт роле һәм ресурстар бүлеү менән идара итеүҙә баҙар роле араһында көсөргәнешлек һаҡлана.
# 573          Күптән түгел баҫылған юғары вазифалы ҡытай чиновниктарының ғаризаһына ярашлы, сәйәси отчетта күрһәтелгән структур реформалар әлеге ваҡытта иҡтисади сәйәсмәндәр өсөн юғары өҫтөнлөк булып тора.
# 574               Бынан тыш, доклад ҡулланыусылар сығымдарының һәм хеҙмәттәренең ролен кәметте, әлеге ваҡытта был бурыстар иҡтисадты модернизациялау өҫтөнлөктәре араһында түбән урынды биләй, тип белдерҙе.
# 575                          Си сәйәси отчетында оптимистик түбәнәйеүсәнлеккә ҡарамаҫтан, ҡытай иҡтисады оҙайлы сроклы структура трансформацияһының тик башланғыс этабында ғына тора, тип уйларға нигеҙ бар.
#
#      sent_len  preds_kk_new  preds_kk_args
# 0          19           0.0            1.0
# 1          26           0.0            0.0
# 2          18           0.0            0.0
# 3          10           0.0            1.0
# 4          17           0.0            0.0
# ..        ...           ...            ...
# 571        23           NaN            NaN
# 572        14           0.0            0.0
# 573        23           0.0            1.0
# 574        22           0.0            0.0
# 575        21           0.0            0.0
#
# [576 rows x 8 columns]

# %%
print((res_2_models_ba['preds_kk_args'] == 1).sum() / res_2_models_ba.shape[0])
# Out:
# 0.24305555555555555
