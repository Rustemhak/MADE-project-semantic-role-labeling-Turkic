# %%
import pandas as pd
import ast

# %%
pd.set_option("max_info_columns", 5)
pd.set_option("display.max_colwidth", None)

# %%
res_2_models_ba = pd.read_csv('data_SRL/res_2_models_ba.csv')

# %%
res_2_models_ba.head()
# Out:
#    Unnamed: 0  \
# 0           0
# 1           1
# 2           2
# 3           3
# 4           4
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           srl_ba  \
# 0                                                                                                                                                                                                  {'verbs': [{'verb': 'күрә', 'description': {'V': 'күрә', 'Arg(субъект ментального состояния)': 'кемдәр', 'Arg(эталон)': 'кемдәр', 'Arg(стимул)': 'донъяны'}, 'tags': ['O', 'V', 'O', 'Arg(субъект ментального состояния)', 'O', 'O', 'O', 'O', 'O', 'Arg(стимул)', 'O', 'O', 'V', 'O', 'O', 'O', 'O', 'O', 'O']}], 'words': ['Шуға', 'күрә', 'мин', 'кемдәр', 'иҫ', 'киткес', 'ғәҙәти', 'күренеш,', 'улар', 'донъяны', 'бик', 'яҡшы', 'күрә', 'һәм', 'етешһеҙлектәрҙе', 'һанға', 'һуҡмай', 'тип', 'уйланым.'], 'metric': 1.0}
# 1  {'verbs': [{'verb': 'торғанда', 'description': {'V': 'торғанда', 'Arg(эталон)': 'торошта.', 'Arg(цель)': 'өлөшө', 'Arg(тема)': 'проценты', 'Arg(пациенс)': 'өлөшө', 'Arg(предмет мысли)': 'мәғлүмәттәренә'}, 'tags': ['O', 'O', 'O', 'O', 'O', 'O', 'Arg(тема)', 'O', 'O', 'O', 'O', 'V', 'O', 'O', 'Arg(цель)', 'O', 'O', 'O', 'Arg(цель)', 'O', 'O', 'Arg(предмет мысли)', 'O', 'O', 'O', 'Arg(эталон)']}], 'words': ['Әммә', 'килеме', 'түбән', 'булған', 'кешеләрҙең', '90', 'проценты', 'сирек', 'быуат', 'дауамында', 'торғонлоҡта', 'торғанда', '(һәм', 'байтаҡ', 'өлөшө', 'кәмей),', 'илдең', 'күпселек', 'өлөшө,', 'һаулыҡ', 'һаҡлау', 'мәғлүмәттәренә', 'мөрәжәғәт', 'итһәң,', 'насар', 'торошта.'], 'metric': 1.0}
# 2                                                                                                                                                                                                                                                                                                                           {'verbs': [{'verb': 'билдәһеҙ', 'description': {'V': 'билдәһеҙ', 'Arg(тема)': '-'}, 'tags': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'V', 'O', 'O', 'O', 'V', 'O']}], 'words': ['Ниндәй', 'сәйәсмәндәр', 'үткәрергә', 'Трамп,', 'ниндәй', 'улар', 'уңышлы', 'булыр', 'йәки', 'ниндәй', 'эҙемтәләре', 'булыр', '-', 'былар', 'барыһы', 'ла', 'билдәһеҙ', 'ҡала.'], 'metric': 1.0}
# 3                                                                                                                                                                                                                                                                                                                                                                                                      {'verbs': [{'verb': 'ҡайта', 'description': {'V': 'ҡайта', 'Arg(конечная точка)': 'балансҡа'}, 'tags': ['O', 'O', 'O', 'O', 'O', 'O', 'Arg(конечная точка)', 'O', 'V', 'Arg(конечная точка)']}], 'words': ['Ә', 'Был', 'Ваҡытҡа', 'Американың', 'сауҙа', 'иҫәбе', 'балансҡа', 'әйләнеп', 'ҡайта', 'ала.'], 'metric': 1.0}
# 4                                                                                                                                                                                                                                                                                 {'verbs': [{'verb': 'килтерәсәк,', 'description': {'V': 'килтерәсәк,', 'Arg(результат)': 'ҡотолғоһоҙ'}, 'tags': ['O', 'O', 'O', 'O', 'O', 'V', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'Arg(результат)', 'O', 'V']}], 'words': ['Был', 'милли', 'һаҡсыллыҡты', 'артабан', 'ҡыҫҡартыуға', 'килтерәсәк,', 'был', 'иһә', 'норманан', 'күпкә', 'юғары', 'булған', 'сауҙа', 'дефицитының', 'ҡотолғоһоҙ', 'артыуына', 'килтерәсәк.'], 'metric': 1.0}
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              result_srl_kk  \
# 0                                                                                                                                                                                       {'verbs': [{'verb': '', 'description': {'ARGM-DIS': 'Шуға', 'ARG0': 'мин уйланым', 'V': '', 'ARG1': 'кемдәр улар яҡшы етешһеҙлектәрҙе күрә күренеш донъяны бик һәм'}, 'tags': ['ARGM-DIS', 'ARG1', 'ARG0', 'ARG1', 'O', 'O', 'O', 'ARG1', 'ARG1', 'ARG1', 'ARG1', 'ARG1', 'ARG1', 'ARG1', 'ARG1', 'O', 'O', 'O', 'ARG0']}, {'verb': '', 'description': {'R-ARG1': 'кемдәр', 'V': '', 'ARG2': 'улар яҡшы етешһеҙлектәрҙе кемдәр күрә күренеш донъяны бик һәм'}, 'tags': ['O', 'ARG2', 'O', 'R-ARG1', 'O', 'O', 'O', 'ARG2', 'ARG2', 'ARG2', 'ARG2', 'ARG2', 'ARG2', 'ARG2', 'ARG2', 'O', 'O', 'O', 'O']}, {'verb': 'күрә күренеш', 'description': {'ARG0': 'улар яҡшы етешһеҙлектәрҙе кемдәр', 'R-ARG0': 'кемдәр', 'V': 'күрә күренеш', 'ARG1': 'донъяны', 'ARGM-MNR': 'бик яҡшы'}, 'tags': ['O', 'V', 'O', 'ARG0', 'O', 'O', 'O', 'V', 'ARG0', 'ARG1', 'ARGM-MNR', 'ARG0', 'V', 'O', 'ARG0', 'O', 'O', 'O', 'O']}, {'verb': '', 'description': {'ARG0': 'улар яҡшы етешһеҙлектәрҙе кемдәр', 'R-ARG0': 'кемдәр', 'V': '', 'ARG1': 'донъяны'}, 'tags': ['O', 'O', 'O', 'ARG0', 'O', 'O', 'O', 'O', 'ARG0', 'ARG1', 'O', 'ARG0', 'O', 'O', 'ARG0', 'O', 'O', 'O', 'O']}], 'words': ['Шуға', 'күрә', 'мин', 'кемдәр', 'иҫ', 'киткес', 'ғәҙәти', 'күренеш,', 'улар', 'донъяны', 'бик', 'яҡшы', 'күрә', 'һәм', 'етешһеҙлектәрҙе', 'һанға', 'һуҡмай', 'тип', 'уйланым.']}
# 1  {'verbs': [{'verb': '', 'description': {'ARG1': 'проценты кешеләрҙең', 'V': '', 'ARGM-TMP': 'кешеләрҙең илдең'}, 'tags': ['O', 'O', 'O', 'O', 'ARG1', 'O', 'ARG1', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'ARGM-TMP', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']}, {'verb': '', 'description': {'ARG1': 'күпселек түбән проценты', 'V': ''}, 'tags': ['O', 'O', 'ARG1', 'O', 'O', 'O', 'ARG1', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'ARG1', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']}, {'verb': '', 'description': {'ARG1': 'күпселек түбән проценты', 'V': ''}, 'tags': ['O', 'O', 'ARG1', 'O', 'O', 'O', 'ARG1', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'ARG1', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']}, {'verb': '', 'description': {'ARG0': 'итһәң', 'V': '', 'ARG1': ''}, 'tags': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'ARG0', 'O', 'O']}, {'verb': '', 'description': {'ARGM-DIS': 'Әммә', 'ARGM-ADV': 'итһәң', 'ARG1': 'күпселек', 'V': '', 'ARG2': 'булған'}, 'tags': ['ARGM-DIS', 'O', 'O', 'ARG2', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'ARG1', 'O', 'O', 'O', 'O', 'O', 'ARGM-ADV', 'O', 'O']}], 'words': ['Әммә', 'килеме', 'түбән', 'булған', 'кешеләрҙең', '90', 'проценты', 'сирек', 'быуат', 'дауамында', 'торғонлоҡта', 'торғанда', '(һәм', 'байтаҡ', 'өлөшө', 'кәмей),', 'илдең', 'күпселек', 'өлөшө,', 'һаулыҡ', 'һаҡлау', 'мәғлүмәттәренә', 'мөрәжәғәт', 'итһәң,', 'насар', 'торошта.']}
# 2                                                                                                                                                                                                                                                                                                                                                                                                  {'verbs': [{'verb': '', 'description': {'ARG1': 'Ниндәй ниндәй эҙемтәләре', 'ARG0': 'Трамп', 'ARGM-MOD': 'булыр', 'V': ''}, 'tags': ['ARG1', 'O', 'O', 'ARG0', 'ARG1', 'O', 'O', 'ARGM-MOD', 'O', 'ARG1', 'ARG1', 'ARGM-MOD', 'ARG1', 'O', 'O', 'O', 'O', 'O']}, {'verb': 'булыр', 'description': {'ARG1': 'улар', 'ARGM-MOD': 'булыр', 'V': 'булыр', 'ARG2': 'уңышлы'}, 'tags': ['O', 'O', 'O', 'O', 'O', 'ARG1', 'ARG2', 'ARGM-MOD', 'O', 'O', 'O', 'ARGM-MOD', 'ARG1', 'O', 'O', 'ARG1', 'O', 'O']}, {'verb': 'булыр', 'description': {'ARG2': 'Ниндәй ниндәй', 'ARG1': 'эҙемтәләре', 'ARGM-MOD': 'булыр', 'V': 'булыр'}, 'tags': ['ARG2', 'O', 'O', 'O', 'ARG2', 'O', 'O', 'ARGM-MOD', 'O', 'ARG2', 'ARG1', 'ARGM-MOD', 'ARG2', 'O', 'O', 'O', 'O', 'O']}, {'verb': '', 'description': {'ARG3': '', 'ARG1': 'былар барыһы', 'V': ''}, 'tags': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'ARG3', 'ARG1', 'ARG1', 'ARG1', 'O', 'O']}], 'words': ['Ниндәй', 'сәйәсмәндәр', 'үткәрергә', 'Трамп,', 'ниндәй', 'улар', 'уңышлы', 'булыр', 'йәки', 'ниндәй', 'эҙемтәләре', 'булыр', '-', 'былар', 'барыһы', 'ла', 'билдәһеҙ', 'ҡала.']}
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             {'verbs': [{'verb': 'ала', 'description': {'ARGM-TMP': 'Был', 'ARG1': 'балансҡа', 'V': 'ала', 'ARG2': 'ала'}, 'tags': ['O', 'ARGM-TMP', 'O', 'O', 'O', 'O', 'ARG1', 'O', 'O', 'ARG1']}, {'verb': '', 'description': {'ARG1': 'балансҡа', 'V': '', 'ARG4': ''}, 'tags': ['O', 'O', 'O', 'O', 'O', 'O', 'ARG1', 'O', 'O', 'ARG1']}], 'words': ['Ә', 'Был', 'Ваҡытҡа', 'Американың', 'сауҙа', 'иҫәбе', 'балансҡа', 'әйләнеп', 'ҡайта', 'ала.']}
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             {'verbs': [{'verb': '', 'description': {'ARG0': 'Был был', 'ARGM-MOD': '', 'V': '', 'ARG2': 'артабан күпкә артыуына килтерәсәк дефицитының юғары норманан'}, 'tags': ['ARG0', 'O', 'O', 'ARG2', 'O', 'ARG2', 'ARG0', 'O', 'ARG2', 'ARG2', 'ARG2', 'O', 'O', 'ARG2', 'O', 'ARG2', 'ARG2']}, {'verb': 'артабан артыуына', 'description': {'ARG0': 'артабан күпкә артыуына', 'R-ARG0': 'килтерәсәк', 'ARGM-MOD': '', 'ARGM-ADV': 'артабан килтерәсәк', 'V': 'артабан артыуына', 'ARG1': 'дефицитының', 'ARG2': 'күпкә юғары артабан артыуына норманан'}, 'tags': ['O', 'O', 'O', 'ARG0', 'O', 'R-ARG0', 'O', 'O', 'ARG2', 'ARG0', 'ARG2', 'O', 'O', 'ARG1', 'O', 'ARG0', 'R-ARG0']}], 'words': ['Был', 'милли', 'һаҡсыллыҡты', 'артабан', 'ҡыҫҡартыуға', 'килтерәсәк,', 'был', 'иһә', 'норманан', 'күпкә', 'юғары', 'булған', 'сауҙа', 'дефицитының', 'ҡотолғоһоҙ', 'артыуына', 'килтерәсәк.']}
#
#    preds_kk  \
# 0       0.0
# 1       0.0
# 2       1.0
# 3       1.0
# 4       0.0
#
#                                                                                                                                                                                                   sentence  \
# 0                                                                                  Шуға күрә мин кемдәр иҫ киткес ғәҙәти күренеш, улар донъяны бик яҡшы күрә һәм етешһеҙлектәрҙе һанға һуҡмай тип уйланым.
# 1  Әммә килеме түбән булған кешеләрҙең 90 проценты сирек быуат дауамында торғонлоҡта торғанда (һәм байтаҡ өлөшө кәмей), илдең күпселек өлөшө, һаулыҡ һаҡлау мәғлүмәттәренә мөрәжәғәт итһәң, насар торошта.
# 2                                                                               Ниндәй сәйәсмәндәр үткәрергә Трамп, ниндәй улар уңышлы булыр йәки ниндәй эҙемтәләре булыр - былар барыһы ла билдәһеҙ ҡала.
# 3                                                                                                                                         Ә Был Ваҡытҡа Американың сауҙа иҫәбе балансҡа әйләнеп ҡайта ала.
# 4                                                              Был милли һаҡсыллыҡты артабан ҡыҫҡартыуға килтерәсәк, был иһә норманан күпкә юғары булған сауҙа дефицитының ҡотолғоһоҙ артыуына килтерәсәк.
#
#    sent_len
# 0        19
# 1        26
# 2        18
# 3        10
# 4        17

# %%
print(ast.literal_eval(res_2_models_ba.loc[0, 'srl_ba'])['verbs'][0]['verb'])
print(ast.literal_eval(res_2_models_ba.loc[0, 'result_srl_kk'])['verbs'][0]['verb'])
# Out:
# күрә

# %%
for i in range(len(res_2_models_ba)):
    try:
        verb1 = ast.literal_eval(res_2_models_ba.loc[i, 'srl_ba'])['verbs'][0]['verb']
        verb2 = set()
        for j in range(len(ast.literal_eval(res_2_models_ba.loc[i, 'result_srl_kk'])['verbs'])):
            verb2.add(ast.literal_eval(res_2_models_ba.loc[i, 'result_srl_kk'])['verbs'][j]['verb'])
        if (verb1 in verb2) & (verb1 != ""):
            res_2_models_ba.loc[i, 'preds_kk_new'] = 1
        else:
            res_2_models_ba.loc[i, 'preds_kk_new'] = 0
    except:
        pass
    print(i, 'v1: ', verb1, 'v2: ', verb2, res_2_models_ba.loc[i, 'preds_kk_new'])
# Out:
# 0 v1:  күрә v2:  {'', 'күрә күренеш'} 0.0
# 1 v1:  торғанда v2:  {''} 0.0
# 2 v1:  билдәһеҙ v2:  {'', 'булыр'} 0.0
# 3 v1:  ҡайта v2:  {'', 'ала'} 0.0
# 4 v1:  килтерәсәк, v2:  {'', 'артабан артыуына'} 0.0
# 5 v1:  барлыҡҡа v2:  {'', 'булып'} 0.0
# 6 v1:  йәки v2:  {'', 'алынған', 'төҙөлгән алынған'} 0.0
# 7 v1:  туплана. v2:  {'күренеш', 'ҡарала туплана'} 0.0
# 8 v1:  кәмеүе v2:  {'', 'күрһәтелеүенсә'} 0.0
# 9 v1:  кәметте, v2:  {'', 'йөкләмәләрҙе', 'була', 'Артабанғы һуңғы'} 0.0
# 10 v1:  был v2:  {'', 'булып', 'килемлелеген', 'булмай'} 0.0
# 11 v1:  Болсонару v2:  {'', 'араһында таяна'} 0.0
# 12 v1:   v2:  {'', 'башланы'} 0.0
# 13 v1:  төҙөү v2:  {'юҡ', 'төҙөү'} 1.0
# 14 v1:  самаһы v2:  {'', 'инвестициялап', 'була', 'һатып алып'} 0.0
# 15 v1:  хаҡтар v2:  {''} 0.0
# 16 v1:  күберәк v2:  {'', 'алыу', 'импорттан алыу'} 0.0
# 17 v1:   v2:  {'', 'булыуы'} 0.0
# 18 v1:  юғарыраҡ v2:  {'', 'етәкселегендәге мәжбүр', 'белдереүенсә', 'инвестицияларға', 'алырға', 'мәжбүр'} 0.0
# 19 v1:  хәле v2:  {''} 0.0
# 20 v1:  финанслау v2:  {'менән булдырыуҙы', 'булдырыуҙы индерелде', 'булдырыуҙы'} 0.0
# 21 v1:  35 v2:  {'йөкләмә', 'ашырыу киңәйтә', 'ашырыу арттырырға', 'Берләшкән ашырыу', 'ашырыу арттырырға киңәйтә'} 0.0
# 22 v1:  көтөргә v2:  {'', 'талап ителә', 'көтөргә'} 1.0
# 23 v1:  буйһонорға v2:  {'сәйәсәткә', 'тырыша'} 0.0
# 24 v1:  аса. v2:  {'аса'} 0.0
# 25 v1:  позицияны v2:  {'нығытырға', 'Был'} 0.0
# 26 v1:  алмаштырырға v2:  {'', 'алмаштырырға', 'әҙерләүселәрҙең алмаштырырға'} 1.0
# 27 v1:  операциялар v2:  {'', 'башҡарырға'} 0.0
# 28 v1:  мәғлүмәт v2:  {'', 'мәжбүр', 'белдереүенсә', 'контролдә'} 0.0
# 29 v1:  сығарып, v2:  {'', 'аңлау', 'кәрәклеген', 'сығарып үҙгәртеү', 'үҙгәртеү'} 0.0
# 30 v1:  пошлиналары v2:  {''} 0.0
# 31 v1:  пошлинаны v2:  {'сығарыу итеп ҡарай', 'ҡарай', 'контролдә'} 0.0
# 32 v1:  килтерәсәк. v2:  {'Хәбәр', 'килтерәсәк'} 0.0
# 33 v1:  яҡлай v2:  {'', 'яҡлай'} 1.0
# 34 v1:  күберәк v2:  {'килтерә', 'КҮРҺӘТЕҮЕНСӘ'} 0.0
# 35 v1:  сығымдарға v2:  {'килтерер', 'булып', 'һөҙөмтәлелеген максималләштереүҙә ҡаҡшатыр килтерер', 'ҡаҡшатыр килтерер'} 0.0
# 36 v1:  кәметергә v2:  {'иҡтисады билдәһеҙлектең', '', 'тырышырға', 'кире'} 0.0
# 37 v1:  теләмәй. v2:  {'', 'булырға', 'теләмәй', 'һайлаһа етәкләмәйенсә'} 0.0
# 38 v1:  хоҡуҡтарын v2:  {'һаҡлап', '', 'теләй', 'сығырҙан БЕРЛЕГЕНЕҢ'} 0.0
# 39 v1:  тамамланмауы v2:  {''} 0.0
# 40 v1:  әҙерләнгән v2:  {'әҙерләнгән әҙерләнә', 'инеүгә әҙерләнгән әҙерләнә', 'Евросоюзға инеүгә'} 0.0
# 41 v1:  айырылып v2:  {''} 0.0
# 42 v1:  яғынан v2:  {'', 'осраша'} 0.0
# 43 v1:  тураһында v2:  {'', 'итеүгә итергә', 'килә'} 0.0
# 44 v1:  хаҡы v2:  {'алып', 'күрһәткестәренә', 'арттырыуға', 'нигеҙләнгән итә'} 0.0
# 45 v1:   v2:  {'', 'түләргә'} 0.0
# 46 v1:  баһалай v2:  {'', 'алмай', 'алмаҫ алмай', 'мохтаж', 'продукцияһын етештереү', 'яңы', 'ала баһалай'} 0.0
# 47 v1:  бизнесҡа v2:  {'', 'һатыуы'} 0.0
# 48 v1:  венчурлы v2:  {'', 'структуралана', 'ҡурҡып бирәсәк'} 0.0
# 49 v1:  һайлаған v2:  {'', 'һайлаған', 'күрә'} 1.0
# 50 v1:  вәкилдәрен v2:  {'кәрәк', '', 'үткәрергә', 'йәлеп'} 0.0
# 51 v1:  шарапты v2:  {''} 0.0
# 52 v1:  тотонорға v2:  {'аңлап', '', 'яңыртылған етештереүгә булдырыласаҡ'} 0.0
# 53 v1:   v2:  {'', 'ярашлы', 'бүлеп сығарған', 'йөрөйәсәк'} 0.0
# 54 v1:  күләмендә v2:  {'', 'һүрәтләгән үҫтерәсәк туҡтатырға', 'тартып', 'buyers тартып', 'тартып алған', 'һүрәтләгән ниәтләй', 'бирәсәк', 'һүрәтләгән'} 0.0
# 55 v1:  шөғөлләнгән v2:  {'шөғөлләнгән йыһазландырылған'} 0.0
# 56 v1:  ярҙам v2:  {'ярҙам итә'} 0.0
# 57 v1:  Урбанизация v2:  {'', 'сығарған ярашлы', 'сығарған килгән', 'булып', 'артты', 'төҙөлөшө', 'артты сығарған килгән'} 0.0
# 58 v1:  бирһә v2:  {'мөмкинлек бирһә бирмәй', 'бирһә бирмәй', 'йөрөргә', 'йөрөргә эшләргә'} 0.0
# 59 v1:  иҫәпләй. v2:  {'', 'килдем', 'быны'} 0.0
# 60 v1:  ҡаршы v2:  {'', 'теләмәй'} 0.0
# 61 v1:  эшләй v2:  {'йәшәгән йәшәй', 'алмай', 'эшләй'} 1.0
# 62 v1:  буйы v2:  {'', 'көсәйтә'} 0.0
# 63 v1:  ысулдарын v2:  {'сығарыу', 'башланы', 'эҙләй'} 0.0
# 64 v1:  һайлауына v2:  {'', 'конвертацияланған ирекле контролдә тотолған', 'манипулировкалауҙа конвертацияланған', 'ғәйепләй'} 0.0
# 65 v1:  тураһында v2:  {'алып', 'алып барыу', 'һөйләшеүҙәр яҙмышы һөйләмәгән'} 0.0
# 66 v1:  әйләнеп v2:  {'һуңыраҡ', '', 'кире'} 0.0
# 67 v1:  килтерәсәк v2:  {'нигеҙләнеп арҡаһында', '', 'тигән'} 0.0
# 68 v1:  аңлатыуы v2:  {'', 'аңлатыуы'} 1.0
# 69 v1:  етәкселек v2:  {'биргән', 'була'} 0.0
# 70 v1:  инә. v2:  {''} 0.0
# 71 v1:  ителгән v2:  {'', 'ителгән'} 1.0
# 72 v1:  акцияларҙы v2:  {'', 'юғары', 'менән тигеҙләргә'} 0.0
# 73 v1:  өсөн v2:  {'артыуы артыуын арттырасаҡ', 'менән', 'компенсациялау'} 0.0
# 74 v1:  етештереүселәрен v2:  {'', 'борсомайынса', 'мәжбүр итә', 'ашыу'} 0.0
# 75 v1:  аша v2:  {'артҡандыр', 'трендыул', 'таратылған'} 0.0
# 76 v1:  раҫлай. v2:  {'түләгән', 'раҫлай'} 0.0
# 77 v1:  үҙгәртергә, v2:  {'', 'финанслау'} 0.0
# 78 v1:  юғары v2:  {'', 'бирә', 'бирә юғары'} 0.0
# 79 v1:  дискредитациялау v2:  {'', 'advised бурысы', 'иткән', 'дискредитациялау', 'кәңәш'} 1.0
# 80 v1:  пакеттарын v2:  {'', 'башлаған', 'тарттырылмағандыр', 'тарттырылмағандыр башлаған'} 0.0
# 81 v1:  һәм v2:  {'', 'әҙерләү бирергә булдырырға', 'яҡшыртырға', 'бирергә', 'бирергә яҡшыртырға'} 0.0
# 82 v1:  симпозиумға v2:  {'барлыҡҡа', 'нығытыу'} 0.0
# 83 v1:  үҙгәртә v2:  {'', 'талап', 'башланы'} 0.0
# 84 v1:  күрһәтә. v2:  {'күрһәтә', 'илһамландыра күрһәтә'} 0.0
# 85 v1:  бара. v2:  {'', 'булдырыу'} 0.0
# 86 v1:  байлыҡтан v2:  {'', 'алмаҫ'} 0.0
# 87 v1:  процесҡа v2:  {'', 'йәлеп'} 0.0
# 88 v1:  алырға v2:  {'зыянға файҙа'} 0.0
# 89 v1:  менән v2:  {'барған бара', 'барған алға'} 0.0
# 90 v1:  хаҡта v2:  {'', 'һөйләй'} 0.0
# 91 v1:  эҙләргә v2:  {'', 'ҡатмарлаштыра'} 0.0
# 92 v1:  роль v2:  {'уйнағаны'} 0.0
# 93 v1:  өҫтөнлөк v2:  {''} 0.0
# 94 v1:  ниндәй v2:  {'', 'ышаныслылығын', 'күрһәтегеҙ', 'булмаған', 'алға киткән итә көткәнен'} 0.0
# 95 v1:  доллары) v2:  {'', 'талабы тейеш', 'исеме Яңы', 'штраф һалынасаҡ'} 0.0
# 96 v1:  ҡыҫҡартыла. v2:  {'', 'алып', 'һалым әҙер'} 0.0
# 97 v1:  килешеүен v2:  {'', 'яуап', 'башлай', 'ала башлай алаБигерәк тартҡас', 'итеп'} 0.0
# 98 v1:  сикләргә v2:  {'ҡатыландырырға', 'ниәтләй'} 0.0
# 99 v1:  был v2:  {'итергә', 'булыуынса юҡ', 'булыуынса'} 0.0
# 100 v1:  йоғонто v2:  {'', 'эшләй ойошҡан'} 0.0
# 101 v1:  йылдың v2:  {'рөхсәт', '', 'тамамлана'} 0.0
# 102 v1:  уйнай. v2:  {''} 0.0
# 103 v1:  алырға v2:  {'', 'менән хәлдәрҙә төрлө', 'менән бәйле төрлө'} 0.0
# 104 v1:  зыян v2:  {'', 'зыян'} 1.0
# 105 v1:  һөйләргә v2:  {'', 'аңлау', 'һөйләргә'} 1.0
# 106 v1:  үткәрәһегеҙ v2:  {'', 'танышаһығыҙ билдәләй', 'булырға', 'уҡыйһығыҙ һөйләшәһегеҙ', 'һөйләшәһегеҙ', 'күрә', 'күҙлегенән', 'айыра'} 0.0
# 107 v1:   v2:  {'', 'булмай'} 0.0
# 108 v1:  өйрәтәләр, v2:  {'бар', 'өйрәтәләр'} 0.0
# 109 v1:  конкурентлыҡ v2:  {'эшҡыуарлыҡты эшләгән конкурентлыҡ', 'эшҡыуарлыҡты эшләгән', 'таратыуға', 'таратыуға сәнәғәт дәртләндерә', 'нигеҙетехнологияларҙы'} 0.0
# 110 v1:  белә. v2:  {'', 'үҙен килгән', 'яҡлай', 'белә'} 0.0
# 111 v1:  тарафынан v2:  {'булды', 'тарафынан өҙөлгән', 'тырыша', 'үлтереүселәр өҙөлгән еткерергә тырыша'} 0.0
# 112 v1:  килемен v2:  {'яҡшыртырға', 'стреыла ала', 'яҡшыртырға арттырырға', 'биреү', 'Башланғыс'} 0.0
# 113 v1:  293-ө v2:  {'йыйған алды'} 0.0
# 114 v1:  буйынса v2:  {'ашырылырға'} 0.0
# 115 v1:  стратегия v2:  {'', 'табырға'} 0.0
# 116 v1:  структура v2:  {'яһағандан билдәләргә', 'яһағандан', 'тырыша', 'анализ яһағандан'} 0.0
# 117 v1:  сараларҙы v2:  {'бара', 'шулай иғтибар итә оҙатып бара'} 0.0
# 118 v1:  маҡсатын v2:  {'билдәләмәй'} 0.0
# 119 v1:  текле v2:  {'', 'һәм', 'алдағы', 'кәрәкле', 'талап итә'} 0.0
# 120 v1:  йәлеп v2:  {'', 'булып'} 0.0
# 121 v1:  бирә: v2:  {'', 'бирә', 'илгә килем', 'алыу', 'булһа'} 0.0
# 122 v1:   v2:  {'', 'иткән', 'мөмкинлек', 'булып', 'тырыша'} 0.0
# 123 v1:  ята. v2:  {''} 0.0
# 124 v1:  эшләмәй. v2:  {'', 'яһаған', 'булмаған', 'иткәндә яһаған'} 0.0
# 125 v1:  кәметәсәк. v2:  {''} 0.0
# 126 v1:  килергә, v2:  {'', 'танылыуынса', 'килергә'} 0.0
# 127 v1:  билдәләү, v2:  {'', 'кәрәкмәгән'} 0.0
# 128 v1:  раҫлай. v2:  {'раҫлай'} 0.0
# 129 v1:  иҫәпләйҙәр. v2:  {''} 0.0
# 130 v1:  етешһеҙлектәре v2:  {'ярыша', 'етешһеҙлектәре', 'бар'} 1.0
# 131 v1:  күренә. v2:  {'', 'булып күренә', 'урынлашҡан'} 0.0
# 132 v1:  сигенһә, v2:  {''} 0.0
# 133 v1:  рецессиянан v2:  {'', 'көрсөгөнән күрә һалынған килтерә', 'һалынған килтерә', 'veto көрсөгөнән вето'} 0.0
# 134 v1:  сикһеҙ v2:  {'', 'ышандыра', 'strengthening нығытыу йомшартып', 'нығытыу тергеҙеү', 'softening нығытыу', 'башланыуы', 'эшләргә'} 0.0
# 135 v1:  тора v2:  {'', 'һәләтлелеген'} 0.0
# 136 v1:  ҡырҡа v2:  {'', 'кимәлен', 'мөмкин', 'өлгәшеүҙең иткән килеүен'} 0.0
# 137 v1:  тәғәйенләнеү v2:  {'барып', 'емерелгән'} 0.0
# 138 v1:  көтә, v2:  {'', 'килгән торлаҡ', 'һайлаған килгән', 'көтә'} 0.0
# 139 v1:  башлана. v2:  {'', 'бирелә', 'башлана'} 0.0
# 140 v1:  күрһәтә v2:  {''} 0.0
# 141 v1:  ҡайта v2:  {'', 'тураһында', 'яуап'} 0.0
# 142 v1:  тирә-йүндәгеләр v2:  {'ҡыҫып төшөрә', 'күренә', 'ҡыҫып'} 0.0
# 143 v1:  контролгә v2:  {'', 'алынған'} 0.0
# 144 v1:  маташыу v2:  {'', 'шул иҫәптән'} 0.0
# 145 v1:  сәйәсәтендә v2:  {'сигнал бирә'} 0.0
# 146 v1:  асҡан v2:  {'', 'асҡан'} 1.0
# 147 v1:  демократияһын v2:  {'', 'формалаштырған', 'уйлау'} 0.0
# 148 v1:  тип v2:  {'ҡараған', '', 'тип'} 1.0
# 149 v1:  идара v2:  {'', 'алып', 'тип'} 0.0
# 150 v1:  сауҙа v2:  {''} 0.0
# 151 v1:  төрҙәрен v2:  {'', 'үҙгәртеүҙең'} 0.0
# 152 v1:  белмәй v2:  {'белмәй', 'булған'} 1.0
# 153 v1:  яулай v2:  set() nan
# 154 v1:  күпмелер v2:  {'булды булып'} 0.0
# 155 v1:  бик v2:  {''} 0.0
# 156 v1:  сығымдары v2:  {'', 'булып'} 0.0
# 157 v1:  булып v2:  {'ҡарамаҫтан', 'булып'} 1.0
# 158 v1:  иртәрәк v2:  {'', 'индикаторКөньяҡ'} 0.0
# 159 v1:  темптары v2:  {''} 0.0
# 160 v1:  бар: v2:  {'итә', 'әҙерләнеүен итә', 'бар', 'Үҫешеүсе'} 0.0
# 161 v1:  асырға v2:  {'', 'иҡтисадты ышандырһа', 'буласаҡ', 'асырға'} 1.0
# 162 v1:  йыйыр. v2:  {'', 'көтөлгәнсә', 'өстән'} 0.0
# 163 v1:  ҡулланырға v2:  {'', 'тыуҙыра', 'бүлеү'} 0.0
# 164 v1:  ҙә v2:  {'', 'була'} 0.0
# 165 v1:  кәметергә v2:  {'', 'ярҙам итә'} 0.0
# 166 v1:  һәм v2:  {'', 'иҫәптән инә'} 0.0
# 167 v1:  күберәк v2:  {'', 'стимуллаштыра', 'башлай', 'күберәк алыу өсөн'} 0.0
# 168 v1:  эшләй. v2:  {'эшләй'} 0.0
# 169 v1:  талап v2:  {'үҫтереү', 'инвестициялар', 'булмағанса', 'талап'} 1.0
# 170 v1:  таянып v2:  {'баҫылып таянып', 'баҫылып', 'иҫбатлап', 'таянып иҫбатлап'} 0.0
# 171 v1:  менән v2:  {'тарата итә', 'тарата'} 0.0
# 172 v1:  алды. v2:  {'алды'} 0.0
# 173 v1:  ҡабул v2:  {'итә', 'көрсөгөнән Булған араһында'} 0.0
# 174 v1:  иҫәпләйем. v2:  {'', 'иҫәпләйем'} 0.0
# 175 v1:  улар v2:  {'', 'мәжбүр', 'теләмәһә теләмәй', 'көсләп'} 0.0
# 176 v1:   v2:  {'', 'яҙмайым', 'теләмәгән кире', 'кире'} 0.0
# 177 v1:  уларҙың v2:  {'вәғәҙә бирәм', 'бирәм'} 0.0
# 178 v1:  тыйыу v2:  {'', 'буласағын', 'буласағын шөғөлләнгән', 'шөғөлләнгән көсөнә'} 0.0
# 179 v1:  донъя v2:  {'', 'килмәй', 'билдәләүенсә', 'төрлө билдәләүенсә'} 0.0
# 180 v1:  ҡаршы v2:  {'', 'килтерә'} 0.0
# 181 v1:   v2:  {'', 'булмаған', 'һаҡланыуы', 'ышанмай'} 0.0
# 182 v1:  әйтә v2:  {'', 'әйтә'} 1.0
# 183 v1:  асыҡлауға v2:  {'раҫлаған аңлай', 'аңлай', 'килтергән', 'булыуын'} 0.0
# 184 v1:  һала. v2:  {''} 0.0
# 185 v1:  контрактты v2:  {'', 'ҡаплау үтәүҙән'} 0.0
# 186 v1:  тенденцияларҙы v2:  {'', 'ашырһа', 'бер', 'туҡтатырға'} 0.0
# 187 v1:   v2:  {'', 'күскенселәрҙең'} 0.0
# 188 v1:  үҙгәртер v2:  {'ине', ''} 0.0
# 189 v1:  менән v2:  {'биреү', 'таҙалығын һаҡлау'} 0.0
# 190 v1:  юл v2:  {'ҡайтып', 'берләштереп әйләнеп'} 0.0
# 191 v1:  ярҙамында v2:  {'', 'стратегия эшкәртеүҙең', 'яҡшырта', 'таба бирә', 'бирә'} 0.0
# 192 v1:  ситләтелгән v2:  {'', 'гарантиялай', 'иткән', 'ситләтелгән гарантиялай иткән киңәйтеүҙә'} 0.0
# 193 v1:  сағылдырыу v2:  {''} 0.0
# 194 v1:  бүленешен v2:  {'билдәләй', 'бүленешен'} 1.0
# 195 v1:  тирәләй v2:  {'мөмкин', 'реформалаштырырға бөтөрөргә сикләгән', 'реформалаштырырға ҡыҫҡартырға бөтөрөргә сикләгән', 'реформалаштырырға', 'табыуҙар', 'реформалаштырырға ҡыҫҡартырға бөтөрөргә'} 0.0
# 196 v1:  реформалау v2:  {'реформалау', 'булмаҫ', 'булған'} 1.0
# 197 v1:  индустрияһын v2:  {'ҡатнашам'} 0.0
# 198 v1:  көслө v2:  {'', 'мөмкинлек бирә'} 0.0
# 199 v1:  проекттарын v2:  {'', 'Ҡулланыусылар ҡушылғанға', 'монетизацияларға'} 0.0
# 200 v1:  тип v2:  {'', 'тип тасуирлай'} 0.0
# 201 v1:  лә v2:  {''} 0.0
# 202 v1:  ҡалды. v2:  {'булып', 'килде'} 0.0
# 203 v1:  бүлеү v2:  {'', 'вәғәҙә'} 0.0
# 204 v1:  артты. v2:  {'', 'менән сағыштырғанда', 'артты', 'йәшәүсе'} 0.0
# 205 v1:  һаҡлап v2:  {'', 'һанала'} 0.0
# 206 v1:  өсөн v2:  {'әҙерләнгән', 'әҙерләнгән тәржемәләренә'} 0.0
# 207 v1:  кәметә. v2:  {'ташыуға йүнәлтелгән', 'артыуына', 'йүнәлтелгән килтерһә'} 0.0
# 208 v1:  эшләй. v2:  {'алып', 'гражданы иҫәптән', 'эшләй'} 0.0
# 209 v1:  составын v2:  {'', 'киңәйтергә'} 0.0
# 210 v1:  килеп v2:  {'', 'Барған'} 0.0
# 211 v1:  идара v2:  {'', 'идара'} 1.0
# 212 v1:  кәметеү v2:  {'', 'ауырлаштыра', 'тотороҡландырыуҙы', 'булыу', 'тотороҡландырыуҙы стабилләштереү'} 0.0
# 213 v1:  ярҙам v2:  {'', 'буласаҡ'} 0.0
# 214 v1:  план v2:  {'яҙылған', 'раҫлай'} 0.0
# 215 v1:  берләштерә. v2:  {'', 'ҡамасаулаусы'} 0.0
# 216 v1:  билдәләргә v2:  {'', 'ярҙам итер', 'булыу'} 0.0
# 217 v1:  аға v2:  {''} 0.0
# 218 v1:  килтерә. v2:  {'тарала килтерә', 'башланған', 'тарала', 'артабан'} 0.0
# 219 v1:  хаҡҡа v2:  {'', 'һатыла'} 0.0
# 220 v1:  кимәлгә v2:  {'', 'кире'} 0.0
# 221 v1:  үтте? v2:  {''} 0.0
# 222 v1:   v2:  {'яҡшырта', 'булып үткән'} 0.0
# 223 v1:  мөрәжәғәт v2:  {'', 'көрсөктән'} 0.0
# 224 v1:  хөкүмәткә v2:  {'', 'ҡарашты ҡыҫҡартып', 'ҡарашты итәләр', 'ҡыҫҡартып'} 0.0
# 225 v1:  отчет v2:  {''} 0.0
# 226 v1:  биргән v2:  {'', 'элитаға', 'биргән'} 1.0
# 227 v1:  уны v2:  {'баһалай'} 0.0
# 228 v1:  белә, v2:  {'көрсөгөн өйрәнгән', '', 'белә'} 0.0
# 229 v1:  итеү v2:  {''} 0.0
# 230 v1:  дәүере v2:  {'', 'башланғанын', 'оноторға', 'йәшәгәнен'} 0.0
# 231 v1:  көсәймәй. v2:  {''} 0.0
# 232 v1:  килтерәсәк v2:  {'', 'артмаясаҡ юҡ', 'килтерәсәк'} 1.0
# 233 v1:  элитаның v2:  {'таныла', 'тыуҙыра'} 0.0
# 234 v1:  формалаштыра. v2:  {'', 'була', 'формалаштыра'} 0.0
# 235 v1:  сауҙанан v2:  {'', 'алған', 'әйтеүенсә'} 0.0
# 236 v1:  күрә. v2:  {'күрә'} 0.0
# 237 v1:  йәшәй, v2:  {'', 'йәшәй', 'юҡ', 'уйлап'} 0.0
# 238 v1:  кәметә, v2:  {'', 'reduces increases артыуына', 'биреүсенең', 'increase increases', 'буласаҡ'} 0.0
# 239 v1:  әйтергә v2:  {'әйтергә', '–'} 1.0
# 240 v1:  француздарҙан v2:  {''} 0.0
# 241 v1:  урынды v2:  {'көрсөгөнә көйләү урынды биләй'} 0.0
# 242 v1:  уйнай v2:  {'ҡарағанда'} 0.0
# 243 v1:  алдан v2:  {'', 'кәрәкмәүен'} 0.0
# 244 v1:  барғанда, v2:  {'', 'тураһында барғанда'} 0.0
# 245 v1:  ныҡлы v2:  {'булдырыу', 'хуплаған'} 0.0
# 246 v1:  партнерлығын v2:  {'', 'яҡлап һаҡлап', 'яҡлап һаҡлап ҡала'} 0.0
# 247 v1:  арбаһын v2:  {'', 'ала'} 0.0
# 248 v1:  хәл v2:  {'булыр'} 0.0
# 249 v1:  эшләү? v2:  {''} 0.0
# 250 v1:  яңылыҡтарға v2:  {'ышанырға'} 0.0
# 251 v1:  эш v2:  {'кәрәк', 'бәйле', 'башҡарырға', ''} 0.0
# 252 v1:  һығылмалы v2:  {'', 'көрсөгө Күрһәтеүенсә', 'менән'} 0.0
# 253 v1:  ай v2:  set() 0.0
# 254 v1:  биләп, v2:  {'Әйтеүенсә', '', 'алыу', 'буласаҡ'} 0.0
# 255 v1:  булып v2:  {'еңгәндән', 'булһа булып'} 0.0
# 256 v1:  тип v2:  {'яҡлаған раҫланы', 'итә яҡлаған', 'лидеры яҡлаған', 'яҡлаған'} 0.0
# 257 v1:  эштәргә v2:  {''} 0.0
# 258 v1:  үлтергән v2:  {'үлтергән', 'бар'} 1.0
# 259 v1:  киләсәк. v2:  {''} 0.0
# 260 v1:  уйлайым, v2:  {'', 'булды', 'һалды'} 0.0
# 261 v1:  билдәләрен v2:  {'', 'күрһәтә'} 0.0
# 262 v1:  янай v2:  {'', 'башлай'} 0.0
# 263 v1:  ҡарашҡа v2:  {'', 'килтереү'} 0.0
# 264 v1:  дөрөҫлөктө v2:  {'', 'айырып', 'ярашлы яһау', 'таянғанлыҡтан'} 0.0
# 265 v1:  йыл v2:  {'', 'таралған', 'йүнәлтелгән уйланылған итә'} 0.0
# 266 v1:  эшкәртергә v2:  {'', 'өйрәттеләр'} 0.0
# 267 v1:  яуаплылыҡҡа v2:  {'', 'тыуҙырған'} 0.0
# 268 v1:  килтерер, v2:  {'', 'үтәлә көтөлмәгән килтерер', 'килтерер'} 0.0
# 269 v1:  булышлыҡ v2:  {'булышлыҡ итә'} 0.0
# 270 v1:  урындарын v2:  {'', 'ярыша', 'бүленә', 'алға'} 0.0
# 271 v1:  компанияларға v2:  {'', 'китә', 'йүнәлтелгән страховкалау менән хәсрәтләнә арта', 'итеп йүнәлтелгән сәйәсәте менән хәсрәтләнә'} 0.0
# 272 v1:  адаптив v2:  {'стреылған көрсөгөнән башланған адаптив тартырға', 'тартырға', 'стреыла'} 0.0
# 273 v1:   v2:  {'төшөүе', '', 'булған', 'белә'} 0.0
# 274 v1:  килһә, v2:  {'барлыҡҡа', 'барлыҡҡа булыр', 'борсолоу'} 0.0
# 275 v1:  ваҡытта v2:  {'', 'артыуы', 'артыуы тырыша', 'тырыша'} 0.0
# 276 v1:  ҡала, v2:  {'', 'тенденцияларға', 'финанслауға', 'нигеҙендәге', 'булып', 'арта юғарыраҡ бүленергә'} 0.0
# 277 v1:  компаниялар v2:  {'', 'артабан үҫтереү баҫтырыу', 'яңы конкурентлыҡ', 'һатып', 'үҫтереү баҫтырыу'} 0.0
# 278 v1:  мөмкинлектәр v2:  {'ҡалдырмай', 'нигеҙләнгән'} 0.0
# 279 v1:  тип v2:  {'атаным'} 0.0
# 280 v1:  артыуына v2:  {'итегеҙ', 'арттырыу'} 0.0
# 281 v1:  проценттан v2:  {'финансланған', 'артмай'} 0.0
# 282 v1:  процентҡа v2:  {''} 0.0
# 283 v1:  өлөштө v2:  {'арттырыу арттыра', 'арттырыу'} 0.0
# 284 v1:  тип v2:  {'ҡарап ҡыҫыла'} 0.0
# 285 v1:  буласағын v2:  {'таный', '', 'буласағын'} 1.0
# 286 v1:  кеше v2:  {''} 0.0
# 287 v1:  итергә v2:  {'кәрәк', 'кимәлдә һайлай', 'теләһә кәрәк', 'конкурентлыҡ'} 0.0
# 288 v1:  Японияла v2:  {'мөмкинлек биргән', 'йәшәргә', 'төҙөргә биргән'} 0.0
# 289 v1:  мөмкинлектәрен v2:  {'дискредитациялай шартлата', '', 'дискредитациялай'} 0.0
# 290 v1:  миҫалы v2:  {'атаған'} 0.0
# 291 v1:  мәнфәғәтендә v2:  {'', 'эшләүен', 'раҫлай', 'булмай'} 0.0
# 292 v1:  индерергә v2:  {''} 0.0
# 293 v1:  көйләү v2:  {'', 'итеүҙә', 'менән', 'килгән'} 0.0
# 294 v1:  булған v2:  {'', 'үҙгәреүсән', 'булып', 'булып ҡалмай'} 0.0
# 295 v1:  нығыраҡ v2:  {'раҫлай'} 0.0
# 296 v1:  юғалта. v2:  {'', 'юғалта'} 0.0
# 297 v1:  ҡала. v2:  {'', 'булып'} 0.0
# 298 v1:  сығара. v2:  {'сығара', '', 'булдырыу'} 0.0
# 299 v1:  әммә v2:  {'', 'теләй', 'ҡалырға'} 0.0
# 300 v1:  һала. v2:  {'нигеҙендә үҙгәртеп ҡиммәттәрендә', '', 'үҙгәртеп ҡороуға консерватория'} 0.0
# 301 v1:  юҡҡа v2:  {'', 'көсһөҙләнә тапшырыла'} 0.0
# 302 v1:  конфликтҡа v2:  {'йылыныунасар', 'башланған', 'башланған килтерә'} 0.0
# 303 v1:  национализациялай. v2:  {'национализациялай'} 0.0
# 304 v1:  асыҡланған v2:  {'иғтибарға иҡтисады', 'юғарыраҡ', 'ала'} 0.0
# 305 v1:  өҫтәлһә. v2:  {''} 0.0
# 306 v1:  күрһәттем. v2:  {'яһап күрһәттем', 'күрһәттем'} 0.0
# 307 v1:   v2:  {'башланым', 'эҙләп тейеш', 'тейеш', 'был эште'} 0.0
# 308 v1:  билдәләргә v2:  {'', 'билдәләргә'} 1.0
# 309 v1:  әле v2:  {'талап ителә', 'булдырырға', 'күрмәйбеҙ', 'ҡамасаулау'} 0.0
# 310 v1:  подразделениеһы v2:  {'', 'булып', 'контролдә'} 0.0
# 311 v1:  буфер v2:  {'күрәбеҙ', 'ойошторорға', 'булыуын'} 0.0
# 312 v1:  менән v2:  {'', 'кимәле эштә башлай', 'аңлай', 'башлай'} 0.0
# 313 v1:  ҡала. v2:  {'етәкләгән', 'булып'} 0.0
# 314 v1:  донъяға v2:  {'суверенитетты', 'онотмай юғалтмайынса', 'юғалтмаған юғалтмайынса'} 0.0
# 315 v1:  күрҙек. v2:  {'күрҙек'} 0.0
# 316 v1:  кәметә. v2:  {'', 'эшләй'} 0.0
# 317 v1:  экспектацияның v2:  {'килтерҙе', 'булыуҙан', 'килтерҙе булыуҙан туҡтай'} 0.0
# 318 v1:  дә v2:  {'', 'һөҙөмтәлелеген рекламалана', 'артыуға', 'артыуға компенсация', 'кире артыуға'} 0.0
# 319 v1:  табышты v2:  {'', 'айырырға', 'килтерһә тырышҡан', 'килтерһә'} 0.0
# 320 v1:  өсөн v2:  {'', 'йүнәлтелергә'} 0.0
# 321 v1:  килгән v2:  {'килгән', 'булып'} 1.0
# 322 v1:  сикләргә v2:  {'әҙерләргә', '', 'тейеш', 'кәрәк тейеш'} 0.0
# 323 v1:  пистолеттан v2:  {'ҡайтарыуға', 'эҙләгәндә ҡайтарыуға һалған', 'эҙләгәндә һалған'} 0.0
# 324 v1:  булып v2:  {'туҡтатты', 'ҡабатланыуын', 'булып'} 1.0
# 325 v1:  булараҡ v2:  {''} 0.0
# 326 v1:  үлтерелеүгә v2:  {'килтергән тигәнде', 'тигәнде аңлата'} 0.0
# 327 v1:  талап v2:  {'', 'туплап', 'талап иткән', 'туплап арала'} 0.0
# 328 v1:  торғанда, v2:  {'барыбыҙ'} 0.0
# 329 v1:  осраҡтары v2:  {''} 0.0
# 330 v1:  янай. v2:  {''} 0.0
# 331 v1:  ла, v2:  {'тураһындағы индерелгән үҙгәрештәргә бирә', '', 'бирә', 'сараһына'} 0.0
# 332 v1:  фонды v2:  {'Respond', 'хәүефһеҙлеген шөғөлләнгән яллаған', 'хәүефһеҙлеген шөғөлләнгән', 'шөғөлләнгән'} 0.0
# 333 v1:  ҡулын v2:  {'мөрәжәғәт', '', 'ойошторолған', 'алып итте'} 0.0
# 334 v1:  тураһында v2:  {'', 'яһағанлыҡтан һөйләргә'} 0.0
# 335 v1:  күләме v2:  {''} 0.0
# 336 v1:  MTVA v2:  {'килгәндән', 'килгәндән сығара'} 0.0
# 337 v1:  килтермәй. v2:  {'яраҡлаштыра', 'килтермәй'} 0.0
# 338 v1:  ҡаты v2:  {'булмаған нығыта', '', 'булмаған була', 'нығыта'} 0.0
# 339 v1:  көсөргәнешлекте v2:  {'сикләй', 'көсөргәнешлекте'} 1.0
# 340 v1:  балансты v2:  {'', 'сағыштырғанда башланы һаҡлап', 'менән сағыштырғанда', 'башланы', 'булмаһа'} 0.0
# 341 v1:  кәмеүен v2:  {'ҡарамаҫтан итә', ''} 0.0
# 342 v1:  икеләтә v2:  {'', 'артыуын', 'билдәләй'} 0.0
# 343 v1:  юҡ v2:  {'', 'Көнсығыш оҙайлы', 'осрай өҫтөнлөгөнә', 'өҫтөнлөгөнә алып', 'күрһәтә'} 0.0
# 344 v1:  көтөргә v2:  {''} 0.0
# 345 v1:  менән v2:  {'', 'эш'} 0.0
# 346 v1:  тәьмин v2:  {'', 'барАлексей'} 0.0
# 347 v1:  кампанияһын v2:  {'анализлай', 'мөмкинлек бирә', 'һайлау'} 0.0
# 348 v1:  сығарҙы, v2:  {'һатып алыуға', 'ҡараған', 'сығарҙы', 'күрһәтте ҡараған', 'күрһәтте', 'һатып алыуын ҡараған'} 0.0
# 349 v1:  тураһында v2:  {'ҡаршы алдынан', 'ителгән яһарға', 'ителгән талап иткән', ''} 0.0
# 350 v1:  үҙ v2:  {'эшләүен ярашлы', 'ҡарамаҫтан', 'күрә', 'ҡолатырға'} 0.0
# 351 v1:  талап v2:  {'', 'талап'} 1.0
# 352 v1:  эшләмәһәләр, v2:  {'', 'эшмәкәрлеген оҙатыусы'} 0.0
# 353 v1:  йыл v2:  {'башланған башланыу', 'башланған тамамлана'} 0.0
# 354 v1:  яҡшыртыусы v2:  {'', 'мөмкинлек бирҙе', 'яҡшыртыусы'} 1.0
# 355 v1:  өҫтөнлөк v2:  {'башынан булмауы', '', 'булмауы'} 0.0
# 356 v1:  дауам v2:  {'иҡтисадына ҡаршы башлаған итә', 'башлаған'} 0.0
# 357 v1:  ингән v2:  {'ситләтеп', 'иҡтисадҡа ерҙә һалынасаҡ'} 0.0
# 358 v1:  килем v2:  {'түләү сығарыуға', 'сығарыуға килтерә'} 0.0
# 359 v1:  та v2:  {'', 'таратыласаҡ', 'булмаған', 'алынған'} 0.0
# 360 v1:  борсолһа, v2:  set() nan
# 361 v1:  файҙаланырға v2:  {'', 'тыуҙырған'} 0.0
# 362 v1:  алыу v2:  {'барлыҡҡа', 'һорау'} 0.0
# 363 v1:  атаған v2:  {'', 'юл киләсәк', 'атаған', 'эске үтергә', 'башлана'} 1.0
# 364 v1:  һанала, v2:  {'һанала'} 0.0
# 365 v1:  һымаҡ v2:  {'', 'күренә'} 0.0
# 366 v1:  тыңлай. v2:  {'тыңлаусылары һоҡланып тыңлай', 'тыңлаусылары көрсөгө ҡарарында'} 0.0
# 367 v1:  иҫәпләй. v2:  {'', 'тип'} 0.0
# 368 v1:  туплауҙың v2:  {'күрһәтте'} 0.0
# 369 v1:  ҡулында v2:  {'башҡарма туплай', 'туплай'} 0.0
# 370 v1:  сәйәсәттең v2:  {'ҡала'} 0.0
# 371 v1:  магазиндарына v2:  {'килә', 'һатып'} 0.0
# 372 v1:  һаҡланыуын v2:  {'баһаланы'} 0.0
# 373 v1:   v2:  {'', 'бергә тикшерә'} 0.0
# 374 v1:  һүҙҙәр v2:  {'эшләне', 'уртаҡлашты'} 0.0
# 375 v1:  үҙгәрешһеҙ v2:  {''} 0.0
# 376 v1:  кеүек v2:  {'эшләй'} 0.0
# 377 v1:  МЕНӘН v2:  {''} 0.0
# 378 v1:  рәсәй v2:  {'составына ингән'} 0.0
# 379 v1:  ултыра. v2:  {''} 0.0
# 380 v1:  скважиналары v2:  {'', 'йыһазландырылған', 'итеп йыһазландырылған юғалтылған'} 0.0
# 381 v1:  үткәргән v2:  {'', 'үткәргән өйрәнеүҙе', 'биргән', 'күрһәтте', 'үткәргән биргән үткәрелгән'} 0.0
# 382 v1:  ҡыҫҡартып, v2:  {'', 'ҡыҫҡартып'} 0.0
# 383 v1:  ҡыҫҡартыу, v2:  {''} 0.0
# 384 v1:  зыян v2:  {''} 0.0
# 385 v1:  үҙләштереү v2:  {'кәрәкмәй', 'үҙләштереү'} 1.0
# 386 v1:  зыян v2:  {'', 'һөйләй'} 0.0
# 387 v1:  көрәшмәй. v2:  {'көрәшмәй'} 0.0
# 388 v1:  уҡ v2:  {'', 'башҡарыр', 'шул эште'} 0.0
# 389 v1:  ташлаған v2:  {'', 'ташлаған'} 1.0
# 390 v1:  сәскә v2:  {'', 'теләй', 'булмай була', 'булмай'} 0.0
# 391 v1:  көрәшеп, v2:  {'', 'көрәшеп тапшыра'} 0.0
# 392 v1:  ҡәтғи v2:  {'', 'Күнекмә иҫкәрттеләр', 'КӨСТӘРЕНЕҢ'} 0.0
# 393 v1:  һәм v2:  {'еңеләйтә арттыра', 'үҙгәртеү', 'арттыра'} 0.0
# 394 v1:  командир v2:  {'барғанда', '', 'уҡырға барғанда'} 0.0
# 395 v1:  проблемаларҙы v2:  {'', 'төҙөлгән', 'буласаҡ'} 0.0
# 396 v1:   v2:  {'булып киткәс итә', 'булып'} 0.0
# 397 v1:  ҡарай. v2:  {'', 'хосусилаштырыу'} 0.0
# 398 v1:  хәүефте v2:  {'', 'мөмкинлегенә'} 0.0
# 399 v1:  итеү v2:  {'', 'еңеләйтеүсе артты', 'талаптар тырыша', 'еңеләйтеүсе', 'артты'} 0.0
# 400 v1:  күтәрә. v2:  {''} 0.0
# 401 v1:  йәки v2:  {'', 'ҡатнашырға көсләп ҡулланылыуы', 'раҫлаған', 'булыр'} 0.0
# 402 v1:  ителешендә v2:  {''} 0.0
# 403 v1:  компанияларының v2:  {'', 'арттыра', 'тарта', 'танырға', 'мәжбүр'} 0.0
# 404 v1:  яуаплылыҡ v2:  {''} 0.0
# 405 v1:  һәм v2:  {''} 0.0
# 406 v1:  йәлеп v2:  {'', 'йәлеп маҡсаттарына иткән', 'йүнәлтеп', 'бәйләп эшләй'} 0.0
# 407 v1:  туплана. v2:  {'туплана', 'йәлеп итеү'} 0.0
# 408 v1:  иҫәпләй. v2:  {''} 0.0
# 409 v1:  ярҙам v2:  {'ҡарағанда', 'күрһәтеп'} 0.0
# 410 v1:  ҡабул v2:  {'итә', 'иткән итә'} 0.0
# 411 v1:  урынды v2:  {'', 'тупланған'} 0.0
# 412 v1:  йылдарҙа v2:  {'өҫтәләсәк бирә', 'бирә', 'алдағы'} 0.0
# 413 v1:  алмаштырыусы v2:  {'бар', 'алмаштырыусы'} 1.0
# 414 v1:  киңәйергә v2:  {'', 'һалмайынса', 'мөмкинлеге булды', 'башлағас'} 0.0
# 415 v1:  һаҡлау v2:  {'', 'аңлауҙы билдәләргә', 'һаҡлау'} 1.0
# 416 v1:  ҡоралы v2:  {''} 0.0
# 417 v1:  аса. v2:  {'', 'ҡалдырып', 'яҡшырта', 'барған', 'эш', 'improving яҡшырта', 'аса ҡалдырып'} 0.0
# 418 v1:  иртәнге v2:  {''} 0.0
# 419 v1:  өлгәшә, v2:  {'', 'таратыуға', 'өлгәшә'} 0.0
# 420 v1:  туиттарҙан v2:  {'', 'оҡшамаған', 'уйнамай', 'булмауы була'} 0.0
# 421 v1:  лә v2:  {'ителмәй'} 0.0
# 422 v1:  эшселәр v2:  {''} 0.0
# 423 v1:  нисек v2:  {'', 'белмәй', 'юғалтҡан', 'зыян'} 0.0
# 424 v1:  табыш v2:  {'', 'килтерә'} 0.0
# 425 v1:  алырға v2:  {'алырға'} 1.0
# 426 v1:  мөмкинлеге v2:  {'', 'бар', 'туҡтатыу'} 0.0
# 427 v1:  ителгән v2:  {'', 'ителгән', 'булмаһа буласаҡ'} 1.0
# 428 v1:  ғына v2:  {'өйрәнеүсе', '', 'һатып түләй', 'яҡшы', 'билдәле', 'һатып алған', 'ҡулланыусы ҡалдырмай һатып алырлыҡ'} 0.0
# 429 v1:  кәметә. v2:  {'', 'кәметә'} 0.0
# 430 v1:  хәл v2:  {'ҡулланыусылар ҡалдырған ҡуллана', 'ҡулланыусылар ҡалдырған', 'ҡулланыусылар', 'бара'} 0.0
# 431 v1:  килтерә. v2:  {''} 0.0
# 432 v1:  билдәләгәндә v2:  {'кәрәкле талап итте', 'кәрәкле', 'билдәләгәндә', 'табыу'} 1.0
# 433 v1:  һәм v2:  {''} 0.0
# 434 v1:   v2:  set() nan
# 435 v1:  раҫлаусы v2:  {''} 0.0
# 436 v1:  башланды. v2:  {'башланды', 'йүнәлтелгән башланды'} 0.0
# 437 v1:  янай. v2:  {'', 'шартлата янай'} 0.0
# 438 v1:  ҡабул v2:  {''} 0.0
# 439 v1:  ҡурҡыныс v2:  set() nan
# 440 v1:  тәьмин v2:  {'', 'иткән', 'алған'} 0.0
# 441 v1:  шартлата. v2:  {'берләштергән шартлата', 'берләштергән'} 0.0
# 442 v1:  альянстарын v2:  {'танымай', 'тышҡы танымай емерә'} 0.0
# 443 v1:  илгә v2:  {'', 'эшләргә', 'әйтергә', 'ғәйепләргә'} 0.0
# 444 v1:  йәшереү v2:  {'', 'тигәнде аңлата'} 0.0
# 445 v1:  мөнәсәбәттәренә v2:  {'тәғәйенләнгән', 'дискредитациялау', 'дискредитациялау тәғәйенләнгән'} 0.0
# 446 v1:  күрәһең, v2:  {'', 'тыуҙырған'} 0.0
# 447 v1:  ҡаты v2:  {'сығарылды', 'алыу'} 0.0
# 448 v1:  итеүҙе v2:  {'', 'корпорацияһыбәлки', 'алдынғы', 'талап итә'} 0.0
# 449 v1:  айырыла. v2:  {'', 'ҡоролмаларынан торған'} 0.0
# 450 v1:  видеоны v2:  {'ҡарарға', 'бар', 'аңлатыусы', 'һайлаусыларға итәм'} 0.0
# 451 v1:  төрлө v2:  {'', 'билдәле таныһа', 'тура', 'киләсәк', 'йыйыу сығарыу'} 0.0
# 452 v1:  үтәлешен v2:  {'', 'бар'} 0.0
# 453 v1:  талап v2:  {'дөйөм алғанда', 'талап итә'} 0.0
# 454 v1:  мөрәжәғәт v2:  {'тормошҡа'} 0.0
# 455 v1:  баҙарын v2:  {'киңәйтә', 'бар'} 0.0
# 456 v1:  ҡарауҙы v2:  {'талап итеп', 'итеп'} 0.0
# 457 v1:  финанслай v2:  {'түләгәндәр', 'ҡарағанда мөмкинлегенә ҡарап', 'финанслай', 'алаәгәр', 'түләгәндәр алһа'} 1.0
# 458 v1:  йылдарҙан v2:  {''} 0.0
# 459 v1:  ярҙам v2:  {'итәләр'} 0.0
# 460 v1:  барыһы v2:  {'талап итә'} 0.0
# 461 v1:  һәм v2:  {'', 'арттырыу'} 0.0
# 462 v1:  лидерлыҡ v2:  {'Трампҡа', 'күрһәтергә'} 0.0
# 463 v1:  традицияларҙы v2:  {'арттырып', 'булып'} 0.0
# 464 v1:  йәйелдерергә v2:  {'рөхсәт', 'биреүҙе', 'талап итә'} 0.0
# 465 v1:  дискредитациялай. v2:  {'дискредитациялай', 'бер килтермәй'} 0.0
# 466 v1:  ҡайтты. v2:  {'ҡайтты'} 0.0
# 467 v1:  юл v2:  {'күрһәтергә'} 0.0
# 468 v1:  йәки v2:  {'арттырырға'} 0.0
# 469 v1:  өсөн v2:  {'арттырыуҙың булып', 'арттырыуҙың', 'булып'} 0.0
# 470 v1:  долларға v2:  {'артыуы', 'алмағанда'} 0.0
# 471 v1:  яҡларға v2:  {'ышандырырға', '', 'мөмкин'} 0.0
# 472 v1:  проекттарын v2:  {'килтергән күсереп яҙған'} 0.0
# 473 v1:  шөғөлләнә, v2:  {'шөғөлләнә бар', 'бар'} 0.0
# 474 v1:  ҡаты v2:  {''} 0.0
# 475 v1:  ҡаршы v2:  {'', 'артыуына', 'һөйләй'} 0.0
# 476 v1:  һатып v2:  {'', 'һатып булдырыу', 'һатып'} 1.0
# 477 v1:  үҙгәрҙе, v2:  {'', 'танымаҫлыҡ'} 0.0
# 478 v1:  доллары v2:  {''} 0.0
# 479 v1:  сығымдарҙы v2:  {'артыҡ дәртләндереүсе', 'дәртләндереүсе', 'килтерҙе'} 0.0
# 480 v1:  Ғәмәлдәре v2:  {'', 'ҡыуаныслы', 'уйлаған аңлатты'} 0.0
# 481 v1:  улар v2:  {'', 'башлаясаҡ', 'йөкләмәләрен', 'алған'} 0.0
# 482 v1:  дошмандан v2:  {'', 'алһа', 'ышандыра', 'һаҡланыу'} 0.0
# 483 v1:  иғлан v2:  {'үтмәне', 'иғлан иткәнсә'} 0.0
# 484 v1:  1 v2:  {'', 'эшләүен', 'файҙаланып', 'Параллель', 'Йылытыу һыуытыу'} 0.0
# 485 v1:  айырыла. v2:  {''} 0.0
# 486 v1:  килтерҙе. v2:  {'килтерҙе'} 0.0
# 487 v1:  тура v2:  {'килгән'} 0.0
# 488 v1:  институционализация v2:  {'талап итә'} 0.0
# 489 v1:  валюта v2:  {'алмашты', 'еңеләйтеү'} 0.0
# 490 v1:  сағылдырмай. v2:  {''} 0.0
# 491 v1:  сауҙаһын v2:  {'зыян килтерә боҙоп', 'зыян', 'ҡулланыусыларына'} 0.0
# 492 v1:  иҫбатлау v2:  {'', 'эшләүен', 'түләүселәр йылытыу', 'итеүенсә', 'мөмкинлек бирәсәк', 'ҡарамаҫтан', 'тыуған итәсәк тултырырға'} 0.0
# 493 v1:  килтерә. v2:  {'килтерә'} 0.0
# 494 v1:  йүнәлештә v2:  {'тора', 'һайлау алды алып'} 0.0
# 495 v1:  ҡулланыу v2:  {'', 'булдырыла', 'булдырыла итеп'} 0.0
# 496 v1:  дауам v2:  {'', 'Ҡыҫҡартылған арттырыу', 'арттырыу'} 0.0
# 497 v1:  бәхәстәр v2:  {'', 'булдыра етәкләгән билдәләй', 'ҡамасаулай булдыра', 'булдыра'} 0.0
# 498 v1:  оноторға v2:  {''} 0.0
# 499 v1:  сығыш v2:  {'', 'продукцияның'} 0.0
# 500 v1:  бүлмәһә, v2:  {'', 'башлағас', 'булмаҫ', 'реформалаштырыуға'} 0.0
# 501 v1:  иһә v2:  {'', 'эшләй', 'алмай уңында'} 0.0
# 502 v1:  кимәлдә v2:  {'ағып киткәнлектән', 'булмаған'} 0.0
# 503 v1:  тип v2:  {'', 'тәғәйенләп тарта', 'прокурор тәғәйенләп тикшереүҙән', 'тәғәйенләп', 'прокурор'} 0.0
# 504 v1:  күрергә v2:  {'менән иҫәптән', 'әйткәндә һайланған', 'күрергә'} 1.0
# 505 v1:  тигеҙһеҙлеккә v2:  {'', 'килтерҙе', 'танырға', 'тейеш килтерҙе'} 0.0
# 506 v1:  тәҡдим v2:  {''} 0.0
# 507 v1:  һөҙөмтәләр v2:  {'көтә', 'булған', 'үткәрелгән'} 0.0
# 508 v1:   v2:  {'', 'һөйләй'} 0.0
# 509 v1:  көтөлә. v2:  {'көтөлә'} 0.0
# 510 v1:  ул v2:  {'', 'эшләй', 'күрмәне', 'алмаҫ', 'теләгән'} 0.0
# 511 v1:  ярҙам v2:  {''} 0.0
# 512 v1:  дөрөҫ v2:  {'', 'аңлай', 'талап иткән', 'тейеш', 'итергә биреү', 'булмауын', 'үлтереүҙең'} 0.0
# 513 v1:  булышлыҡ v2:  {'сағыла өҫтәйәсәк', 'бирелгәнлеге'} 0.0
# 514 v1:  - v2:  {'', 'increase артыуы', 'буласаҡ', 'expanded артыуы'} 0.0
# 515 v1:  сәйәси v2:  {'', 'аңлата', 'ашырыу'} 0.0
# 516 v1:  тикшереүгә v2:  {'мохтаж', 'раҫлау', 'мохтаж талап'} 0.0
# 517 v1:  һайлаусыларҙың v2:  {'', 'яҙылмаһа яҡлаған', 'яҡлаған'} 0.0
# 518 v1:  көрәшергә v2:  {'', 'кәрәк', 'көрәшергә'} 1.0
# 519 v1:  таныу, v2:  {'танырға', 'булмаһын'} 0.0
# 520 v1:  идараһы v2:  {'', 'киңәйтеп', 'ала', 'киңәйтеп нығыта'} 0.0
# 521 v1:  яҡланған, v2:  {'', 'булыр'} 0.0
# 522 v1:  дә v2:  {'', 'белмәй', 'тыуҙырҙы'} 0.0
# 523 v1:  килтерә. v2:  {'', 'ҡалһа һаҡланһа түбәнәйһә', 'һаҡланһа килтерә', 'һаҡланһа түбәнәйһә килтерә'} 0.0
# 524 v1:  ҡаласаҡ. v2:  {''} 0.0
# 525 v1:  буйынса v2:  {'', 'ҡыйбатлана'} 0.0
# 526 v1:  дәрәжәһенә v2:  {''} 0.0
# 527 v1:  мәғлүмәттәр v2:  {'бирер'} 0.0
# 528 v1:  өлөшөн v2:  {'', 'Башланған', 'өлөшөн әйләнде әҙерләгән өлгәшелде', 'Башланған үҙгәртеп тамамлауға әҙерләгән ҡулланыуға индерелгән күҙәтелгән', 'тамамлауға әҙерләгән индерелгән күҙәтелгән', 'булмаған', 'әйләнде әҙерләгән өлгәшелде'} 0.0
# 529 v1:  туҡтатып, v2:  {'', 'promote туҡтатып', 'promoting', 'ебәреп иҫкергән', 'нығытып туҡтатып', 'иҫкергән алған менән', 'нығытып'} 0.0
# 530 v1:  доллар v2:  {'экономиялай'} 0.0
# 531 v1:  йыймауын v2:  {'', 'иҫәпкә'} 0.0
# 532 v1:  күрһәтте. v2:  {'', 'күрһәтте'} 0.0
# 533 v1:  ҡытай v2:  {'', 'эшләй'} 0.0
# 534 v1:  насарайыуын v2:  {'', 'аңлатыу', 'яҙырға', 'ине'} 0.0
# 535 v1:  реструктуризациялауға v2:  {'', 'була', 'әҙерләгәндә бирә'} 0.0
# 536 v1:  ҡаса v2:  {'', 'алды'} 0.0
# 537 v1:  биргән v2:  {'', 'менән биргән', 'биргән'} 1.0
# 538 v1:  сәскә v2:  {'', 'теләгән'} 0.0
# 539 v1:  эләгә. v2:  {''} 0.0
# 540 v1:  булып v2:  {'', 'бәйле', 'көрсөгө күрһәткән', 'булып'} 1.0
# 541 v1:  сәйәсәтен v2:  {'яңыртырға', ''} 0.0
# 542 v1:  штраф v2:  {'штраф', 'була', 'ҡаршы файҙаланыуы'} 1.0
# 543 v1:  ЭШЛӘРГӘ v2:  {'', 'Был', 'саҡырыу пауза'} 0.0
# 544 v1:  нығытырға v2:  {'', 'нығытырға', 'өйрәнергә'} 1.0
# 545 v1:  хужалығына v2:  {'', 'буласаҡ'} 0.0
# 546 v1:  үҙгәртелмәһә v2:  {'', 'артыуы'} 0.0
# 547 v1:  булып v2:  {'булып'} 1.0
# 548 v1:  ҡайтырға v2:  {'', 'теләй', 'ҡайтырға'} 1.0
# 549 v1:  иғлан v2:  {'', 'итә'} 0.0
# 550 v1:  ҡулға v2:  {''} 0.0
# 551 v1:  булып v2:  {'булып'} 1.0
# 552 v1:  ныҡ v2:  {'', 'сәйәсмәндәр', 'эшләмәһәләр биреләсәк'} 0.0
# 553 v1:  үҙгәреүенә v2:  {'', 'булып'} 0.0
# 554 v1:  ҡулланыла v2:  {'', 'булмаған', 'бар', 'ҡулланыла'} 1.0
# 555 v1:  үткәреп, v2:  {'үткәреп', 'кампанияны үткәреп'} 0.0
# 556 v1:  үтергә v2:  {'үтергә', 'үткәрелгәйне ине'} 1.0
# 557 v1:  вазифаға v2:  {'итеп һайлана'} 0.0
# 558 v1:  мөрәжәғәт v2:  {'', 'мәжбүр', 'һорап итергә'} 0.0
# 559 v1:  туплай v2:  {'', 'Артабанғы', 'башлай', 'туплай'} 1.0
# 560 v1:  үткәрергә v2:  {'араһында параллель үткәрергә'} 0.0
# 561 v1:  миссияһын v2:  {''} 0.0
# 562 v1:  вазифаға v2:  {'', 'яллай', 'етәкселегендәге яллай'} 0.0
# 563 v1:  өҫтәмә v2:  {'', 'транспарентлыҡ үтәргә алыусы', 'финанслау алыусы'} 0.0
# 564 v1:  еңел v2:  {'бирә', 'арттырыу'} 0.0
# 565 v1:  эш v2:  {'арттырыр', 'билдәләнгән', 'күләмен тип'} 0.0
# 566 v1:  тотоуҙы v2:  {'', 'арттырыуға'} 0.0
# 567 v1:   v2:  {'', 'теләгенә таянып', 'бар', 'башлаясаҡ'} 0.0
# 568 v1:   v2:  {'атаған'} 0.0
# 569 v1:  асырға v2:  {'асырға'} 1.0
# 570 v1:  нығыта. v2:  {'', 'тәғәйенләнгәндән нығыта'} 0.0
# 571 v1:  булыуын v2:  set() nan
# 572 v1:  араһында v2:  {''} 0.0
# 573 v1:   v2:  {'баҫылған күрһәтелгән', 'булып'} 0.0
# 574 v1:  урынды v2:  {'', 'кәметте белдерҙе'} 0.0
# 575 v1:  тора, v2:  {''} 0.0

# %%
(res_2_models_ba['preds_kk_new'] == 1).sum()
# Out:
# 56

# %%
(res_2_models_ba['preds_kk'] == 1).sum()
# Out:
# 250

# %%
arguments1 = ast.literal_eval(res_2_models_ba.loc[0, 'srl_ba'])['verbs'][0]['description']
args1 = set()
for key, value in arguments1.items():
    if key != 'V':
        args1.add(value)
print(args1)
# Out:
# {'донъяны', 'кемдәр'}

# %%
arguments2 = ast.literal_eval(res_2_models_ba.loc[0, 'result_srl_kk'])['verbs'][0]['description']
args2 = set()
for key, value in arguments2.items():
    if key != 'V':
        args2.add(value)
print(args2)
# Out:
# {'Шуға', 'мин уйланым', 'кемдәр улар яҡшы етешһеҙлектәрҙе күрә күренеш донъяны бик һәм'}

# %%
if len(args1.intersection(args2)) != 0:
    print('ok')

# %%
for i in range(len(res_2_models_ba)):
    try:
        verb1 = ast.literal_eval(res_2_models_ba.loc[i, 'srl_ba'])['verbs'][0]['verb']
        verb2 = set()
        for j in range(len(ast.literal_eval(res_2_models_ba.loc[i, 'result_srl_kk'])['verbs'])):
            verb2.add(ast.literal_eval(res_2_models_ba.loc[i, 'result_srl_kk'])['verbs'][j]['verb'])
        if (verb1 in verb2) & (verb1 != ""):
            res_2_models_ba.loc[i, 'preds_kk_new'] = 1
        else:
            res_2_models_ba.loc[i, 'preds_kk_new'] = 0
        
        arguments1 = ast.literal_eval(res_2_models_ba.loc[i, 'srl_ba'])['verbs'][0]['description']
        args1 = set()
        for key, value in arguments1.items():
            if key != 'V':
                args1.add(value)
        
        args2 = set()
        
        for j in range(len(ast.literal_eval(res_2_models_ba.loc[i, 'result_srl_kk'])['verbs'])):
            arguments2 = ast.literal_eval(res_2_models_ba.loc[i, 'result_srl_kk'])['verbs'][j]['description']
            for key, value in arguments2.items():
                if key != 'V':
                    args2.add(value)
        if len(args1.intersection(args2)) != 0:
            res_2_models_ba.loc[i, 'preds_kk_args'] = 1
        else:
            res_2_models_ba.loc[i, 'preds_kk_args'] = 0
    except:
        pass
    print(i, 'v1: ', verb1, 'v2: ', verb2, res_2_models_ba.loc[i, 'preds_kk_new'], 
         res_2_models_ba.loc[i, 'preds_kk_args'])
# Out:
# 0 v1:  күрә v2:  {'', 'күрә күренеш'} 0.0 1.0
# 1 v1:  торғанда v2:  {''} 0.0 0.0
# 2 v1:  билдәһеҙ v2:  {'', 'булыр'} 0.0 0.0
# 3 v1:  ҡайта v2:  {'', 'ала'} 0.0 1.0
# 4 v1:  килтерәсәк, v2:  {'', 'артабан артыуына'} 0.0 0.0
# 5 v1:  барлыҡҡа v2:  {'', 'булып'} 0.0 0.0
# 6 v1:  йәки v2:  {'', 'алынған', 'төҙөлгән алынған'} 0.0 0.0
# 7 v1:  туплана. v2:  {'күренеш', 'ҡарала туплана'} 0.0 0.0
# 8 v1:  кәмеүе v2:  {'', 'күрһәтелеүенсә'} 0.0 0.0
# 9 v1:  кәметте, v2:  {'', 'йөкләмәләрҙе', 'була', 'Артабанғы һуңғы'} 0.0 0.0
# 10 v1:  был v2:  {'', 'булып', 'килемлелеген', 'булмай'} 0.0 0.0
# 11 v1:  Болсонару v2:  {'', 'араһында таяна'} 0.0 0.0
# 12 v1:   v2:  {'', 'башланы'} 0.0 1.0
# 13 v1:  төҙөү v2:  {'юҡ', 'төҙөү'} 1.0 0.0
# 14 v1:  самаһы v2:  {'', 'инвестициялап', 'була', 'һатып алып'} 0.0 1.0
# 15 v1:  хаҡтар v2:  {''} 0.0 0.0
# 16 v1:  күберәк v2:  {'', 'алыу', 'импорттан алыу'} 0.0 0.0
# 17 v1:   v2:  {'', 'булыуы'} 0.0 0.0
# 18 v1:  юғарыраҡ v2:  {'', 'етәкселегендәге мәжбүр', 'белдереүенсә', 'инвестицияларға', 'алырға', 'мәжбүр'} 0.0 0.0
# 19 v1:  хәле v2:  {''} 0.0 0.0
# 20 v1:  финанслау v2:  {'менән булдырыуҙы', 'булдырыуҙы индерелде', 'булдырыуҙы'} 0.0 0.0
# 21 v1:  35 v2:  {'йөкләмә', 'ашырыу киңәйтә', 'ашырыу арттырырға', 'Берләшкән ашырыу', 'ашырыу арттырырға киңәйтә'} 0.0 0.0
# 22 v1:  көтөргә v2:  {'', 'талап ителә', 'көтөргә'} 1.0 0.0
# 23 v1:  буйһонорға v2:  {'сәйәсәткә', 'тырыша'} 0.0 0.0
# 24 v1:  аса. v2:  {'аса'} 0.0 0.0
# 25 v1:  позицияны v2:  {'нығытырға', 'Был'} 0.0 1.0
# 26 v1:  алмаштырырға v2:  {'', 'алмаштырырға', 'әҙерләүселәрҙең алмаштырырға'} 1.0 1.0
# 27 v1:  операциялар v2:  {'', 'башҡарырға'} 0.0 1.0
# 28 v1:  мәғлүмәт v2:  {'', 'мәжбүр', 'белдереүенсә', 'контролдә'} 0.0 1.0
# 29 v1:  сығарып, v2:  {'', 'аңлау', 'кәрәклеген', 'сығарып үҙгәртеү', 'үҙгәртеү'} 0.0 0.0
# 30 v1:  пошлиналары v2:  {''} 0.0 0.0
# 31 v1:  пошлинаны v2:  {'сығарыу итеп ҡарай', 'ҡарай', 'контролдә'} 0.0 0.0
# 32 v1:  килтерәсәк. v2:  {'Хәбәр', 'килтерәсәк'} 0.0 1.0
# 33 v1:  яҡлай v2:  {'', 'яҡлай'} 1.0 1.0
# 34 v1:  күберәк v2:  {'килтерә', 'КҮРҺӘТЕҮЕНСӘ'} 0.0 0.0
# 35 v1:  сығымдарға v2:  {'килтерер', 'булып', 'һөҙөмтәлелеген максималләштереүҙә ҡаҡшатыр килтерер', 'ҡаҡшатыр килтерер'} 0.0 0.0
# 36 v1:  кәметергә v2:  {'иҡтисады билдәһеҙлектең', '', 'тырышырға', 'кире'} 0.0 0.0
# 37 v1:  теләмәй. v2:  {'', 'булырға', 'теләмәй', 'һайлаһа етәкләмәйенсә'} 0.0 1.0
# 38 v1:  хоҡуҡтарын v2:  {'һаҡлап', '', 'теләй', 'сығырҙан БЕРЛЕГЕНЕҢ'} 0.0 0.0
# 39 v1:  тамамланмауы v2:  {''} 0.0 0.0
# 40 v1:  әҙерләнгән v2:  {'әҙерләнгән әҙерләнә', 'инеүгә әҙерләнгән әҙерләнә', 'Евросоюзға инеүгә'} 0.0 0.0
# 41 v1:  айырылып v2:  {''} 0.0 0.0
# 42 v1:  яғынан v2:  {'', 'осраша'} 0.0 0.0
# 43 v1:  тураһында v2:  {'', 'итеүгә итергә', 'килә'} 0.0 0.0
# 44 v1:  хаҡы v2:  {'алып', 'күрһәткестәренә', 'арттырыуға', 'нигеҙләнгән итә'} 0.0 0.0
# 45 v1:   v2:  {'', 'түләргә'} 0.0 1.0
# 46 v1:  баһалай v2:  {'', 'алмай', 'алмаҫ алмай', 'мохтаж', 'продукцияһын етештереү', 'яңы', 'ала баһалай'} 0.0 1.0
# 47 v1:  бизнесҡа v2:  {'', 'һатыуы'} 0.0 0.0
# 48 v1:  венчурлы v2:  {'', 'структуралана', 'ҡурҡып бирәсәк'} 0.0 0.0
# 49 v1:  һайлаған v2:  {'', 'һайлаған', 'күрә'} 1.0 1.0
# 50 v1:  вәкилдәрен v2:  {'кәрәк', '', 'үткәрергә', 'йәлеп'} 0.0 0.0
# 51 v1:  шарапты v2:  {''} 0.0 0.0
# 52 v1:  тотонорға v2:  {'аңлап', '', 'яңыртылған етештереүгә булдырыласаҡ'} 0.0 1.0
# 53 v1:   v2:  {'', 'ярашлы', 'бүлеп сығарған', 'йөрөйәсәк'} 0.0 1.0
# 54 v1:  күләмендә v2:  {'', 'һүрәтләгән үҫтерәсәк туҡтатырға', 'тартып', 'buyers тартып', 'тартып алған', 'һүрәтләгән ниәтләй', 'бирәсәк', 'һүрәтләгән'} 0.0 0.0
# 55 v1:  шөғөлләнгән v2:  {'шөғөлләнгән йыһазландырылған'} 0.0 0.0
# 56 v1:  ярҙам v2:  {'ярҙам итә'} 0.0 0.0
# 57 v1:  Урбанизация v2:  {'', 'сығарған ярашлы', 'сығарған килгән', 'булып', 'артты', 'төҙөлөшө', 'артты сығарған килгән'} 0.0 0.0
# 58 v1:  бирһә v2:  {'мөмкинлек бирһә бирмәй', 'бирһә бирмәй', 'йөрөргә', 'йөрөргә эшләргә'} 0.0 0.0
# 59 v1:  иҫәпләй. v2:  {'', 'килдем', 'быны'} 0.0 1.0
# 60 v1:  ҡаршы v2:  {'', 'теләмәй'} 0.0 1.0
# 61 v1:  эшләй v2:  {'йәшәгән йәшәй', 'алмай', 'эшләй'} 1.0 0.0
# 62 v1:  буйы v2:  {'', 'көсәйтә'} 0.0 1.0
# 63 v1:  ысулдарын v2:  {'сығарыу', 'башланы', 'эҙләй'} 0.0 0.0
# 64 v1:  һайлауына v2:  {'', 'конвертацияланған ирекле контролдә тотолған', 'манипулировкалауҙа конвертацияланған', 'ғәйепләй'} 0.0 0.0
# 65 v1:  тураһында v2:  {'алып', 'алып барыу', 'һөйләшеүҙәр яҙмышы һөйләмәгән'} 0.0 0.0
# 66 v1:  әйләнеп v2:  {'һуңыраҡ', '', 'кире'} 0.0 0.0
# 67 v1:  килтерәсәк v2:  {'нигеҙләнеп арҡаһында', '', 'тигән'} 0.0 0.0
# 68 v1:  аңлатыуы v2:  {'', 'аңлатыуы'} 1.0 0.0
# 69 v1:  етәкселек v2:  {'биргән', 'була'} 0.0 1.0
# 70 v1:  инә. v2:  {''} 0.0 0.0
# 71 v1:  ителгән v2:  {'', 'ителгән'} 1.0 0.0
# 72 v1:  акцияларҙы v2:  {'', 'юғары', 'менән тигеҙләргә'} 0.0 0.0
# 73 v1:  өсөн v2:  {'артыуы артыуын арттырасаҡ', 'менән', 'компенсациялау'} 0.0 0.0
# 74 v1:  етештереүселәрен v2:  {'', 'борсомайынса', 'мәжбүр итә', 'ашыу'} 0.0 0.0
# 75 v1:  аша v2:  {'артҡандыр', 'трендыул', 'таратылған'} 0.0 0.0
# 76 v1:  раҫлай. v2:  {'түләгән', 'раҫлай'} 0.0 0.0
# 77 v1:  үҙгәртергә, v2:  {'', 'финанслау'} 0.0 0.0
# 78 v1:  юғары v2:  {'', 'бирә', 'бирә юғары'} 0.0 1.0
# 79 v1:  дискредитациялау v2:  {'', 'advised бурысы', 'иткән', 'дискредитациялау', 'кәңәш'} 1.0 0.0
# 80 v1:  пакеттарын v2:  {'', 'башлаған', 'тарттырылмағандыр', 'тарттырылмағандыр башлаған'} 0.0 1.0
# 81 v1:  һәм v2:  {'', 'әҙерләү бирергә булдырырға', 'яҡшыртырға', 'бирергә', 'бирергә яҡшыртырға'} 0.0 1.0
# 82 v1:  симпозиумға v2:  {'барлыҡҡа', 'нығытыу'} 0.0 0.0
# 83 v1:  үҙгәртә v2:  {'', 'талап', 'башланы'} 0.0 0.0
# 84 v1:  күрһәтә. v2:  {'күрһәтә', 'илһамландыра күрһәтә'} 0.0 1.0
# 85 v1:  бара. v2:  {'', 'булдырыу'} 0.0 0.0
# 86 v1:  байлыҡтан v2:  {'', 'алмаҫ'} 0.0 0.0
# 87 v1:  процесҡа v2:  {'', 'йәлеп'} 0.0 0.0
# 88 v1:  алырға v2:  {'зыянға файҙа'} 0.0 0.0
# 89 v1:  менән v2:  {'барған бара', 'барған алға'} 0.0 0.0
# 90 v1:  хаҡта v2:  {'', 'һөйләй'} 0.0 0.0
# 91 v1:  эҙләргә v2:  {'', 'ҡатмарлаштыра'} 0.0 1.0
# 92 v1:  роль v2:  {'уйнағаны'} 0.0 0.0
# 93 v1:  өҫтөнлөк v2:  {''} 0.0 0.0
# 94 v1:  ниндәй v2:  {'', 'ышаныслылығын', 'күрһәтегеҙ', 'булмаған', 'алға киткән итә көткәнен'} 0.0 0.0
# 95 v1:  доллары) v2:  {'', 'талабы тейеш', 'исеме Яңы', 'штраф һалынасаҡ'} 0.0 1.0
# 96 v1:  ҡыҫҡартыла. v2:  {'', 'алып', 'һалым әҙер'} 0.0 0.0
# 97 v1:  килешеүен v2:  {'', 'яуап', 'башлай', 'ала башлай алаБигерәк тартҡас', 'итеп'} 0.0 0.0
# 98 v1:  сикләргә v2:  {'ҡатыландырырға', 'ниәтләй'} 0.0 0.0
# 99 v1:  был v2:  {'итергә', 'булыуынса юҡ', 'булыуынса'} 0.0 0.0
# 100 v1:  йоғонто v2:  {'', 'эшләй ойошҡан'} 0.0 0.0
# 101 v1:  йылдың v2:  {'рөхсәт', '', 'тамамлана'} 0.0 0.0
# 102 v1:  уйнай. v2:  {''} 0.0 1.0
# 103 v1:  алырға v2:  {'', 'менән хәлдәрҙә төрлө', 'менән бәйле төрлө'} 0.0 0.0
# 104 v1:  зыян v2:  {'', 'зыян'} 1.0 1.0
# 105 v1:  һөйләргә v2:  {'', 'аңлау', 'һөйләргә'} 1.0 0.0
# 106 v1:  үткәрәһегеҙ v2:  {'', 'танышаһығыҙ билдәләй', 'булырға', 'уҡыйһығыҙ һөйләшәһегеҙ', 'һөйләшәһегеҙ', 'күрә', 'күҙлегенән', 'айыра'} 0.0 1.0
# 107 v1:   v2:  {'', 'булмай'} 0.0 0.0
# 108 v1:  өйрәтәләр, v2:  {'бар', 'өйрәтәләр'} 0.0 0.0
# 109 v1:  конкурентлыҡ v2:  {'эшҡыуарлыҡты эшләгән конкурентлыҡ', 'эшҡыуарлыҡты эшләгән', 'таратыуға', 'таратыуға сәнәғәт дәртләндерә', 'нигеҙетехнологияларҙы'} 0.0 0.0
# 110 v1:  белә. v2:  {'', 'үҙен килгән', 'яҡлай', 'белә'} 0.0 1.0
# 111 v1:  тарафынан v2:  {'булды', 'тарафынан өҙөлгән', 'тырыша', 'үлтереүселәр өҙөлгән еткерергә тырыша'} 0.0 0.0
# 112 v1:  килемен v2:  {'яҡшыртырға', 'стреыла ала', 'яҡшыртырға арттырырға', 'биреү', 'Башланғыс'} 0.0 0.0
# 113 v1:  293-ө v2:  {'йыйған алды'} 0.0 0.0
# 114 v1:  буйынса v2:  {'ашырылырға'} 0.0 0.0
# 115 v1:  стратегия v2:  {'', 'табырға'} 0.0 0.0
# 116 v1:  структура v2:  {'яһағандан билдәләргә', 'яһағандан', 'тырыша', 'анализ яһағандан'} 0.0 0.0
# 117 v1:  сараларҙы v2:  {'бара', 'шулай иғтибар итә оҙатып бара'} 0.0 0.0
# 118 v1:  маҡсатын v2:  {'билдәләмәй'} 0.0 0.0
# 119 v1:  текле v2:  {'', 'һәм', 'алдағы', 'кәрәкле', 'талап итә'} 0.0 0.0
# 120 v1:  йәлеп v2:  {'', 'булып'} 0.0 1.0
# 121 v1:  бирә: v2:  {'', 'бирә', 'илгә килем', 'алыу', 'булһа'} 0.0 1.0
# 122 v1:   v2:  {'', 'иткән', 'мөмкинлек', 'булып', 'тырыша'} 0.0 0.0
# 123 v1:  ята. v2:  {''} 0.0 0.0
# 124 v1:  эшләмәй. v2:  {'', 'яһаған', 'булмаған', 'иткәндә яһаған'} 0.0 1.0
# 125 v1:  кәметәсәк. v2:  {''} 0.0 0.0
# 126 v1:  килергә, v2:  {'', 'танылыуынса', 'килергә'} 0.0 0.0
# 127 v1:  билдәләү, v2:  {'', 'кәрәкмәгән'} 0.0 1.0
# 128 v1:  раҫлай. v2:  {'раҫлай'} 0.0 0.0
# 129 v1:  иҫәпләйҙәр. v2:  {''} 0.0 0.0
# 130 v1:  етешһеҙлектәре v2:  {'ярыша', 'етешһеҙлектәре', 'бар'} 1.0 1.0
# 131 v1:  күренә. v2:  {'', 'булып күренә', 'урынлашҡан'} 0.0 0.0
# 132 v1:  сигенһә, v2:  {''} 0.0 0.0
# 133 v1:  рецессиянан v2:  {'', 'көрсөгөнән күрә һалынған килтерә', 'һалынған килтерә', 'veto көрсөгөнән вето'} 0.0 0.0
# 134 v1:  сикһеҙ v2:  {'', 'ышандыра', 'strengthening нығытыу йомшартып', 'нығытыу тергеҙеү', 'softening нығытыу', 'башланыуы', 'эшләргә'} 0.0 0.0
# 135 v1:  тора v2:  {'', 'һәләтлелеген'} 0.0 0.0
# 136 v1:  ҡырҡа v2:  {'', 'кимәлен', 'мөмкин', 'өлгәшеүҙең иткән килеүен'} 0.0 0.0
# 137 v1:  тәғәйенләнеү v2:  {'барып', 'емерелгән'} 0.0 0.0
# 138 v1:  көтә, v2:  {'', 'килгән торлаҡ', 'һайлаған килгән', 'көтә'} 0.0 0.0
# 139 v1:  башлана. v2:  {'', 'бирелә', 'башлана'} 0.0 1.0
# 140 v1:  күрһәтә v2:  {''} 0.0 0.0
# 141 v1:  ҡайта v2:  {'', 'тураһында', 'яуап'} 0.0 1.0
# 142 v1:  тирә-йүндәгеләр v2:  {'ҡыҫып төшөрә', 'күренә', 'ҡыҫып'} 0.0 0.0
# 143 v1:  контролгә v2:  {'', 'алынған'} 0.0 0.0
# 144 v1:  маташыу v2:  {'', 'шул иҫәптән'} 0.0 0.0
# 145 v1:  сәйәсәтендә v2:  {'сигнал бирә'} 0.0 1.0
# 146 v1:  асҡан v2:  {'', 'асҡан'} 1.0 0.0
# 147 v1:  демократияһын v2:  {'', 'формалаштырған', 'уйлау'} 0.0 0.0
# 148 v1:  тип v2:  {'ҡараған', '', 'тип'} 1.0 0.0
# 149 v1:  идара v2:  {'', 'алып', 'тип'} 0.0 0.0
# 150 v1:  сауҙа v2:  {''} 0.0 0.0
# 151 v1:  төрҙәрен v2:  {'', 'үҙгәртеүҙең'} 0.0 1.0
# 152 v1:  белмәй v2:  {'белмәй', 'булған'} 1.0 1.0
# 153 v1:  яулай v2:  set() nan nan
# 154 v1:  күпмелер v2:  {'булды булып'} 0.0 1.0
# 155 v1:  бик v2:  {''} 0.0 0.0
# 156 v1:  сығымдары v2:  {'', 'булып'} 0.0 0.0
# 157 v1:  булып v2:  {'ҡарамаҫтан', 'булып'} 1.0 0.0
# 158 v1:  иртәрәк v2:  {'', 'индикаторКөньяҡ'} 0.0 0.0
# 159 v1:  темптары v2:  {''} 0.0 0.0
# 160 v1:  бар: v2:  {'итә', 'әҙерләнеүен итә', 'бар', 'Үҫешеүсе'} 0.0 0.0
# 161 v1:  асырға v2:  {'', 'иҡтисадты ышандырһа', 'буласаҡ', 'асырға'} 1.0 0.0
# 162 v1:  йыйыр. v2:  {'', 'көтөлгәнсә', 'өстән'} 0.0 0.0
# 163 v1:  ҡулланырға v2:  {'', 'тыуҙыра', 'бүлеү'} 0.0 0.0
# 164 v1:  ҙә v2:  {'', 'була'} 0.0 0.0
# 165 v1:  кәметергә v2:  {'', 'ярҙам итә'} 0.0 0.0
# 166 v1:  һәм v2:  {'', 'иҫәптән инә'} 0.0 0.0
# 167 v1:  күберәк v2:  {'', 'стимуллаштыра', 'башлай', 'күберәк алыу өсөн'} 0.0 0.0
# 168 v1:  эшләй. v2:  {'эшләй'} 0.0 0.0
# 169 v1:  талап v2:  {'үҫтереү', 'инвестициялар', 'булмағанса', 'талап'} 1.0 0.0
# 170 v1:  таянып v2:  {'баҫылып таянып', 'баҫылып', 'иҫбатлап', 'таянып иҫбатлап'} 0.0 1.0
# 171 v1:  менән v2:  {'тарата итә', 'тарата'} 0.0 0.0
# 172 v1:  алды. v2:  {'алды'} 0.0 0.0
# 173 v1:  ҡабул v2:  {'итә', 'көрсөгөнән Булған араһында'} 0.0 0.0
# 174 v1:  иҫәпләйем. v2:  {'', 'иҫәпләйем'} 0.0 1.0
# 175 v1:  улар v2:  {'', 'мәжбүр', 'теләмәһә теләмәй', 'көсләп'} 0.0 1.0
# 176 v1:   v2:  {'', 'яҙмайым', 'теләмәгән кире', 'кире'} 0.0 1.0
# 177 v1:  уларҙың v2:  {'вәғәҙә бирәм', 'бирәм'} 0.0 0.0
# 178 v1:  тыйыу v2:  {'', 'буласағын', 'буласағын шөғөлләнгән', 'шөғөлләнгән көсөнә'} 0.0 0.0
# 179 v1:  донъя v2:  {'', 'килмәй', 'билдәләүенсә', 'төрлө билдәләүенсә'} 0.0 0.0
# 180 v1:  ҡаршы v2:  {'', 'килтерә'} 0.0 1.0
# 181 v1:   v2:  {'', 'булмаған', 'һаҡланыуы', 'ышанмай'} 0.0 0.0
# 182 v1:  әйтә v2:  {'', 'әйтә'} 1.0 0.0
# 183 v1:  асыҡлауға v2:  {'раҫлаған аңлай', 'аңлай', 'килтергән', 'булыуын'} 0.0 0.0
# 184 v1:  һала. v2:  {''} 0.0 0.0
# 185 v1:  контрактты v2:  {'', 'ҡаплау үтәүҙән'} 0.0 1.0
# 186 v1:  тенденцияларҙы v2:  {'', 'ашырһа', 'бер', 'туҡтатырға'} 0.0 0.0
# 187 v1:   v2:  {'', 'күскенселәрҙең'} 0.0 1.0
# 188 v1:  үҙгәртер v2:  {'ине', ''} 0.0 0.0
# 189 v1:  менән v2:  {'биреү', 'таҙалығын һаҡлау'} 0.0 0.0
# 190 v1:  юл v2:  {'ҡайтып', 'берләштереп әйләнеп'} 0.0 0.0
# 191 v1:  ярҙамында v2:  {'', 'стратегия эшкәртеүҙең', 'яҡшырта', 'таба бирә', 'бирә'} 0.0 0.0
# 192 v1:  ситләтелгән v2:  {'', 'гарантиялай', 'иткән', 'ситләтелгән гарантиялай иткән киңәйтеүҙә'} 0.0 0.0
# 193 v1:  сағылдырыу v2:  {''} 0.0 0.0
# 194 v1:  бүленешен v2:  {'билдәләй', 'бүленешен'} 1.0 0.0
# 195 v1:  тирәләй v2:  {'мөмкин', 'реформалаштырырға бөтөрөргә сикләгән', 'реформалаштырырға ҡыҫҡартырға бөтөрөргә сикләгән', 'реформалаштырырға', 'табыуҙар', 'реформалаштырырға ҡыҫҡартырға бөтөрөргә'} 0.0 0.0
# 196 v1:  реформалау v2:  {'реформалау', 'булмаҫ', 'булған'} 1.0 0.0
# 197 v1:  индустрияһын v2:  {'ҡатнашам'} 0.0 0.0
# 198 v1:  көслө v2:  {'', 'мөмкинлек бирә'} 0.0 0.0
# 199 v1:  проекттарын v2:  {'', 'Ҡулланыусылар ҡушылғанға', 'монетизацияларға'} 0.0 1.0
# 200 v1:  тип v2:  {'', 'тип тасуирлай'} 0.0 1.0
# 201 v1:  лә v2:  {''} 0.0 0.0
# 202 v1:  ҡалды. v2:  {'булып', 'килде'} 0.0 0.0
# 203 v1:  бүлеү v2:  {'', 'вәғәҙә'} 0.0 0.0
# 204 v1:  артты. v2:  {'', 'менән сағыштырғанда', 'артты', 'йәшәүсе'} 0.0 0.0
# 205 v1:  һаҡлап v2:  {'', 'һанала'} 0.0 0.0
# 206 v1:  өсөн v2:  {'әҙерләнгән', 'әҙерләнгән тәржемәләренә'} 0.0 0.0
# 207 v1:  кәметә. v2:  {'ташыуға йүнәлтелгән', 'артыуына', 'йүнәлтелгән килтерһә'} 0.0 1.0
# 208 v1:  эшләй. v2:  {'алып', 'гражданы иҫәптән', 'эшләй'} 0.0 0.0
# 209 v1:  составын v2:  {'', 'киңәйтергә'} 0.0 0.0
# 210 v1:  килеп v2:  {'', 'Барған'} 0.0 0.0
# 211 v1:  идара v2:  {'', 'идара'} 1.0 0.0
# 212 v1:  кәметеү v2:  {'', 'ауырлаштыра', 'тотороҡландырыуҙы', 'булыу', 'тотороҡландырыуҙы стабилләштереү'} 0.0 1.0
# 213 v1:  ярҙам v2:  {'', 'буласаҡ'} 0.0 1.0
# 214 v1:  план v2:  {'яҙылған', 'раҫлай'} 0.0 0.0
# 215 v1:  берләштерә. v2:  {'', 'ҡамасаулаусы'} 0.0 0.0
# 216 v1:  билдәләргә v2:  {'', 'ярҙам итер', 'булыу'} 0.0 1.0
# 217 v1:  аға v2:  {''} 0.0 0.0
# 218 v1:  килтерә. v2:  {'тарала килтерә', 'башланған', 'тарала', 'артабан'} 0.0 0.0
# 219 v1:  хаҡҡа v2:  {'', 'һатыла'} 0.0 0.0
# 220 v1:  кимәлгә v2:  {'', 'кире'} 0.0 0.0
# 221 v1:  үтте? v2:  {''} 0.0 0.0
# 222 v1:   v2:  {'яҡшырта', 'булып үткән'} 0.0 0.0
# 223 v1:  мөрәжәғәт v2:  {'', 'көрсөктән'} 0.0 0.0
# 224 v1:  хөкүмәткә v2:  {'', 'ҡарашты ҡыҫҡартып', 'ҡарашты итәләр', 'ҡыҫҡартып'} 0.0 0.0
# 225 v1:  отчет v2:  {''} 0.0 1.0
# 226 v1:  биргән v2:  {'', 'элитаға', 'биргән'} 1.0 0.0
# 227 v1:  уны v2:  {'баһалай'} 0.0 0.0
# 228 v1:  белә, v2:  {'көрсөгөн өйрәнгән', '', 'белә'} 0.0 1.0
# 229 v1:  итеү v2:  {''} 0.0 0.0
# 230 v1:  дәүере v2:  {'', 'башланғанын', 'оноторға', 'йәшәгәнен'} 0.0 0.0
# 231 v1:  көсәймәй. v2:  {''} 0.0 1.0
# 232 v1:  килтерәсәк v2:  {'', 'артмаясаҡ юҡ', 'килтерәсәк'} 1.0 0.0
# 233 v1:  элитаның v2:  {'таныла', 'тыуҙыра'} 0.0 0.0
# 234 v1:  формалаштыра. v2:  {'', 'була', 'формалаштыра'} 0.0 0.0
# 235 v1:  сауҙанан v2:  {'', 'алған', 'әйтеүенсә'} 0.0 0.0
# 236 v1:  күрә. v2:  {'күрә'} 0.0 0.0
# 237 v1:  йәшәй, v2:  {'', 'йәшәй', 'юҡ', 'уйлап'} 0.0 0.0
# 238 v1:  кәметә, v2:  {'', 'reduces increases артыуына', 'биреүсенең', 'increase increases', 'буласаҡ'} 0.0 0.0
# 239 v1:  әйтергә v2:  {'әйтергә', '–'} 1.0 0.0
# 240 v1:  француздарҙан v2:  {''} 0.0 0.0
# 241 v1:  урынды v2:  {'көрсөгөнә көйләү урынды биләй'} 0.0 1.0
# 242 v1:  уйнай v2:  {'ҡарағанда'} 0.0 1.0
# 243 v1:  алдан v2:  {'', 'кәрәкмәүен'} 0.0 1.0
# 244 v1:  барғанда, v2:  {'', 'тураһында барғанда'} 0.0 0.0
# 245 v1:  ныҡлы v2:  {'булдырыу', 'хуплаған'} 0.0 1.0
# 246 v1:  партнерлығын v2:  {'', 'яҡлап һаҡлап', 'яҡлап һаҡлап ҡала'} 0.0 1.0
# 247 v1:  арбаһын v2:  {'', 'ала'} 0.0 1.0
# 248 v1:  хәл v2:  {'булыр'} 0.0 0.0
# 249 v1:  эшләү? v2:  {''} 0.0 0.0
# 250 v1:  яңылыҡтарға v2:  {'ышанырға'} 0.0 0.0
# 251 v1:  эш v2:  {'кәрәк', 'бәйле', 'башҡарырға', ''} 0.0 0.0
# 252 v1:  һығылмалы v2:  {'', 'көрсөгө Күрһәтеүенсә', 'менән'} 0.0 0.0
# 253 v1:  ай v2:  set() 0.0 0.0
# 254 v1:  биләп, v2:  {'Әйтеүенсә', '', 'алыу', 'буласаҡ'} 0.0 0.0
# 255 v1:  булып v2:  {'еңгәндән', 'булһа булып'} 0.0 0.0
# 256 v1:  тип v2:  {'яҡлаған раҫланы', 'итә яҡлаған', 'лидеры яҡлаған', 'яҡлаған'} 0.0 0.0
# 257 v1:  эштәргә v2:  {''} 0.0 0.0
# 258 v1:  үлтергән v2:  {'үлтергән', 'бар'} 1.0 0.0
# 259 v1:  киләсәк. v2:  {''} 0.0 0.0
# 260 v1:  уйлайым, v2:  {'', 'булды', 'һалды'} 0.0 1.0
# 261 v1:  билдәләрен v2:  {'', 'күрһәтә'} 0.0 0.0
# 262 v1:  янай v2:  {'', 'башлай'} 0.0 0.0
# 263 v1:  ҡарашҡа v2:  {'', 'килтереү'} 0.0 0.0
# 264 v1:  дөрөҫлөктө v2:  {'', 'айырып', 'ярашлы яһау', 'таянғанлыҡтан'} 0.0 0.0
# 265 v1:  йыл v2:  {'', 'таралған', 'йүнәлтелгән уйланылған итә'} 0.0 0.0
# 266 v1:  эшкәртергә v2:  {'', 'өйрәттеләр'} 0.0 0.0
# 267 v1:  яуаплылыҡҡа v2:  {'', 'тыуҙырған'} 0.0 0.0
# 268 v1:  килтерер, v2:  {'', 'үтәлә көтөлмәгән килтерер', 'килтерер'} 0.0 1.0
# 269 v1:  булышлыҡ v2:  {'булышлыҡ итә'} 0.0 0.0
# 270 v1:  урындарын v2:  {'', 'ярыша', 'бүленә', 'алға'} 0.0 1.0
# 271 v1:  компанияларға v2:  {'', 'китә', 'йүнәлтелгән страховкалау менән хәсрәтләнә арта', 'итеп йүнәлтелгән сәйәсәте менән хәсрәтләнә'} 0.0 0.0
# 272 v1:  адаптив v2:  {'стреылған көрсөгөнән башланған адаптив тартырға', 'тартырға', 'стреыла'} 0.0 0.0
# 273 v1:   v2:  {'төшөүе', '', 'булған', 'белә'} 0.0 1.0
# 274 v1:  килһә, v2:  {'барлыҡҡа', 'барлыҡҡа булыр', 'борсолоу'} 0.0 0.0
# 275 v1:  ваҡытта v2:  {'', 'артыуы', 'артыуы тырыша', 'тырыша'} 0.0 1.0
# 276 v1:  ҡала, v2:  {'', 'тенденцияларға', 'финанслауға', 'нигеҙендәге', 'булып', 'арта юғарыраҡ бүленергә'} 0.0 0.0
# 277 v1:  компаниялар v2:  {'', 'артабан үҫтереү баҫтырыу', 'яңы конкурентлыҡ', 'һатып', 'үҫтереү баҫтырыу'} 0.0 1.0
# 278 v1:  мөмкинлектәр v2:  {'ҡалдырмай', 'нигеҙләнгән'} 0.0 0.0
# 279 v1:  тип v2:  {'атаным'} 0.0 0.0
# 280 v1:  артыуына v2:  {'итегеҙ', 'арттырыу'} 0.0 0.0
# 281 v1:  проценттан v2:  {'финансланған', 'артмай'} 0.0 0.0
# 282 v1:  процентҡа v2:  {''} 0.0 0.0
# 283 v1:  өлөштө v2:  {'арттырыу арттыра', 'арттырыу'} 0.0 1.0
# 284 v1:  тип v2:  {'ҡарап ҡыҫыла'} 0.0 0.0
# 285 v1:  буласағын v2:  {'таный', '', 'буласағын'} 1.0 0.0
# 286 v1:  кеше v2:  {''} 0.0 0.0
# 287 v1:  итергә v2:  {'кәрәк', 'кимәлдә һайлай', 'теләһә кәрәк', 'конкурентлыҡ'} 0.0 0.0
# 288 v1:  Японияла v2:  {'мөмкинлек биргән', 'йәшәргә', 'төҙөргә биргән'} 0.0 0.0
# 289 v1:  мөмкинлектәрен v2:  {'дискредитациялай шартлата', '', 'дискредитациялай'} 0.0 0.0
# 290 v1:  миҫалы v2:  {'атаған'} 0.0 0.0
# 291 v1:  мәнфәғәтендә v2:  {'', 'эшләүен', 'раҫлай', 'булмай'} 0.0 1.0
# 292 v1:  индерергә v2:  {''} 0.0 0.0
# 293 v1:  көйләү v2:  {'', 'итеүҙә', 'менән', 'килгән'} 0.0 0.0
# 294 v1:  булған v2:  {'', 'үҙгәреүсән', 'булып', 'булып ҡалмай'} 0.0 0.0
# 295 v1:  нығыраҡ v2:  {'раҫлай'} 0.0 1.0
# 296 v1:  юғалта. v2:  {'', 'юғалта'} 0.0 0.0
# 297 v1:  ҡала. v2:  {'', 'булып'} 0.0 0.0
# 298 v1:  сығара. v2:  {'сығара', '', 'булдырыу'} 0.0 0.0
# 299 v1:  әммә v2:  {'', 'теләй', 'ҡалырға'} 0.0 1.0
# 300 v1:  һала. v2:  {'нигеҙендә үҙгәртеп ҡиммәттәрендә', '', 'үҙгәртеп ҡороуға консерватория'} 0.0 1.0
# 301 v1:  юҡҡа v2:  {'', 'көсһөҙләнә тапшырыла'} 0.0 0.0
# 302 v1:  конфликтҡа v2:  {'йылыныунасар', 'башланған', 'башланған килтерә'} 0.0 0.0
# 303 v1:  национализациялай. v2:  {'национализациялай'} 0.0 0.0
# 304 v1:  асыҡланған v2:  {'иғтибарға иҡтисады', 'юғарыраҡ', 'ала'} 0.0 0.0
# 305 v1:  өҫтәлһә. v2:  {''} 0.0 0.0
# 306 v1:  күрһәттем. v2:  {'яһап күрһәттем', 'күрһәттем'} 0.0 1.0
# 307 v1:   v2:  {'башланым', 'эҙләп тейеш', 'тейеш', 'был эште'} 0.0 1.0
# 308 v1:  билдәләргә v2:  {'', 'билдәләргә'} 1.0 1.0
# 309 v1:  әле v2:  {'талап ителә', 'булдырырға', 'күрмәйбеҙ', 'ҡамасаулау'} 0.0 0.0
# 310 v1:  подразделениеһы v2:  {'', 'булып', 'контролдә'} 0.0 0.0
# 311 v1:  буфер v2:  {'күрәбеҙ', 'ойошторорға', 'булыуын'} 0.0 0.0
# 312 v1:  менән v2:  {'', 'кимәле эштә башлай', 'аңлай', 'башлай'} 0.0 0.0
# 313 v1:  ҡала. v2:  {'етәкләгән', 'булып'} 0.0 0.0
# 314 v1:  донъяға v2:  {'суверенитетты', 'онотмай юғалтмайынса', 'юғалтмаған юғалтмайынса'} 0.0 1.0
# 315 v1:  күрҙек. v2:  {'күрҙек'} 0.0 1.0
# 316 v1:  кәметә. v2:  {'', 'эшләй'} 0.0 0.0
# 317 v1:  экспектацияның v2:  {'килтерҙе', 'булыуҙан', 'килтерҙе булыуҙан туҡтай'} 0.0 0.0
# 318 v1:  дә v2:  {'', 'һөҙөмтәлелеген рекламалана', 'артыуға', 'артыуға компенсация', 'кире артыуға'} 0.0 0.0
# 319 v1:  табышты v2:  {'', 'айырырға', 'килтерһә тырышҡан', 'килтерһә'} 0.0 1.0
# 320 v1:  өсөн v2:  {'', 'йүнәлтелергә'} 0.0 0.0
# 321 v1:  килгән v2:  {'килгән', 'булып'} 1.0 0.0
# 322 v1:  сикләргә v2:  {'әҙерләргә', '', 'тейеш', 'кәрәк тейеш'} 0.0 0.0
# 323 v1:  пистолеттан v2:  {'ҡайтарыуға', 'эҙләгәндә ҡайтарыуға һалған', 'эҙләгәндә һалған'} 0.0 1.0
# 324 v1:  булып v2:  {'туҡтатты', 'ҡабатланыуын', 'булып'} 1.0 1.0
# 325 v1:  булараҡ v2:  {''} 0.0 0.0
# 326 v1:  үлтерелеүгә v2:  {'килтергән тигәнде', 'тигәнде аңлата'} 0.0 0.0
# 327 v1:  талап v2:  {'', 'туплап', 'талап иткән', 'туплап арала'} 0.0 0.0
# 328 v1:  торғанда, v2:  {'барыбыҙ'} 0.0 0.0
# 329 v1:  осраҡтары v2:  {''} 0.0 0.0
# 330 v1:  янай. v2:  {''} 0.0 1.0
# 331 v1:  ла, v2:  {'тураһындағы индерелгән үҙгәрештәргә бирә', '', 'бирә', 'сараһына'} 0.0 0.0
# 332 v1:  фонды v2:  {'Respond', 'хәүефһеҙлеген шөғөлләнгән яллаған', 'хәүефһеҙлеген шөғөлләнгән', 'шөғөлләнгән'} 0.0 0.0
# 333 v1:  ҡулын v2:  {'мөрәжәғәт', '', 'ойошторолған', 'алып итте'} 0.0 0.0
# 334 v1:  тураһында v2:  {'', 'яһағанлыҡтан һөйләргә'} 0.0 0.0
# 335 v1:  күләме v2:  {''} 0.0 0.0
# 336 v1:  MTVA v2:  {'килгәндән', 'килгәндән сығара'} 0.0 0.0
# 337 v1:  килтермәй. v2:  {'яраҡлаштыра', 'килтермәй'} 0.0 1.0
# 338 v1:  ҡаты v2:  {'булмаған нығыта', '', 'булмаған була', 'нығыта'} 0.0 0.0
# 339 v1:  көсөргәнешлекте v2:  {'сикләй', 'көсөргәнешлекте'} 1.0 0.0
# 340 v1:  балансты v2:  {'', 'сағыштырғанда башланы һаҡлап', 'менән сағыштырғанда', 'башланы', 'булмаһа'} 0.0 0.0
# 341 v1:  кәмеүен v2:  {'ҡарамаҫтан итә', ''} 0.0 0.0
# 342 v1:  икеләтә v2:  {'', 'артыуын', 'билдәләй'} 0.0 0.0
# 343 v1:  юҡ v2:  {'', 'Көнсығыш оҙайлы', 'осрай өҫтөнлөгөнә', 'өҫтөнлөгөнә алып', 'күрһәтә'} 0.0 0.0
# 344 v1:  көтөргә v2:  {''} 0.0 1.0
# 345 v1:  менән v2:  {'', 'эш'} 0.0 1.0
# 346 v1:  тәьмин v2:  {'', 'барАлексей'} 0.0 1.0
# 347 v1:  кампанияһын v2:  {'анализлай', 'мөмкинлек бирә', 'һайлау'} 0.0 1.0
# 348 v1:  сығарҙы, v2:  {'һатып алыуға', 'ҡараған', 'сығарҙы', 'күрһәтте ҡараған', 'күрһәтте', 'һатып алыуын ҡараған'} 0.0 0.0
# 349 v1:  тураһында v2:  {'ҡаршы алдынан', 'ителгән яһарға', 'ителгән талап иткән', ''} 0.0 0.0
# 350 v1:  үҙ v2:  {'эшләүен ярашлы', 'ҡарамаҫтан', 'күрә', 'ҡолатырға'} 0.0 0.0
# 351 v1:  талап v2:  {'', 'талап'} 1.0 0.0
# 352 v1:  эшләмәһәләр, v2:  {'', 'эшмәкәрлеген оҙатыусы'} 0.0 1.0
# 353 v1:  йыл v2:  {'башланған башланыу', 'башланған тамамлана'} 0.0 0.0
# 354 v1:  яҡшыртыусы v2:  {'', 'мөмкинлек бирҙе', 'яҡшыртыусы'} 1.0 0.0
# 355 v1:  өҫтөнлөк v2:  {'башынан булмауы', '', 'булмауы'} 0.0 1.0
# 356 v1:  дауам v2:  {'иҡтисадына ҡаршы башлаған итә', 'башлаған'} 0.0 1.0
# 357 v1:  ингән v2:  {'ситләтеп', 'иҡтисадҡа ерҙә һалынасаҡ'} 0.0 0.0
# 358 v1:  килем v2:  {'түләү сығарыуға', 'сығарыуға килтерә'} 0.0 0.0
# 359 v1:  та v2:  {'', 'таратыласаҡ', 'булмаған', 'алынған'} 0.0 1.0
# 360 v1:  борсолһа, v2:  set() nan nan
# 361 v1:  файҙаланырға v2:  {'', 'тыуҙырған'} 0.0 1.0
# 362 v1:  алыу v2:  {'барлыҡҡа', 'һорау'} 0.0 1.0
# 363 v1:  атаған v2:  {'', 'юл киләсәк', 'атаған', 'эске үтергә', 'башлана'} 1.0 0.0
# 364 v1:  һанала, v2:  {'һанала'} 0.0 0.0
# 365 v1:  һымаҡ v2:  {'', 'күренә'} 0.0 1.0
# 366 v1:  тыңлай. v2:  {'тыңлаусылары һоҡланып тыңлай', 'тыңлаусылары көрсөгө ҡарарында'} 0.0 0.0
# 367 v1:  иҫәпләй. v2:  {'', 'тип'} 0.0 0.0
# 368 v1:  туплауҙың v2:  {'күрһәтте'} 0.0 0.0
# 369 v1:  ҡулында v2:  {'башҡарма туплай', 'туплай'} 0.0 1.0
# 370 v1:  сәйәсәттең v2:  {'ҡала'} 0.0 0.0
# 371 v1:  магазиндарына v2:  {'килә', 'һатып'} 0.0 0.0
# 372 v1:  һаҡланыуын v2:  {'баһаланы'} 0.0 0.0
# 373 v1:   v2:  {'', 'бергә тикшерә'} 0.0 0.0
# 374 v1:  һүҙҙәр v2:  {'эшләне', 'уртаҡлашты'} 0.0 1.0
# 375 v1:  үҙгәрешһеҙ v2:  {''} 0.0 0.0
# 376 v1:  кеүек v2:  {'эшләй'} 0.0 0.0
# 377 v1:  МЕНӘН v2:  {''} 0.0 0.0
# 378 v1:  рәсәй v2:  {'составына ингән'} 0.0 0.0
# 379 v1:  ултыра. v2:  {''} 0.0 0.0
# 380 v1:  скважиналары v2:  {'', 'йыһазландырылған', 'итеп йыһазландырылған юғалтылған'} 0.0 0.0
# 381 v1:  үткәргән v2:  {'', 'үткәргән өйрәнеүҙе', 'биргән', 'күрһәтте', 'үткәргән биргән үткәрелгән'} 0.0 0.0
# 382 v1:  ҡыҫҡартып, v2:  {'', 'ҡыҫҡартып'} 0.0 0.0
# 383 v1:  ҡыҫҡартыу, v2:  {''} 0.0 0.0
# 384 v1:  зыян v2:  {''} 0.0 0.0
# 385 v1:  үҙләштереү v2:  {'кәрәкмәй', 'үҙләштереү'} 1.0 0.0
# 386 v1:  зыян v2:  {'', 'һөйләй'} 0.0 0.0
# 387 v1:  көрәшмәй. v2:  {'көрәшмәй'} 0.0 0.0
# 388 v1:  уҡ v2:  {'', 'башҡарыр', 'шул эште'} 0.0 0.0
# 389 v1:  ташлаған v2:  {'', 'ташлаған'} 1.0 0.0
# 390 v1:  сәскә v2:  {'', 'теләй', 'булмай була', 'булмай'} 0.0 1.0
# 391 v1:  көрәшеп, v2:  {'', 'көрәшеп тапшыра'} 0.0 0.0
# 392 v1:  ҡәтғи v2:  {'', 'Күнекмә иҫкәрттеләр', 'КӨСТӘРЕНЕҢ'} 0.0 1.0
# 393 v1:  һәм v2:  {'еңеләйтә арттыра', 'үҙгәртеү', 'арттыра'} 0.0 0.0
# 394 v1:  командир v2:  {'барғанда', '', 'уҡырға барғанда'} 0.0 0.0
# 395 v1:  проблемаларҙы v2:  {'', 'төҙөлгән', 'буласаҡ'} 0.0 1.0
# 396 v1:   v2:  {'булып киткәс итә', 'булып'} 0.0 0.0
# 397 v1:  ҡарай. v2:  {'', 'хосусилаштырыу'} 0.0 0.0
# 398 v1:  хәүефте v2:  {'', 'мөмкинлегенә'} 0.0 0.0
# 399 v1:  итеү v2:  {'', 'еңеләйтеүсе артты', 'талаптар тырыша', 'еңеләйтеүсе', 'артты'} 0.0 0.0
# 400 v1:  күтәрә. v2:  {''} 0.0 0.0
# 401 v1:  йәки v2:  {'', 'ҡатнашырға көсләп ҡулланылыуы', 'раҫлаған', 'булыр'} 0.0 1.0
# 402 v1:  ителешендә v2:  {''} 0.0 0.0
# 403 v1:  компанияларының v2:  {'', 'арттыра', 'тарта', 'танырға', 'мәжбүр'} 0.0 1.0
# 404 v1:  яуаплылыҡ v2:  {''} 0.0 0.0
# 405 v1:  һәм v2:  {''} 0.0 0.0
# 406 v1:  йәлеп v2:  {'', 'йәлеп маҡсаттарына иткән', 'йүнәлтеп', 'бәйләп эшләй'} 0.0 0.0
# 407 v1:  туплана. v2:  {'туплана', 'йәлеп итеү'} 0.0 0.0
# 408 v1:  иҫәпләй. v2:  {''} 0.0 0.0
# 409 v1:  ярҙам v2:  {'ҡарағанда', 'күрһәтеп'} 0.0 0.0
# 410 v1:  ҡабул v2:  {'итә', 'иткән итә'} 0.0 0.0
# 411 v1:  урынды v2:  {'', 'тупланған'} 0.0 1.0
# 412 v1:  йылдарҙа v2:  {'өҫтәләсәк бирә', 'бирә', 'алдағы'} 0.0 0.0
# 413 v1:  алмаштырыусы v2:  {'бар', 'алмаштырыусы'} 1.0 1.0
# 414 v1:  киңәйергә v2:  {'', 'һалмайынса', 'мөмкинлеге булды', 'башлағас'} 0.0 0.0
# 415 v1:  һаҡлау v2:  {'', 'аңлауҙы билдәләргә', 'һаҡлау'} 1.0 0.0
# 416 v1:  ҡоралы v2:  {''} 0.0 0.0
# 417 v1:  аса. v2:  {'', 'ҡалдырып', 'яҡшырта', 'барған', 'эш', 'improving яҡшырта', 'аса ҡалдырып'} 0.0 0.0
# 418 v1:  иртәнге v2:  {''} 0.0 0.0
# 419 v1:  өлгәшә, v2:  {'', 'таратыуға', 'өлгәшә'} 0.0 0.0
# 420 v1:  туиттарҙан v2:  {'', 'оҡшамаған', 'уйнамай', 'булмауы була'} 0.0 0.0
# 421 v1:  лә v2:  {'ителмәй'} 0.0 0.0
# 422 v1:  эшселәр v2:  {''} 0.0 0.0
# 423 v1:  нисек v2:  {'', 'белмәй', 'юғалтҡан', 'зыян'} 0.0 0.0
# 424 v1:  табыш v2:  {'', 'килтерә'} 0.0 1.0
# 425 v1:  алырға v2:  {'алырға'} 1.0 0.0
# 426 v1:  мөмкинлеге v2:  {'', 'бар', 'туҡтатыу'} 0.0 0.0
# 427 v1:  ителгән v2:  {'', 'ителгән', 'булмаһа буласаҡ'} 1.0 1.0
# 428 v1:  ғына v2:  {'өйрәнеүсе', '', 'һатып түләй', 'яҡшы', 'билдәле', 'һатып алған', 'ҡулланыусы ҡалдырмай һатып алырлыҡ'} 0.0 1.0
# 429 v1:  кәметә. v2:  {'', 'кәметә'} 0.0 0.0
# 430 v1:  хәл v2:  {'ҡулланыусылар ҡалдырған ҡуллана', 'ҡулланыусылар ҡалдырған', 'ҡулланыусылар', 'бара'} 0.0 0.0
# 431 v1:  килтерә. v2:  {''} 0.0 1.0
# 432 v1:  билдәләгәндә v2:  {'кәрәкле талап итте', 'кәрәкле', 'билдәләгәндә', 'табыу'} 1.0 0.0
# 433 v1:  һәм v2:  {''} 0.0 0.0
# 434 v1:   v2:  set() nan nan
# 435 v1:  раҫлаусы v2:  {''} 0.0 0.0
# 436 v1:  башланды. v2:  {'башланды', 'йүнәлтелгән башланды'} 0.0 1.0
# 437 v1:  янай. v2:  {'', 'шартлата янай'} 0.0 0.0
# 438 v1:  ҡабул v2:  {''} 0.0 1.0
# 439 v1:  ҡурҡыныс v2:  set() nan nan
# 440 v1:  тәьмин v2:  {'', 'иткән', 'алған'} 0.0 0.0
# 441 v1:  шартлата. v2:  {'берләштергән шартлата', 'берләштергән'} 0.0 1.0
# 442 v1:  альянстарын v2:  {'танымай', 'тышҡы танымай емерә'} 0.0 0.0
# 443 v1:  илгә v2:  {'', 'эшләргә', 'әйтергә', 'ғәйепләргә'} 0.0 0.0
# 444 v1:  йәшереү v2:  {'', 'тигәнде аңлата'} 0.0 0.0
# 445 v1:  мөнәсәбәттәренә v2:  {'тәғәйенләнгән', 'дискредитациялау', 'дискредитациялау тәғәйенләнгән'} 0.0 0.0
# 446 v1:  күрәһең, v2:  {'', 'тыуҙырған'} 0.0 0.0
# 447 v1:  ҡаты v2:  {'сығарылды', 'алыу'} 0.0 0.0
# 448 v1:  итеүҙе v2:  {'', 'корпорацияһыбәлки', 'алдынғы', 'талап итә'} 0.0 0.0
# 449 v1:  айырыла. v2:  {'', 'ҡоролмаларынан торған'} 0.0 0.0
# 450 v1:  видеоны v2:  {'ҡарарға', 'бар', 'аңлатыусы', 'һайлаусыларға итәм'} 0.0 0.0
# 451 v1:  төрлө v2:  {'', 'билдәле таныһа', 'тура', 'киләсәк', 'йыйыу сығарыу'} 0.0 0.0
# 452 v1:  үтәлешен v2:  {'', 'бар'} 0.0 1.0
# 453 v1:  талап v2:  {'дөйөм алғанда', 'талап итә'} 0.0 0.0
# 454 v1:  мөрәжәғәт v2:  {'тормошҡа'} 0.0 0.0
# 455 v1:  баҙарын v2:  {'киңәйтә', 'бар'} 0.0 0.0
# 456 v1:  ҡарауҙы v2:  {'талап итеп', 'итеп'} 0.0 0.0
# 457 v1:  финанслай v2:  {'түләгәндәр', 'ҡарағанда мөмкинлегенә ҡарап', 'финанслай', 'алаәгәр', 'түләгәндәр алһа'} 1.0 0.0
# 458 v1:  йылдарҙан v2:  {''} 0.0 0.0
# 459 v1:  ярҙам v2:  {'итәләр'} 0.0 0.0
# 460 v1:  барыһы v2:  {'талап итә'} 0.0 0.0
# 461 v1:  һәм v2:  {'', 'арттырыу'} 0.0 0.0
# 462 v1:  лидерлыҡ v2:  {'Трампҡа', 'күрһәтергә'} 0.0 0.0
# 463 v1:  традицияларҙы v2:  {'арттырып', 'булып'} 0.0 0.0
# 464 v1:  йәйелдерергә v2:  {'рөхсәт', 'биреүҙе', 'талап итә'} 0.0 0.0
# 465 v1:  дискредитациялай. v2:  {'дискредитациялай', 'бер килтермәй'} 0.0 0.0
# 466 v1:  ҡайтты. v2:  {'ҡайтты'} 0.0 1.0
# 467 v1:  юл v2:  {'күрһәтергә'} 0.0 0.0
# 468 v1:  йәки v2:  {'арттырырға'} 0.0 0.0
# 469 v1:  өсөн v2:  {'арттырыуҙың булып', 'арттырыуҙың', 'булып'} 0.0 1.0
# 470 v1:  долларға v2:  {'артыуы', 'алмағанда'} 0.0 0.0
# 471 v1:  яҡларға v2:  {'ышандырырға', '', 'мөмкин'} 0.0 0.0
# 472 v1:  проекттарын v2:  {'килтергән күсереп яҙған'} 0.0 0.0
# 473 v1:  шөғөлләнә, v2:  {'шөғөлләнә бар', 'бар'} 0.0 0.0
# 474 v1:  ҡаты v2:  {''} 0.0 0.0
# 475 v1:  ҡаршы v2:  {'', 'артыуына', 'һөйләй'} 0.0 0.0
# 476 v1:  һатып v2:  {'', 'һатып булдырыу', 'һатып'} 1.0 0.0
# 477 v1:  үҙгәрҙе, v2:  {'', 'танымаҫлыҡ'} 0.0 0.0
# 478 v1:  доллары v2:  {''} 0.0 0.0
# 479 v1:  сығымдарҙы v2:  {'артыҡ дәртләндереүсе', 'дәртләндереүсе', 'килтерҙе'} 0.0 1.0
# 480 v1:  Ғәмәлдәре v2:  {'', 'ҡыуаныслы', 'уйлаған аңлатты'} 0.0 0.0
# 481 v1:  улар v2:  {'', 'башлаясаҡ', 'йөкләмәләрен', 'алған'} 0.0 0.0
# 482 v1:  дошмандан v2:  {'', 'алһа', 'ышандыра', 'һаҡланыу'} 0.0 0.0
# 483 v1:  иғлан v2:  {'үтмәне', 'иғлан иткәнсә'} 0.0 0.0
# 484 v1:  1 v2:  {'', 'эшләүен', 'файҙаланып', 'Параллель', 'Йылытыу һыуытыу'} 0.0 0.0
# 485 v1:  айырыла. v2:  {''} 0.0 0.0
# 486 v1:  килтерҙе. v2:  {'килтерҙе'} 0.0 0.0
# 487 v1:  тура v2:  {'килгән'} 0.0 0.0
# 488 v1:  институционализация v2:  {'талап итә'} 0.0 0.0
# 489 v1:  валюта v2:  {'алмашты', 'еңеләйтеү'} 0.0 0.0
# 490 v1:  сағылдырмай. v2:  {''} 0.0 0.0
# 491 v1:  сауҙаһын v2:  {'зыян килтерә боҙоп', 'зыян', 'ҡулланыусыларына'} 0.0 0.0
# 492 v1:  иҫбатлау v2:  {'', 'эшләүен', 'түләүселәр йылытыу', 'итеүенсә', 'мөмкинлек бирәсәк', 'ҡарамаҫтан', 'тыуған итәсәк тултырырға'} 0.0 0.0
# 493 v1:  килтерә. v2:  {'килтерә'} 0.0 0.0
# 494 v1:  йүнәлештә v2:  {'тора', 'һайлау алды алып'} 0.0 0.0
# 495 v1:  ҡулланыу v2:  {'', 'булдырыла', 'булдырыла итеп'} 0.0 1.0
# 496 v1:  дауам v2:  {'', 'Ҡыҫҡартылған арттырыу', 'арттырыу'} 0.0 0.0
# 497 v1:  бәхәстәр v2:  {'', 'булдыра етәкләгән билдәләй', 'ҡамасаулай булдыра', 'булдыра'} 0.0 0.0
# 498 v1:  оноторға v2:  {''} 0.0 0.0
# 499 v1:  сығыш v2:  {'', 'продукцияның'} 0.0 1.0
# 500 v1:  бүлмәһә, v2:  {'', 'башлағас', 'булмаҫ', 'реформалаштырыуға'} 0.0 0.0
# 501 v1:  иһә v2:  {'', 'эшләй', 'алмай уңында'} 0.0 1.0
# 502 v1:  кимәлдә v2:  {'ағып киткәнлектән', 'булмаған'} 0.0 1.0
# 503 v1:  тип v2:  {'', 'тәғәйенләп тарта', 'прокурор тәғәйенләп тикшереүҙән', 'тәғәйенләп', 'прокурор'} 0.0 1.0
# 504 v1:  күрергә v2:  {'менән иҫәптән', 'әйткәндә һайланған', 'күрергә'} 1.0 0.0
# 505 v1:  тигеҙһеҙлеккә v2:  {'', 'килтерҙе', 'танырға', 'тейеш килтерҙе'} 0.0 0.0
# 506 v1:  тәҡдим v2:  {''} 0.0 0.0
# 507 v1:  һөҙөмтәләр v2:  {'көтә', 'булған', 'үткәрелгән'} 0.0 0.0
# 508 v1:   v2:  {'', 'һөйләй'} 0.0 0.0
# 509 v1:  көтөлә. v2:  {'көтөлә'} 0.0 0.0
# 510 v1:  ул v2:  {'', 'эшләй', 'күрмәне', 'алмаҫ', 'теләгән'} 0.0 0.0
# 511 v1:  ярҙам v2:  {''} 0.0 0.0
# 512 v1:  дөрөҫ v2:  {'', 'аңлай', 'талап иткән', 'тейеш', 'итергә биреү', 'булмауын', 'үлтереүҙең'} 0.0 1.0
# 513 v1:  булышлыҡ v2:  {'сағыла өҫтәйәсәк', 'бирелгәнлеге'} 0.0 1.0
# 514 v1:  - v2:  {'', 'increase артыуы', 'буласаҡ', 'expanded артыуы'} 0.0 1.0
# 515 v1:  сәйәси v2:  {'', 'аңлата', 'ашырыу'} 0.0 0.0
# 516 v1:  тикшереүгә v2:  {'мохтаж', 'раҫлау', 'мохтаж талап'} 0.0 0.0
# 517 v1:  һайлаусыларҙың v2:  {'', 'яҙылмаһа яҡлаған', 'яҡлаған'} 0.0 0.0
# 518 v1:  көрәшергә v2:  {'', 'кәрәк', 'көрәшергә'} 1.0 0.0
# 519 v1:  таныу, v2:  {'танырға', 'булмаһын'} 0.0 0.0
# 520 v1:  идараһы v2:  {'', 'киңәйтеп', 'ала', 'киңәйтеп нығыта'} 0.0 0.0
# 521 v1:  яҡланған, v2:  {'', 'булыр'} 0.0 0.0
# 522 v1:  дә v2:  {'', 'белмәй', 'тыуҙырҙы'} 0.0 0.0
# 523 v1:  килтерә. v2:  {'', 'ҡалһа һаҡланһа түбәнәйһә', 'һаҡланһа килтерә', 'һаҡланһа түбәнәйһә килтерә'} 0.0 1.0
# 524 v1:  ҡаласаҡ. v2:  {''} 0.0 0.0
# 525 v1:  буйынса v2:  {'', 'ҡыйбатлана'} 0.0 1.0
# 526 v1:  дәрәжәһенә v2:  {''} 0.0 1.0
# 527 v1:  мәғлүмәттәр v2:  {'бирер'} 0.0 0.0
# 528 v1:  өлөшөн v2:  {'', 'Башланған', 'өлөшөн әйләнде әҙерләгән өлгәшелде', 'Башланған үҙгәртеп тамамлауға әҙерләгән ҡулланыуға индерелгән күҙәтелгән', 'тамамлауға әҙерләгән индерелгән күҙәтелгән', 'булмаған', 'әйләнде әҙерләгән өлгәшелде'} 0.0 0.0
# 529 v1:  туҡтатып, v2:  {'', 'promote туҡтатып', 'promoting', 'ебәреп иҫкергән', 'нығытып туҡтатып', 'иҫкергән алған менән', 'нығытып'} 0.0 0.0
# 530 v1:  доллар v2:  {'экономиялай'} 0.0 0.0
# 531 v1:  йыймауын v2:  {'', 'иҫәпкә'} 0.0 0.0
# 532 v1:  күрһәтте. v2:  {'', 'күрһәтте'} 0.0 1.0
# 533 v1:  ҡытай v2:  {'', 'эшләй'} 0.0 0.0
# 534 v1:  насарайыуын v2:  {'', 'аңлатыу', 'яҙырға', 'ине'} 0.0 0.0
# 535 v1:  реструктуризациялауға v2:  {'', 'була', 'әҙерләгәндә бирә'} 0.0 0.0
# 536 v1:  ҡаса v2:  {'', 'алды'} 0.0 1.0
# 537 v1:  биргән v2:  {'', 'менән биргән', 'биргән'} 1.0 1.0
# 538 v1:  сәскә v2:  {'', 'теләгән'} 0.0 0.0
# 539 v1:  эләгә. v2:  {''} 0.0 0.0
# 540 v1:  булып v2:  {'', 'бәйле', 'көрсөгө күрһәткән', 'булып'} 1.0 0.0
# 541 v1:  сәйәсәтен v2:  {'яңыртырға', ''} 0.0 0.0
# 542 v1:  штраф v2:  {'штраф', 'була', 'ҡаршы файҙаланыуы'} 1.0 0.0
# 543 v1:  ЭШЛӘРГӘ v2:  {'', 'Был', 'саҡырыу пауза'} 0.0 0.0
# 544 v1:  нығытырға v2:  {'', 'нығытырға', 'өйрәнергә'} 1.0 0.0
# 545 v1:  хужалығына v2:  {'', 'буласаҡ'} 0.0 0.0
# 546 v1:  үҙгәртелмәһә v2:  {'', 'артыуы'} 0.0 0.0
# 547 v1:  булып v2:  {'булып'} 1.0 0.0
# 548 v1:  ҡайтырға v2:  {'', 'теләй', 'ҡайтырға'} 1.0 1.0
# 549 v1:  иғлан v2:  {'', 'итә'} 0.0 1.0
# 550 v1:  ҡулға v2:  {''} 0.0 0.0
# 551 v1:  булып v2:  {'булып'} 1.0 0.0
# 552 v1:  ныҡ v2:  {'', 'сәйәсмәндәр', 'эшләмәһәләр биреләсәк'} 0.0 1.0
# 553 v1:  үҙгәреүенә v2:  {'', 'булып'} 0.0 0.0
# 554 v1:  ҡулланыла v2:  {'', 'булмаған', 'бар', 'ҡулланыла'} 1.0 1.0
# 555 v1:  үткәреп, v2:  {'үткәреп', 'кампанияны үткәреп'} 0.0 1.0
# 556 v1:  үтергә v2:  {'үтергә', 'үткәрелгәйне ине'} 1.0 0.0
# 557 v1:  вазифаға v2:  {'итеп һайлана'} 0.0 0.0
# 558 v1:  мөрәжәғәт v2:  {'', 'мәжбүр', 'һорап итергә'} 0.0 1.0
# 559 v1:  туплай v2:  {'', 'Артабанғы', 'башлай', 'туплай'} 1.0 1.0
# 560 v1:  үткәрергә v2:  {'араһында параллель үткәрергә'} 0.0 1.0
# 561 v1:  миссияһын v2:  {''} 0.0 0.0
# 562 v1:  вазифаға v2:  {'', 'яллай', 'етәкселегендәге яллай'} 0.0 0.0
# 563 v1:  өҫтәмә v2:  {'', 'транспарентлыҡ үтәргә алыусы', 'финанслау алыусы'} 0.0 0.0
# 564 v1:  еңел v2:  {'бирә', 'арттырыу'} 0.0 0.0
# 565 v1:  эш v2:  {'арттырыр', 'билдәләнгән', 'күләмен тип'} 0.0 1.0
# 566 v1:  тотоуҙы v2:  {'', 'арттырыуға'} 0.0 0.0
# 567 v1:   v2:  {'', 'теләгенә таянып', 'бар', 'башлаясаҡ'} 0.0 0.0
# 568 v1:   v2:  {'атаған'} 0.0 0.0
# 569 v1:  асырға v2:  {'асырға'} 1.0 0.0
# 570 v1:  нығыта. v2:  {'', 'тәғәйенләнгәндән нығыта'} 0.0 1.0
# 571 v1:  булыуын v2:  set() nan nan
# 572 v1:  араһында v2:  {''} 0.0 0.0
# 573 v1:   v2:  {'баҫылған күрһәтелгән', 'булып'} 0.0 1.0
# 574 v1:  урынды v2:  {'', 'кәметте белдерҙе'} 0.0 0.0
# 575 v1:  тора, v2:  {''} 0.0 0.0

# %%
res_2_models_ba
# Out:
#      Unnamed: 0  \
# 0             0
# 1             1
# 2             2
# 3             3
# 4             4
# ..          ...
# 571         571
# 572         572
# 573         573
# 574         574
# 575         575
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             srl_ba  \
# 0                                                                                                                                                                                                    {'verbs': [{'verb': 'күрә', 'description': {'V': 'күрә', 'Arg(субъект ментального состояния)': 'кемдәр', 'Arg(эталон)': 'кемдәр', 'Arg(стимул)': 'донъяны'}, 'tags': ['O', 'V', 'O', 'Arg(субъект ментального состояния)', 'O', 'O', 'O', 'O', 'O', 'Arg(стимул)', 'O', 'O', 'V', 'O', 'O', 'O', 'O', 'O', 'O']}], 'words': ['Шуға', 'күрә', 'мин', 'кемдәр', 'иҫ', 'киткес', 'ғәҙәти', 'күренеш,', 'улар', 'донъяны', 'бик', 'яҡшы', 'күрә', 'һәм', 'етешһеҙлектәрҙе', 'һанға', 'һуҡмай', 'тип', 'уйланым.'], 'metric': 1.0}
# 1    {'verbs': [{'verb': 'торғанда', 'description': {'V': 'торғанда', 'Arg(эталон)': 'торошта.', 'Arg(цель)': 'өлөшө', 'Arg(тема)': 'проценты', 'Arg(пациенс)': 'өлөшө', 'Arg(предмет мысли)': 'мәғлүмәттәренә'}, 'tags': ['O', 'O', 'O', 'O', 'O', 'O', 'Arg(тема)', 'O', 'O', 'O', 'O', 'V', 'O', 'O', 'Arg(цель)', 'O', 'O', 'O', 'Arg(цель)', 'O', 'O', 'Arg(предмет мысли)', 'O', 'O', 'O', 'Arg(эталон)']}], 'words': ['Әммә', 'килеме', 'түбән', 'булған', 'кешеләрҙең', '90', 'проценты', 'сирек', 'быуат', 'дауамында', 'торғонлоҡта', 'торғанда', '(һәм', 'байтаҡ', 'өлөшө', 'кәмей),', 'илдең', 'күпселек', 'өлөшө,', 'һаулыҡ', 'һаҡлау', 'мәғлүмәттәренә', 'мөрәжәғәт', 'итһәң,', 'насар', 'торошта.'], 'metric': 1.0}
# 2                                                                                                                                                                                                                                                                                                                             {'verbs': [{'verb': 'билдәһеҙ', 'description': {'V': 'билдәһеҙ', 'Arg(тема)': '-'}, 'tags': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'V', 'O', 'O', 'O', 'V', 'O']}], 'words': ['Ниндәй', 'сәйәсмәндәр', 'үткәрергә', 'Трамп,', 'ниндәй', 'улар', 'уңышлы', 'булыр', 'йәки', 'ниндәй', 'эҙемтәләре', 'булыр', '-', 'былар', 'барыһы', 'ла', 'билдәһеҙ', 'ҡала.'], 'metric': 1.0}
# 3                                                                                                                                                                                                                                                                                                                                                                                                        {'verbs': [{'verb': 'ҡайта', 'description': {'V': 'ҡайта', 'Arg(конечная точка)': 'балансҡа'}, 'tags': ['O', 'O', 'O', 'O', 'O', 'O', 'Arg(конечная точка)', 'O', 'V', 'Arg(конечная точка)']}], 'words': ['Ә', 'Был', 'Ваҡытҡа', 'Американың', 'сауҙа', 'иҫәбе', 'балансҡа', 'әйләнеп', 'ҡайта', 'ала.'], 'metric': 1.0}
# 4                                                                                                                                                                                                                                                                                   {'verbs': [{'verb': 'килтерәсәк,', 'description': {'V': 'килтерәсәк,', 'Arg(результат)': 'ҡотолғоһоҙ'}, 'tags': ['O', 'O', 'O', 'O', 'O', 'V', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'Arg(результат)', 'O', 'V']}], 'words': ['Был', 'милли', 'һаҡсыллыҡты', 'артабан', 'ҡыҫҡартыуға', 'килтерәсәк,', 'был', 'иһә', 'норманан', 'күпкә', 'юғары', 'булған', 'сауҙа', 'дефицитының', 'ҡотолғоһоҙ', 'артыуына', 'килтерәсәк.'], 'metric': 1.0}
# ..                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             ...
# 571                                                                                                                                                       {'verbs': [{'verb': 'булыуын', 'description': {'V': 'булыуын', 'Arg(содержание высказывания)': 'иҡтисадының'}, 'tags': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'Arg(содержание высказывания)', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'V', 'O', 'O', 'O', 'O', 'O', 'O', 'O']}], 'words': ['Был', 'шулай', 'уҡ', '2007', 'йылдың', 'мартында', 'ҡытай', 'иҡтисадының', 'тотороҡһоҙ,', 'тигеҙләнмәгән,', 'тигеҙһеҙ', 'һәм', '[ахыр', 'сиктә]', 'тотороҡһоҙ', 'булыуын', 'билдәләгән', 'элекке', 'премьер-министр', 'Вэнь', 'Цзябаоның', 'тәнҡитләүенә', 'бәйле.'], 'metric': 1.0}
# 572                                                                                                                                                                                                                                                                                                                                                         {'verbs': [{'verb': 'араһында', 'description': {'V': 'араһында', 'Arg(тема)': 'роле'}, 'tags': ['O', 'O', 'Arg(тема)', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'Arg(тема)', 'V', 'O', 'O']}], 'words': ['Беренсенән,', 'дәүләт', 'роле', 'һәм', 'ресурстар', 'бүлеү', 'менән', 'идара', 'итеүҙә', 'баҙар', 'роле', 'араһында', 'көсөргәнешлек', 'һаҡлана.'], 'metric': 1.0}
# 573                                                                                                            {'verbs': [{'verb': '', 'description': {'Arg(место)': 'сәйәси', 'Arg(тема)': 'ҡытай', 'Arg(эталон)': 'әлеге', 'Arg(статус)': 'юғары'}, 'tags': ['O', 'O', 'O', 'Arg(статус)', 'O', 'Arg(тема)', 'O', 'O', 'O', 'Arg(место)', 'O', 'O', 'O', 'O', 'Arg(эталон)', 'O', 'O', 'O', 'O', 'Arg(статус)', 'O', 'O', 'O']}], 'words': ['Күптән', 'түгел', 'баҫылған', 'юғары', 'вазифалы', 'ҡытай', 'чиновниктарының', 'ғаризаһына', 'ярашлы,', 'сәйәси', 'отчетта', 'күрһәтелгән', 'структур', 'реформалар', 'әлеге', 'ваҡытта', 'иҡтисади', 'сәйәсмәндәр', 'өсөн', 'юғары', 'өҫтөнлөк', 'булып', 'тора.'], 'metric': 0.8}
# 574                                                                                                                                            {'verbs': [{'verb': 'урынды', 'description': {'V': 'урынды', 'Arg(агенс)': 'доклад', 'Arg(говорящий)': 'доклад', 'Arg(результат)': 'түбән'}, 'tags': ['O', 'O', 'Arg(агенс)', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'Arg(результат)', 'V', 'O', 'O', 'O']}], 'words': ['Бынан', 'тыш,', 'доклад', 'ҡулланыусылар', 'сығымдарының', 'һәм', 'хеҙмәттәренең', 'ролен', 'кәметте,', 'әлеге', 'ваҡытта', 'был', 'бурыстар', 'иҡтисадты', 'модернизациялау', 'өҫтөнлөктәре', 'араһында', 'түбән', 'урынды', 'биләй,', 'тип', 'белдерҙе.'], 'metric': 0.8}
# 575                                                                                                                                                                                                {'verbs': [{'verb': 'тора,', 'description': {'V': 'тора,', 'Arg(эталон)': 'этабында', 'Arg(тема)': 'иҡтисады'}, 'tags': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'Arg(тема)', 'O', 'O', 'O', 'O', 'O', 'O', 'Arg(эталон)', 'O', 'V', 'O', 'O', 'O', 'O']}], 'words': ['Си', 'сәйәси', 'отчетында', 'оптимистик', 'түбәнәйеүсәнлеккә', 'ҡарамаҫтан,', 'ҡытай', 'иҡтисады', 'оҙайлы', 'сроклы', 'структура', 'трансформацияһының', 'тик', 'башланғыс', 'этабында', 'ғына', 'тора,', 'тип', 'уйларға', 'нигеҙ', 'бар.'], 'metric': 1.0}
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                result_srl_kk  \
# 0                                                                                                                                                                                         {'verbs': [{'verb': '', 'description': {'ARGM-DIS': 'Шуға', 'ARG0': 'мин уйланым', 'V': '', 'ARG1': 'кемдәр улар яҡшы етешһеҙлектәрҙе күрә күренеш донъяны бик һәм'}, 'tags': ['ARGM-DIS', 'ARG1', 'ARG0', 'ARG1', 'O', 'O', 'O', 'ARG1', 'ARG1', 'ARG1', 'ARG1', 'ARG1', 'ARG1', 'ARG1', 'ARG1', 'O', 'O', 'O', 'ARG0']}, {'verb': '', 'description': {'R-ARG1': 'кемдәр', 'V': '', 'ARG2': 'улар яҡшы етешһеҙлектәрҙе кемдәр күрә күренеш донъяны бик һәм'}, 'tags': ['O', 'ARG2', 'O', 'R-ARG1', 'O', 'O', 'O', 'ARG2', 'ARG2', 'ARG2', 'ARG2', 'ARG2', 'ARG2', 'ARG2', 'ARG2', 'O', 'O', 'O', 'O']}, {'verb': 'күрә күренеш', 'description': {'ARG0': 'улар яҡшы етешһеҙлектәрҙе кемдәр', 'R-ARG0': 'кемдәр', 'V': 'күрә күренеш', 'ARG1': 'донъяны', 'ARGM-MNR': 'бик яҡшы'}, 'tags': ['O', 'V', 'O', 'ARG0', 'O', 'O', 'O', 'V', 'ARG0', 'ARG1', 'ARGM-MNR', 'ARG0', 'V', 'O', 'ARG0', 'O', 'O', 'O', 'O']}, {'verb': '', 'description': {'ARG0': 'улар яҡшы етешһеҙлектәрҙе кемдәр', 'R-ARG0': 'кемдәр', 'V': '', 'ARG1': 'донъяны'}, 'tags': ['O', 'O', 'O', 'ARG0', 'O', 'O', 'O', 'O', 'ARG0', 'ARG1', 'O', 'ARG0', 'O', 'O', 'ARG0', 'O', 'O', 'O', 'O']}], 'words': ['Шуға', 'күрә', 'мин', 'кемдәр', 'иҫ', 'киткес', 'ғәҙәти', 'күренеш,', 'улар', 'донъяны', 'бик', 'яҡшы', 'күрә', 'һәм', 'етешһеҙлектәрҙе', 'һанға', 'һуҡмай', 'тип', 'уйланым.']}
# 1    {'verbs': [{'verb': '', 'description': {'ARG1': 'проценты кешеләрҙең', 'V': '', 'ARGM-TMP': 'кешеләрҙең илдең'}, 'tags': ['O', 'O', 'O', 'O', 'ARG1', 'O', 'ARG1', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'ARGM-TMP', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']}, {'verb': '', 'description': {'ARG1': 'күпселек түбән проценты', 'V': ''}, 'tags': ['O', 'O', 'ARG1', 'O', 'O', 'O', 'ARG1', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'ARG1', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']}, {'verb': '', 'description': {'ARG1': 'күпселек түбән проценты', 'V': ''}, 'tags': ['O', 'O', 'ARG1', 'O', 'O', 'O', 'ARG1', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'ARG1', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']}, {'verb': '', 'description': {'ARG0': 'итһәң', 'V': '', 'ARG1': ''}, 'tags': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'ARG0', 'O', 'O']}, {'verb': '', 'description': {'ARGM-DIS': 'Әммә', 'ARGM-ADV': 'итһәң', 'ARG1': 'күпселек', 'V': '', 'ARG2': 'булған'}, 'tags': ['ARGM-DIS', 'O', 'O', 'ARG2', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'ARG1', 'O', 'O', 'O', 'O', 'O', 'ARGM-ADV', 'O', 'O']}], 'words': ['Әммә', 'килеме', 'түбән', 'булған', 'кешеләрҙең', '90', 'проценты', 'сирек', 'быуат', 'дауамында', 'торғонлоҡта', 'торғанда', '(һәм', 'байтаҡ', 'өлөшө', 'кәмей),', 'илдең', 'күпселек', 'өлөшө,', 'һаулыҡ', 'һаҡлау', 'мәғлүмәттәренә', 'мөрәжәғәт', 'итһәң,', 'насар', 'торошта.']}
# 2                                                                                                                                                                                                                                                                                                                                                                                                    {'verbs': [{'verb': '', 'description': {'ARG1': 'Ниндәй ниндәй эҙемтәләре', 'ARG0': 'Трамп', 'ARGM-MOD': 'булыр', 'V': ''}, 'tags': ['ARG1', 'O', 'O', 'ARG0', 'ARG1', 'O', 'O', 'ARGM-MOD', 'O', 'ARG1', 'ARG1', 'ARGM-MOD', 'ARG1', 'O', 'O', 'O', 'O', 'O']}, {'verb': 'булыр', 'description': {'ARG1': 'улар', 'ARGM-MOD': 'булыр', 'V': 'булыр', 'ARG2': 'уңышлы'}, 'tags': ['O', 'O', 'O', 'O', 'O', 'ARG1', 'ARG2', 'ARGM-MOD', 'O', 'O', 'O', 'ARGM-MOD', 'ARG1', 'O', 'O', 'ARG1', 'O', 'O']}, {'verb': 'булыр', 'description': {'ARG2': 'Ниндәй ниндәй', 'ARG1': 'эҙемтәләре', 'ARGM-MOD': 'булыр', 'V': 'булыр'}, 'tags': ['ARG2', 'O', 'O', 'O', 'ARG2', 'O', 'O', 'ARGM-MOD', 'O', 'ARG2', 'ARG1', 'ARGM-MOD', 'ARG2', 'O', 'O', 'O', 'O', 'O']}, {'verb': '', 'description': {'ARG3': '', 'ARG1': 'былар барыһы', 'V': ''}, 'tags': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'ARG3', 'ARG1', 'ARG1', 'ARG1', 'O', 'O']}], 'words': ['Ниндәй', 'сәйәсмәндәр', 'үткәрергә', 'Трамп,', 'ниндәй', 'улар', 'уңышлы', 'булыр', 'йәки', 'ниндәй', 'эҙемтәләре', 'булыр', '-', 'былар', 'барыһы', 'ла', 'билдәһеҙ', 'ҡала.']}
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               {'verbs': [{'verb': 'ала', 'description': {'ARGM-TMP': 'Был', 'ARG1': 'балансҡа', 'V': 'ала', 'ARG2': 'ала'}, 'tags': ['O', 'ARGM-TMP', 'O', 'O', 'O', 'O', 'ARG1', 'O', 'O', 'ARG1']}, {'verb': '', 'description': {'ARG1': 'балансҡа', 'V': '', 'ARG4': ''}, 'tags': ['O', 'O', 'O', 'O', 'O', 'O', 'ARG1', 'O', 'O', 'ARG1']}], 'words': ['Ә', 'Был', 'Ваҡытҡа', 'Американың', 'сауҙа', 'иҫәбе', 'балансҡа', 'әйләнеп', 'ҡайта', 'ала.']}
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               {'verbs': [{'verb': '', 'description': {'ARG0': 'Был был', 'ARGM-MOD': '', 'V': '', 'ARG2': 'артабан күпкә артыуына килтерәсәк дефицитының юғары норманан'}, 'tags': ['ARG0', 'O', 'O', 'ARG2', 'O', 'ARG2', 'ARG0', 'O', 'ARG2', 'ARG2', 'ARG2', 'O', 'O', 'ARG2', 'O', 'ARG2', 'ARG2']}, {'verb': 'артабан артыуына', 'description': {'ARG0': 'артабан күпкә артыуына', 'R-ARG0': 'килтерәсәк', 'ARGM-MOD': '', 'ARGM-ADV': 'артабан килтерәсәк', 'V': 'артабан артыуына', 'ARG1': 'дефицитының', 'ARG2': 'күпкә юғары артабан артыуына норманан'}, 'tags': ['O', 'O', 'O', 'ARG0', 'O', 'R-ARG0', 'O', 'O', 'ARG2', 'ARG0', 'ARG2', 'O', 'O', 'ARG1', 'O', 'ARG0', 'R-ARG0']}], 'words': ['Был', 'милли', 'һаҡсыллыҡты', 'артабан', 'ҡыҫҡартыуға', 'килтерәсәк,', 'был', 'иһә', 'норманан', 'күпкә', 'юғары', 'булған', 'сауҙа', 'дефицитының', 'ҡотолғоһоҙ', 'артыуына', 'килтерәсәк.']}
# ..                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       ...
# 571                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     None
# 572                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               {'verbs': [{'verb': '', 'description': {'ARGM-ADV': '', 'V': '', 'ARG1': 'көсөргәнешлек һаҡлана Беренсенән менән араһында роле дәүләт һәм ресурстар бүлеү'}, 'tags': ['ARG1', 'ARG1', 'ARG1', 'ARG1', 'ARG1', 'ARG1', 'ARG1', 'O', 'O', 'O', 'ARG1', 'ARG1', 'ARG1', 'ARG1']}, {'verb': '', 'description': {'V': '', 'ARG1': 'бүлеү'}, 'tags': ['O', 'O', 'O', 'O', 'O', 'ARG1', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']}], 'words': ['Беренсенән,', 'дәүләт', 'роле', 'һәм', 'ресурстар', 'бүлеү', 'менән', 'идара', 'итеүҙә', 'баҙар', 'роле', 'араһында', 'көсөргәнешлек', 'һаҡлана.']}
# 573                                                                                                                                                                                                    {'verbs': [{'verb': 'баҫылған күрһәтелгән', 'description': {'ARGM-TMP': 'Күптән', 'V': 'баҫылған күрһәтелгән', 'ARG1': 'отчетта'}, 'tags': ['ARGM-TMP', 'O', 'V', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'ARG1', 'V', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']}, {'verb': 'баҫылған күрһәтелгән', 'description': {'ARG1': 'вазифалы структур реформалар', 'V': 'баҫылған күрһәтелгән', 'ARGM-LOC': 'policymakers ғаризаһына отчетта'}, 'tags': ['O', 'O', 'V', 'O', 'ARG1', 'O', 'O', 'ARGM-LOC', 'O', 'O', 'ARGM-LOC', 'V', 'ARG1', 'ARG1', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']}, {'verb': 'булып', 'description': {'ARGM-ADV': 'баҫылған Күптән күрһәтелгән отчетта сәйәси ҡытай', 'ARG1': 'вазифалы структур реформалар баҫылған күрһәтелгән policymakers ғаризаһына отчетта', 'V': 'булып', 'ARGM-TMP': 'Күптән', 'ARG2': 'юғары', 'ARGM-GOL': ''}, 'tags': ['ARGM-ADV', 'O', 'ARGM-ADV', 'ARG2', 'ARG1', 'ARGM-ADV', 'O', 'ARG1', 'O', 'ARGM-ADV', 'ARGM-ADV', 'ARGM-ADV', 'ARG1', 'ARG1', 'O', 'O', 'O', 'O', 'O', 'ARG2', 'O', 'V', 'O']}], 'words': ['Күптән', 'түгел', 'баҫылған', 'юғары', 'вазифалы', 'ҡытай', 'чиновниктарының', 'ғаризаһына', 'ярашлы,', 'сәйәси', 'отчетта', 'күрһәтелгән', 'структур', 'реформалар', 'әлеге', 'ваҡытта', 'иҡтисади', 'сәйәсмәндәр', 'өсөн', 'юғары', 'өҫтөнлөк', 'булып', 'тора.']}
# 574                                                                                                                                                                                                                                                                      {'verbs': [{'verb': '', 'description': {'ARGM-DIS': 'Бынан', 'ARG0': 'өҫтөнлөктәре доклад', 'V': '', 'ARG1': 'өҫтөнлөктәре ролен һәм', 'ARGM-ADV': 'кәметте белдерҙе был бурыстар ваҡытта ролен араһында өҫтөнлөктәре'}, 'tags': ['ARGM-DIS', 'O', 'ARG0', 'O', 'O', 'ARG1', 'O', 'ARG1', 'ARGM-ADV', 'O', 'ARGM-ADV', 'ARGM-ADV', 'ARGM-ADV', 'O', 'O', 'ARG0', 'ARGM-ADV', 'O', 'O', 'O', 'O', 'ARGM-ADV']}, {'verb': 'кәметте белдерҙе', 'description': {'ARG0': 'өҫтөнлөктәре доклад', 'V': 'кәметте белдерҙе', 'ARG1': 'был бурыстар ваҡытта ролен араһында өҫтөнлөктәре'}, 'tags': ['O', 'O', 'ARG0', 'O', 'O', 'O', 'O', 'ARG1', 'V', 'O', 'ARG1', 'ARG1', 'ARG1', 'O', 'O', 'ARG0', 'ARG1', 'O', 'O', 'O', 'O', 'V']}, {'verb': '', 'description': {'ARG0': 'был бурыстар', 'ARGM-TMP': 'ваҡытта', 'V': '', 'ARG1': 'ролен араһында өҫтөнлөктәре'}, 'tags': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'ARG1', 'O', 'O', 'ARGM-TMP', 'ARG0', 'ARG0', 'O', 'O', 'ARG1', 'ARG1', 'O', 'O', 'O', 'O', 'O']}], 'words': ['Бынан', 'тыш,', 'доклад', 'ҡулланыусылар', 'сығымдарының', 'һәм', 'хеҙмәттәренең', 'ролен', 'кәметте,', 'әлеге', 'ваҡытта', 'был', 'бурыстар', 'иҡтисадты', 'модернизациялау', 'өҫтөнлөктәре', 'араһында', 'түбән', 'урынды', 'биләй,', 'тип', 'белдерҙе.']}
# 575                                                                                                                                                                                                                {'verbs': [{'verb': '', 'description': {'ARGM-ADV': 'түбәнәйеүсәнлеккә ҡарамаҫтан башланғыс этабында оптимистик отчетында сәйәси ҡытай', 'V': '', 'ARG1': 'нигеҙ тип ҡарамаҫтан башланғыс этабында ҡытай оҙайлы ғына тик сроклы структура'}, 'tags': ['O', 'ARGM-ADV', 'ARGM-ADV', 'ARGM-ADV', 'ARGM-ADV', 'ARGM-ADV', 'ARGM-ADV', 'O', 'ARG1', 'ARG1', 'ARG1', 'O', 'ARGM-ADV', 'ARGM-ADV', 'ARGM-ADV', 'ARG1', 'O', 'ARG1', 'O', 'ARG1', 'O']}, {'verb': '', 'description': {'ARGM-CAU': 'нигеҙ', 'V': '', 'ARG1': 'ҡарамаҫтан тип башланғыс этабында ҡытай оҙайлы ғына тик сроклы структура'}, 'tags': ['O', 'O', 'O', 'O', 'O', 'ARG1', 'ARG1', 'O', 'ARG1', 'ARG1', 'ARG1', 'O', 'ARG1', 'ARG1', 'ARG1', 'ARG1', 'O', 'ARG1', 'O', 'ARGM-CAU', 'O']}, {'verb': '', 'description': {'ARG1': 'башланғыс этабында ҡытай', 'V': '', 'ARGM-ADV': 'оҙайлы ғына', 'ARG2': 'башланғыс этабында тик оҙайлы сроклы структура'}, 'tags': ['O', 'O', 'O', 'O', 'O', 'O', 'ARG1', 'O', 'ARGM-ADV', 'ARG2', 'ARG2', 'O', 'ARG2', 'ARG1', 'ARG1', 'ARGM-ADV', 'O', 'O', 'O', 'O', 'O']}], 'words': ['Си', 'сәйәси', 'отчетында', 'оптимистик', 'түбәнәйеүсәнлеккә', 'ҡарамаҫтан,', 'ҡытай', 'иҡтисады', 'оҙайлы', 'сроклы', 'структура', 'трансформацияһының', 'тик', 'башланғыс', 'этабында', 'ғына', 'тора,', 'тип', 'уйларға', 'нигеҙ', 'бар.']}
#
#      preds_kk  \
# 0         0.0
# 1         0.0
# 2         1.0
# 3         1.0
# 4         0.0
# ..        ...
# 571       NaN
# 572       NaN
# 573       NaN
# 574       NaN
# 575       NaN
#
#                                                                                                                                                                                                     sentence  \
# 0                                                                                    Шуға күрә мин кемдәр иҫ киткес ғәҙәти күренеш, улар донъяны бик яҡшы күрә һәм етешһеҙлектәрҙе һанға һуҡмай тип уйланым.
# 1    Әммә килеме түбән булған кешеләрҙең 90 проценты сирек быуат дауамында торғонлоҡта торғанда (һәм байтаҡ өлөшө кәмей), илдең күпселек өлөшө, һаулыҡ һаҡлау мәғлүмәттәренә мөрәжәғәт итһәң, насар торошта.
# 2                                                                                 Ниндәй сәйәсмәндәр үткәрергә Трамп, ниндәй улар уңышлы булыр йәки ниндәй эҙемтәләре булыр - былар барыһы ла билдәһеҙ ҡала.
# 3                                                                                                                                           Ә Был Ваҡытҡа Американың сауҙа иҫәбе балансҡа әйләнеп ҡайта ала.
# 4                                                                Был милли һаҡсыллыҡты артабан ҡыҫҡартыуға килтерәсәк, был иһә норманан күпкә юғары булған сауҙа дефицитының ҡотолғоһоҙ артыуына килтерәсәк.
# ..                                                                                                                                                                                                       ...
# 571         Был шулай уҡ 2007 йылдың мартында ҡытай иҡтисадының тотороҡһоҙ, тигеҙләнмәгән, тигеҙһеҙ һәм [ахыр сиктә] тотороҡһоҙ булыуын билдәләгән элекке премьер-министр Вэнь Цзябаоның тәнҡитләүенә бәйле.
# 572                                                                                                Беренсенән, дәүләт роле һәм ресурстар бүлеү менән идара итеүҙә баҙар роле араһында көсөргәнешлек һаҡлана.
# 573          Күптән түгел баҫылған юғары вазифалы ҡытай чиновниктарының ғаризаһына ярашлы, сәйәси отчетта күрһәтелгән структур реформалар әлеге ваҡытта иҡтисади сәйәсмәндәр өсөн юғары өҫтөнлөк булып тора.
# 574               Бынан тыш, доклад ҡулланыусылар сығымдарының һәм хеҙмәттәренең ролен кәметте, әлеге ваҡытта был бурыстар иҡтисадты модернизациялау өҫтөнлөктәре араһында түбән урынды биләй, тип белдерҙе.
# 575                          Си сәйәси отчетында оптимистик түбәнәйеүсәнлеккә ҡарамаҫтан, ҡытай иҡтисады оҙайлы сроклы структура трансформацияһының тик башланғыс этабында ғына тора, тип уйларға нигеҙ бар.
#
#      sent_len  preds_kk_new  preds_kk_args
# 0          19           0.0            1.0
# 1          26           0.0            0.0
# 2          18           0.0            0.0
# 3          10           0.0            1.0
# 4          17           0.0            0.0
# ..        ...           ...            ...
# 571        23           NaN            NaN
# 572        14           0.0            0.0
# 573        23           0.0            1.0
# 574        22           0.0            0.0
# 575        21           0.0            0.0
#
# [576 rows x 8 columns]

# %%
(res_2_models_ba['preds_kk_args'] == 1).sum()
# Out:
# 140
