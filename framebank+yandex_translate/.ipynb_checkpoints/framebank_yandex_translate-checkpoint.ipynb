# %%
import sys
sys.path.append("../")

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import requests
import json
import time

from pprint import pprint as print_
from collections import OrderedDict
import numpy as np
from tqdm import tqdm_notebook as tqdm

from isanlp_srl_framebank.pipeline_default import PipelineDefault

# %%
IAM_TOKEN = 't1.9euelZqaz5DGjI6Py5bLnoqTlo_Oju3rnpWaj46Nkc6ejZaLyZvOmZqWj53l8_dIF2Zk-e9eDic9_t3z9whGY2T5714OJz3-.1UJE5innTD10cDR2-7YbCzvwem5VKOvoIQCksQwLbJAA7oAdm4OpX9lgQyC6cosbkLvAMqxKaFT1SfQlDXTlBg'
folder_id = 'b1gs2kplab3ve997i80t'

# %%
language_code_dict =  {
'татарский': 'tt',
'казахский' : 'kk',
'башкирский':'ba',
'турецкий' : 'tr'
}

# %%
# docker run --rm -p 3333:3333 inemo/isanlp
# docker run --rm --shm-size=1024m -ti -p 3334:9999 inemo/syntaxnet_rus server 0.0.0.0 9999
# docker run --rm -p 3335:3333 inemo/isanlp_srl_framebank

# %%
ppl = PipelineDefault(address_morph=('localhost', 3333),
                      address_syntax=('localhost', 3334),
                      address_srl=('localhost', 3335))

# %%
def print_roles(lemma, role_annot, targetLanguage=None):
    for sent_num, ann_sent in enumerate(role_annot):
        for event in ann_sent:
            lemma_pred = lemma[sent_num][event.pred[0]]
            if targetLanguage is not None:
                trg_lang = language_code_dict[targetLanguage]
                src_lang = 'ru'
                print('=====Pred: {}'.format(get_translations(lemma_pred, src_lang, trg_lang)[0]))
            else:
                print('=====Pred: {}'.format(lemma_pred))
            for arg in event.args:
                lemma_arg  = lemma[sent_num][arg.begin]
                if targetLanguage is not None:
                    print('Arg({}): {}'.format(arg.tag, get_translations(lemma_arg, src_lang, trg_lang)[0]))
                else:
                    print('Arg({}): {}'.format(arg.tag, lemma_arg))

# %%
def get_translations(texts, source_language='tt', target_language='ru'):

    body = {
        "targetLanguageCode": target_language,
        "texts": texts,
        "folderId": folder_id,
        "sourceLanguageCode":  source_language
    }

    headers = {
        "Content-Type": "application/json",
        "Authorization": "Bearer {0}".format(IAM_TOKEN)
    }
    url = 'https://translate.api.cloud.yandex.net/translate/v2/translate'
    response = requests.post(url,
        json = body,
        headers = headers
    )
    if response.status_code != 200:
        print('Ожидаю 0.5 секунды...')  
        time.sleep(0.5)
        response = requests.post(url,
        json = body,
        headers = headers
        )
    d = json.loads(response.text)
    translations = d['translations']
    return [t['text'] for t in translations]
    
# print(response.text)

# %%
def get_srl_turkic(texts, selected_language):
    # texts = ["Без дачага киттек.", "Балалар өйдән кача һәм урманда югалып кала.","Әни рамны юды. Әти машинаны йөртте."]
    src_code = language_code_dict[selected_language]
    translations = get_translations(texts, source_language=src_code, )
    # print(translations)
    for i, translation in enumerate(translations):
        print(f'исходный  текст на {selected_language[:-2]}ом')
        print()
        print(texts[i])
        rus_text = translation
        print('переведенный текст на русском')
        print()
        print(rus_text)
        res = ppl(rus_text)
        print(f'разметка семантических ролей на русском')
        print_roles(res['lemma'], res['srl'])
        print()
        print(f'разметка семантических ролей на {selected_language[:-2]}ом')
        print_roles(res['lemma'], res['srl'], selected_language)

# %%
with open('text_tt.txt', encoding='utf-8') as f:
    texts_tt = f.readlines()
selected_language = 'татарский'
get_srl_turkic(texts_tt, selected_language)
# Out:
# исходный  текст на татарском
#
# Без дачага киттек.
#
# переведенный текст на русском
#
# Мы поехали на дачу.
#
# разметка семантических ролей на русском
# =====Pred: поехать
# Arg(субъект перемещения): мы
# Arg(конечная точка): дача
#
# разметка семантических ролей на татарском
# =====Pred: бару
# Arg(субъект перемещения): без
# Arg(конечная точка): дача
# исходный  текст на татарском
#
# Балалар өйдән кача һәм урманда югалып кала.
#
# переведенный текст на русском
#
# Дети убегают из дома и теряются в лесу.
#
# разметка семантических ролей на русском
# =====Pred: убегать
# Arg(субъект перемещения): ребенок
# Arg(начальная точка): дом
# =====Pred: теряться
# Arg(место): лес
#
# разметка семантических ролей на татарском
# =====Pred: качу
# Arg(субъект перемещения): балалар
# Arg(начальная точка): йорт
# =====Pred: югалту
# Arg(место): урман
# исходный  текст на татарском
#
# Әни рамны юды. Әти машинаны йөртте.
# переведенный текст на русском
#
# Мама вымыла раму. Отец водил машину.
# ...

# %%
with open('text_bb.txt', encoding='utf-8') as f:
    texts_bb = f.readlines()
selected_language = 'башкирский'
get_srl_turkic(texts_bb, selected_language)
# Out:
# исходный  текст на башкирском
#
# Беҙ дачаға барҙыҡ.
#
# переведенный текст на русском
#
# Мы поехали на дачу.
#
# разметка семантических ролей на русском
# =====Pred: поехать
# Arg(субъект перемещения): мы
# Arg(конечная точка): дача
#
# разметка семантических ролей на башкирском
# =====Pred: барыу
# Arg(субъект перемещения): беҙ
# Arg(конечная точка): дача
# исходный  текст на башкирском
#
# Балалар өйҙән ҡасып киткән һәм урманда аҙашҡан.
#
# переведенный текст на русском
#
# Дети убежали из дома и заблудились в лесу.
#
# разметка семантических ролей на русском
# =====Pred: убегать
# Arg(субъект перемещения): ребенок
# Arg(начальная точка): дом
# =====Pred: заблудиться
# Arg(субъект перемещения): ребенок
# Arg(место): лес
#
# разметка семантических ролей на башкирском
# =====Pred: йүгереү
# Arg(субъект перемещения): бала
# Arg(начальная точка): өй
# =====Pred: аҙашыу
# Arg(субъект перемещения): бала
# Arg(место): урман
# исходный  текст на башкирском
#
# ...

# %%
with open('text_kk.txt', encoding='utf-8') as f:
    texts_kk = f.readlines()
print(texts_kk)
selected_language = 'казахский'
get_srl_turkic(texts_kk, selected_language)
# Out:
# ['Біз елге бардық.\n', 'Балалар үйден қашып, орманда адасып кетті.\n', 'Анам жақтауды жуды. Әкем көлік жүргізді.']
# исходный  текст на казахском
#
# Біз елге бардық.
#
# переведенный текст на русском
#
# Мы поехали на дачу.
#
# разметка семантических ролей на русском
# =====Pred: поехать
# Arg(субъект перемещения): мы
# Arg(конечная точка): дача
#
# разметка семантических ролей на казахском
# =====Pred: бару
# Arg(субъект перемещения): біз
# Arg(конечная точка): саяжай
# исходный  текст на казахском
#
# Балалар үйден қашып, орманда адасып кетті.
#
# переведенный текст на русском
#
# Дети сбежали из дома и заблудились в лесу.
#
# разметка семантических ролей на русском
# =====Pred: сбегать
# Arg(субъект перемещения): ребенок
# Arg(начальная точка): дом
# =====Pred: заблудиться
# Arg(субъект перемещения): ребенок
# Arg(место): лес
#
# разметка семантических ролей на казахском
# =====Pred: қашу
# Arg(субъект перемещения): бала
# Arg(начальная точка): үй
# =====Pred: адасып кету
# ...

# %%
with open('text_tr.txt', encoding='utf-8') as f:
    text_tr = f.readlines()
selected_language = 'турецкий'
get_srl_turkic(text_tr, selected_language)
# Out:
# исходный  текст на турецком
#
# Kır evine gittik.
#
# переведенный текст на русском
#
# Мы поехали в загородный дом.
#
# разметка семантических ролей на русском
# =====Pred: поехать
# Arg(субъект перемещения): мы
# Arg(конечная точка): дом
#
# разметка семантических ролей на турецком
# =====Pred: gitmek
# Arg(субъект перемещения): biz
# Arg(конечная точка): ev
# исходный  текст на турецком
#
# Çocuklar evden kaçtılar ve ormanda kayboldular.
#
# переведенный текст на русском
#
# Дети сбежали из дома и заблудились в лесу.
#
# разметка семантических ролей на русском
# =====Pred: сбегать
# Arg(субъект перемещения): ребенок
# Arg(начальная точка): дом
# =====Pred: заблудиться
# Arg(субъект перемещения): ребенок
# Arg(место): лес
#
# разметка семантических ролей на турецком
# =====Pred: kaçalım
# Arg(субъект перемещения): çocuk
# Arg(начальная точка): ev
# =====Pred: kaybolmak
# Arg(субъект перемещения): çocuk
# Arg(место): Orman
# исходный  текст на турецком
#
# ...

# %% [markdown]
# __Предложение: Для языков с кириллицей обучаться на русском. А для латиницы на английском.__

# %% [markdown]
# Актуальные вопросы:
# - Добавить разные языки +
# - Модель запоминала сама язык +- (есть параметр detectedLanguage)
# - Лемматизатор для тюрского языка. (apertium)
# - Получить список возможных переводов??? (Вариант: парсить страницу с переводом)
# - Подумать как валидироваться??? (Смотреть на есть ли такое слово в исходном предложении)
# - Слова и индекс предложения (они сохраняются)

# %%
# git clone https://github.com/apertium/apertium-tat.git
# cd apertium-tat
# ./autogen.sh
# make
